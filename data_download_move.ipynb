# %%
###Code to monitor the downloading of files and put in the "initial" folder for a specific week###
import os
import time
import shutil
import datetime
from watchdog.observers import Observer
from watchdog.events import FileSystemEventHandler

# --- Configuration ---
DOWNLOADS_FOLDER = os.path.expanduser("~/Downloads")
WORKING_DIRECTORY = os.path.expanduser("~/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial")
FILE_EXTENSION = ".pdf"

# Create the main working directory if it doesn't exist
if not os.path.exists(WORKING_DIRECTORY):
    os.makedirs(WORKING_DIRECTORY)
    print(f"Created working directory: {WORKING_DIRECTORY}")

class PDFHandler(FileSystemEventHandler):
    def on_created(self, event):
        # Only consider files (not directories) that end with .pdf
        if not event.is_directory and event.src_path.lower().endswith(FILE_EXTENSION):
            print(f"Detected new file: {event.src_path}")
            self.move_file(event.src_path)

    def on_moved(self, event):
        # This event fires when a file is renamed or moved.
        if not event.is_directory and event.dest_path.lower().endswith(FILE_EXTENSION):
            print(f"Detected moved/renamed file: {event.dest_path}")
            self.move_file(event.dest_path)

    def move_file(self, src_path):
        # Determine the current week’s Monday
        today = datetime.date.today()
        # weekday() returns 0 for Monday, so subtract the current weekday to get Monday's date.
        monday = today - datetime.timedelta(days=today.weekday())
        week_folder_name = monday.strftime("%Y-%m-%d")
        week_folder_path = os.path.join(WORKING_DIRECTORY, week_folder_name)

        # Create the subfolder if it doesn't exist yet
        if not os.path.exists(week_folder_path):
            os.makedirs(week_folder_path)
            print(f"Created subfolder for week starting {week_folder_name}")

        # Set the destination path inside the weekly subfolder
        filename = os.path.basename(src_path)
        destination = os.path.join(week_folder_path, filename)

        # Avoid overwriting files by appending a counter if needed
        base, ext = os.path.splitext(filename)
        counter = 1
        while os.path.exists(destination):
            destination = os.path.join(week_folder_path, f"{base}_{counter}{ext}")
            counter += 1

        # Wait until the file is ready (not locked by another process)
        while not self.is_file_ready(src_path):
            time.sleep(1)
        
        try:
            shutil.move(src_path, destination)
            print(f"Moved '{filename}' to '{destination}'")
        except Exception as e:
            print(f"Error moving file '{filename}': {e}")

    def is_file_ready(self, file_path):
        """
        Check if a file is ready by attempting to open it.
        If it’s still being written (or locked), an IOError may occur.
        """
        try:
            with open(file_path, 'rb'):
                return True
        except IOError:
            return False

def main():
    event_handler = PDFHandler()
    observer = Observer()
    observer.schedule(event_handler, path=DOWNLOADS_FOLDER, recursive=False)
    observer.start()
    print(f"Monitoring '{DOWNLOADS_FOLDER}' for new PDF files...")
    
    try:
        while True:
            time.sleep(1)
    except KeyboardInterrupt:
        observer.stop()
        print("Stopping the PDF mover.")
    observer.join()

#if __name__ == "__main__":
#    main()

# %%
main()
# Out:
# Monitoring 'C:\Users\lawre/Downloads' for new PDF files...
# Detected moved/renamed file: C:\Users\lawre/Downloads\531e97c2-5b90-83e0-4927-2901cd970b99.pdf
# Created subfolder for week starting 2025-03-03
# Moved '531e97c2-5b90-83e0-4927-2901cd970b99.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\531e97c2-5b90-83e0-4927-2901cd970b99.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\47f80092-3211-cf23-17ba-8aa6c518caef.pdf
# Moved '47f80092-3211-cf23-17ba-8aa6c518caef.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\47f80092-3211-cf23-17ba-8aa6c518caef.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\2496e036-66a6-15c0-510e-9c4729590643.pdf
# Moved '2496e036-66a6-15c0-510e-9c4729590643.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\2496e036-66a6-15c0-510e-9c4729590643.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\dfe429f3-2520-ce52-9cab-764e99cab641.pdf
# Moved 'dfe429f3-2520-ce52-9cab-764e99cab641.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\dfe429f3-2520-ce52-9cab-764e99cab641.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\ff1d13ff-ac4d-88f5-fa36-249a78f373f2.pdf
# Moved 'ff1d13ff-ac4d-88f5-fa36-249a78f373f2.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\ff1d13ff-ac4d-88f5-fa36-249a78f373f2.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\b985b2a7-bc63-7071-8a54-0c0123c4f1a1.pdf
# Moved 'b985b2a7-bc63-7071-8a54-0c0123c4f1a1.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\b985b2a7-bc63-7071-8a54-0c0123c4f1a1.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\f9c24780-b76f-0082-ab7d-90b650b26bed.pdf
# Moved 'f9c24780-b76f-0082-ab7d-90b650b26bed.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\f9c24780-b76f-0082-ab7d-90b650b26bed.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\3e5200d0-c5de-fb87-73f8-9c513d137943.pdf
# Moved '3e5200d0-c5de-fb87-73f8-9c513d137943.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\3e5200d0-c5de-fb87-73f8-9c513d137943.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\68dd0cb4-4336-a5c1-0d3d-00f5eed2aa56.pdf
# Moved '68dd0cb4-4336-a5c1-0d3d-00f5eed2aa56.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\68dd0cb4-4336-a5c1-0d3d-00f5eed2aa56.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\b59592ad-b696-eafc-96aa-5465c8645b3b.pdf
# Moved 'b59592ad-b696-eafc-96aa-5465c8645b3b.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\b59592ad-b696-eafc-96aa-5465c8645b3b.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\8c308d30-c118-5681-fdef-1fc098969beb.pdf
# Moved '8c308d30-c118-5681-fdef-1fc098969beb.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\8c308d30-c118-5681-fdef-1fc098969beb.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\47336af4-4ba9-3b15-623c-ed6d5eb76265.pdf
# Moved '47336af4-4ba9-3b15-623c-ed6d5eb76265.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\47336af4-4ba9-3b15-623c-ed6d5eb76265.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\30bb0f08-cb5d-2f22-749d-488075f03ee8.pdf
# Moved '30bb0f08-cb5d-2f22-749d-488075f03ee8.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\30bb0f08-cb5d-2f22-749d-488075f03ee8.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\8e9d5457-23f1-fb78-e5dc-6476573f2f29.pdf
# Moved '8e9d5457-23f1-fb78-e5dc-6476573f2f29.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\8e9d5457-23f1-fb78-e5dc-6476573f2f29.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\dbe18072-9c64-1397-ad9d-5c0ea2609285.pdf
# Moved 'dbe18072-9c64-1397-ad9d-5c0ea2609285.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\dbe18072-9c64-1397-ad9d-5c0ea2609285.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\98abd2ec-51fa-feba-3f1f-fc2d1dfd80ce.pdf
# Moved '98abd2ec-51fa-feba-3f1f-fc2d1dfd80ce.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\98abd2ec-51fa-feba-3f1f-fc2d1dfd80ce.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\7d3178a9-4159-6207-eeeb-b9b31ccd4693.pdf
# Moved '7d3178a9-4159-6207-eeeb-b9b31ccd4693.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\7d3178a9-4159-6207-eeeb-b9b31ccd4693.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\097072c1-6a8f-1d8d-2de7-426f534be14a.pdf
# Moved '097072c1-6a8f-1d8d-2de7-426f534be14a.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\097072c1-6a8f-1d8d-2de7-426f534be14a.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\7f3abd58-6eea-9bee-557b-e57b3d5480e0.pdf
# Moved '7f3abd58-6eea-9bee-557b-e57b3d5480e0.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\7f3abd58-6eea-9bee-557b-e57b3d5480e0.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\e0fe3bd8-da3f-bea2-136b-d4c30254a961.pdf
# Moved 'e0fe3bd8-da3f-bea2-136b-d4c30254a961.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\e0fe3bd8-da3f-bea2-136b-d4c30254a961.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\19531937-23ca-9480-8906-db7bc535c922.pdf
# Moved '19531937-23ca-9480-8906-db7bc535c922.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\19531937-23ca-9480-8906-db7bc535c922.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\d5a60d5a-c5e5-2178-7e9f-b92219f4c03f.pdf
# Moved 'd5a60d5a-c5e5-2178-7e9f-b92219f4c03f.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\d5a60d5a-c5e5-2178-7e9f-b92219f4c03f.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\fdf24dcd-58e6-52bf-e14f-b7e289046de9.pdf
# Moved 'fdf24dcd-58e6-52bf-e14f-b7e289046de9.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\fdf24dcd-58e6-52bf-e14f-b7e289046de9.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\99ea655d-ecac-07b4-74e7-ea0987b0324f.pdf
# Moved '99ea655d-ecac-07b4-74e7-ea0987b0324f.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\99ea655d-ecac-07b4-74e7-ea0987b0324f.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\5cf9f91f-576b-c32c-1577-77612669ad3c.pdf
# Moved '5cf9f91f-576b-c32c-1577-77612669ad3c.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\5cf9f91f-576b-c32c-1577-77612669ad3c.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\d8b300ce-782a-67c5-eab5-2e7f2d955002.pdf
# Moved 'd8b300ce-782a-67c5-eab5-2e7f2d955002.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\d8b300ce-782a-67c5-eab5-2e7f2d955002.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\b5cc5558-8b9f-eaff-c28c-c07dc17802fd.pdf
# Moved 'b5cc5558-8b9f-eaff-c28c-c07dc17802fd.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\b5cc5558-8b9f-eaff-c28c-c07dc17802fd.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\185df4bf-960a-d141-7092-74775ba1d27e.pdf
# Moved '185df4bf-960a-d141-7092-74775ba1d27e.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\185df4bf-960a-d141-7092-74775ba1d27e.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\d086413b-faaa-c9b7-f6c0-87321057e951.pdf
# Moved 'd086413b-faaa-c9b7-f6c0-87321057e951.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\d086413b-faaa-c9b7-f6c0-87321057e951.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\b4a1c078-b940-94f7-0fc8-cc66cbc0a956.pdf
# Moved 'b4a1c078-b940-94f7-0fc8-cc66cbc0a956.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\b4a1c078-b940-94f7-0fc8-cc66cbc0a956.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\4fc28d49-a7f4-6b8e-522c-e1d5b2037569.pdf
# Moved '4fc28d49-a7f4-6b8e-522c-e1d5b2037569.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\4fc28d49-a7f4-6b8e-522c-e1d5b2037569.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\96f5f4cd-8501-3561-e5ea-47067780ad94.pdf
# Moved '96f5f4cd-8501-3561-e5ea-47067780ad94.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\96f5f4cd-8501-3561-e5ea-47067780ad94.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\d1ff8055-149a-6f8b-acdb-6b2cabd1066c.pdf
# Moved 'd1ff8055-149a-6f8b-acdb-6b2cabd1066c.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\d1ff8055-149a-6f8b-acdb-6b2cabd1066c.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\784b07a6-9b5f-b44a-fd8e-f4c54627f7ad.pdf
# Moved '784b07a6-9b5f-b44a-fd8e-f4c54627f7ad.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\784b07a6-9b5f-b44a-fd8e-f4c54627f7ad.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\7d22c6ce-9aac-1e09-7c00-e0dc40b6cdc1.pdf
# Moved '7d22c6ce-9aac-1e09-7c00-e0dc40b6cdc1.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\7d22c6ce-9aac-1e09-7c00-e0dc40b6cdc1.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\9021f385-99f9-f5ae-097e-11dc6aa156a9.pdf
# Moved '9021f385-99f9-f5ae-097e-11dc6aa156a9.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\9021f385-99f9-f5ae-097e-11dc6aa156a9.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\aa6cea0b-e74d-7a4b-12db-a793281d78c4.pdf
# Moved 'aa6cea0b-e74d-7a4b-12db-a793281d78c4.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\aa6cea0b-e74d-7a4b-12db-a793281d78c4.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\bb6abfc8-b56c-8482-b84e-1058506aee2e.pdf
# Moved 'bb6abfc8-b56c-8482-b84e-1058506aee2e.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\bb6abfc8-b56c-8482-b84e-1058506aee2e.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\23ca3985-9cdf-4777-0128-b593fc6e067b.pdf
# Moved '23ca3985-9cdf-4777-0128-b593fc6e067b.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\23ca3985-9cdf-4777-0128-b593fc6e067b.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\79feef43-86db-6351-4c98-46f0d4da2fd2.pdf
# Moved '79feef43-86db-6351-4c98-46f0d4da2fd2.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\79feef43-86db-6351-4c98-46f0d4da2fd2.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\3b811bb2-39ec-9409-40da-56f728a71139.pdf
# Moved '3b811bb2-39ec-9409-40da-56f728a71139.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\3b811bb2-39ec-9409-40da-56f728a71139.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\a9e78969-f93a-26df-c23d-61f1fd8f4c2c.pdf
# Moved 'a9e78969-f93a-26df-c23d-61f1fd8f4c2c.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\a9e78969-f93a-26df-c23d-61f1fd8f4c2c.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\88b19c9d-40a2-c4bb-1c48-9227ef616cea.pdf
# Moved '88b19c9d-40a2-c4bb-1c48-9227ef616cea.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\88b19c9d-40a2-c4bb-1c48-9227ef616cea.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\9c8d6d39-643d-b8ec-3024-74ac86925b53.pdf
# Moved '9c8d6d39-643d-b8ec-3024-74ac86925b53.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\9c8d6d39-643d-b8ec-3024-74ac86925b53.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\8182ec4c-896e-138b-c5ca-6d0775eb4f5f.pdf
# Moved '8182ec4c-896e-138b-c5ca-6d0775eb4f5f.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\8182ec4c-896e-138b-c5ca-6d0775eb4f5f.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\5b78fea6-88f4-f20d-84ae-3242fd0276e8.pdf
# Moved '5b78fea6-88f4-f20d-84ae-3242fd0276e8.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\5b78fea6-88f4-f20d-84ae-3242fd0276e8.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\79611127-1bce-3441-73f5-6c4f000b658b.pdf
# Moved '79611127-1bce-3441-73f5-6c4f000b658b.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\79611127-1bce-3441-73f5-6c4f000b658b.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\fe771b0f-9683-fa1e-1da1-628df321d624.pdf
# Moved 'fe771b0f-9683-fa1e-1da1-628df321d624.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\fe771b0f-9683-fa1e-1da1-628df321d624.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\36471ffc-b438-f8e8-43cd-ca3f42ee9d9f.pdf
# Moved '36471ffc-b438-f8e8-43cd-ca3f42ee9d9f.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\36471ffc-b438-f8e8-43cd-ca3f42ee9d9f.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\9b6660c4-7b7a-d099-84cd-bce359e49936.pdf
# Moved '9b6660c4-7b7a-d099-84cd-bce359e49936.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\9b6660c4-7b7a-d099-84cd-bce359e49936.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\335c0962-a6e8-5103-f9d3-8f04293b8045.pdf
# Moved '335c0962-a6e8-5103-f9d3-8f04293b8045.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\335c0962-a6e8-5103-f9d3-8f04293b8045.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\bba900fa-ad55-03ce-fdff-7fbd1d12f2f6.pdf
# Moved 'bba900fa-ad55-03ce-fdff-7fbd1d12f2f6.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\bba900fa-ad55-03ce-fdff-7fbd1d12f2f6.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\51251747-499d-4b01-7932-dbda0e8704b6.pdf
# Moved '51251747-499d-4b01-7932-dbda0e8704b6.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\51251747-499d-4b01-7932-dbda0e8704b6.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\9a73bb2c-e699-1da3-f64a-96997b82d357.pdf
# Moved '9a73bb2c-e699-1da3-f64a-96997b82d357.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\9a73bb2c-e699-1da3-f64a-96997b82d357.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\8daa7a72-e01a-3aa0-404a-508dcca13a3c.pdf
# Moved '8daa7a72-e01a-3aa0-404a-508dcca13a3c.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\8daa7a72-e01a-3aa0-404a-508dcca13a3c.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\466150b3-59c7-39a0-e5c3-935d9bb0d020.pdf
# Moved '466150b3-59c7-39a0-e5c3-935d9bb0d020.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\466150b3-59c7-39a0-e5c3-935d9bb0d020.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\2bee3cc9-0cfb-23ef-8ac0-d43cd101d51a.pdf
# Moved '2bee3cc9-0cfb-23ef-8ac0-d43cd101d51a.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\2bee3cc9-0cfb-23ef-8ac0-d43cd101d51a.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\8aa546ba-ae8e-9851-99f0-be23aaa3492e.pdf
# Moved '8aa546ba-ae8e-9851-99f0-be23aaa3492e.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\8aa546ba-ae8e-9851-99f0-be23aaa3492e.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\bef168f4-d2b6-4d79-33ff-e814a54c67ec.pdf
# Moved 'bef168f4-d2b6-4d79-33ff-e814a54c67ec.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\bef168f4-d2b6-4d79-33ff-e814a54c67ec.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\ad7fcf69-c134-95ef-0f54-b93f7345474d.pdf
# Moved 'ad7fcf69-c134-95ef-0f54-b93f7345474d.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\ad7fcf69-c134-95ef-0f54-b93f7345474d.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\8c889205-eb5d-2092-dd42-b6372d65c42e.pdf
# Moved '8c889205-eb5d-2092-dd42-b6372d65c42e.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\8c889205-eb5d-2092-dd42-b6372d65c42e.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\c7d8be8e-9e47-a36b-859c-e182ccea4b47.pdf
# Moved 'c7d8be8e-9e47-a36b-859c-e182ccea4b47.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\c7d8be8e-9e47-a36b-859c-e182ccea4b47.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\52aab419-e7e2-e0ff-c696-aac9d73e5e04.pdf
# Moved '52aab419-e7e2-e0ff-c696-aac9d73e5e04.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\52aab419-e7e2-e0ff-c696-aac9d73e5e04.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\a0421d1e-f9eb-eb16-a450-71140f80e9c4.pdf
# Moved 'a0421d1e-f9eb-eb16-a450-71140f80e9c4.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\a0421d1e-f9eb-eb16-a450-71140f80e9c4.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\61a240eb-b14c-16df-6a80-cde89182977f.pdf
# Moved '61a240eb-b14c-16df-6a80-cde89182977f.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\61a240eb-b14c-16df-6a80-cde89182977f.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\6b60ddd5-06f1-aeb1-8e8e-f68326951318.pdf
# Moved '6b60ddd5-06f1-aeb1-8e8e-f68326951318.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\6b60ddd5-06f1-aeb1-8e8e-f68326951318.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\2a4c9841-4174-42c5-fb31-2b14ccac3118.pdf
# Moved '2a4c9841-4174-42c5-fb31-2b14ccac3118.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\2a4c9841-4174-42c5-fb31-2b14ccac3118.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\58ec9aea-ab9c-e182-1d5d-9a5b52c7001b.pdf
# Moved '58ec9aea-ab9c-e182-1d5d-9a5b52c7001b.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\58ec9aea-ab9c-e182-1d5d-9a5b52c7001b.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\dea98ac6-fecc-d885-7e46-76e7f1dff454.pdf
# Moved 'dea98ac6-fecc-d885-7e46-76e7f1dff454.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\dea98ac6-fecc-d885-7e46-76e7f1dff454.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\6bbf9443-2fab-4ccb-6081-f75c4754832a.pdf
# Moved '6bbf9443-2fab-4ccb-6081-f75c4754832a.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\6bbf9443-2fab-4ccb-6081-f75c4754832a.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\b6d2633b-a38d-dc06-b385-d53ed1bc8788.pdf
# Moved 'b6d2633b-a38d-dc06-b385-d53ed1bc8788.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\b6d2633b-a38d-dc06-b385-d53ed1bc8788.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\25c200b4-a5ea-f37d-26c5-36aeeb183589.pdf
# Moved '25c200b4-a5ea-f37d-26c5-36aeeb183589.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\25c200b4-a5ea-f37d-26c5-36aeeb183589.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\e481236a-55ab-0e3f-83b0-1b9de48a1e42.pdf
# Moved 'e481236a-55ab-0e3f-83b0-1b9de48a1e42.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\e481236a-55ab-0e3f-83b0-1b9de48a1e42.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\fb785ae2-b187-f133-17ee-ab69b2b7e3c6.pdf
# Moved 'fb785ae2-b187-f133-17ee-ab69b2b7e3c6.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\fb785ae2-b187-f133-17ee-ab69b2b7e3c6.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\6d22c653-27d4-71c0-adc8-d8fc427858eb.pdf
# Moved '6d22c653-27d4-71c0-adc8-d8fc427858eb.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\6d22c653-27d4-71c0-adc8-d8fc427858eb.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\9411e87c-697b-6207-4a5a-4ed48e5c8150.pdf
# Moved '9411e87c-697b-6207-4a5a-4ed48e5c8150.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\9411e87c-697b-6207-4a5a-4ed48e5c8150.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\0caf7506-df00-0962-793f-f6fd9ec2aa6e.pdf
# Moved '0caf7506-df00-0962-793f-f6fd9ec2aa6e.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\0caf7506-df00-0962-793f-f6fd9ec2aa6e.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\480e4764-6788-a8de-ea76-54894d447f05.pdf
# Moved '480e4764-6788-a8de-ea76-54894d447f05.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\480e4764-6788-a8de-ea76-54894d447f05.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\03f40995-61e7-090b-ec29-bb2f00ef130f.pdf
# Moved '03f40995-61e7-090b-ec29-bb2f00ef130f.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\03f40995-61e7-090b-ec29-bb2f00ef130f.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\28641e02-48ef-e194-1091-40f8a4471148.pdf
# Moved '28641e02-48ef-e194-1091-40f8a4471148.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\28641e02-48ef-e194-1091-40f8a4471148.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\5dd2c46c-f5eb-3783-0851-8cafe4af2009.pdf
# Moved '5dd2c46c-f5eb-3783-0851-8cafe4af2009.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\5dd2c46c-f5eb-3783-0851-8cafe4af2009.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\34f0cded-2e6b-3622-6fca-f06510e64327.pdf
# Moved '34f0cded-2e6b-3622-6fca-f06510e64327.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\34f0cded-2e6b-3622-6fca-f06510e64327.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\e62dd54d-4d00-1b55-8695-860d16ab810e.pdf
# Moved 'e62dd54d-4d00-1b55-8695-860d16ab810e.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\e62dd54d-4d00-1b55-8695-860d16ab810e.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\895a49cf-60a0-9610-9166-132b2f30a0d6.pdf
# Moved '895a49cf-60a0-9610-9166-132b2f30a0d6.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\895a49cf-60a0-9610-9166-132b2f30a0d6.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\531e97c2-5b90-83e0-4927-2901cd970b99.pdf
# Moved '531e97c2-5b90-83e0-4927-2901cd970b99.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\531e97c2-5b90-83e0-4927-2901cd970b99_1.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\47f80092-3211-cf23-17ba-8aa6c518caef.pdf
# Moved '47f80092-3211-cf23-17ba-8aa6c518caef.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\47f80092-3211-cf23-17ba-8aa6c518caef_1.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\fbd0b6e1-8c52-5802-1d69-b515bea23802.pdf
# Moved 'fbd0b6e1-8c52-5802-1d69-b515bea23802.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\fbd0b6e1-8c52-5802-1d69-b515bea23802.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\645ff4b1-8bf6-a696-5fb6-225a29603acc.pdf
# Moved '645ff4b1-8bf6-a696-5fb6-225a29603acc.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\645ff4b1-8bf6-a696-5fb6-225a29603acc.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\fa0533a1-8a5c-b1b6-6e1e-0dfb47a3bc14.pdf
# Moved 'fa0533a1-8a5c-b1b6-6e1e-0dfb47a3bc14.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\fa0533a1-8a5c-b1b6-6e1e-0dfb47a3bc14.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\137a2e60-c738-1e3d-7abb-cff9cf522ee2.pdf
# Moved '137a2e60-c738-1e3d-7abb-cff9cf522ee2.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\137a2e60-c738-1e3d-7abb-cff9cf522ee2.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\28497323-9289-fcc2-a19a-d839ddfc1598.pdf
# Moved '28497323-9289-fcc2-a19a-d839ddfc1598.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-03\28497323-9289-fcc2-a19a-d839ddfc1598.pdf'
# Stopping the PDF mover.

# %%
## Code to move and rename filings from the "initial" folder to the "final" folder ##

import os
import glob
import re
import shutil
import PyPDF2

def extract_fields_from_pdf(pdf_path):
    """
    Opens the PDF file and extracts key fields from the first page:
      - SERFF Tracking number (the first token after 'SERFF Tracking #:')
      - State (the text after "State:" until the newline, then mapped to its 2-letter abbreviation)
      - Filing Company (the text after "Filing Company:" until the newline)
    Returns a tuple: (serff, state, filing_company)
    """
    with open(pdf_path, "rb") as file:
        reader = PyPDF2.PdfReader(file)
        first_page_text = reader.pages[0].extract_text()

    # Define regular expressions to capture the values.
    serff_regex = r"SERFF Tracking #:\s*([^\n]+)"
    state_regex = r"State:\s*([^\n]+)"
    filing_company_regex = r"Filing Company:\s*([^\n]+)"

    serff_match = re.search(serff_regex, first_page_text)
    state_match = re.search(state_regex, first_page_text)
    filing_company_match = re.search(filing_company_regex, first_page_text)

    serff = serff_match.group(1).strip() if serff_match else None
    state = state_match.group(1).strip() if state_match else None
    filing_company = filing_company_match.group(1).strip() if filing_company_match else None

    # Clean up the SERFF value: take only the first token
    if serff:
        serff = serff.split()[0]

    # Update the mapping dictionary to explicitly include two-word states.
    state_mapping = {
        "Alabama": "AL",
        "Alaska": "AK",
        "Arizona": "AZ",
        "Arkansas": "AR",
        "California": "CA",
        "Colorado": "CO",
        "Connecticut": "CT",
        "Delaware": "DE",
        "Florida": "FL",
        "Georgia": "GA",
        "Hawaii": "HI",
        "Idaho": "ID",
        "Illinois": "IL",
        "Indiana": "IN",
        "Iowa": "IA",
        "Kansas": "KS",
        "Kentucky": "KY",
        "Louisiana": "LA",
        "Maine": "ME",
        "Maryland": "MD",
        "Massachusetts": "MA",
        "Michigan": "MI",
        "Minnesota": "MN",
        "Mississippi": "MS",
        "Missouri": "MO",
        "Montana": "MT",
        "Nebraska": "NE",
        "Nevada": "NV",
        "New Hampshire": "NH",
        "New Jersey": "NJ",
        "New Mexico": "NM",
        "New York": "NY",
        "North Carolina": "NC",
        "North Dakota": "ND",
        "Ohio": "OH",
        "Oklahoma": "OK",
        "Oregon": "OR",
        "Pennsylvania": "PA",
        "Rhode Island": "RI",
        "South Carolina": "SC",
        "South Dakota": "SD",
        "Tennessee": "TN",
        "Texas": "TX",
        "Utah": "UT",
        "Vermont": "VT",
        "Virginia": "VA",
        "Washington": "WA",
        "West Virginia": "WV",
        "Wisconsin": "WI",
        "Wyoming": "WY"
    }
    
    # Process the state string: if it begins with a known two-word state, use both words.
    if state:
        tokens = state.split()
        if len(tokens) >= 2:
            candidate = " ".join(tokens[:2])
            two_word_states = {"New York", "New Jersey", "New Hampshire", "New Mexico",
                               "South Carolina",  "South Dakota" ,"North Carolina", "North Dakota", "Rhode Island", "West Virginia"}
            if candidate in two_word_states:
                state_full = candidate
            else:
                state_full = tokens[0]
        else:
            state_full = state.strip()
        state = state_mapping.get(state_full, state_full)

    return serff, state, filing_company

def process_filings_for_week(week_date):
    """
    Given a week_date string (e.g., '2025-02-03'), this function:
      1. Sets the source folder as './Filings/Initial/<week_date>'
      2. Creates a destination folder './Filings/Final/<week_date>' if it doesn't exist.
      3. Loops through each PDF file in the source folder, ordered descending by modification time.
      4. For each PDF, extracts the SERFF Tracking number and State.
      5. Copies the file to the destination folder, renaming it to "State_SERFF#.pdf".
         (If a file for that SERFF already exists, it is replaced with the new one.)
    """
    # Define folder paths
    initial_folder = os.path.join("Filings", "Initial", week_date)
    final_folder = os.path.join("Filings", "Final", week_date)

    # Create the destination folder if it doesn't exist
    os.makedirs(final_folder, exist_ok=True)

    # Get a list of all PDF files in the initial folder
    pdf_files = glob.glob(os.path.join(initial_folder, "*.pdf"))
    
    # Sort the list in descending order by modified time
    pdf_files.sort(key=lambda f: os.path.getmtime(f), reverse=True)

    for pdf_file in pdf_files:
        serff, state, filing_company = extract_fields_from_pdf(pdf_file)
        if serff is None:
            print(f"Warning: Could not extract SERFF Tracking number from {pdf_file}. Skipping.")
            continue

        # Create the new filename as "State_SERFF#.pdf". If state isn't available, use only SERFF.
        if state:
            new_filename = f"{state}_{serff}.pdf"
        else:
            new_filename = f"{serff}.pdf"

        dest_file = os.path.join(final_folder, new_filename)
        if os.path.exists(dest_file):
            print(f"Replacing duplicate SERFF {serff} in {pdf_file}")
        else:
            print(f"Copying {pdf_file} to {dest_file}")

        # Copy the file to the destination (this overwrites if the file exists)
        shutil.copy2(pdf_file, dest_file)

# Example usage:
# process_filings_for_week("2025-02-03")

# %%
process_filings_for_week("2025-03-03")
# Out:
# Copying Filings\Initial\2025-03-03\28497323-9289-fcc2-a19a-d839ddfc1598.pdf to Filings\Final\2025-03-03\VA_HART-134429350.pdf
# Copying Filings\Initial\2025-03-03\137a2e60-c738-1e3d-7abb-cff9cf522ee2.pdf to Filings\Final\2025-03-03\TN_USAA-134436312.pdf
# Copying Filings\Initial\2025-03-03\fa0533a1-8a5c-b1b6-6e1e-0dfb47a3bc14.pdf to Filings\Final\2025-03-03\TN_LBPM-134434596.pdf
# Copying Filings\Initial\2025-03-03\645ff4b1-8bf6-a696-5fb6-225a29603acc.pdf to Filings\Final\2025-03-03\CT_TRVD-G134412788.pdf
# Copying Filings\Initial\2025-03-03\fbd0b6e1-8c52-5802-1d69-b515bea23802.pdf to Filings\Final\2025-03-03\TX_GMMX-134436826.pdf
# Copying Filings\Initial\2025-03-03\47f80092-3211-cf23-17ba-8aa6c518caef_1.pdf to Filings\Final\2025-03-03\AL_LBPM-134436753.pdf
# Copying Filings\Initial\2025-03-03\531e97c2-5b90-83e0-4927-2901cd970b99_1.pdf to Filings\Final\2025-03-03\NE_TRVD-G134437855.pdf
# Copying Filings\Initial\2025-03-03\895a49cf-60a0-9610-9166-132b2f30a0d6.pdf to Filings\Final\2025-03-03\MI_LBPM-134437587.pdf
# Copying Filings\Initial\2025-03-03\e62dd54d-4d00-1b55-8695-860d16ab810e.pdf to Filings\Final\2025-03-03\MI_LBPM-134437577.pdf
# Copying Filings\Initial\2025-03-03\34f0cded-2e6b-3622-6fca-f06510e64327.pdf to Filings\Final\2025-03-03\TN_HART-134429213.pdf
# Copying Filings\Initial\2025-03-03\5dd2c46c-f5eb-3783-0851-8cafe4af2009.pdf to Filings\Final\2025-03-03\NV_HART-134433449.pdf
# Copying Filings\Initial\2025-03-03\28641e02-48ef-e194-1091-40f8a4471148.pdf to Filings\Final\2025-03-03\WA_GMMX-134441494.pdf
# Warning: Could not extract SERFF Tracking number from Filings\Initial\2025-03-03\03f40995-61e7-090b-ec29-bb2f00ef130f.pdf. Skipping.
# Copying Filings\Initial\2025-03-03\480e4764-6788-a8de-ea76-54894d447f05.pdf to Filings\Final\2025-03-03\MI_ALSE-134443416.pdf
# Copying Filings\Initial\2025-03-03\0caf7506-df00-0962-793f-f6fd9ec2aa6e.pdf to Filings\Final\2025-03-03\TX_ALSE-133994457.pdf
# Copying Filings\Initial\2025-03-03\9411e87c-697b-6207-4a5a-4ed48e5c8150.pdf to Filings\Final\2025-03-03\TX_ALSE-133994492.pdf
# Copying Filings\Initial\2025-03-03\6d22c653-27d4-71c0-adc8-d8fc427858eb.pdf to Filings\Final\2025-03-03\TX_ALSE-133995002.pdf
# Copying Filings\Initial\2025-03-03\fb785ae2-b187-f133-17ee-ab69b2b7e3c6.pdf to Filings\Final\2025-03-03\AZ_TRVD-134038097.pdf
# Copying Filings\Initial\2025-03-03\e481236a-55ab-0e3f-83b0-1b9de48a1e42.pdf to Filings\Final\2025-03-03\MN_TRVD-G134202060.pdf
# Copying Filings\Initial\2025-03-03\25c200b4-a5ea-f37d-26c5-36aeeb183589.pdf to Filings\Final\2025-03-03\CO_LEMO-134207600.pdf
# Copying Filings\Initial\2025-03-03\b6d2633b-a38d-dc06-b385-d53ed1bc8788.pdf to Filings\Final\2025-03-03\CA_LBRM-134233558.pdf
# Copying Filings\Initial\2025-03-03\6bbf9443-2fab-4ccb-6081-f75c4754832a.pdf to Filings\Final\2025-03-03\NV_AMSI-134209900.pdf
# Copying Filings\Initial\2025-03-03\dea98ac6-fecc-d885-7e46-76e7f1dff454.pdf to Filings\Final\2025-03-03\IA_AMSI-134274777.pdf
# Copying Filings\Initial\2025-03-03\58ec9aea-ab9c-e182-1d5d-9a5b52c7001b.pdf to Filings\Final\2025-03-03\LA_LBPM-134284450.pdf
# Copying Filings\Initial\2025-03-03\2a4c9841-4174-42c5-fb31-2b14ccac3118.pdf to Filings\Final\2025-03-03\AL_ALSE-134300517.pdf
# Copying Filings\Initial\2025-03-03\6b60ddd5-06f1-aeb1-8e8e-f68326951318.pdf to Filings\Final\2025-03-03\CA_ALSE-134306035.pdf
# Copying Filings\Initial\2025-03-03\61a240eb-b14c-16df-6a80-cde89182977f.pdf to Filings\Final\2025-03-03\MO_TRVD-G134325887.pdf
# Copying Filings\Initial\2025-03-03\a0421d1e-f9eb-eb16-a450-71140f80e9c4.pdf to Filings\Final\2025-03-03\SC_AMSI-134171194.pdf
# Copying Filings\Initial\2025-03-03\52aab419-e7e2-e0ff-c696-aac9d73e5e04.pdf to Filings\Final\2025-03-03\GA_ALSE-134333693.pdf
# Copying Filings\Initial\2025-03-03\c7d8be8e-9e47-a36b-859c-e182ccea4b47.pdf to Filings\Final\2025-03-03\GA_ALSE-134336890.pdf
# Copying Filings\Initial\2025-03-03\8c889205-eb5d-2092-dd42-b6372d65c42e.pdf to Filings\Final\2025-03-03\GA_ALSE-134337450.pdf
# Copying Filings\Initial\2025-03-03\ad7fcf69-c134-95ef-0f54-b93f7345474d.pdf to Filings\Final\2025-03-03\GA_ALSE-134337637.pdf
# Copying Filings\Initial\2025-03-03\bef168f4-d2b6-4d79-33ff-e814a54c67ec.pdf to Filings\Final\2025-03-03\GA_ALSE-134336829.pdf
# Copying Filings\Initial\2025-03-03\8aa546ba-ae8e-9851-99f0-be23aaa3492e.pdf to Filings\Final\2025-03-03\GA_ALSE-134337677.pdf
# Copying Filings\Initial\2025-03-03\2bee3cc9-0cfb-23ef-8ac0-d43cd101d51a.pdf to Filings\Final\2025-03-03\GA_ALSE-134337686.pdf
# Copying Filings\Initial\2025-03-03\466150b3-59c7-39a0-e5c3-935d9bb0d020.pdf to Filings\Final\2025-03-03\CO_USAA-134337652.pdf
# Copying Filings\Initial\2025-03-03\8daa7a72-e01a-3aa0-404a-508dcca13a3c.pdf to Filings\Final\2025-03-03\VA_TRVD-G134337488.pdf
# Copying Filings\Initial\2025-03-03\9a73bb2c-e699-1da3-f64a-96997b82d357.pdf to Filings\Final\2025-03-03\CA_LBRM-134354159.pdf
# Copying Filings\Initial\2025-03-03\51251747-499d-4b01-7932-dbda0e8704b6.pdf to Filings\Final\2025-03-03\MO_LBPM-134358153.pdf
# Copying Filings\Initial\2025-03-03\bba900fa-ad55-03ce-fdff-7fbd1d12f2f6.pdf to Filings\Final\2025-03-03\GA_TRVD-G134360540.pdf
# Copying Filings\Initial\2025-03-03\335c0962-a6e8-5103-f9d3-8f04293b8045.pdf to Filings\Final\2025-03-03\MO_LBPM-134364067.pdf
# Copying Filings\Initial\2025-03-03\9b6660c4-7b7a-d099-84cd-bce359e49936.pdf to Filings\Final\2025-03-03\NJ_LBPM-134367579.pdf
# Copying Filings\Initial\2025-03-03\36471ffc-b438-f8e8-43cd-ca3f42ee9d9f.pdf to Filings\Final\2025-03-03\TX_LBPM-134367508.pdf
# Copying Filings\Initial\2025-03-03\79611127-1bce-3441-73f5-6c4f000b658b.pdf to Filings\Final\2025-03-03\KS_LBPM-134379791.pdf
# Copying Filings\Initial\2025-03-03\fe771b0f-9683-fa1e-1da1-628df321d624.pdf to Filings\Final\2025-03-03\VA_AMSI-134375543.pdf
# Copying Filings\Initial\2025-03-03\5b78fea6-88f4-f20d-84ae-3242fd0276e8.pdf to Filings\Final\2025-03-03\NV_HART-134384733.pdf
# Copying Filings\Initial\2025-03-03\8182ec4c-896e-138b-c5ca-6d0775eb4f5f.pdf to Filings\Final\2025-03-03\IL_HART-134383807.pdf
# Copying Filings\Initial\2025-03-03\9c8d6d39-643d-b8ec-3024-74ac86925b53.pdf to Filings\Final\2025-03-03\RI_LBPM-134392464.pdf
# Copying Filings\Initial\2025-03-03\88b19c9d-40a2-c4bb-1c48-9227ef616cea.pdf to Filings\Final\2025-03-03\WV_AMSI-134244221.pdf
# Copying Filings\Initial\2025-03-03\a9e78969-f93a-26df-c23d-61f1fd8f4c2c.pdf to Filings\Final\2025-03-03\KY_ALSE-134398945.pdf
# Copying Filings\Initial\2025-03-03\3b811bb2-39ec-9409-40da-56f728a71139.pdf to Filings\Final\2025-03-03\KY_ALSE-134398573.pdf
# Copying Filings\Initial\2025-03-03\79feef43-86db-6351-4c98-46f0d4da2fd2.pdf to Filings\Final\2025-03-03\SC_LBPM-134400516.pdf
# Copying Filings\Initial\2025-03-03\23ca3985-9cdf-4777-0128-b593fc6e067b.pdf to Filings\Final\2025-03-03\GA_TRVD-G134400530.pdf
# Copying Filings\Initial\2025-03-03\bb6abfc8-b56c-8482-b84e-1058506aee2e.pdf to Filings\Final\2025-03-03\SC_LBPM-134401992.pdf
# Copying Filings\Initial\2025-03-03\aa6cea0b-e74d-7a4b-12db-a793281d78c4.pdf to Filings\Final\2025-03-03\GA_LEMO-134376013.pdf
# Copying Filings\Initial\2025-03-03\9021f385-99f9-f5ae-097e-11dc6aa156a9.pdf to Filings\Final\2025-03-03\GA_LEMO-134374428.pdf
# Copying Filings\Initial\2025-03-03\7d22c6ce-9aac-1e09-7c00-e0dc40b6cdc1.pdf to Filings\Final\2025-03-03\SC_LBPM-134406290.pdf
# Copying Filings\Initial\2025-03-03\784b07a6-9b5f-b44a-fd8e-f4c54627f7ad.pdf to Filings\Final\2025-03-03\MN_ALSE-134409609.pdf
# Copying Filings\Initial\2025-03-03\d1ff8055-149a-6f8b-acdb-6b2cabd1066c.pdf to Filings\Final\2025-03-03\UT_LBPM-134409711.pdf
# Copying Filings\Initial\2025-03-03\96f5f4cd-8501-3561-e5ea-47067780ad94.pdf to Filings\Final\2025-03-03\MN_ALSE-134409640.pdf
# Copying Filings\Initial\2025-03-03\4fc28d49-a7f4-6b8e-522c-e1d5b2037569.pdf to Filings\Final\2025-03-03\KS_LBPM-134409706.pdf
# Copying Filings\Initial\2025-03-03\b4a1c078-b940-94f7-0fc8-cc66cbc0a956.pdf to Filings\Final\2025-03-03\TN_LBPM-134412900.pdf
# Copying Filings\Initial\2025-03-03\d086413b-faaa-c9b7-f6c0-87321057e951.pdf to Filings\Final\2025-03-03\ND_GMMX-134414199.pdf
# Copying Filings\Initial\2025-03-03\185df4bf-960a-d141-7092-74775ba1d27e.pdf to Filings\Final\2025-03-03\ND_GMMX-134414147.pdf
# Copying Filings\Initial\2025-03-03\b5cc5558-8b9f-eaff-c28c-c07dc17802fd.pdf to Filings\Final\2025-03-03\ND_GMMX-134414190.pdf
# Copying Filings\Initial\2025-03-03\d8b300ce-782a-67c5-eab5-2e7f2d955002.pdf to Filings\Final\2025-03-03\MN_AMSI-134380414.pdf
# Copying Filings\Initial\2025-03-03\5cf9f91f-576b-c32c-1577-77612669ad3c.pdf to Filings\Final\2025-03-03\OR_ALSE-134413977.pdf
# Copying Filings\Initial\2025-03-03\99ea655d-ecac-07b4-74e7-ea0987b0324f.pdf to Filings\Final\2025-03-03\OR_ALSE-134413946.pdf
# Copying Filings\Initial\2025-03-03\fdf24dcd-58e6-52bf-e14f-b7e289046de9.pdf to Filings\Final\2025-03-03\OR_ALSE-134417934.pdf
# Copying Filings\Initial\2025-03-03\d5a60d5a-c5e5-2178-7e9f-b92219f4c03f.pdf to Filings\Final\2025-03-03\OR_ALSE-134417942.pdf
# Copying Filings\Initial\2025-03-03\19531937-23ca-9480-8906-db7bc535c922.pdf to Filings\Final\2025-03-03\OR_ALSE-134417973.pdf
# Copying Filings\Initial\2025-03-03\e0fe3bd8-da3f-bea2-136b-d4c30254a961.pdf to Filings\Final\2025-03-03\OR_ALSE-134418009.pdf
# Copying Filings\Initial\2025-03-03\7f3abd58-6eea-9bee-557b-e57b3d5480e0.pdf to Filings\Final\2025-03-03\OR_ALSE-134418028.pdf
# Copying Filings\Initial\2025-03-03\097072c1-6a8f-1d8d-2de7-426f534be14a.pdf to Filings\Final\2025-03-03\AZ_TRVD-G134416866.pdf
# Copying Filings\Initial\2025-03-03\7d3178a9-4159-6207-eeeb-b9b31ccd4693.pdf to Filings\Final\2025-03-03\AZ_TRVD-G134417169.pdf
# Copying Filings\Initial\2025-03-03\98abd2ec-51fa-feba-3f1f-fc2d1dfd80ce.pdf to Filings\Final\2025-03-03\NC_USAA-134418343.pdf
# Copying Filings\Initial\2025-03-03\dbe18072-9c64-1397-ad9d-5c0ea2609285.pdf to Filings\Final\2025-03-03\NC_USAA-134418355.pdf
# Copying Filings\Initial\2025-03-03\8e9d5457-23f1-fb78-e5dc-6476573f2f29.pdf to Filings\Final\2025-03-03\NC_USAA-134418345.pdf
# Copying Filings\Initial\2025-03-03\30bb0f08-cb5d-2f22-749d-488075f03ee8.pdf to Filings\Final\2025-03-03\NC_USAA-134418351.pdf
# Copying Filings\Initial\2025-03-03\47336af4-4ba9-3b15-623c-ed6d5eb76265.pdf to Filings\Final\2025-03-03\CO_LBPM-134412448.pdf
# Warning: Could not extract SERFF Tracking number from Filings\Initial\2025-03-03\8c308d30-c118-5681-fdef-1fc098969beb.pdf. Skipping.
# Warning: Could not extract SERFF Tracking number from Filings\Initial\2025-03-03\b59592ad-b696-eafc-96aa-5465c8645b3b.pdf. Skipping.
# Copying Filings\Initial\2025-03-03\68dd0cb4-4336-a5c1-0d3d-00f5eed2aa56.pdf to Filings\Final\2025-03-03\MI_ALSE-134422885.pdf
# Copying Filings\Initial\2025-03-03\3e5200d0-c5de-fb87-73f8-9c513d137943.pdf to Filings\Final\2025-03-03\IL_LEMO-134419957.pdf
# Copying Filings\Initial\2025-03-03\f9c24780-b76f-0082-ab7d-90b650b26bed.pdf to Filings\Final\2025-03-03\KY_USAA-134421819.pdf
# Copying Filings\Initial\2025-03-03\b985b2a7-bc63-7071-8a54-0c0123c4f1a1.pdf to Filings\Final\2025-03-03\NM_TRVD-G134428427.pdf
# Copying Filings\Initial\2025-03-03\ff1d13ff-ac4d-88f5-fa36-249a78f373f2.pdf to Filings\Final\2025-03-03\AR_TRVD-G134425501.pdf
# Copying Filings\Initial\2025-03-03\dfe429f3-2520-ce52-9cab-764e99cab641.pdf to Filings\Final\2025-03-03\PA_LEMO-134412814.pdf
# Replacing duplicate SERFF LBPM-134436753 in Filings\Initial\2025-03-03\47f80092-3211-cf23-17ba-8aa6c518caef.pdf
# Copying Filings\Initial\2025-03-03\2496e036-66a6-15c0-510e-9c4729590643.pdf to Filings\Final\2025-03-03\KS_GMMX-134433936.pdf
# Replacing duplicate SERFF TRVD-G134437855 in Filings\Initial\2025-03-03\531e97c2-5b90-83e0-4927-2901cd970b99.pdf

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\lawre\\OneDrive\\Documents\\Competitor_filings_monitor'
