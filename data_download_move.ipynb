# %%
###Code to monitor the downloading of files and put in the "initial" folder for a specific week###
import os
import time
import shutil
import datetime
from watchdog.observers import Observer
from watchdog.events import FileSystemEventHandler

# --- Configuration ---
DOWNLOADS_FOLDER = os.path.expanduser("~/Downloads")
WORKING_DIRECTORY = os.path.expanduser("~/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial")
FILE_EXTENSION = ".pdf"

# Create the main working directory if it doesn't exist
if not os.path.exists(WORKING_DIRECTORY):
    os.makedirs(WORKING_DIRECTORY)
    print(f"Created working directory: {WORKING_DIRECTORY}")

class PDFHandler(FileSystemEventHandler):
    def on_created(self, event):
        # Only consider files (not directories) that end with .pdf
        if not event.is_directory and event.src_path.lower().endswith(FILE_EXTENSION):
            print(f"Detected new file: {event.src_path}")
            self.move_file(event.src_path)

    def on_moved(self, event):
        # This event fires when a file is renamed or moved.
        if not event.is_directory and event.dest_path.lower().endswith(FILE_EXTENSION):
            print(f"Detected moved/renamed file: {event.dest_path}")
            self.move_file(event.dest_path)

    def move_file(self, src_path):
        # Determine the current week’s Monday
        today = datetime.date.today()
        # weekday() returns 0 for Monday, so subtract the current weekday to get Monday's date.
        monday = today - datetime.timedelta(days=today.weekday())
        week_folder_name = monday.strftime("%Y-%m-%d")
        week_folder_path = os.path.join(WORKING_DIRECTORY, week_folder_name)

        # Create the subfolder if it doesn't exist yet
        if not os.path.exists(week_folder_path):
            os.makedirs(week_folder_path)
            print(f"Created subfolder for week starting {week_folder_name}")

        # Set the destination path inside the weekly subfolder
        filename = os.path.basename(src_path)
        destination = os.path.join(week_folder_path, filename)

        # Avoid overwriting files by appending a counter if needed
        base, ext = os.path.splitext(filename)
        counter = 1
        while os.path.exists(destination):
            destination = os.path.join(week_folder_path, f"{base}_{counter}{ext}")
            counter += 1

        # Wait until the file is ready (not locked by another process)
        while not self.is_file_ready(src_path):
            time.sleep(1)
        
        try:
            shutil.move(src_path, destination)
            print(f"Moved '{filename}' to '{destination}'")
        except Exception as e:
            print(f"Error moving file '{filename}': {e}")

    def is_file_ready(self, file_path):
        """
        Check if a file is ready by attempting to open it.
        If it’s still being written (or locked), an IOError may occur.
        """
        try:
            with open(file_path, 'rb'):
                return True
        except IOError:
            return False

def main():
    event_handler = PDFHandler()
    observer = Observer()
    observer.schedule(event_handler, path=DOWNLOADS_FOLDER, recursive=False)
    observer.start()
    print(f"Monitoring '{DOWNLOADS_FOLDER}' for new PDF files...")
    
    try:
        while True:
            time.sleep(1)
    except KeyboardInterrupt:
        observer.stop()
        print("Stopping the PDF mover.")
    observer.join()

#if __name__ == "__main__":
#    main()

# %%
main()
# Out:
# Monitoring 'C:\Users\lawre/Downloads' for new PDF files...
# Detected moved/renamed file: C:\Users\lawre/Downloads\d560b564-03ac-b978-4575-e5acddca51d5.pdf
# Created subfolder for week starting 2025-03-10
# Moved 'd560b564-03ac-b978-4575-e5acddca51d5.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\d560b564-03ac-b978-4575-e5acddca51d5.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\f5d032d1-3164-2470-9352-2955395e6857.pdf
# Moved 'f5d032d1-3164-2470-9352-2955395e6857.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\f5d032d1-3164-2470-9352-2955395e6857.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\8cb7917f-e668-8aec-8f84-42235d99d358.pdf
# Moved '8cb7917f-e668-8aec-8f84-42235d99d358.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\8cb7917f-e668-8aec-8f84-42235d99d358.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\e978ce50-6be9-8e09-1b40-14aa76bdf035.pdf
# Moved 'e978ce50-6be9-8e09-1b40-14aa76bdf035.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\e978ce50-6be9-8e09-1b40-14aa76bdf035.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\f47fe5b7-f4cf-1a8c-da4a-db7b6fef6529.pdf
# Moved 'f47fe5b7-f4cf-1a8c-da4a-db7b6fef6529.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\f47fe5b7-f4cf-1a8c-da4a-db7b6fef6529.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\bc06ef03-f601-22bd-3813-12d98f89c069.pdf
# Moved 'bc06ef03-f601-22bd-3813-12d98f89c069.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\bc06ef03-f601-22bd-3813-12d98f89c069.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\be84fa26-310b-0324-2b1a-7de788dcd87b.pdf
# Moved 'be84fa26-310b-0324-2b1a-7de788dcd87b.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\be84fa26-310b-0324-2b1a-7de788dcd87b.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\2496e036-66a6-15c0-510e-9c4729590643.pdf
# Moved '2496e036-66a6-15c0-510e-9c4729590643.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\2496e036-66a6-15c0-510e-9c4729590643.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\dfe429f3-2520-ce52-9cab-764e99cab641.pdf
# Moved 'dfe429f3-2520-ce52-9cab-764e99cab641.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\dfe429f3-2520-ce52-9cab-764e99cab641.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\15765a1f-5287-9a1a-cb93-cb83dbfa21f0.pdf
# Moved '15765a1f-5287-9a1a-cb93-cb83dbfa21f0.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\15765a1f-5287-9a1a-cb93-cb83dbfa21f0.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\1e14b3e0-3e25-71bd-c8dd-f2eec59ff5a9.pdf
# Moved '1e14b3e0-3e25-71bd-c8dd-f2eec59ff5a9.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\1e14b3e0-3e25-71bd-c8dd-f2eec59ff5a9.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\e2f2c319-f382-1d1a-4fc3-9123441582d8.pdf
# Moved 'e2f2c319-f382-1d1a-4fc3-9123441582d8.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\e2f2c319-f382-1d1a-4fc3-9123441582d8.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\72d6bef0-46a4-01ff-5616-dc6bd925b48a.pdf
# Moved '72d6bef0-46a4-01ff-5616-dc6bd925b48a.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\72d6bef0-46a4-01ff-5616-dc6bd925b48a.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\a0076393-e31f-aba6-9719-9d67526aeeb8.pdf
# Moved 'a0076393-e31f-aba6-9719-9d67526aeeb8.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\a0076393-e31f-aba6-9719-9d67526aeeb8.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\dddc74b5-c70c-05b5-1f30-7fd53c3917b5.pdf
# Moved 'dddc74b5-c70c-05b5-1f30-7fd53c3917b5.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\dddc74b5-c70c-05b5-1f30-7fd53c3917b5.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\d20831c8-570f-f3d6-a9fe-0d5db24ee5cb.pdf
# Moved 'd20831c8-570f-f3d6-a9fe-0d5db24ee5cb.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\d20831c8-570f-f3d6-a9fe-0d5db24ee5cb.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\2736944e-afd5-3c6d-d29b-337a28df18e3.pdf
# Moved '2736944e-afd5-3c6d-d29b-337a28df18e3.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\2736944e-afd5-3c6d-d29b-337a28df18e3.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\68dd0cb4-4336-a5c1-0d3d-00f5eed2aa56.pdf
# Moved '68dd0cb4-4336-a5c1-0d3d-00f5eed2aa56.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\68dd0cb4-4336-a5c1-0d3d-00f5eed2aa56.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\b59592ad-b696-eafc-96aa-5465c8645b3b.pdf
# Moved 'b59592ad-b696-eafc-96aa-5465c8645b3b.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\b59592ad-b696-eafc-96aa-5465c8645b3b.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\8c308d30-c118-5681-fdef-1fc098969beb.pdf
# Moved '8c308d30-c118-5681-fdef-1fc098969beb.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\8c308d30-c118-5681-fdef-1fc098969beb.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\c60f05c5-9a59-c401-05d5-6898c541f2f9.pdf
# Moved 'c60f05c5-9a59-c401-05d5-6898c541f2f9.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\c60f05c5-9a59-c401-05d5-6898c541f2f9.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\a6743b6c-87f0-2923-4705-d0a2d414ae3f.pdf
# Moved 'a6743b6c-87f0-2923-4705-d0a2d414ae3f.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\a6743b6c-87f0-2923-4705-d0a2d414ae3f.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\47336af4-4ba9-3b15-623c-ed6d5eb76265.pdf
# Moved '47336af4-4ba9-3b15-623c-ed6d5eb76265.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\47336af4-4ba9-3b15-623c-ed6d5eb76265.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\30bb0f08-cb5d-2f22-749d-488075f03ee8.pdf
# Moved '30bb0f08-cb5d-2f22-749d-488075f03ee8.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\30bb0f08-cb5d-2f22-749d-488075f03ee8.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\8e9d5457-23f1-fb78-e5dc-6476573f2f29.pdf
# Moved '8e9d5457-23f1-fb78-e5dc-6476573f2f29.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\8e9d5457-23f1-fb78-e5dc-6476573f2f29.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\dbe18072-9c64-1397-ad9d-5c0ea2609285.pdf
# Moved 'dbe18072-9c64-1397-ad9d-5c0ea2609285.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\dbe18072-9c64-1397-ad9d-5c0ea2609285.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\98abd2ec-51fa-feba-3f1f-fc2d1dfd80ce.pdf
# Moved '98abd2ec-51fa-feba-3f1f-fc2d1dfd80ce.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\98abd2ec-51fa-feba-3f1f-fc2d1dfd80ce.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\53f087fc-b3c6-87b5-7217-78cf9ec74126.pdf
# Moved '53f087fc-b3c6-87b5-7217-78cf9ec74126.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\53f087fc-b3c6-87b5-7217-78cf9ec74126.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\d27579d0-5910-e37e-1b2a-b323f34ebb0e.pdf
# Moved 'd27579d0-5910-e37e-1b2a-b323f34ebb0e.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\d27579d0-5910-e37e-1b2a-b323f34ebb0e.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\b5cc5558-8b9f-eaff-c28c-c07dc17802fd.pdf
# Moved 'b5cc5558-8b9f-eaff-c28c-c07dc17802fd.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\b5cc5558-8b9f-eaff-c28c-c07dc17802fd.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\185df4bf-960a-d141-7092-74775ba1d27e.pdf
# Moved '185df4bf-960a-d141-7092-74775ba1d27e.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\185df4bf-960a-d141-7092-74775ba1d27e.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\d086413b-faaa-c9b7-f6c0-87321057e951.pdf
# Moved 'd086413b-faaa-c9b7-f6c0-87321057e951.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\d086413b-faaa-c9b7-f6c0-87321057e951.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\7d22c6ce-9aac-1e09-7c00-e0dc40b6cdc1.pdf
# Moved '7d22c6ce-9aac-1e09-7c00-e0dc40b6cdc1.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\7d22c6ce-9aac-1e09-7c00-e0dc40b6cdc1.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\bb6abfc8-b56c-8482-b84e-1058506aee2e.pdf
# Moved 'bb6abfc8-b56c-8482-b84e-1058506aee2e.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\bb6abfc8-b56c-8482-b84e-1058506aee2e.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\23ca3985-9cdf-4777-0128-b593fc6e067b.pdf
# Moved '23ca3985-9cdf-4777-0128-b593fc6e067b.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\23ca3985-9cdf-4777-0128-b593fc6e067b.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\df57d2dd-8aef-b8c5-383a-0806940a6372.pdf
# Moved 'df57d2dd-8aef-b8c5-383a-0806940a6372.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\df57d2dd-8aef-b8c5-383a-0806940a6372.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\79feef43-86db-6351-4c98-46f0d4da2fd2.pdf
# Moved '79feef43-86db-6351-4c98-46f0d4da2fd2.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\79feef43-86db-6351-4c98-46f0d4da2fd2.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\9efe2b3e-a558-37d9-d932-36a2c9d65ef1.pdf
# Moved '9efe2b3e-a558-37d9-d932-36a2c9d65ef1.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\9efe2b3e-a558-37d9-d932-36a2c9d65ef1.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\0bdba24d-8166-0be1-0772-25df9851da08.pdf
# Moved '0bdba24d-8166-0be1-0772-25df9851da08.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\0bdba24d-8166-0be1-0772-25df9851da08.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\588d5f58-fa9a-b991-d34a-215cb648346d.pdf
# Moved '588d5f58-fa9a-b991-d34a-215cb648346d.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\588d5f58-fa9a-b991-d34a-215cb648346d.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\92da494c-7ebd-1878-adf3-b4a9757f8685.pdf
# Moved '92da494c-7ebd-1878-adf3-b4a9757f8685.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\92da494c-7ebd-1878-adf3-b4a9757f8685.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\9125c9b3-2c02-4b2e-fd31-4aa50fe193bc.pdf
# Moved '9125c9b3-2c02-4b2e-fd31-4aa50fe193bc.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\9125c9b3-2c02-4b2e-fd31-4aa50fe193bc.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\6cd83549-7a7c-13cd-a372-d9bbd2ab2df0.pdf
# Moved '6cd83549-7a7c-13cd-a372-d9bbd2ab2df0.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\6cd83549-7a7c-13cd-a372-d9bbd2ab2df0.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\5b78fea6-88f4-f20d-84ae-3242fd0276e8.pdf
# Moved '5b78fea6-88f4-f20d-84ae-3242fd0276e8.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\5b78fea6-88f4-f20d-84ae-3242fd0276e8.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\fe771b0f-9683-fa1e-1da1-628df321d624.pdf
# Moved 'fe771b0f-9683-fa1e-1da1-628df321d624.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\fe771b0f-9683-fa1e-1da1-628df321d624.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\9b6660c4-7b7a-d099-84cd-bce359e49936.pdf
# Moved '9b6660c4-7b7a-d099-84cd-bce359e49936.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\9b6660c4-7b7a-d099-84cd-bce359e49936.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\bba900fa-ad55-03ce-fdff-7fbd1d12f2f6.pdf
# Moved 'bba900fa-ad55-03ce-fdff-7fbd1d12f2f6.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\bba900fa-ad55-03ce-fdff-7fbd1d12f2f6.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\2e8cda90-33b1-c126-5802-7a1ceb3533e0.pdf
# Moved '2e8cda90-33b1-c126-5802-7a1ceb3533e0.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\2e8cda90-33b1-c126-5802-7a1ceb3533e0.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\9a73bb2c-e699-1da3-f64a-96997b82d357.pdf
# Moved '9a73bb2c-e699-1da3-f64a-96997b82d357.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\9a73bb2c-e699-1da3-f64a-96997b82d357.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\8c889205-eb5d-2092-dd42-b6372d65c42e.pdf
# Moved '8c889205-eb5d-2092-dd42-b6372d65c42e.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\8c889205-eb5d-2092-dd42-b6372d65c42e.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\88b19c9d-40a2-c4bb-1c48-9227ef616cea.pdf
# Moved '88b19c9d-40a2-c4bb-1c48-9227ef616cea.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\88b19c9d-40a2-c4bb-1c48-9227ef616cea.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\f2f9d6b0-2acf-e535-ae45-824d5c26eac8.pdf
# Moved 'f2f9d6b0-2acf-e535-ae45-824d5c26eac8.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\f2f9d6b0-2acf-e535-ae45-824d5c26eac8.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\dafbb73c-4c86-68e4-7294-f83e45ffcf55.pdf
# Moved 'dafbb73c-4c86-68e4-7294-f83e45ffcf55.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\dafbb73c-4c86-68e4-7294-f83e45ffcf55.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\143ca8a5-5dbe-90e0-ac6e-e736904ec7ba.pdf
# Moved '143ca8a5-5dbe-90e0-ac6e-e736904ec7ba.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\143ca8a5-5dbe-90e0-ac6e-e736904ec7ba.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\ebb5648d-d2d5-1452-0047-9ab88a9e4e4f.pdf
# Moved 'ebb5648d-d2d5-1452-0047-9ab88a9e4e4f.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\ebb5648d-d2d5-1452-0047-9ab88a9e4e4f.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\259ad822-baf4-85b9-40c6-500c48e25682.pdf
# Moved '259ad822-baf4-85b9-40c6-500c48e25682.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\259ad822-baf4-85b9-40c6-500c48e25682.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\d994c86a-64e3-391b-c9e1-19f6f6e92a7f.pdf
# Moved 'd994c86a-64e3-391b-c9e1-19f6f6e92a7f.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\d994c86a-64e3-391b-c9e1-19f6f6e92a7f.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\88c9922f-1dd3-e00a-df3b-3c2d091c6923.pdf
# Moved '88c9922f-1dd3-e00a-df3b-3c2d091c6923.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\88c9922f-1dd3-e00a-df3b-3c2d091c6923.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\d3b39657-3d42-9705-741a-966b38069cf4.pdf
# Moved 'd3b39657-3d42-9705-741a-966b38069cf4.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\d3b39657-3d42-9705-741a-966b38069cf4.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\77fe5e0e-2c46-e900-5c5e-488f986f0578.pdf
# Moved '77fe5e0e-2c46-e900-5c5e-488f986f0578.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\77fe5e0e-2c46-e900-5c5e-488f986f0578.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\7338aef9-1da4-75f9-d06a-65ea557d371f.pdf
# Moved '7338aef9-1da4-75f9-d06a-65ea557d371f.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\7338aef9-1da4-75f9-d06a-65ea557d371f.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\29889bd1-48c5-2e67-a737-ca14e3fb0bfb.pdf
# Moved '29889bd1-48c5-2e67-a737-ca14e3fb0bfb.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\29889bd1-48c5-2e67-a737-ca14e3fb0bfb.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\e3c1a80e-8de2-cb24-3bfa-c230d36dcd4b.pdf
# Moved 'e3c1a80e-8de2-cb24-3bfa-c230d36dcd4b.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\e3c1a80e-8de2-cb24-3bfa-c230d36dcd4b.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\8b72c6d3-6247-b712-80d1-e5d5e0b2378c.pdf
# Moved '8b72c6d3-6247-b712-80d1-e5d5e0b2378c.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\8b72c6d3-6247-b712-80d1-e5d5e0b2378c.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\d9ca9230-0de6-2cae-8653-23612549482d.pdf
# Moved 'd9ca9230-0de6-2cae-8653-23612549482d.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\d9ca9230-0de6-2cae-8653-23612549482d.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\8a9f3d44-5fb8-e8f4-0021-5da369e5ccc5.pdf
# Moved '8a9f3d44-5fb8-e8f4-0021-5da369e5ccc5.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\8a9f3d44-5fb8-e8f4-0021-5da369e5ccc5.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\d3224f26-c5eb-7ece-818d-41eb46372e5d.pdf
# Moved 'd3224f26-c5eb-7ece-818d-41eb46372e5d.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\d3224f26-c5eb-7ece-818d-41eb46372e5d.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\693cbaaf-65ea-aaba-7a88-7e2cf542d1f6.pdf
# Moved '693cbaaf-65ea-aaba-7a88-7e2cf542d1f6.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\693cbaaf-65ea-aaba-7a88-7e2cf542d1f6.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\8776807d-713d-16d0-0dd2-197b8d7103b7.pdf
# Moved '8776807d-713d-16d0-0dd2-197b8d7103b7.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\8776807d-713d-16d0-0dd2-197b8d7103b7.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\89db0de7-7a89-7d9c-35b1-2ec79b2e605b.pdf
# Moved '89db0de7-7a89-7d9c-35b1-2ec79b2e605b.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\89db0de7-7a89-7d9c-35b1-2ec79b2e605b.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\b79075c8-cfdb-c7d5-3b53-dfb9a3b7fe7c.pdf
# Moved 'b79075c8-cfdb-c7d5-3b53-dfb9a3b7fe7c.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\b79075c8-cfdb-c7d5-3b53-dfb9a3b7fe7c.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\1d2f18dd-5cd4-b069-7351-0189af660a28.pdf
# Moved '1d2f18dd-5cd4-b069-7351-0189af660a28.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\1d2f18dd-5cd4-b069-7351-0189af660a28.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\ecabb490-734f-2114-92a5-bbdcc731cb83.pdf
# Moved 'ecabb490-734f-2114-92a5-bbdcc731cb83.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\ecabb490-734f-2114-92a5-bbdcc731cb83.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\3124657a-7cc8-463b-9a3d-4ce0ca0cac2d.pdf
# Moved '3124657a-7cc8-463b-9a3d-4ce0ca0cac2d.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\3124657a-7cc8-463b-9a3d-4ce0ca0cac2d.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\d560b564-03ac-b978-4575-e5acddca51d5.pdf
# Moved 'd560b564-03ac-b978-4575-e5acddca51d5.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\d560b564-03ac-b978-4575-e5acddca51d5_1.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\be84fa26-310b-0324-2b1a-7de788dcd87b.pdf
# Moved 'be84fa26-310b-0324-2b1a-7de788dcd87b.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\be84fa26-310b-0324-2b1a-7de788dcd87b_1.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\ff956bc2-43db-d19c-e956-99aa6b665502.pdf
# Moved 'ff956bc2-43db-d19c-e956-99aa6b665502.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\ff956bc2-43db-d19c-e956-99aa6b665502.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\307f1970-6359-4e46-160c-7c4e2ba6137c.pdf
# Moved '307f1970-6359-4e46-160c-7c4e2ba6137c.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\307f1970-6359-4e46-160c-7c4e2ba6137c.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\3cd9d181-ea3c-c160-8843-e4f61bbd7652.pdf
# Moved '3cd9d181-ea3c-c160-8843-e4f61bbd7652.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\3cd9d181-ea3c-c160-8843-e4f61bbd7652.pdf'
# Detected moved/renamed file: C:\Users\lawre/Downloads\8e018be0-a302-61d0-05d0-47015e83446f.pdf
# Moved '8e018be0-a302-61d0-05d0-47015e83446f.pdf' to 'C:\Users\lawre/OneDrive/Documents/Competitor_filings_monitor/Filings/Initial\2025-03-10\8e018be0-a302-61d0-05d0-47015e83446f.pdf'
# Stopping the PDF mover.

# %%
## Code to move and rename filings from the "initial" folder to the "final" folder ##

import os
import glob
import re
import shutil
import PyPDF2

def extract_fields_from_pdf(pdf_path):
    """
    Opens the PDF file and extracts key fields from the first page:
      - SERFF Tracking number (the first token after 'SERFF Tracking #:')
      - State (the text after "State:" until the newline, then mapped to its 2-letter abbreviation)
      - Filing Company (the text after "Filing Company:" until the newline)
    Returns a tuple: (serff, state, filing_company)
    """
    with open(pdf_path, "rb") as file:
        reader = PyPDF2.PdfReader(file)
        first_page_text = reader.pages[0].extract_text()

    # Define regular expressions to capture the values.
    serff_regex = r"SERFF Tracking #:\s*([^\n]+)"
    state_regex = r"State:\s*([^\n]+)"
    filing_company_regex = r"Filing Company:\s*([^\n]+)"

    serff_match = re.search(serff_regex, first_page_text)
    state_match = re.search(state_regex, first_page_text)
    filing_company_match = re.search(filing_company_regex, first_page_text)

    serff = serff_match.group(1).strip() if serff_match else None
    state = state_match.group(1).strip() if state_match else None
    filing_company = filing_company_match.group(1).strip() if filing_company_match else None

    # Clean up the SERFF value: take only the first token
    if serff:
        serff = serff.split()[0]

    # Update the mapping dictionary to explicitly include two-word states.
    state_mapping = {
        "Alabama": "AL",
        "Alaska": "AK",
        "Arizona": "AZ",
        "Arkansas": "AR",
        "California": "CA",
        "Colorado": "CO",
        "Connecticut": "CT",
        "Delaware": "DE",
        "Florida": "FL",
        "Georgia": "GA",
        "Hawaii": "HI",
        "Idaho": "ID",
        "Illinois": "IL",
        "Indiana": "IN",
        "Iowa": "IA",
        "Kansas": "KS",
        "Kentucky": "KY",
        "Louisiana": "LA",
        "Maine": "ME",
        "Maryland": "MD",
        "Massachusetts": "MA",
        "Michigan": "MI",
        "Minnesota": "MN",
        "Mississippi": "MS",
        "Missouri": "MO",
        "Montana": "MT",
        "Nebraska": "NE",
        "Nevada": "NV",
        "New Hampshire": "NH",
        "New Jersey": "NJ",
        "New Mexico": "NM",
        "New York": "NY",
        "North Carolina": "NC",
        "North Dakota": "ND",
        "Ohio": "OH",
        "Oklahoma": "OK",
        "Oregon": "OR",
        "Pennsylvania": "PA",
        "Rhode Island": "RI",
        "South Carolina": "SC",
        "South Dakota": "SD",
        "Tennessee": "TN",
        "Texas": "TX",
        "Utah": "UT",
        "Vermont": "VT",
        "Virginia": "VA",
        "Washington": "WA",
        "West Virginia": "WV",
        "Wisconsin": "WI",
        "Wyoming": "WY"
    }
    
    # Process the state string: if it begins with a known two-word state, use both words.
    if state:
        tokens = state.split()
        if len(tokens) >= 2:
            candidate = " ".join(tokens[:2])
            two_word_states = {"New York", "New Jersey", "New Hampshire", "New Mexico",
                               "South Carolina",  "South Dakota" ,"North Carolina", "North Dakota", "Rhode Island", "West Virginia"}
            if candidate in two_word_states:
                state_full = candidate
            else:
                state_full = tokens[0]
        else:
            state_full = state.strip()
        state = state_mapping.get(state_full, state_full)

    return serff, state, filing_company

def process_filings_for_week(week_date):
    """
    Given a week_date string (e.g., '2025-02-03'), this function:
      1. Sets the source folder as './Filings/Initial/<week_date>'
      2. Creates a destination folder './Filings/Final/<week_date>' if it doesn't exist.
      3. Loops through each PDF file in the source folder, ordered descending by modification time.
      4. For each PDF, extracts the SERFF Tracking number and State.
      5. Copies the file to the destination folder, renaming it to "State_SERFF#.pdf".
         (If a file for that SERFF already exists, it is replaced with the new one.)
    """
    # Define folder paths
    initial_folder = os.path.join("Filings", "Initial", week_date)
    final_folder = os.path.join("Filings", "Final", week_date)

    # Create the destination folder if it doesn't exist
    os.makedirs(final_folder, exist_ok=True)

    # Get a list of all PDF files in the initial folder
    pdf_files = glob.glob(os.path.join(initial_folder, "*.pdf"))
    
    # Sort the list in descending order by modified time
    pdf_files.sort(key=lambda f: os.path.getmtime(f), reverse=True)

    for pdf_file in pdf_files:
        serff, state, filing_company = extract_fields_from_pdf(pdf_file)
        if serff is None:
            print(f"Warning: Could not extract SERFF Tracking number from {pdf_file}. Skipping.")
            continue

        # Create the new filename as "State_SERFF#.pdf". If state isn't available, use only SERFF.
        if state:
            new_filename = f"{state}_{serff}.pdf"
        else:
            new_filename = f"{serff}.pdf"

        dest_file = os.path.join(final_folder, new_filename)
        if os.path.exists(dest_file):
            print(f"Replacing duplicate SERFF {serff} in {pdf_file}")
        else:
            print(f"Copying {pdf_file} to {dest_file}")

        # Copy the file to the destination (this overwrites if the file exists)
        shutil.copy2(pdf_file, dest_file)

# Example usage:
# process_filings_for_week("2025-02-03")

# %%
process_filings_for_week("2025-03-10")
# Out:
# Copying Filings\Initial\2025-03-10\8e018be0-a302-61d0-05d0-47015e83446f.pdf to Filings\Final\2025-03-10\MI_ALSE-134443416.pdf
# Copying Filings\Initial\2025-03-10\3cd9d181-ea3c-c160-8843-e4f61bbd7652.pdf to Filings\Final\2025-03-10\NE_GMMX-134443628.pdf
# Copying Filings\Initial\2025-03-10\307f1970-6359-4e46-160c-7c4e2ba6137c.pdf to Filings\Final\2025-03-10\MI_ALSE-134445641.pdf
# Copying Filings\Initial\2025-03-10\ff956bc2-43db-d19c-e956-99aa6b665502.pdf to Filings\Final\2025-03-10\NJ_AMSI-134443262.pdf
# Copying Filings\Initial\2025-03-10\be84fa26-310b-0324-2b1a-7de788dcd87b_1.pdf to Filings\Final\2025-03-10\AZ_TRVD-G134444542.pdf
# Copying Filings\Initial\2025-03-10\d560b564-03ac-b978-4575-e5acddca51d5_1.pdf to Filings\Final\2025-03-10\AZ_TRVD-G134444680.pdf
# Copying Filings\Initial\2025-03-10\3124657a-7cc8-463b-9a3d-4ce0ca0cac2d.pdf to Filings\Final\2025-03-10\WI_AMSI-133860671.pdf
# Copying Filings\Initial\2025-03-10\ecabb490-734f-2114-92a5-bbdcc731cb83.pdf to Filings\Final\2025-03-10\WA_LBPM-134447017.pdf
# Copying Filings\Initial\2025-03-10\1d2f18dd-5cd4-b069-7351-0189af660a28.pdf to Filings\Final\2025-03-10\OR_AMSI-134435230.pdf
# Copying Filings\Initial\2025-03-10\b79075c8-cfdb-c7d5-3b53-dfb9a3b7fe7c.pdf to Filings\Final\2025-03-10\OR_AMSI-134435390.pdf
# Copying Filings\Initial\2025-03-10\89db0de7-7a89-7d9c-35b1-2ec79b2e605b.pdf to Filings\Final\2025-03-10\VA_LEMO-134441439.pdf
# Copying Filings\Initial\2025-03-10\8776807d-713d-16d0-0dd2-197b8d7103b7.pdf to Filings\Final\2025-03-10\TX_USAA-134443396.pdf
# Copying Filings\Initial\2025-03-10\693cbaaf-65ea-aaba-7a88-7e2cf542d1f6.pdf to Filings\Final\2025-03-10\TX_SFMA-134447409.pdf
# Copying Filings\Initial\2025-03-10\d3224f26-c5eb-7ece-818d-41eb46372e5d.pdf to Filings\Final\2025-03-10\OR_HART-134431622.pdf
# Copying Filings\Initial\2025-03-10\8a9f3d44-5fb8-e8f4-0021-5da369e5ccc5.pdf to Filings\Final\2025-03-10\MI_HART-134433875.pdf
# Copying Filings\Initial\2025-03-10\d9ca9230-0de6-2cae-8653-23612549482d.pdf to Filings\Final\2025-03-10\MI_TRVD-G134446450.pdf
# Copying Filings\Initial\2025-03-10\8b72c6d3-6247-b712-80d1-e5d5e0b2378c.pdf to Filings\Final\2025-03-10\MI_HART-134433892.pdf
# Copying Filings\Initial\2025-03-10\e3c1a80e-8de2-cb24-3bfa-c230d36dcd4b.pdf to Filings\Final\2025-03-10\GA_LBPM-134447081.pdf
# Copying Filings\Initial\2025-03-10\29889bd1-48c5-2e67-a737-ca14e3fb0bfb.pdf to Filings\Final\2025-03-10\GA_LBPM-134447335.pdf
# Copying Filings\Initial\2025-03-10\7338aef9-1da4-75f9-d06a-65ea557d371f.pdf to Filings\Final\2025-03-10\NC_ALSE-134449660.pdf
# Copying Filings\Initial\2025-03-10\77fe5e0e-2c46-e900-5c5e-488f986f0578.pdf to Filings\Final\2025-03-10\TX_USAA-134443395.pdf
# Copying Filings\Initial\2025-03-10\d3b39657-3d42-9705-741a-966b38069cf4.pdf to Filings\Final\2025-03-10\KS_TRVD-G134448245.pdf
# Copying Filings\Initial\2025-03-10\88c9922f-1dd3-e00a-df3b-3c2d091c6923.pdf to Filings\Final\2025-03-10\GA_LBPM-134449473.pdf
# Copying Filings\Initial\2025-03-10\d994c86a-64e3-391b-c9e1-19f6f6e92a7f.pdf to Filings\Final\2025-03-10\KS_SFMA-134449763.pdf
# Copying Filings\Initial\2025-03-10\259ad822-baf4-85b9-40c6-500c48e25682.pdf to Filings\Final\2025-03-10\ID_LBPM-134449496.pdf
# Copying Filings\Initial\2025-03-10\ebb5648d-d2d5-1452-0047-9ab88a9e4e4f.pdf to Filings\Final\2025-03-10\MO_USAA-134449959.pdf
# Copying Filings\Initial\2025-03-10\143ca8a5-5dbe-90e0-ac6e-e736904ec7ba.pdf to Filings\Final\2025-03-10\MI_AMSI-134336870.pdf
# Copying Filings\Initial\2025-03-10\dafbb73c-4c86-68e4-7294-f83e45ffcf55.pdf to Filings\Final\2025-03-10\TN_ALSE-134450014.pdf
# Copying Filings\Initial\2025-03-10\f2f9d6b0-2acf-e535-ae45-824d5c26eac8.pdf to Filings\Final\2025-03-10\CO_GMMX-134450913.pdf
# Copying Filings\Initial\2025-03-10\88b19c9d-40a2-c4bb-1c48-9227ef616cea.pdf to Filings\Final\2025-03-10\WV_AMSI-134244221.pdf
# Copying Filings\Initial\2025-03-10\8c889205-eb5d-2092-dd42-b6372d65c42e.pdf to Filings\Final\2025-03-10\GA_ALSE-134337450.pdf
# Copying Filings\Initial\2025-03-10\9a73bb2c-e699-1da3-f64a-96997b82d357.pdf to Filings\Final\2025-03-10\CA_LBRM-134354159.pdf
# Copying Filings\Initial\2025-03-10\2e8cda90-33b1-c126-5802-7a1ceb3533e0.pdf to Filings\Final\2025-03-10\CA_LBRM-134354250.pdf
# Copying Filings\Initial\2025-03-10\bba900fa-ad55-03ce-fdff-7fbd1d12f2f6.pdf to Filings\Final\2025-03-10\GA_TRVD-G134360540.pdf
# Copying Filings\Initial\2025-03-10\9b6660c4-7b7a-d099-84cd-bce359e49936.pdf to Filings\Final\2025-03-10\NJ_LBPM-134367579.pdf
# Copying Filings\Initial\2025-03-10\fe771b0f-9683-fa1e-1da1-628df321d624.pdf to Filings\Final\2025-03-10\VA_AMSI-134375543.pdf
# Copying Filings\Initial\2025-03-10\5b78fea6-88f4-f20d-84ae-3242fd0276e8.pdf to Filings\Final\2025-03-10\NV_HART-134384733.pdf
# Copying Filings\Initial\2025-03-10\6cd83549-7a7c-13cd-a372-d9bbd2ab2df0.pdf to Filings\Final\2025-03-10\District_TRVD-G134382695.pdf
# Copying Filings\Initial\2025-03-10\9125c9b3-2c02-4b2e-fd31-4aa50fe193bc.pdf to Filings\Final\2025-03-10\District_TRVD-G134382657.pdf
# Copying Filings\Initial\2025-03-10\92da494c-7ebd-1878-adf3-b4a9757f8685.pdf to Filings\Final\2025-03-10\District_TRVD-G134382426.pdf
# Copying Filings\Initial\2025-03-10\588d5f58-fa9a-b991-d34a-215cb648346d.pdf to Filings\Final\2025-03-10\OR_LEMO-134373821.pdf
# Copying Filings\Initial\2025-03-10\0bdba24d-8166-0be1-0772-25df9851da08.pdf to Filings\Final\2025-03-10\NJ_LEMO-134389427.pdf
# Copying Filings\Initial\2025-03-10\9efe2b3e-a558-37d9-d932-36a2c9d65ef1.pdf to Filings\Final\2025-03-10\WI_LEMO-134385206.pdf
# Copying Filings\Initial\2025-03-10\79feef43-86db-6351-4c98-46f0d4da2fd2.pdf to Filings\Final\2025-03-10\SC_LBPM-134400516.pdf
# Copying Filings\Initial\2025-03-10\df57d2dd-8aef-b8c5-383a-0806940a6372.pdf to Filings\Final\2025-03-10\OK_AMSI-134369860.pdf
# Copying Filings\Initial\2025-03-10\15765a1f-5287-9a1a-cb93-cb83dbfa21f0.pdf to Filings\Final\2025-03-10\WI_LBPM-134430805.pdf
# Copying Filings\Initial\2025-03-10\23ca3985-9cdf-4777-0128-b593fc6e067b.pdf to Filings\Final\2025-03-10\GA_TRVD-G134400530.pdf
# Copying Filings\Initial\2025-03-10\bb6abfc8-b56c-8482-b84e-1058506aee2e.pdf to Filings\Final\2025-03-10\SC_LBPM-134401992.pdf
# Copying Filings\Initial\2025-03-10\7d22c6ce-9aac-1e09-7c00-e0dc40b6cdc1.pdf to Filings\Final\2025-03-10\SC_LBPM-134406290.pdf
# Copying Filings\Initial\2025-03-10\d086413b-faaa-c9b7-f6c0-87321057e951.pdf to Filings\Final\2025-03-10\ND_GMMX-134414199.pdf
# Copying Filings\Initial\2025-03-10\185df4bf-960a-d141-7092-74775ba1d27e.pdf to Filings\Final\2025-03-10\ND_GMMX-134414147.pdf
# Copying Filings\Initial\2025-03-10\b5cc5558-8b9f-eaff-c28c-c07dc17802fd.pdf to Filings\Final\2025-03-10\ND_GMMX-134414190.pdf
# Copying Filings\Initial\2025-03-10\d27579d0-5910-e37e-1b2a-b323f34ebb0e.pdf to Filings\Final\2025-03-10\IL_SFMA-134413708.pdf
# Copying Filings\Initial\2025-03-10\53f087fc-b3c6-87b5-7217-78cf9ec74126.pdf to Filings\Final\2025-03-10\GA_HART-134414600.pdf
# Copying Filings\Initial\2025-03-10\98abd2ec-51fa-feba-3f1f-fc2d1dfd80ce.pdf to Filings\Final\2025-03-10\NC_USAA-134418343.pdf
# Copying Filings\Initial\2025-03-10\dbe18072-9c64-1397-ad9d-5c0ea2609285.pdf to Filings\Final\2025-03-10\NC_USAA-134418355.pdf
# Copying Filings\Initial\2025-03-10\8e9d5457-23f1-fb78-e5dc-6476573f2f29.pdf to Filings\Final\2025-03-10\NC_USAA-134418345.pdf
# Copying Filings\Initial\2025-03-10\30bb0f08-cb5d-2f22-749d-488075f03ee8.pdf to Filings\Final\2025-03-10\NC_USAA-134418351.pdf
# Copying Filings\Initial\2025-03-10\47336af4-4ba9-3b15-623c-ed6d5eb76265.pdf to Filings\Final\2025-03-10\CO_LBPM-134412448.pdf
# Copying Filings\Initial\2025-03-10\a6743b6c-87f0-2923-4705-d0a2d414ae3f.pdf to Filings\Final\2025-03-10\TX_SFMA-134410201.pdf
# Copying Filings\Initial\2025-03-10\c60f05c5-9a59-c401-05d5-6898c541f2f9.pdf to Filings\Final\2025-03-10\TX_SFMA-134410218.pdf
# Warning: Could not extract SERFF Tracking number from Filings\Initial\2025-03-10\8c308d30-c118-5681-fdef-1fc098969beb.pdf. Skipping.
# Warning: Could not extract SERFF Tracking number from Filings\Initial\2025-03-10\b59592ad-b696-eafc-96aa-5465c8645b3b.pdf. Skipping.
# Copying Filings\Initial\2025-03-10\68dd0cb4-4336-a5c1-0d3d-00f5eed2aa56.pdf to Filings\Final\2025-03-10\MI_ALSE-134422885.pdf
# Copying Filings\Initial\2025-03-10\2736944e-afd5-3c6d-d29b-337a28df18e3.pdf to Filings\Final\2025-03-10\ME_TRVD-G134422686.pdf
# Copying Filings\Initial\2025-03-10\d20831c8-570f-f3d6-a9fe-0d5db24ee5cb.pdf to Filings\Final\2025-03-10\GA_SFMA-134413084.pdf
# Copying Filings\Initial\2025-03-10\dddc74b5-c70c-05b5-1f30-7fd53c3917b5.pdf to Filings\Final\2025-03-10\TX_HART-134398746.pdf
# Copying Filings\Initial\2025-03-10\a0076393-e31f-aba6-9719-9d67526aeeb8.pdf to Filings\Final\2025-03-10\TX_HART-134407174.pdf
# Copying Filings\Initial\2025-03-10\72d6bef0-46a4-01ff-5616-dc6bd925b48a.pdf to Filings\Final\2025-03-10\MN_SFMA-134414598.pdf
# Copying Filings\Initial\2025-03-10\8cb7917f-e668-8aec-8f84-42235d99d358.pdf to Filings\Final\2025-03-10\WI_SFMA-134421547.pdf
# Copying Filings\Initial\2025-03-10\e2f2c319-f382-1d1a-4fc3-9123441582d8.pdf to Filings\Final\2025-03-10\TX_HART-134405817.pdf
# Copying Filings\Initial\2025-03-10\1e14b3e0-3e25-71bd-c8dd-f2eec59ff5a9.pdf to Filings\Final\2025-03-10\TX_HART-134429816.pdf
# Copying Filings\Initial\2025-03-10\f47fe5b7-f4cf-1a8c-da4a-db7b6fef6529.pdf to Filings\Final\2025-03-10\AZ_HART-134440906.pdf
# Copying Filings\Initial\2025-03-10\dfe429f3-2520-ce52-9cab-764e99cab641.pdf to Filings\Final\2025-03-10\PA_LEMO-134412814.pdf
# Copying Filings\Initial\2025-03-10\2496e036-66a6-15c0-510e-9c4729590643.pdf to Filings\Final\2025-03-10\KS_GMMX-134433936.pdf
# Copying Filings\Initial\2025-03-10\f5d032d1-3164-2470-9352-2955395e6857.pdf to Filings\Final\2025-03-10\AZ_HART-134440946.pdf
# Copying Filings\Initial\2025-03-10\bc06ef03-f601-22bd-3813-12d98f89c069.pdf to Filings\Final\2025-03-10\IL_ALSE-134437284.pdf
# Copying Filings\Initial\2025-03-10\e978ce50-6be9-8e09-1b40-14aa76bdf035.pdf to Filings\Final\2025-03-10\MI_LBPM-134437577.pdf
# Replacing duplicate SERFF TRVD-G134444542 in Filings\Initial\2025-03-10\be84fa26-310b-0324-2b1a-7de788dcd87b.pdf
# Replacing duplicate SERFF TRVD-G134444680 in Filings\Initial\2025-03-10\d560b564-03ac-b978-4575-e5acddca51d5.pdf

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\lawre\\OneDrive\\Documents\\Competitor_filings_monitor'
