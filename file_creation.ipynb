# %%
###2.21: added parameters to avoid calling the API###

import os
import re
import glob
import fitz  # PyMuPDF
import json
import pandas as pd
from datetime import datetime
from pprint import pprint
from dotenv import load_dotenv
import tiktoken  # pip install tiktoken

# Load environment variables (which should include api_key and grok_api_key)
load_dotenv()

# === API Call Control Parameters ===
# Set each to 'Y' to call the API, or 'N' to skip the API call.
CALL_GPT_3_5 = "Y"
CALL_O1_MINI = "N"
CALL_XAI = "N"

# Create OpenAI client for standard models
from openai import OpenAI
api_key = os.getenv("api_key")
client = OpenAI(api_key=api_key)

# Create a separate client for the xAI API
XAI_API_KEY = os.getenv("grok_api_key")
xai_client = OpenAI(api_key=XAI_API_KEY, base_url="https://api.x.ai/v1")

# Define the download week as a string and convert it to a datetime object.
date = "2025-02-24"
download_week_dt = datetime.strptime(date, "%Y-%m-%d")

# --- Helper functions for token counting and truncation using tiktoken ---

def count_tokens(text, model="gpt-3.5-turbo"):
    """
    Returns the number of tokens in the given text using tiktoken.
    """
    try:
        encoding = tiktoken.encoding_for_model(model)
    except Exception:
        encoding = tiktoken.get_encoding("cl100k_base")
    tokens = encoding.encode(text)
    return len(tokens)

def truncate_text(text, max_tokens, model="gpt-3.5-turbo"):
    """
    Truncates `text` to at most `max_tokens` using tiktoken encoding.
    """
    try:
        encoding = tiktoken.encoding_for_model(model)
    except Exception:
        encoding = tiktoken.get_encoding("cl100k_base")
    tokens = encoding.encode(text)
    if len(tokens) > max_tokens:
        truncated_tokens = tokens[:max_tokens]
        truncated_text = encoding.decode(truncated_tokens)
        return truncated_text
    return text

# --- API call functions ---

def call_gpt_3_5_turbo(full_text):
    try:
        completion = client.chat.completions.create(
            model="gpt-3.5-turbo",
            messages=[
                {"role": "system", "content": "You are an analyst doing competitive intelligence research on insurance companies."},
                {"role": "user", "content": f"The following is a filing with a DOI from an insurance company: '{full_text}'. Give a summary of the rate filing."}
            ],
            max_tokens=300
        )
        print("GPT-3.5 Summary:", completion.choices[0].message.content)
        return completion.choices[0].message.content
    except Exception as e:
        print(f"Error calling GPT-3.5-turbo: {e}")
        return ""

def call_o1_mini(full_text):
    try:
        completion = client.chat.completions.create(
            model="o1-mini",
            messages=[
                {"role": "user", "content": "You are an analyst doing competitive intelligence research on insurance companies."},
                {"role": "user", "content": f"The following is a filing with a DOI from an insurance company: '{full_text}'. Give a summary of the rate filing."}
            ]
        )
        print("o1-mini Summary:", completion.choices[0].message.content)
        return completion.choices[0].message.content
    except Exception as e:
        print(f"Error calling o1-mini: {e}")
        return ""

def call_xai(full_text):
    try:
        completion = xai_client.chat.completions.create(
            model="grok-2-latest",
            messages=[
                {"role": "system", "content": "You are an analyst doing competitive intelligence research on insurance companies."},
                {"role": "user", "content": f"The following is a filing with a DOI from an insurance company: '{full_text}'. Give a summary of the rate filing."}
            ]
        )
        print("xAI Summary:", completion.choices[0].message.content)
        return completion.choices[0].message.content
    except Exception as e:
        print(f"Error calling xAI: {e}")
        return ""

# --- Extraction functions for non-API parts ---

def extract_full_text(pdf_path, max_pages=None):
    """
    Extracts full text from PDF.
    If max_pages is provided, only extracts from the first max_pages pages.
    """
    doc = fitz.open(pdf_path)
    full_text = ""
    for i, page in enumerate(doc):
        if max_pages is not None and i >= max_pages:
            break
        full_text += page.get_text() + "\n"
    doc.close()
    return full_text

def split_list_objections(text):
    parts = re.split(r"(?m)^\s*(?:\(?(\d+)\)?[.\)])\s*", text)
    objections = {}
    if len(parts) >= 3:
        for i in range(1, len(parts)-1, 2):
            num = parts[i].strip()
            obj_text = parts[i+1].strip()
            objections[f"objection{num}"] = obj_text
        if not objections:
            objections["objection1"] = text.strip()
    else:
        objections["objection1"] = text.strip()
    return objections

def parse_objection_letters(text):
    pattern = r"(Objection Letter.*?Objection Letter Date\s+(\d{2}/\d{2}/\d{4}).*?Introduction:\s*(.*?)\s*Conclusion:)"
    matches = list(re.finditer(pattern, text, flags=re.IGNORECASE | re.DOTALL))
    letter_dict = {}
    for idx, m in enumerate(matches, start=1):
        letter_date = m.group(2).strip()
        body = m.group(3).strip()
        explicit_objs = list(re.finditer(r"Objection\s+(\d+)", body, flags=re.IGNORECASE))
        if len(explicit_objs) > 1:
            obj_pattern = r"(Objection\s+(\d+).*?)(?=(Objection\s+\d+|Conclusion:|$))"
            objections = {}
            for om in re.finditer(obj_pattern, body, flags=re.IGNORECASE | re.DOTALL):
                num = om.group(2).strip()
                obj_text = om.group(1).strip()
                objections[f"objection{num}"] = obj_text
        else:
            if re.search(r"(?m)^\s*(\(?\d+\)?[.\)])", body):
                objections = split_list_objections(body)
            else:
                objections = {"objection1": body}
        letter_dict[f"Objection_letter{idx}"] = {
            "objection_letter_date": letter_date,
            **objections
        }
    return letter_dict

def extract_filing_company_info(text):
    company_codes = re.findall(r"CoCode:\s*(\d+)", text, flags=re.IGNORECASE)
    group_codes = re.findall(r"Group Code:\s*(\d+)", text, flags=re.IGNORECASE)
    company_codes = [int(code) for code in company_codes] if company_codes else []
    group_code = int(group_codes[0]) if group_codes else None
    return group_code, company_codes

# --- Extraction functions for additional filing info ---

def parse_filing_at_a_glance(text):
    info = {}
    match = re.search(r"Filing at a Glance(.*?)(?=\n[A-Z][a-z]+ Information|$)", text, flags=re.IGNORECASE | re.DOTALL)
    section = match.group(1) if match else ""
    
    serff_match = re.search(r"SERFF Tr Num:\s*([A-Z0-9\-]+)", section, flags=re.IGNORECASE)
    info["serff_tr_num"] = serff_match.group(1).strip() if serff_match else ""
    
    filing_type_match = re.search(r"Filing Type:\s*([^\n]+)", section, flags=re.IGNORECASE)
    info["filing_type"] = filing_type_match.group(1).strip() if filing_type_match else ""
    
    date_submitted_match = re.search(r"Date Submitted:\s*(\d{2}/\d{2}/\d{4})", section, flags=re.IGNORECASE)
    info["date_submitted"] = date_submitted_match.group(1).strip() if date_submitted_match else ""
    
    effective_new_match = re.search(r"Effective Date\s*Requested\s*\(New\):\s*(\d{2}/\d{2}/\d{4})", section, flags=re.IGNORECASE)
    info["effective_date_requested_new"] = effective_new_match.group(1).strip() if effective_new_match else ""
    
    effective_renewal_match = re.search(r"Effective Date\s*Requested\s*\(Renewal\):\s*(\d{2}/\d{2}/\d{4})", section, flags=re.IGNORECASE)
    info["effective_date_requested_renewal"] = effective_renewal_match.group(1).strip() if effective_renewal_match else ""
    
    serff_status_match = re.search(r"SERFF Status:\s*([^\n]+)", section, flags=re.IGNORECASE)
    info["serff_status"] = serff_status_match.group(1).strip() if serff_status_match else ""
    
    toi_match = re.search(r"TOI:\s*([^\n]+)", section, flags=re.IGNORECASE)
    info["toi"] = toi_match.group(1).strip() if toi_match else ""
    
    return info

def parse_filing_description(text):
    match = re.search(r"Filing Description:\s*(.*?)\s*(Filing Contact Information|Filing Company Information)", 
                      text, flags=re.IGNORECASE | re.DOTALL)
    if match:
        return match.group(1).strip()
    return ""

# --- API Call Functions (as defined above) ---
# (call_gpt_3_5_turbo, call_o1_mini, call_xai already defined above)

# --- Processing functions for additional filing info ---

def extract_full_text_all(pdf_path):
    """
    Extracts full text from the PDF using up to the first 3000 pages.
    This prevents the code from getting stuck on extremely large PDFs.
    """
    return extract_full_text(pdf_path, max_pages=3000)

def process_pdf_additional(pdf_path):
    """
    Processes a single PDF file and extracts additional filing info.
    For non-API extraction, only the first 100 pages are used.
    For API calls, the full text (subject to token constraints) is used.
    Returns a dictionary with keys:
      serff_tr_num, filing_type, date_submitted, effective_date_requested_new,
      effective_date_requested_renewal, serff_status, filing_description, filing_method,
      toi, group_code, company_codes, download_week, gpt_3_5_summary, o1_mini_summary, xai_summary.
    """
    # Use first 100 pages for non-API info
    limited_text = extract_full_text(pdf_path, max_pages=100)
    filing_at_a_glance = parse_filing_at_a_glance(limited_text)
    filing_description = parse_filing_description(limited_text)
    group_code, company_codes = extract_filing_company_info(limited_text)
    
    # For API calls, use the full text from up to 3000 pages.
    full_text_all = extract_full_text_all(pdf_path)
    token_count = count_tokens(full_text_all, model="gpt-3.5-turbo")
    print(f"Token count for API call in {os.path.basename(pdf_path)}: {token_count}")
    
    # Determine the API text and whether to call GPT-3.5-turbo:
    if token_count < 16385:
        api_text = full_text_all
        gpt_3_5_summary = call_gpt_3_5_turbo(full_text_all) if CALL_GPT_3_5 == "Y" else ""
    elif token_count < 75000:
        api_text = full_text_all
        gpt_3_5_summary = ""  # Do not call GPT-3.5-turbo if tokens > 16385
    else:
        api_text = truncate_text(full_text_all, max_tokens=75000, model="gpt-3.5-turbo")
        gpt_3_5_summary = ""  # Do not call GPT-3.5-turbo
    
    o1_mini_summary = call_o1_mini(api_text) if CALL_O1_MINI == "Y" else ""
    xai_summary = call_xai(api_text) if CALL_XAI == "Y" else ""
    
    additional = {
        "serff_tr_num": filing_at_a_glance.get("serff_tr_num", ""),
        "filing_type": filing_at_a_glance.get("filing_type", ""),
        "date_submitted": filing_at_a_glance.get("date_submitted", ""),
        "effective_date_requested_new": filing_at_a_glance.get("effective_date_requested_new", ""),
        "effective_date_requested_renewal": filing_at_a_glance.get("effective_date_requested_renewal", ""),
        "serff_status": filing_at_a_glance.get("serff_status", ""),
        "filing_description": filing_description,
        "filing_method": "",  # Not extracted in this version.
        "toi": filing_at_a_glance.get("toi", ""),
        "group_code": group_code,
        "company_codes": company_codes,
        "download_week": download_week_dt,
        "gpt_3_5_summary": gpt_3_5_summary,
        "o1_mini_summary": o1_mini_summary,
        "xai_summary": xai_summary
    }
    print(f"Processed additional filing info for: {os.path.basename(pdf_path)}")
    return additional

def process_all_pdfs_additional(pdf_folder):
    results = {}
    pdf_files = glob.glob(os.path.join(pdf_folder, "*.pdf"))
    for pdf_file in pdf_files:
        file_key = os.path.splitext(os.path.basename(pdf_file))[0]
        results[file_key] = process_pdf_additional(pdf_file)
    return results

def additional_to_dataframe(results):
    rows = []
    for file_key, info in results.items():
        row = {
            "SERFF Tr Num": info.get("serff_tr_num", ""),
            "Filing Type": info.get("filing_type", ""),
            "Date Submitted": info.get("date_submitted", ""),
            "Effective Date Requested (New)": info.get("effective_date_requested_new", ""),
            "Effective Date Requested (Renewal)": info.get("effective_date_requested_renewal", ""),
            "SERFF Status": info.get("serff_status", ""),
            "Filing Description": info.get("filing_description", ""),
            "Filing Method": info.get("filing_method", ""),
            "TOI": info.get("toi", ""),
            "Group_Code": info.get("group_code", ""),
            "Company_Codes": str(info.get("company_codes", "")),
            "week_date": info.get("download_week", None),
            "gpt_3_5_summary": info.get("gpt_3_5_summary", ""),
            "o1_mini_summary": info.get("o1_mini_summary", ""),
            "xai_summary": info.get("xai_summary", "")
        }
        rows.append(row)
    df = pd.DataFrame(rows, columns=[
        "SERFF Tr Num", "Filing Type", "Date Submitted", 
        "Effective Date Requested (New)", "Effective Date Requested (Renewal)",
        "SERFF Status", "Filing Description", "Filing Method", "TOI",
        "Group_Code", "Company_Codes", "week_date",
        "gpt_3_5_summary", "o1_mini_summary", "xai_summary"
    ])
    return df

# --- DataFrame for objections (unchanged from before) ---
def results_to_dataframe_objections(results):
    rows = []
    for file_key, file_info in results.items():
        filing_type = file_info.get("filing_type", "")
        date_submitted = file_info.get("date_submitted", "")
        serff_status = file_info.get("serff_status", "")
        state_abbr = file_key.split('_')[0] if "_" in file_key else file_key[:2]
        group_code = file_info.get("group_code", "No objections")
        company_codes = file_info.get("company_codes", [])
        company_code_first = company_codes[0] if company_codes else "No objections"
        company_codes_str = str(company_codes) if company_codes else "No objections"
        download_week = file_info.get("download_week", None)
        letter_dict = file_info.get("objections", {})
        if not letter_dict:
            rows.append({
                "SERFF#": file_key,
                "Filing Type": filing_type,
                "Date Submitted": date_submitted,
                "SERFF Status": serff_status,
                "State": state_abbr,
                "Group_Code": group_code,
                "Company_Code": company_code_first,
                "Company_Code_all": company_codes_str,
                "Objection_letter_date": "No objections",
                "Objectionletter#": "No objections",
                "Objection#": "No objections",
                "Objection": "No objections",
                "download_week": download_week
            })
        else:
            for letter_key, letter_content in letter_dict.items():
                letter_date = letter_content.get("objection_letter_date", "No objections")
                for obj_key, obj_text in letter_content.items():
                    if obj_key == "objection_letter_date":
                        continue
                    rows.append({
                        "SERFF#": file_key,
                        "Filing Type": filing_type,
                        "Date Submitted": date_submitted,
                        "SERFF Status": serff_status,
                        "State": state_abbr,
                        "Group_Code": group_code,
                        "Company_Code": company_code_first,
                        "Company_Code_all": company_codes_str,
                        "Objection_letter_date": letter_date,
                        "Objectionletter#": letter_key,
                        "Objection#": obj_key,
                        "Objection": obj_text.replace("\n", " ").strip(),
                        "download_week": download_week
                    })
    df = pd.DataFrame(rows, columns=[
        "SERFF#", "Filing Type", "Date Submitted", "SERFF Status", "State",
        "Group_Code", "Company_Code", "Company_Code_all", "Objection_letter_date",
        "Objectionletter#", "Objection#", "Objection", "download_week"
    ])
    return df

# --- Main Processing ---

pdf_folder = f"Filings/Final/{date}"  # Folder path based on date parameter

# Process objections
objection_results = process_all_pdfs_additional(pdf_folder)
json_output_path = f"objections_output_{date}.json"
with open(json_output_path, "w", encoding="utf-8") as f:
    json.dump(objection_results, f, default=lambda o: o.isoformat() if isinstance(o, datetime) else o, ensure_ascii=False, indent=4)
print(f"Saved objections JSON output to {json_output_path}")

df_objections = results_to_dataframe_objections(objection_results)
csv_output_path = f"objections_output_{date}.csv"
df_objections.to_csv(csv_output_path, index=False)
print(f"Saved objections CSV output to {csv_output_path}")

# Process additional filing info.
additional_results = process_all_pdfs_additional(pdf_folder)
additional_json_output_path = f"additional_filing_info_{date}.json"
with open(additional_json_output_path, "w", encoding="utf-8") as f:
    json.dump(additional_results, f, default=lambda o: o.isoformat() if isinstance(o, datetime) else o, ensure_ascii=False, indent=4)
print(f"Saved additional filing info JSON output to {additional_json_output_path}")

df_additional = additional_to_dataframe(additional_results)
additional_csv_output_path = f"additional_filing_info_{date}.csv"
df_additional.to_csv(additional_csv_output_path, index=False)
print(f"Saved additional filing info CSV output to {additional_csv_output_path}")
# Out:
# Token count for API call in AR_LBPM-134402349.pdf: 6626
# GPT-3.5 Summary: The rate filing submitted by American Economy Insurance Company for their Homeowners product in Arkansas includes a decrease in overall rates of 1.1%. The filing was submitted on 02/11/2025 and the effective date requested for the new rates is 03/06/2025.
#
# The filing involves proposed revisions to their Homeowners program, specifically related to the Home Rating Manual and the Home Tiering Manual. The proposed changes include introducing a Multi-Policy Discount and a Peril Offset.
#
# The filing was reviewed by Robert Lively and Matthew Rowland, with Becky Harrington being the primary reviewer. The disposition date was on 02/18/2025, and the filing was marked as Filed on that date. The SERFF Status is Closed-Filed. The company tracking number for this filing is 25-AR-S-HO-R-HMR 2.5-ASR.
#
# The filing required a fee of $100.00, and it was processed on 02/11/2025. The objection letter was submitted on 02/12/2025, and the response letter was submitted on 02/14/2025.
#
# Overall, the rate filing indicates a decrease in rates with a minimal impact on the company's written premiums and policyholders affected. The filing includes various supporting documents such as the Homeowners Abstract, NAIC Loss Cost Data Entry Document, P&C Actuarial Justification, and Mock document.
#
# The rate change history shows a 29.
# Processed additional filing info for: AR_LBPM-134402349.pdf
# Token count for API call in AR_LBPM-134415366.pdf: 11129
# GPT-3.5 Summary: Based on the filing documents provided, the rate filing for the Homeowners insurance program by Liberty Mutual Group includes various endorsements such as Homeprotector Plus, Optional Loss Settlement, Excess Dwelling Coverage, and Expanded Replacement Cost. The filings focus on changes to coverage limits, loss settlement provisions, replacement cost provisions for dwelling and personal property, increased limits for coverage D, and additional coverages such as refrigerators and freezers contents coverage and lock replacement coverage.
#
# The filings also detail the conditions for the endorsements to apply, including notifying the company of additions or changes to the dwelling that increase replacement cost by $5,000 or more within 90 days, and the loss settlement criteria for different types of property.
#
# The rate filing is comprehensive and involves multiple forms and endorsements aimed at enhancing coverage and providing specific settlement provisions for covered losses.
# Processed additional filing info for: AR_LBPM-134415366.pdf
# Token count for API call in AR_SFMA-134403457.pdf: 6946
# GPT-3.5 Summary: The rate filing submitted by State Farm Fire and Casualty Company for their Arkansas Homeowners Program involves revised rates resulting in a rate level change of 0.0% statewide. The filing aims to maintain competitive premiums while meeting actuarially suggested income needs. Key points include:
#
# 1. Introduction of various Wind/Hail deductible options (1%, 2%, 3%, 4%, and 5%).
# 2. The changes account for expected impacts on underwriting experience due to prior policy language changes.
# 3. The company emphasizes financial stability through rate adjustments, internal controls, loss settlement enhancements, and loss prevention initiatives.
# 4. No impact on fire departments was identified.
# 5. Effective dates: March 15, 2025, for new business and May 15, 2025, for renewals.
# 6. Author: Erin G Winters
# 7. Submission includes various supporting documents such as actuarial justifications, loss cost data entry documents, and responses to objections.
#
# In response to an objection regarding Wind/Hail deductible factors, a detailed rating example was provided to explain how these factors apply in relation to previously filed manual pages. The company addressed the objection effectively, ensuring transparency and clarity in their rate adjustments scheme.
# Processed additional filing info for: AR_SFMA-134403457.pdf
# Token count for API call in AZ_ALSE-134423427.pdf: 26212
# Processed additional filing info for: AZ_ALSE-134423427.pdf
# Token count for API call in AZ_ALSE-134423455.pdf: 86920
# Processed additional filing info for: AZ_ALSE-134423455.pdf
# Token count for API call in AZ_ALSE-134423481.pdf: 46180
# Processed additional filing info for: AZ_ALSE-134423481.pdf
# Token count for API call in AZ_ALSE-134424632.pdf: 27076
# Processed additional filing info for: AZ_ALSE-134424632.pdf
# Token count for API call in AZ_ALSE-134424807.pdf: 16357
# Error calling GPT-3.5-turbo: Error code: 400 - {'error': {'message': "This model's maximum context length is 16385 tokens. However, your messages resulted in 16403 tokens. Please reduce the length of the messages.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Processed additional filing info for: AZ_ALSE-134424807.pdf
# Token count for API call in AZ_ALSE-134424886.pdf: 15126
# GPT-3.5 Summary: The rate filing submitted by Allstate Insurance Company for their AIC MBH product in Arizona includes proposed changes to the installment fees and late payment fee. The changes are as follows:
#
# 1. Increase the Installment Fee for the Allstate Easy Pay Plan from $1.50 to $2.00.
# 2. Increase the Installment Fee for all other payment methods (excluding Allstate Payroll Deductions) from $4.00 to $5.00.
# 3. Allstate Payroll Deductions will continue to have no installment fees.
# 4. Increase the Late Payment Fee from $10.00 to $15.00.
#
# The filing also includes supporting documents providing justification for the proposed fee changes, including a breakdown of operational costs, bad debt associated with non-automatic payments, and calculations for implementing the new fees.
#
# Overall, the filing aims to adjust the fees associated with their AIC MBH product in Arizona to better reflect operational costs and ensure fair pricing for policyholders.
# Processed additional filing info for: AZ_ALSE-134424886.pdf
# Token count for API call in AZ_ALSE-134424967.pdf: 36507
# Processed additional filing info for: AZ_ALSE-134424967.pdf
# Token count for API call in AZ_FARM-134267371.pdf: 24014
# Processed additional filing info for: AZ_FARM-134267371.pdf
# Token count for API call in AZ_GMMX-134417367.pdf: 37283
# Processed additional filing info for: AZ_GMMX-134417367.pdf
# Token count for API call in CA_ALSE-134306035.pdf: 270849
# Processed additional filing info for: CA_ALSE-134306035.pdf
# Token count for API call in CA_AMSI-134390951.pdf: 656947
# Processed additional filing info for: CA_AMSI-134390951.pdf
# Token count for API call in CA_HART-133954912.pdf: 6898174
# Processed additional filing info for: CA_HART-133954912.pdf
# Token count for API call in CA_LBPM-134324308.pdf: 16210
# Error calling GPT-3.5-turbo: Error code: 400 - {'error': {'message': "This model's maximum context length is 16385 tokens. However, you requested 16556 tokens (16256 in the messages, 300 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Processed additional filing info for: CA_LBPM-134324308.pdf
# Token count for API call in CA_LBPM-134324330.pdf: 17054
# Processed additional filing info for: CA_LBPM-134324330.pdf
# Token count for API call in CA_LBRM-134134101.pdf: 272298
# Processed additional filing info for: CA_LBRM-134134101.pdf
# Token count for API call in CA_LBRM-134324203.pdf: 51710
# Processed additional filing info for: CA_LBRM-134324203.pdf
# Token count for API call in CA_LBRM-134324217.pdf: 52244
# Processed additional filing info for: CA_LBRM-134324217.pdf
# Token count for API call in CA_LBRM-134354158.pdf: 15775
# GPT-3.5 Summary: The rate filing submitted by First National Insurance Company of America to the California Department of Insurance is regarding the non-renewal of their Difference in Condition (DIC) homeowners insurance product. The company has planned to withdraw this specific product from the market in California, effective January 1, 2026. The filing includes information about the policies in force, direct written premium, and the decision to simplify and focus investments on core products, leading to the withdrawal of the mentioned program. The non-renewal notices will be sent to impacted policyholders starting from policies with an effective date of January 1, 2026. This decision is part of the company's strategic move to streamline their product offerings in the state.
# Processed additional filing info for: CA_LBRM-134354158.pdf
# Token count for API call in CA_LEMO-134259792.pdf: 208472
# Processed additional filing info for: CA_LEMO-134259792.pdf
# Token count for API call in CO_ALSE-134421825.pdf: 5387
# GPT-3.5 Summary: This rate filing pertains to Allstate Indemnity Company's AI REN (Allstate Indemnity Renters) product in the state of Colorado. The filing includes a revision to the underwriting guidelines for renters insurance, specifically for new business and endorsements effective on or after March 18, 2025. The changes involve altering the distribution channels for new policies, with a shift to offering new policies exclusively through Independent Agents, no longer selling through Exclusive Agents or Direct Channels.
#
# Key updates in the underwriting guidelines cover aspects such as insurable interest requirements, administrative procedures, consumer credit report checks, fire protection criteria, prior insurance considerations, coverage limits and deductible requirements, ineligible dwellings, and procedures for invoking a moratorium during a catastrophe. The filing emphasizes the need for compliance with Colorado laws and regulations, outlines the effective date requested, and includes detailed information on the reasons for the filing.
# Processed additional filing info for: CO_ALSE-134421825.pdf
# Token count for API call in CO_ALSE-134421846.pdf: 5008
# GPT-3.5 Summary: The rate filing involves Allstate North American Insurance Company proposing a change to its Renters underwriting guidelines in the state of Colorado. The effective date for this change is requested to be on or after March 18, 2025, for new business. The filing involves revisions to the underwriting guidelines, specifically removing the Applicability section. The filing contact for this submission is Jennifer Olson, a State Filings Analyst at Allstate.
#
# The filing indicates that applications can be bound effective up to 90 days in the future, backdated applications and coverage endorsements are ineligible, and there are specific requirements related to the insured property, credit history checks on primary named insured, insurable interests, and specific dwellings that are considered ineligible.
#
# The rate filing includes details such as the proposed effective date, program title, reason for filing, changes made to manual rule numbers, and overall % rate impact/change justification. It also outlines expenses, expected loss ratio, and details on the expected impact on policyholders.
#
# Overall, the rate filing focuses on ensuring compliance with state laws and regulations in Colorado, providing a clear overview of the changes being made to the underwriting guidelines for Renters insurance offered by Allstate North American Insurance Company in the state.
# Processed additional filing info for: CO_ALSE-134421846.pdf
# Token count for API call in CO_TRVD-G134410645.pdf: 7953
# GPT-3.5 Summary: Based on the provided information from the insurance company's filing with the DOI, the rate filing is for The Travelers Home and Marine Insurance Company's Quantum Homeowners product in the state of Colorado. The filing includes amendments to two rules: Rule 511 Loss Assessment Coverage and Rule 535 Enhanced Home Package. The effective date requested for the changes is April 7, 2025, both for new business and renewals.
#
# The rate filing involves changes to eligibility requirements, increased premium limits by policy form, and endorsements for Loss Assessment Coverage (Rule 511) and Enhanced Home Package (Rule 535). The amendments aim to enhance certain coverage limits, replacement cost protection, and other benefits under the Quantum Homeowners product.
#
# The company's contact information for filing inquiries is provided, along with details on the filing process and supporting documents submitted. The overall rate impact of these changes is stated as 0.00%, with no written premium change or policyholders expected to be affected. Additionally, a detailed schedule of superseded items and a note regarding the absence of confidential information in the filing are included in the documentation.
#
# However, it is important to conduct a thorough review and analysis of the filed documents to understand the full scope and implications of the rate changes on the insurance product and market landscape.
# Processed additional filing info for: CO_TRVD-G134410645.pdf
# Token count for API call in CO_TRVD-G134412529.pdf: 7187
# GPT-3.5 Summary: The rate filing pertains to multiple insurance companies under The Travelers group, specifically The Automobile Insurance Company of Hartford, Connecticut, The Standard Fire Insurance Company, and The Travelers Indemnity Company of America. The filing is for homeowners and high-value homeowners insurance programs in Colorado.
#
# The filing includes revisions to rules such as Loss Assessment Coverage (Rules 511) and Additional Coverage Endorsement - ACE (Rule 530) for both standard homeowners and high-value homeowners policies. The changes impact eligibility requirements, limits of liability, premium adjustments, and coverage enhancements. The effective date for these changes for renewal business is set for 04/07/2025.
#
# The filing documentation includes Rule Manual Pages, Supporting Documents, Explanatory Memorandum, and submissions in compliance with Colorado regulations. The overall rate impact is indicated as 0.000%, with no changes to written premiums or number of policyholders affected. The filing was submitted on 02/12/2025 and closed as Filed on the same day.
# Processed additional filing info for: CO_TRVD-G134412529.pdf
# Token count for API call in CT_FAIG-134409705.pdf: 23339
# Processed additional filing info for: CT_FAIG-134409705.pdf
# Token count for API call in CT_FAIG-134410056.pdf: 122008
# Processed additional filing info for: CT_FAIG-134410056.pdf
# Token count for API call in CT_FAIG-134410555.pdf: 184149
# Processed additional filing info for: CT_FAIG-134410555.pdf
# Token count for API call in CT_FAIG-134413686.pdf: 17927
# Processed additional filing info for: CT_FAIG-134413686.pdf
# Token count for API call in CT_LBPM-134347841.pdf: 36821
# Processed additional filing info for: CT_LBPM-134347841.pdf
# Token count for API call in CT_LBPM-134349046.pdf: 37995
# Processed additional filing info for: CT_LBPM-134349046.pdf
# Token count for API call in CT_LBPM-134358227.pdf: 158981
# Processed additional filing info for: CT_LBPM-134358227.pdf
# Token count for API call in CT_LBPM-134359707.pdf: 160774
# Processed additional filing info for: CT_LBPM-134359707.pdf
# Token count for API call in CT_TRVD-G134420493.pdf: 22556
# Processed additional filing info for: CT_TRVD-G134420493.pdf
# Token count for API call in CT_TRVD-G134426399.pdf: 207244
# Processed additional filing info for: CT_TRVD-G134426399.pdf
# Token count for API call in District_HART-134400407.pdf: 5151
# GPT-3.5 Summary: The rate filing pertains to the introduction of a credit card surcharge to The Hartford's Home products. Policyholders choosing to pay premiums by credit card will incur a surcharge not to exceed 3% of the total premium amount. The surcharge will be collected by a third-party payment vendor and will apply to transactions processed on or after July 01, 2025. The request for the credit card surcharge was submitted with the SERFF tracking number HART-134400407 and the filing was approved on 02/18/2025. The filing includes responses to objection letters, where the company clarified the surcharge amount and the process for credit card payments. The response indicated that the credit card surcharge will be a flat rate of 2.95% for all customers choosing this payment method.
# Processed additional filing info for: District_HART-134400407.pdf
# Token count for API call in GA_FARM-134357205.pdf: 9962
# GPT-3.5 Summary: This rate filing is for the Farmers Insurance Exchange's product named FLEX Home in the state of Georgia, under the category of Homeowners insurance. The submission was categorized as a Rate/Rule filing other than PPA, with a Date Submitted of 12/31/2024. The Effective Date requested for the new rules is 03/10/2025, with the renewal Effective Date set for 04/12/2025.
#
# The filing mainly focused on changes and updates to the Underwriting manual for the FLEX Home product. In particular, modifications were made to the Scheduled Roof requirements, including additions of roof types such as 'Flat', 'Metal', and 'Other'. There was a detailed breakdown of various elements considered in the rating process, such as geographic/demographic data, prior insurance information, claims history, rating variables, and exclusion rules.
#
# The rate indication support and modeling aspects were not extensively covered in this filing, as the primary emphasis was on the underwriting guidelines and rates associated with the FLEX Home product. The file included responses to required additional information sections, with detailed lists of rating variables and premium components.
#
# Overall, the submission appeared to focus on detailing the specifics of the FLEX Home underwriting rules and ensuring compliance with regulatory aspects in Georgia for the provided product.
# Processed additional filing info for: GA_FARM-134357205.pdf
# Token count for API call in GA_FORE-134361553.pdf: 6529
# GPT-3.5 Summary: Based on the information provided in the filing, here is a summary of the rate filing for Foremost Insurance Company's Landlord Manufactured Home Program in Georgia:
#
# - The filing was submitted on 12/23/2024 and had a disposition date of 02/18/2025. The effective date requested for both new and renewal policies is 03/01/2025.
#
# - The filing requested revisions to the rule and rate section of the Landlord Manufactured Home Program.
#
# - The filing requested a neutral rate change, with an overall percentage of 0.000% and no impact on the written premium.
#
# - The company has indicated a change in the rate pages and the bookmarked manual for the program.
#
# - The filing includes various coverage details such as Earthquake coverage, Premises Liability, Replacement Cost on Dwelling, and discounts for features like Fortified Homes.
#
# - The filing also includes important rules related to eligibility, term, premiums, minimum written premium, changes, and cancellations.
#
# - Supporting documents in the filing include Rate Indication Summary, Explanatory Memorandum - Rate/Rule, Compliance Certification, and Filing Fee Transmittal Form.
#
# - The filing certification was signed by Dianne Janes, the State Filings Administrator, with contact information provided for further inquiries.
#
# This summary provides an overview of the rate filing for the Landlord Manufactured Home Program by Foremost Insurance Company in Georgia.
# Processed additional filing info for: GA_FORE-134361553.pdf
# Token count for API call in GA_HART-134406305.pdf: 10332
# GPT-3.5 Summary: The rate filing in question is related to the implementation of Homeowners 2022 multistate forms, rules, and loss costs revisions in Georgia by Nutmeg Insurance Company. The effective date requested for the new implementation is July 1, 2025. The filing was closed and approved on February 19, 2025. The project involved various individuals such as Maureen Church, Geraldine Daly, Heather Vendetti, Betsy Llanes, and Jennifer Dooling. The Certification Statement was signed by Geraldine Daly on February 6, 2025. The filing pertains to the product name "GA Non-Adopt Homeowners 2022 Multistate Forms Implementation Effective 7/1/25 (Nutmeg)" and falls under the TOI/Sub-TOI category of 04.0 Homeowners/04.0000 Homeowners Sub-TOI Combinations. The Company Tracking Number associated with this filing is FF.14.001.2025.02.
#
# Overall, the rate filing involves the adoption and implementation of multistate forms, rules, and loss costs revisions for Homeowners insurance in Georgia by Nutmeg Insurance Company with an effective date of July 1, 2025.
# Processed additional filing info for: GA_HART-134406305.pdf
# Token count for API call in GA_HART-134406348.pdf: 11113
# GPT-3.5 Summary: The rate filing pertains to Nutmeg Insurance Company's implementation of the Georgia Non-Adopt Homeowners 2022 Multistate Rules, effective 7/1/25. The filing involves changes in rules and forms related to the ISO Homeowners Program. The overall percentage change in rate impact for Nutmeg Insurance Company was 0.000%, with no written premium change or policyholders affected. The filing was acknowledged by the SERFF system on 02/19/2025, with a disposition status of Acknowledged. The effective date for the new rate requested was 07/01/2025. The company did not undertake any changes or modifications, and the filing complied with Georgia state regulations.
# Processed additional filing info for: GA_HART-134406348.pdf
# Token count for API call in GA_HART-134414600.pdf: 4594
# GPT-3.5 Summary: The rate filing pertains to the introduction of a credit card surcharge for The Hartford's Home products in Georgia. Policyholders who opt to pay their premium by credit card will face a surcharge that will be charged and collected by a third-party payment vendor, not exceeding 3% of the total payment amount. This surcharge will be displayed at the time of the transaction and will be effective for all transactions processed on or after July 01, 2025.
#
# The filing includes the following companies: Hartford Casualty Insurance Company, Hartford Insurance Company of the Midwest, Hartford Insurance Company of the Southeast, Property and Casualty Insurance Company of Hartford, Trumbull Insurance Company, and Nutmeg Insurance Company.
#
# The rate filing methodology is mentioned as File & Use with a Rate Change Type listed as Neutral. The filing includes no rate changes for any of the involved companies, resulting in a 0.000% overall change in rates and written premiums for the program. Each company's details, as well as their respective filing fees, are also provided in the filing documentation.
#
# If you need further details or specific information, feel free to ask!
# Processed additional filing info for: GA_HART-134414600.pdf
# Token count for API call in GA_LBPM-134383820.pdf: 7046
# GPT-3.5 Summary: The rate filing for the Georgia Homeowners, Condo, and Simple Renters program by Liberty Mutual and its affiliated companies involved multiple forms and endorsements related to policy declarations and coverages under Sections I and II. The forms submitted with the filing included Policy Declarations (FMHO 3047 10 24), a Filing Compliance Certification, a Filing Fee Transmittal Form, an Explanatory Memorandum - Forms, Readability Certification for Personal Automobile and Homeowners', and a Side by Side Comparison - Forms.
#
# The rate filing indicated that the overall percentage rate was 0.000%, with no impact on written premium or the number of policyholders affected. The effective dates for the new filing were requested to be 05/19/2025 and for the renewal to be 06/23/2025.
#
# Additionally, the filing included information on the companies involved, the multi-state filing fees, and details on the changes made to the forms submitted with the filing. The overall rate impact for this filing was negligible, with no significant changes to the premium or policyholder information.
# Processed additional filing info for: GA_LBPM-134383820.pdf
# Token count for API call in GA_LBPM-134414714.pdf: 16386
# Processed additional filing info for: GA_LBPM-134414714.pdf
# Token count for API call in GA_LEMO-134183570.pdf: 270995
# Processed additional filing info for: GA_LEMO-134183570.pdf
# Token count for API call in GA_LEMO-134374428.pdf: 3737
# GPT-3.5 Summary: The rate filing submitted by Lemonade Insurance Company pertains to the introduction of a new optional coverage called Refrigerated Property Coverage for their homeowners insurance program in the state of Georgia. This new coverage will provide protection for covered property stored in freezers or refrigerators on the residence premises for direct loss caused by specific scenarios related to electrical service interruption or mechanical failure of the storage unit.
#
# Lemonade Insurance Company has requested that this filing apply to all new business policies written on or after May 15, 2025, and to all renewal business effective on or after May 16, 2025. The filing includes the endorsement form LEM-3051 (01-25) for Refrigerated Property Coverage, along with supporting documents such as the Filing Compliance Certification, Readability Certification, and an Explanatory Memorandum.
#
# The rate filing also details the associated filing fees, totaling $25.00 per form submitted, with no retaliatory fees applicable. The filing was submitted on February 6, 2025, with a requested effective date for the new coverage of May 15, 2025. The certification within the filing indicates that the enclosed forms meet the minimum readability requirements set forth by the Department Regulation in Georgia.
# Processed additional filing info for: GA_LEMO-134374428.pdf
# Token count for API call in GA_LEMO-134376013.pdf: 22707
# Processed additional filing info for: GA_LEMO-134376013.pdf
# Token count for API call in GA_LEMO-134376046.pdf: 8181
# GPT-3.5 Summary: Metromile Insurance Company submitted a rate filing for their MIC Renters insurance product in Georgia. The filing introduces a new optional coverage called Refrigerated Property Coverage. The effective date requested for new business policies is May 15, 2025, and for renewal business policies is May 16, 2025. The filing includes adjustments to the rate tables for different coverage limits, such as $100, $250, and $500, with no overall rate impact indicated.
#
# The filing details the new coverage options, supporting documentation, compliance certifications, rate indications, and confirmation that various factors like claims history, credit scoring models, and not-at-fault accidents are not used in the rating. The disposition status of the filing was "Acknowledged," indicating that the state has acknowledged the filing, and no objections were raised requiring further documentation.
# Processed additional filing info for: GA_LEMO-134376046.pdf
# Token count for API call in GA_LEMO-134384633.pdf: 25635
# Processed additional filing info for: GA_LEMO-134384633.pdf
# Token count for API call in GA_SFMA-134413084.pdf: 69342
# Processed additional filing info for: GA_SFMA-134413084.pdf
# Token count for API call in GA_TRVD-G134400682.pdf: 5876
# GPT-3.5 Summary: The rate filing pertains to the Homesaver program in Georgia by three insurance companies: The Automobile Insurance Company of Hartford, The Phoenix Insurance Company, and The Travelers Indemnity Company of America. The filing involves revisions to the Homesaver product as outlined in an attached memo. The filing type is a Rate/Rule other than PPA, and the effective date requested is 02/28/2025. The filing includes amendments to provide premium discounts to eligible policyholders through a new Rule 424 - Windstorm Mitigation Discount.
#
# Multiple attachments are included in the filing, such as Windstorm Mitigation Discount forms, Filing Compliance Certification, Rate/Rule Exhibits, Objection Response Letters, and more. The filing fee for the state of Georgia is $225.00, with $75.00 paid by each of the three insurance companies involved. The SERFF status is Pending State Action, with a response required by 02/24/2025. Additionally, there are ongoing correspondence and objection/response letters between the filing company and the state.
# Processed additional filing info for: GA_TRVD-G134400682.pdf
# Token count for API call in HI_ALSE-134338646.pdf: 116700
# Processed additional filing info for: HI_ALSE-134338646.pdf
# Token count for API call in HI_HART-134349469.pdf: 19393
# Processed additional filing info for: HI_HART-134349469.pdf
# Token count for API call in IA_SFMA-134377596.pdf: 26319
# Processed additional filing info for: IA_SFMA-134377596.pdf
# Token count for API call in IA_TRVD-G134419374.pdf: 9149
# GPT-3.5 Summary: This rate filing pertains to the Quantum Homeowners 2.0, Quantum Home, and Legacy Home insurance programs by The Automobile Insurance Company of Hartford, Connecticut and other Travelers affiliated companies in Iowa. The filing involves revisions to various coverage packages and rules including Rule 106 Coverage Packages, Rule 905 Loss Assessment, Rule 511 Loss Assessment Coverage, Rule 535 Enhanced Home Package, Rule 305 High Value Home Coverage, and Rule 530 Additional Coverage Endorsement. The filing includes changes to eligibility requirements, premium calculations, and coverage enhancements for the mentioned programs. The effective date for the new rules and packages is requested to be 03/14/2025 for new business and 05/13/2025 for renewals. The filing has been approved with a 0.000% overall rate impact and is closed-approved as of 02/17/2025.
# Processed additional filing info for: IA_TRVD-G134419374.pdf
# Token count for API call in ID_AMSI-134173339.pdf: 456563
# Processed additional filing info for: ID_AMSI-134173339.pdf
# Token count for API call in ID_HART-134424457.pdf: 6003
# GPT-3.5 Summary: In this rate filing from Nutmeg Insurance Company for Idaho, the company is proposing a revision to the Broadened Home-sharing Host Activities Coverage under the ISO By-peril Rating Supplement to the Homeowners Policy Program Manual. The revised rule (HO-2024-BPR1) is set to be effective on May 1, 2025, impacting all policies written on or after that date. The changes involve adjusting factors for different types of home-sharing accommodations and the number of nights stayed, affecting the additional premium calculation for broadened coverage. The filing was submitted by Geraldine Daly, a Product Analyst at Nutmeg Insurance Company, and the ISO Circular LI-HO-2025-015 provides detailed information on the revisions being implemented. This filing was submitted on February 19, 2025, and was ultimately closed and filed with the state.
# Processed additional filing info for: ID_HART-134424457.pdf
# Token count for API call in ID_SFMA-134424081.pdf: 23426
# Processed additional filing info for: ID_SFMA-134424081.pdf
# Token count for API call in IN_FARM-134411373.pdf: 8090
# GPT-3.5 Summary: The rate filing in question relates to the Indiana insurance market, specifically for homeowners insurance products offered by Farmers Insurance Exchange, Illinois Farmers Insurance Company, and Truck Insurance Exchange. The filing consists of several policy endorsements and amendatory endorsements, such as those for General Conditions, Intentional Acts, Criminal Acts, Fraud, Suit Against Us, Assignment, and more. These endorsements modify coverage terms and conditions within the policies, addressing matters like assignment and death provisions, intentional acts, suits against the insurer, and policy cancellation.
#
# The rate filing also includes details on the effective date requested for the new terms, which is set to be 07/10/2025 for both new and renewal business. Different forms have been created, revised, or withdrawn as part of this filing, each affecting the Legacy Homeowners, Smart Plan Renter, and Smart Plan Condo products offered by the insurers. The filing memo indicates that these changes are being made in response to Indiana House Bill 1034 concerning the transfer of property upon death.
#
# Overall, the rate filing seeks to update and refine the insurance coverage provided by the insurers in line with regulatory requirements and policy revisions, aiming to enhance clarity, compliance, and coverage for policyholders in the Indiana market.
# Processed additional filing info for: IN_FARM-134411373.pdf
# Token count for API call in IN_HART-134419899.pdf: 3906
# GPT-3.5 Summary: Summary of the Rate Filing:
#
# - Company: Hartford Insurance Company of the Southeast
# - Product Name: IN Home Prevail – HICSE
# - State: Indiana
# - Type of Insurance: Homeowners
# - Filing Type: Rate
# - Effective Date Requested (New): 02/06/2025
# - Effective Date Requested (Renewal): 03/29/2025
# - Disposition Status: Filed
# - Rate Change Type: Neutral
# - Overall Percentage of Last Rate Revision: 4.000%
# - Overall Indicated Change: 0.000%
# - Overall Rate Impact: 0.000%
# - Written Premium Change for this Program: $0
# - Number of Policyholders Affected: 5,327
# - Written Premium for this Program: $5,089,895
#
# The rate filing involved proposing revisions to The Hartford's Home product in Indiana, impacting both new business policies written on or after February 6, 2025, and renewal policies effective on or after March 29, 2025. The filing included clerical adjustments to the capping rate page and was prepared by pricing and product management personnel. The filing fee was $35.00, and the filing method was File & Use.
# Processed additional filing info for: IN_HART-134419899.pdf
# Token count for API call in KS_ALSE-134335664.pdf: 44310
# Processed additional filing info for: KS_ALSE-134335664.pdf
# Token count for API call in KS_HART-134403020.pdf: 4975
# GPT-3.5 Summary: The rate filing mentioned in the provided document involves the introduction of a credit card surcharge to The Hartford's Home products in the writing companies associated with Hartford Insurance Company of the Southeast, Property and Casualty Insurance Company of Hartford, Trumbull Insurance Company, Twin City Fire Insurance Company, Hartford Accident and Indemnity Company, and Hartford Fire Insurance Company. Policyholders opting to pay their premium by credit card will face a surcharge not exceeding 3% of the total payment amount, collected by a third-party payment vendor. This surcharge will be effective for all transactions processed on or after July 1, 2025. The filing includes details about the project name, project number, effective dates requested, filing types, companies involved, and the corresponding tracking numbers. The filing company information for each entity involved in the rate filing is also provided, along with the contact details for the filing contact associated with this submission. Objection letters, response letters, and supportive document schedules related to the rate filing are also included, with objections raised regarding the consideration of surcharge charges in loss ratio calculations, premium tax calculations, and more. The objection responses detail the handling of service charges and fees related to the credit card surcharge proposed in the rate filing.
# Processed additional filing info for: KS_HART-134403020.pdf
# Token count for API call in KS_LBPM-134379791.pdf: 31184
# Processed additional filing info for: KS_LBPM-134379791.pdf
# Token count for API call in KY_LBPM-134418505.pdf: 4517
# GPT-3.5 Summary: The rate filing submitted by American Economy Insurance Company for their Homeowners product in Kentucky involves a rate revision effective from January 1st, 2025, for both new business and in-force business. The filing included updates to mine subsidence rates in accordance with KY House Bill 371 & Bulletin 2024-07. Despite being filed outside the statutory timeframe, the changes were allowed to be effective from 01/01/2025 as mandated by the General Assembly. This filing had no rate impact, resulting in a 0.000% overall percentage of last rate revision and $0 written premium change for the program. The filing fees for the rate revision amounted to $35.00, as required by Kentucky's filing provision.
# Processed additional filing info for: KY_LBPM-134418505.pdf
# Token count for API call in KY_LBPM-134419964.pdf: 4397
# GPT-3.5 Summary: The rate filing is for Safeco Insurance Company of America's homeowners product in the state of Kentucky. The filing was a rate change type and was submitted as a renewal business effective January 1, 2025. The main update in the filing was related to mine subsidence rates, which were adjusted per Kentucky House Bill 371 & Bulletin 2024-07. The filing indicated a neutral rate change overall but with specific rate adjustments for different coverage limits under Coverage A. The filing included adjustments to the Mine Subsidence factors. The filing had a fee of $5.00 and was closed and acknowledged by the relevant authorities. The disposition status was acknowledged, and the effective date for the renewal was set to January 1, 2025. The filing was reviewed by Patricia Pippenger, Matthew Rowland, and Melissa Lee.
# Processed additional filing info for: KY_LBPM-134419964.pdf
# Token count for API call in KY_SFMA-134415672.pdf: 64301
# Processed additional filing info for: KY_SFMA-134415672.pdf
# Token count for API call in KY_TRVD-G134354974.pdf: 6941
# GPT-3.5 Summary: Based on the information provided from the filing with the DOI, the rate filing pertains to Travelers Personal Insurance Company's Quantum Home 2.0 product in the state of Kentucky within the Homeowners insurance category. The rate change requested is for an overall increase of 11.6%, compared to an overall indicated rate change of 12.8%. The filing includes revisions to the Quantum Home 2.0 model, introducing new variables and updating existing ones such as Roof Square Footage, Tree Overhang, Insurance Score, Auto Bodily Injury Limit, and others.
#
# The company uses data from various third-party vendors for modeling and validation purposes, including Nearmap for aerial imagery analysis using Convolutional Neural Networks (CNN). The model was extensively validated through metrics like accuracy, specificity, recall, RMSE, MAE, and confusion matrices to ensure reliability. The determination of variable selection, including factors like Roof Condition, Presence of Zinc Staining, and Tree Overhang, was supported by model performance metrics.
#
# The rate filing demonstrates compliance with regulatory requirements in Kentucky and provides substantial data to support the adjustments. Actuarial approval has been recommended, and objection letters have been addressed with responses and justifications for the proposed changes. The filing reflects a detailed and thorough process in updating the Quantum Home 2.0 product to align with company objectives and regulatory standards.
# Processed additional filing info for: KY_TRVD-G134354974.pdf
# Token count for API call in KY_TRVD-G134417165.pdf: 10950
# GPT-3.5 Summary: The rate filing involves revisions and amendments to various rules and coverage packages for homeowners insurance, specifically for the Quantum Home 2.0, Quantum Home, and Legacy Home products.
#
# Key elements of the rate filing include:
# - Rule 106: Coverage Packages, with enhancements and additions to the coverage options.
# - Rule 905: Loss Assessment coverage modifications to increase limits and coverage details.
# - Rule 511: Loss Assessment Coverage adjustments for increased limits and premium calculations.
# - Rule 535: Enhanced Home Package updates for additional coverages and eligibility criteria.
# - Rule 530: Additional Coverage Endorsement - ACE revisions for coverage enhancements.
# - Rule 305: High Value Home Coverage for changes in coverage details.
#
# The rate filing also includes a fee of $30, split among multiple companies within the Travelers group. The effective dates for the changes vary based on new business issuance and renewal dates.
#
# The rate filing aims to enhance coverage options, increase limits, and ensure compliance with state regulations, particularly in Kentucky.
# Processed additional filing info for: KY_TRVD-G134417165.pdf
# Token count for API call in LA_LBPM-134415785.pdf: 14267
# GPT-3.5 Summary: The rate filing for the Louisiana Optional Loss Settlement Endorsement, Expanded Replacement Cost Endorsement, and Homeprotector Plus Endorsement for the Liberty Mutual Group's Homeowners program involved a detailed submission of revised policy forms and endorsements to the Louisiana Department of Insurance. The filing included updates to the loss settlement conditions, coverage for specific items like jewelry and watches, and provisions for increased limits and additional coverages.
#
# Specifically, the rate filing outlined changes such as:
# 1. Loss settlement conditions including payment methods for covered property losses
# 2. Increased special limits of liability for valuables like jewelry, watches, furs, and stones
# 3. Replacement cost provisions for dwellings and personal property
# 4. Additional coverages for refrigerators, freezers, and lock replacement coverage
#
# These changes were intended to provide more comprehensive coverage and improved clarity in the policy language for policyholders under the Homeowners program offered by Liberty Mutual Group.
# Processed additional filing info for: LA_LBPM-134415785.pdf
# Token count for API call in MD_ALSE-134276603.pdf: 833014
# Processed additional filing info for: MD_ALSE-134276603.pdf
# Token count for API call in MD_ALSE-134280641.pdf: 138192
# Processed additional filing info for: MD_ALSE-134280641.pdf
# Token count for API call in MD_ALSE-134284768.pdf: 98958
# Processed additional filing info for: MD_ALSE-134284768.pdf
# Token count for API call in MD_ALSE-134426297.pdf: 41175
# Processed additional filing info for: MD_ALSE-134426297.pdf
# Token count for API call in MD_AMSI-134131102.pdf: 1434907
# Processed additional filing info for: MD_AMSI-134131102.pdf
# Token count for API call in MD_AMSI-134415777.pdf: 510120
# Processed additional filing info for: MD_AMSI-134415777.pdf
# Token count for API call in MD_FARM-134406950.pdf: 19522
# Processed additional filing info for: MD_FARM-134406950.pdf
# Token count for API call in MD_LEMO-134414879.pdf: 45160
# Processed additional filing info for: MD_LEMO-134414879.pdf
# Token count for API call in MI_ALSE-134371700.pdf: 17510
# Processed additional filing info for: MI_ALSE-134371700.pdf
# Token count for API call in MI_ALSE-134422885.pdf: 78208
# Processed additional filing info for: MI_ALSE-134422885.pdf
# Token count for API call in MI_FAIG-134421996.pdf: 2856
# GPT-3.5 Summary: Based on the filing provided, Farmers Property and Casualty Insurance Company and Farmers Group Property and Casualty Insurance Company submitted a rate filing for a revised endorsement for their homeowners product in Michigan. The revised endorsement, HA05MI 0125 Actual Cash Value Definition Amendatory, aligns with the requirements of the State of Michigan Department of Insurance and Finance Services bulletin 2024-18-INS issued on July 3, 2024.
#
# The revision to the endorsement removes language specifying that labor expenses are no longer subject to depreciation as part of the repair or replacement costs. The companies requested that this filing become effective for both new business and renewal business policies starting on July 1, 2025.
#
# In support of the rate filing, both a marked-up version and a clean copy of the updated form were included. The companies emphasized their compliance with the regulatory requirements and requested a prompt review of the filing. Murshed Khondker, the Personal Lines Contracts Development Analyst, submitted the filing on behalf of the companies.
# Processed additional filing info for: MI_FAIG-134421996.pdf
# Token count for API call in MI_TRVD-G134420573.pdf: 6663
# GPT-3.5 Summary: Based on the information provided in the filing, the rate filing for the Quantum Homeowners 2.0 program by TravCo Insurance Company in Michigan involves revisions to the Policy Declarations form PL-50355 MI (05-17). The revised form, PL-50355 MI (05-25), includes updates to the information About Your Property section, specifically adding a paragraph related to the use of aerial imagery to determine home characteristics that impact premiums.
#
# The effective date for the new business issued with the revised form is requested to be 05/18/2025, while for renewal business, it is requested to be effective on or after 07/07/2025. The filing was reviewed and approved, with all rates, rules, and forms required to comply with applicable Michigan laws and regulations according to the Insurance Code.
#
# The rate data does not apply to this filing as it mainly focuses on form revisions and declarations related to the Quantum Home 2.0 program for homeowners in Michigan.
# Processed additional filing info for: MI_TRVD-G134420573.pdf
# Token count for API call in MN_ALSE-134082968.pdf: 5544
# GPT-3.5 Summary: The rate filing submitted by Allstate Insurance Company in Minnesota pertains to the introduction of new forms in accordance with Minn. Stat. 60A.0812. The specific forms introduced are related to the Minnesota Watercraft Family Protection Act Liability Endorsement (AP5007) and the Minnesota Watercraft Liability – Declination of Coverage (LT820). These forms are aimed at addressing requirements under the Family Protection Act, focusing on liability coverage for watercraft and the option for policyholders to decline coverage for family and household members.
#
# The rate filing indicates the company's compliance efforts with the statutory provisions outlined in the Act, particularly regarding the reduction of premium when a policyholder declines watercraft liability coverage for family and household members. Allstate has engaged in discussions with the Minnesota Department of Insurance to ensure understanding and adherence to the legislative requirements.
#
# The effective dates for the filing were revised, with the new business effective date set to 02/10/2025 and the renewal business effective date set to 03/27/2025. Additionally, the filing includes forms that have been approved, such as the Minnesota Watercraft Family Protection Act Liability Endorsement and the Minnesota Watercraft Liability – Declination of Coverage, indicating compliance with regulatory standards.
# Processed additional filing info for: MN_ALSE-134082968.pdf
# Token count for API call in MN_ALSE-134082984.pdf: 6499
# GPT-3.5 Summary: The rate filing submitted by Allstate Insurance Company in Minnesota pertains to the introduction of new forms in accordance with the Minnesota Statute 60A.0812. The requested effective date for this filing is February 10, 2025, for new business and March 27, 2025, for renewal business. The initial effective dates requested were revised from November 4, 2024, to February 10, 2025, and from December 19, 2024, to March 27, 2025. The filing was approved with all eight forms being approved. The overall percentage rate indicated for this filing is 0.000%, with no impact on the overall percentage rate and no change in written premium or the number of policyholders affected. Additionally, the filing includes a Minnesota Watercraft Family Protection Act Liability Endorsement (AP5006) and a Minnesota Watercraft Liability Declination of Coverage (LT820).
# Processed additional filing info for: MN_ALSE-134082984.pdf
# Token count for API call in MN_ALSE-134082986.pdf: 5630
# GPT-3.5 Summary: Based on the filing information provided for Allstate Indemnity Company's rate filing in Minnesota, the company introduced new forms in accordance with Minn. Stat. 60A.0812 related to watercraft liability coverage under the Minnesota Family Protection Act. The filing included two newly approved forms: the Minnesota Watercraft Family Protection Act Liability Endorsement (AP5008) and the Minnesota Watercraft Liability – Declination of Coverage (LT820).
#
# The effective dates requested for the rate filing were 02/10/2025 for new policies and 03/27/2025 for policy renewals. However, there were objections raised regarding compliance issues in the response letter, particularly related to the effective date of the Family Protection Act and the requirement for premium reductions when declining watercraft liability coverage for family and household members.
#
# ...
# Processed additional filing info for: TX_HART-134405817.pdf
# Token count for API call in TX_HART-134407174.pdf: 4399
# GPT-3.5 Summary: The rate filing involves the consolidation of home insurance products from Hartford Lloyd's Insurance Company into Trumbull Insurance Company's Home Advantage rate plan via an Affiliate Transfer process. This consolidation aims to provide policyholders with enhanced features and benefits under the new plan. Although some coverage options and limits may change for policyholders, they will be notified in advance of the policy effective date and given the opportunity to discuss their coverage options and limits. The transfer will occur at renewal without interrupting coverage, starting on October 31, 2025, and lasting for one year. Policyholders will receive a notice of transfer 30 days prior to the transfer to inform them of the change and provide contact information for any inquiries. The effective date of the rate revision is requested to be October 31, 2025.
# Processed additional filing info for: TX_HART-134407174.pdf
# Token count for API call in TX_LBPM-134159927.pdf: 437970
# Processed additional filing info for: TX_LBPM-134159927.pdf
# Token count for API call in TX_LBPM-134367641.pdf: 32652
# Processed additional filing info for: TX_LBPM-134367641.pdf
# Token count for API call in TX_LBPM-134413687.pdf: 3870055
# Processed additional filing info for: TX_LBPM-134413687.pdf
# Token count for API call in TX_LEMO-134323240.pdf: 248505
# Processed additional filing info for: TX_LEMO-134323240.pdf
# Token count for API call in TX_SFMA-134221173.pdf: 269421
# Processed additional filing info for: TX_SFMA-134221173.pdf
# Token count for API call in TX_SFMA-134227799.pdf: 36900
# Processed additional filing info for: TX_SFMA-134227799.pdf
# Token count for API call in TX_SFMA-134410201.pdf: 3865
# GPT-3.5 Summary: The rate filing submitted by State Farm Lloyds for project MH-48034 in Texas pertains to homeowners insurance, specifically mobile homeowners. The filing was submitted as a Rate/Rule type on 02/14/2025 with an effective date requested for both new and renewal business of 05/01/2025. The overall percentage of the last rate revision was 7.500%, dating back to 02/15/2019. The filing method was File and Use, and there was a neutral rate change type indicated. The company reported no written premium change for this program, impacting 22,484 policyholders with $34,562,531 in written premium. Actuarial support was bypassed for this filing as it was deemed to have no rate impact. The filing also included supporting documents such as Exhibit A (Rate Filing Checklist), Exhibit C (Statewide Average Rate Level Information), and a Filing Memorandum related to the Texas FAIR Plan recoupment surcharge for manufactured home policies.
# Processed additional filing info for: TX_SFMA-134410201.pdf
# Token count for API call in TX_SFMA-134410218.pdf: 4214
# GPT-3.5 Summary: ### Summary of Rate Filing for State Farm Lloyds HO-48033 in Texas
#
# **Company Information:**
# - Company: State Farm Lloyds
# - Headquarters: Richardson, TX
# - Domiciled in: Texas
# - Contact: Jennifer Heizer, home.f.mail.394n00@statefarm.com
#
# **Filing Details:**
# - Filing Type: Rate/Rule
# - Filing Status: Submitted to State
# - Effective Date Requested: 05/01/2025
# - Product Name: HO-48033
# - Project Name/Number: HO-48033/HO-48033
#
# **Rate Information:**
# - Filing Method: File and Use
# - Rate Change Type: Neutral
# - Overall Percentage of Last Rate Revision: 9.900%
# - Effective Date of Last Rate Revision: 04/15/2024
# - Written Premium for this Program: $3,517,540,553
#
# **Supporting Documents:**
# - Rate Filing Checklist (Exhibit A)
# - Statewide Average Rate Level Information (Exhibit C)
# - Filing Memorandum for FAIR Plan Recoupment
#
# **Additional Information:**
# - The filing does not contain any confidential information.
# - It includes information on recoupment surcharge resulting from the 2023 Texas FAIR Plan Association Assessment.
#
# Overall, this rate filing for State Farm Lloyds HO-48033 in Texas shows a neutral rate change with a
# Processed additional filing info for: TX_SFMA-134410218.pdf
# Token count for API call in TX_TRVD-G134425009.pdf: 6594
# GPT-3.5 Summary: The rate filing is for the Quantum Home 2.0 homeowners insurance program by Travelers Personal Insurance Company in Texas. The filing includes new business eligibility guidelines which outline the risks that are eligible or ineligible for the program. It also provides detailed criteria for determining eligibility based on various factors such as property condition, prior claims history, presence of certain features or risks, and location-specific considerations like proximity to fire departments or coastal areas. Additionally, the filing covers catastrophe management measures, including temporary suspensions of binding coverage for certain catastrophic events, such as hurricanes.
#
# Overall, the rate filing provides a comprehensive overview of the underwriting guidelines and eligibility criteria for the Quantum Home 2.0 program in Texas, aiming to ensure that only suitable risks are accepted into the insurance program to manage potential liabilities effectively.
# Processed additional filing info for: TX_TRVD-G134425009.pdf
# Token count for API call in UT_SFMA-134405135.pdf: 27657
# Processed additional filing info for: UT_SFMA-134405135.pdf
# Token count for API call in VA_FAIG-134391614.pdf: 12975
# GPT-3.5 Summary: Based on the information provided in the filing, here is a summary of the rate filing by Farmers Property and Casualty Insurance Company, Farmers Casualty Insurance Company, and Economy Premier Assurance Company for their homeowners insurance product "Homeowners" in Virginia:
#
# 1. **Filing Details**:
#    - **Filing Type**: Form Filing
#    - **Date Submitted**: 01/24/2025
#    - **SERFF Tracking Number**: FAIG-134391614
#    - **State**: Virginia
#    - **TOI/Sub-TOI**: 04.0 Homeowners/04.0000 Homeowners Sub-TOI Combinations
#    - **Product Name**: Homeowners
#    - **Effective Date Requested (New/Renewal)**: 07/01/2025
#
# 2. **Companies**:
#    - Farmers Property and Casualty Insurance Company
#    - Farmers Casualty Insurance Company
#    - Economy Premier Assurance Company
#
# 3. **Document Highlights**:
#    - Various forms and endorsements were submitted for approval.
#    - Specifically, the Scheduled Personal Property endorsement (HF80VA) was revised, and a new edition (1124) was filed for approval.
#
# 4. **Disposition**:
#    - **Disposition Date**: 02/14/2025
#    - **Disposition Status**: Approved and Filed
#    - **Effective Date**: 07/01/2025
#    - **Comment**: All rule and rate amendments
# Processed additional filing info for: VA_FAIG-134391614.pdf
# Token count for API call in VA_FARM-134394962.pdf: 24164
# Processed additional filing info for: VA_FARM-134394962.pdf
# Token count for API call in VA_FORE-134214272.pdf: 11279
# GPT-3.5 Summary: The rate filing submitted by Foremost Insurance Company for the Classic Market Value Homeowners Program in Virginia was a request for revisions to the rule and rate sections. The filing aimed to introduce a new credit model known as the Verisk Inflection™ Model. The revisions included adjustments to premium modifiers and factors related to various aspects such as affinity, masonry, burglar alarm, central fire alarm, insurance score, insured age, and other rating parameters.
#
# The company conducted a retrovalidation study to determine the appropriate credit factors to be used with the new Inflection credit model. The study analyzed data from 2020 to 2022 and adjusted the modeled credit factors to achieve rate neutrality, ensuring consistency with the existing book of business and maintaining rate levels for both new customers and renewals.
#
# The rate filing process involved multiple revisions to rule and rate pages, as well as the replacement of manual pages to reflect the updated rules and factors. The filing was later acknowledged as withdrawn with the effective date requested for July 1, 2025, for both new and renewal policies. The disposition of the filing indicated a status of "Withdrawn" following the company's decision not to use the Inflection in its products.
#
# Processed additional filing info for: VA_FORE-134214272.pdf
# Token count for API call in VA_FORE-134214343.pdf: 14525
# GPT-3.5 Summary: The rate filing submitted by Foremost Insurance Company for their Homeowners Program in Virginia includes revisions to the rate section and the introduction of a new credit model, the Verisk Inflection™ Model from Insurance Services Office, Inc. The filing specified the base premiums, coverage details, rating criteria, and factors affecting premiums, such as the credit-based insurance risk assessment score, loss history, and various modifiers like masonry construction, affinity group membership, and protective devices.
#
# The company conducted a retrovalidation study to determine credit factors for the new model, ensuring consistency with existing business rates. The submission involved retrovalidation of data from 2020 to 2022 to align the modeled countrywide credit factors with the existing business in Virginia. Several rate pages were revised, and comparisons were provided to show the changes made.
#
# However, the filing eventually got withdrawn as per the note from the company seeking to remove the inflection model from their products. The rate filing was acknowledged as withdrawn by the company on February 19, 2025.
# Processed additional filing info for: VA_FORE-134214343.pdf
# Token count for API call in VA_FORE-134214394.pdf: 12527
# GPT-3.5 Summary: The rate filing submitted by Foremost Insurance Company for their Tenant Program in Virginia includes revisions to the rule and rate sections. They are introducing a new credit model, the Verisk Inflection™ Model from ISO. The filing was requested to be effective from 07/01/2025 for both new and renewal policies. However, the filing was ultimately withdrawn on 02/19/2025 by the company, indicating they will not be using Inflection in their products. The filing included a retrovalidation study to determine proper factors for the Inflection credit model and adjustments to ensure consistency in rate levels. The filing also included various supporting documents and feedback from DOI correspondences.
# Processed additional filing info for: VA_FORE-134214394.pdf
# Token count for API call in VA_HART-134374576.pdf: 16155
# Error calling GPT-3.5-turbo: Error code: 400 - {'error': {'message': "This model's maximum context length is 16385 tokens. However, you requested 16501 tokens (16201 in the messages, 300 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Processed additional filing info for: VA_HART-134374576.pdf
# Token count for API call in VA_LBPM-134395045.pdf: 3363981
# Processed additional filing info for: VA_LBPM-134395045.pdf
# Token count for API call in VA_SFMA-134386972.pdf: 95791
# Processed additional filing info for: VA_SFMA-134386972.pdf
# Token count for API call in VT_FAIG-134392452.pdf: 13019
# GPT-3.5 Summary: The rate filing submitted by Economy Fire & Casualty Company pertains to homeowners insurance in Vermont. The filing includes rate changes for Homeowners, Condo, and Renters policies, effective June 1, 2025. The filing consists of detailed information on the rating steps, premium calculations for various perils, optional coverages like Equipment Breakdown and Service Line coverage, as well as valuable personal property and scheduled personal property items.
#
# The filing also includes supporting documents such as Actuarial Memorandum, Certification of Rate or Premium Stability Rules, histograms showing percentage and dollar changes, side-by-side comparisons, and other necessary attachments. The overall impact of the proposed rate revision is estimated to be immaterial. The filing is submitted in compliance with Vermont regulations and guidelines related to rate stability rules and premium determinations.
# Processed additional filing info for: VT_FAIG-134392452.pdf
# Token count for API call in VT_TRVD-G134383069.pdf: 19260
# Processed additional filing info for: VT_TRVD-G134383069.pdf
# Token count for API call in WA_FAIG-134060459.pdf: 173259
# Processed additional filing info for: WA_FAIG-134060459.pdf
# Token count for API call in WI_SFMA-134414626.pdf: 35089
# Processed additional filing info for: WI_SFMA-134414626.pdf
# Token count for API call in WV_ALSE-134414963.pdf: 5104
# GPT-3.5 Summary: The rate filing by Allstate Vehicle and Property Insurance Company in West Virginia proposes changes to the installment fees for their homeowners insurance product, specifically the AVPIC HO Increase Installment Plans. The filing includes updates to the Installment Fee amounts for different payment methods. The changes involve increasing the Installment Fee for the Allstate Easy Pay Plan from $1.50 to $2.00 and increasing the fee for other payment methods (excluding Allstate Payroll Deductions) from $3.00 to $5.00. Additionally, the filing clarifies that Allstate Payroll Deductions will continue to have no Installment Fees.
#
# Overall, the filing aims to adjust and standardize the installment fee structure for their homeowners insurance policies in West Virginia to align with regulatory requirements and company practices. The filing was approved and has an effective date of July 14, 2025, for new policies and August 28, 2025, for renewals.
# Processed additional filing info for: WV_ALSE-134414963.pdf
# Token count for API call in WY_FARM-134351956.pdf: 94807
# Processed additional filing info for: WY_FARM-134351956.pdf
# Token count for API call in WY_FORE-134419284.pdf: 9365
# GPT-3.5 Summary: The rate filing pertains to the Foremost Insurance Company's Homeowners Program in Wyoming. The revised form, Form 5447 02/25 – Required Change - Wyoming, replaced the previous version, Form 5447 04/23, to remove reference to a minimum earned premium based on a data call filed under FORE-134375537. The filing was submitted on 02/17/2025 and was approved with an effective date of 06/01/2025. The SERFF Tracking Number for this filing is FORE-134419284, and it experienced a closed-approved status.
#
# The key changes in the form included alterations to personal liability coverage provisions, policy conditions regarding legal actions, and the transfer of the policy. Additionally, new conditions related to policy cancellation, nonrenewal, and automatic termination were introduced. The filing covered various forms associated with the Homeowners Program, ensuring compliance with Wyoming regulations for all facets of homeowners insurance coverage.
#
# The rate filing emphasizes the company's commitment to maintaining compliance with Wyoming Insurance Department regulations and ensuring that coverage for policyholders aligns with the state's legal requirements.
# Processed additional filing info for: WY_FORE-134419284.pdf
# Token count for API call in WY_FORE-134419401.pdf: 8731
# GPT-3.5 Summary: Based on the filing information provided, the insurance company Foremost Insurance Company submitted a rate filing for its Homeowners ACV Program in the state of Wyoming. The rate filing for the Homeowners ACV Program, specifically related to Form 35037, underwent a required change specific to Wyoming regulations. The disposition of the filing was approved with an effective date for both new and renewal policies set for June 1, 2025. The filing involved modifications to exclusions, policy conditions, transfer conditions, cancellation policies, nonrenewal procedures, and automatic termination provisions in the policy. Additionally, supporting documents and associated forms were included in the filing for compliance and informational purposes.
# Processed additional filing info for: WY_FORE-134419401.pdf
# Saved additional filing info JSON output to additional_filing_info_2025-02-24.json
# Saved additional filing info CSV output to additional_filing_info_2025-02-24.csv

# %%
###Updated so that the objection files are not the same as the additional info files 3.3. ###
###Note: this code doesn't work because the objections output code is taking too long (3.4)

# %%
import os
import re
import glob
import fitz  # PyMuPDF
import json
import pandas as pd
from datetime import datetime
from pprint import pprint
from dotenv import load_dotenv
import tiktoken  # pip install tiktoken

# Load environment variables (which should include api_key and grok_api_key)
load_dotenv()

# === API Call Control Parameters for additional filing info (not used for objections) ===
# Set each to 'Y' to call the API, or 'N' to skip the API call.
CALL_GPT_3_5 = "Y"
CALL_O1_MINI = "N"
CALL_XAI = "N"

# Create OpenAI client for standard models
from openai import OpenAI
api_key = os.getenv("api_key")
client = OpenAI(api_key=api_key)

# Create a separate client for the xAI API
XAI_API_KEY = os.getenv("grok_api_key")
xai_client = OpenAI(api_key=XAI_API_KEY, base_url="https://api.x.ai/v1")

# Define the download week as a string and convert it to a datetime object.
date = "2025-02-24"
download_week_dt = datetime.strptime(date, "%Y-%m-%d")

# --- Helper functions for token counting and truncation using tiktoken ---
def count_tokens(text, model="gpt-3.5-turbo"):
    """
    Returns the number of tokens in the given text using tiktoken.
    """
    try:
        encoding = tiktoken.encoding_for_model(model)
    except Exception:
        encoding = tiktoken.get_encoding("cl100k_base")
    tokens = encoding.encode(text)
    return len(tokens)

def truncate_text(text, max_tokens, model="gpt-3.5-turbo"):
    """
    Truncates `text` to at most `max_tokens` using tiktoken encoding.
    """
    try:
        encoding = tiktoken.encoding_for_model(model)
    except Exception:
        encoding = tiktoken.get_encoding("cl100k_base")
    tokens = encoding.encode(text)
    if len(tokens) > max_tokens:
        truncated_tokens = tokens[:max_tokens]
        truncated_text = encoding.decode(truncated_tokens)
        return truncated_text
    return text

# --- API call functions (used in additional filing info only) ---
def call_gpt_3_5_turbo(full_text):
    try:
        completion = client.chat.completions.create(
            model="gpt-3.5-turbo",
            messages=[
                {"role": "system", "content": "You are an analyst doing competitive intelligence research on insurance companies."},
                {"role": "user", "content": f"The following is a filing with a DOI from an insurance company: '{full_text}'. Give a summary of the rate filing."}
            ],
            max_tokens=300
        )
        print("GPT-3.5 Summary:", completion.choices[0].message.content)
        return completion.choices[0].message.content
    except Exception as e:
        print(f"Error calling GPT-3.5-turbo: {e}")
        return ""

def call_o1_mini(full_text):
    try:
        completion = client.chat.completions.create(
            model="o1-mini",
            messages=[
                {"role": "user", "content": "You are an analyst doing competitive intelligence research on insurance companies."},
                {"role": "user", "content": f"The following is a filing with a DOI from an insurance company: '{full_text}'. Give a summary of the rate filing."}
            ]
        )
        print("o1-mini Summary:", completion.choices[0].message.content)
        return completion.choices[0].message.content
    except Exception as e:
        print(f"Error calling o1-mini: {e}")
        return ""

def call_xai(full_text):
    try:
        completion = xai_client.chat.completions.create(
            model="grok-2-latest",
            messages=[
                {"role": "system", "content": "You are an analyst doing competitive intelligence research on insurance companies."},
                {"role": "user", "content": f"The following is a filing with a DOI from an insurance company: '{full_text}'. Give a summary of the rate filing."}
            ]
        )
        print("xAI Summary:", completion.choices[0].message.content)
        return completion.choices[0].message.content
    except Exception as e:
        print(f"Error calling xAI: {e}")
        return ""

# --- Extraction functions for non-API parts ---
def extract_full_text(pdf_path, max_pages=None):
    """
    Extracts full text from PDF.
    If max_pages is provided, only extracts from the first max_pages pages.
    """
    doc = fitz.open(pdf_path)
    full_text = ""
    for i, page in enumerate(doc):
        if max_pages is not None and i >= max_pages:
            break
        full_text += page.get_text() + "\n"
    doc.close()
    return full_text

def split_list_objections(text):
    parts = re.split(r"(?m)^\s*(?:\(?(\d+)\)?[.\)])\s*", text)
    objections = {}
    if len(parts) >= 3:
        for i in range(1, len(parts)-1, 2):
            num = parts[i].strip()
            obj_text = parts[i+1].strip()
            objections[f"objection{num}"] = obj_text
        if not objections:
            objections["objection1"] = text.strip()
    else:
        objections["objection1"] = text.strip()
    return objections

def parse_objection_letters(text):
    """
    Splits the full text into separate objection letter sections.
    A valid objection letter must contain "Objection Letter Date", "Introduction:" and "Conclusion:".
    Returns a dictionary where each key is "Objection_letterX" with its parsed objections.
    """
    pattern = r"(Objection Letter.*?Objection Letter Date\s+(\d{2}/\d{2}/\d{4}).*?Introduction:\s*(.*?)\s*Conclusion:)"
    matches = list(re.finditer(pattern, text, flags=re.IGNORECASE | re.DOTALL))
    letter_dict = {}
    for idx, m in enumerate(matches, start=1):
        letter_date = m.group(2).strip()
        body = m.group(3).strip()
        explicit_objs = list(re.finditer(r"Objection\s+(\d+)", body, flags=re.IGNORECASE))
        if len(explicit_objs) > 1:
            obj_pattern = r"(Objection\s+(\d+).*?)(?=(Objection\s+\d+|Conclusion:|$))"
            objections = {}
            for om in re.finditer(obj_pattern, body, flags=re.IGNORECASE | re.DOTALL):
                num = om.group(2).strip()
                obj_text = om.group(1).strip()
                objections[f"objection{num}"] = obj_text
        else:
            if re.search(r"(?m)^\s*(\(?\d+\)?[.\)])", body):
                objections = split_list_objections(body)
            else:
                objections = {"objection1": body}
        letter_dict[f"Objection_letter{idx}"] = {
            "objection_letter_date": letter_date,
            **objections
        }
    return letter_dict

def extract_filing_company_info(text):
    """
    Extracts filing company information.
    Returns a tuple: (group_code, company_codes)
    """
    company_codes = re.findall(r"CoCode:\s*(\d+)", text, flags=re.IGNORECASE)
    group_codes = re.findall(r"Group Code:\s*(\d+)", text, flags=re.IGNORECASE)
    company_codes = [int(code) for code in company_codes] if company_codes else []
    group_code = int(group_codes[0]) if group_codes else None
    return group_code, company_codes

# --- Extraction functions for additional filing info ---
def parse_filing_at_a_glance(text):
    """
    Extracts key filing info from the "Filing at a Glance" section.
    Returns a dictionary with keys: serff_tr_num, filing_type, date_submitted,
    effective_date_requested_new, effective_date_requested_renewal, serff_status, toi.
    """
    info = {}
    match = re.search(r"Filing at a Glance(.*?)(?=\n[A-Z][a-z]+ Information|$)", text, flags=re.IGNORECASE | re.DOTALL)
    section = match.group(1) if match else ""
    
    serff_match = re.search(r"SERFF Tr Num:\s*([A-Z0-9\-]+)", section, flags=re.IGNORECASE)
    info["serff_tr_num"] = serff_match.group(1).strip() if serff_match else ""
    
    filing_type_match = re.search(r"Filing Type:\s*([^\n]+)", section, flags=re.IGNORECASE)
    info["filing_type"] = filing_type_match.group(1).strip() if filing_type_match else ""
    
    date_submitted_match = re.search(r"Date Submitted:\s*(\d{2}/\d{2}/\d{4})", section, flags=re.IGNORECASE)
    info["date_submitted"] = date_submitted_match.group(1).strip() if date_submitted_match else ""
    
    effective_new_match = re.search(r"Effective Date\s*Requested\s*\(New\):\s*(\d{2}/\d{2}/\d{4})", section, flags=re.IGNORECASE)
    info["effective_date_requested_new"] = effective_new_match.group(1).strip() if effective_new_match else ""
    
    effective_renewal_match = re.search(r"Effective Date\s*Requested\s*\(Renewal\):\s*(\d{2}/\d{2}/\d{4})", section, flags=re.IGNORECASE)
    info["effective_date_requested_renewal"] = effective_renewal_match.group(1).strip() if effective_renewal_match else ""
    
    serff_status_match = re.search(r"SERFF Status:\s*([^\n]+)", section, flags=re.IGNORECASE)
    info["serff_status"] = serff_status_match.group(1).strip() if serff_status_match else ""
    
    toi_match = re.search(r"TOI:\s*([^\n]+)", section, flags=re.IGNORECASE)
    info["toi"] = toi_match.group(1).strip() if toi_match else ""
    
    return info

def parse_filing_description(text):
    """
    Extracts the Filing Description from the text.
    Returns the description string.
    """
    match = re.search(r"Filing Description:\s*(.*?)\s*(Filing Contact Information|Filing Company Information)", 
                      text, flags=re.IGNORECASE | re.DOTALL)
    if match:
        return match.group(1).strip()
    return ""

# --- Processing functions for objections (old version) ---
def process_pdf_file(pdf_path):
    """
    Processes a single PDF file for objections output.
    Returns a dictionary with keys:
      - "objections": parsed objection letters,
      - "group_code": extracted group code,
      - "company_codes": list of CoCodes,
      - "download_week": the download_week datetime.
    """
    full_text = extract_full_text(pdf_path)
    parsed_letters = parse_objection_letters(full_text)
    group_code, company_codes = extract_filing_company_info(full_text)
    file_key = os.path.splitext(os.path.basename(pdf_path))[0]
    return {file_key: {
                "objections": parsed_letters,
                "group_code": group_code,
                "company_codes": company_codes,
                "download_week": download_week_dt
            }}

def process_all_pdfs_in_folder(pdf_folder):
    """
    Loops through all PDF files in the folder and processes each for objections output.
    Returns a nested dictionary.
    """
    results = {}
    pdf_files = glob.glob(os.path.join(pdf_folder, "*.pdf"))
    for pdf_file in pdf_files:
        print(pdf_file)
        print(datetime.now())
        results.update(process_pdf_file(pdf_file))
    return results

# --- Processing functions for additional filing info (with API calls) ---
def extract_full_text_all(pdf_path):
    """
    Extracts full text from the PDF using up to the first 3000 pages.
    """
    return extract_full_text(pdf_path, max_pages=3000)

def process_pdf_additional(pdf_path):
    """
    Processes a single PDF file and extracts additional filing info.
    For non-API info, uses the first 100 pages.
    For API calls, uses the full text (up to 3000 pages) subject to token constraints.
    Returns a dictionary with keys including API summaries.
    """
    # Non-API extraction (first 100 pages)
    limited_text = extract_full_text(pdf_path, max_pages=100)
    filing_at_a_glance = parse_filing_at_a_glance(limited_text)
    filing_description = parse_filing_description(limited_text)
    group_code, company_codes = extract_filing_company_info(limited_text)
    
    # API extraction using full text (up to 3000 pages)
    full_text_all = extract_full_text_all(pdf_path)
    token_count = count_tokens(full_text_all, model="gpt-3.5-turbo")
    print(f"Token count for API call in {os.path.basename(pdf_path)}: {token_count}")
    
    if token_count < 16385:
        api_text = full_text_all
        gpt_3_5_summary = call_gpt_3_5_turbo(full_text_all) if CALL_GPT_3_5 == "Y" else ""
    elif token_count < 75000:
        api_text = full_text_all
        gpt_3_5_summary = ""  # Skip GPT-3.5-turbo
    else:
        api_text = truncate_text(full_text_all, max_tokens=75000, model="gpt-3.5-turbo")
        gpt_3_5_summary = ""
    
    o1_mini_summary = call_o1_mini(api_text) if CALL_O1_MINI == "Y" else ""
    xai_summary = call_xai(api_text) if CALL_XAI == "Y" else ""
    
    additional = {
        "serff_tr_num": filing_at_a_glance.get("serff_tr_num", ""),
        "filing_type": filing_at_a_glance.get("filing_type", ""),
        "date_submitted": filing_at_a_glance.get("date_submitted", ""),
        "effective_date_requested_new": filing_at_a_glance.get("effective_date_requested_new", ""),
        "effective_date_requested_renewal": filing_at_a_glance.get("effective_date_requested_renewal", ""),
        "serff_status": filing_at_a_glance.get("serff_status", ""),
        "filing_description": filing_description,
        "filing_method": "",  # Not extracted
        "toi": filing_at_a_glance.get("toi", ""),
        "group_code": group_code,
        "company_codes": company_codes,
        "download_week": download_week_dt,
        "gpt_3_5_summary": gpt_3_5_summary,
        "o1_mini_summary": o1_mini_summary,
        "xai_summary": xai_summary
    }
    print(f"Processed additional filing info for: {os.path.basename(pdf_path)}")
    return additional

def process_all_pdfs_additional(pdf_folder):
    """
    Processes all PDFs in the folder for additional filing info.
    Returns a dictionary keyed by file name.
    """
    results = {}
    pdf_files = glob.glob(os.path.join(pdf_folder, "*.pdf"))
    for pdf_file in pdf_files:
        print(pdf_file)
        print(datetime.now())
        file_key = os.path.splitext(os.path.basename(pdf_file))[0]
        results[file_key] = process_pdf_additional(pdf_file)
    return results

def additional_to_dataframe(results):
    """
    Converts the additional filing info dictionary into a DataFrame.
    """
    rows = []
    for file_key, info in results.items():
        row = {
            "SERFF Tr Num": info.get("serff_tr_num", ""),
            "Filing Type": info.get("filing_type", ""),
            "Date Submitted": info.get("date_submitted", ""),
            "Effective Date Requested (New)": info.get("effective_date_requested_new", ""),
            "Effective Date Requested (Renewal)": info.get("effective_date_requested_renewal", ""),
            "SERFF Status": info.get("serff_status", ""),
            "Filing Description": info.get("filing_description", ""),
            "Filing Method": info.get("filing_method", ""),
            "TOI": info.get("toi", ""),
            "Group_Code": info.get("group_code", ""),
            "Company_Codes": str(info.get("company_codes", "")),
            "week_date": info.get("download_week", None),
            "gpt_3_5_summary": info.get("gpt_3_5_summary", ""),
            "o1_mini_summary": info.get("o1_mini_summary", ""),
            "xai_summary": info.get("xai_summary", "")
        }
        rows.append(row)
    df = pd.DataFrame(rows, columns=[
        "SERFF Tr Num", "Filing Type", "Date Submitted", 
        "Effective Date Requested (New)", "Effective Date Requested (Renewal)",
        "SERFF Status", "Filing Description", "Filing Method", "TOI",
        "Group_Code", "Company_Codes", "week_date",
        "gpt_3_5_summary", "o1_mini_summary", "xai_summary"
    ])
    return df

# --- DataFrame for objections ---
def results_to_dataframe_objections(results):
    """
    Converts the objections dictionary (from process_all_pdfs_in_folder) into a DataFrame.
    """
    rows = []
    for file_key, file_info in results.items():
        state_abbr = file_key.split('_')[0] if "_" in file_key else file_key[:2]
        group_code = file_info.get("group_code", "No objections")
        company_codes = file_info.get("company_codes", [])
        company_code_first = company_codes[0] if company_codes else "No objections"
        company_codes_str = str(company_codes) if company_codes else "No objections"
        download_week = file_info.get("download_week", None)
        letter_dict = file_info.get("objections", {})
        if not letter_dict:
            rows.append({
                "SERFF#": file_key,
                "State": state_abbr,
                "Group_Code": group_code,
                "Company_Code": company_code_first,
                "Company_Code_all": company_codes_str,
                "Objection_letter_date": "No objections",
                "Objectionletter#": "No objections",
                "Objection#": "No objections",
                "Objection": "No objections",
                "download_week": download_week
            })
        else:
            for letter_key, letter_content in letter_dict.items():
                letter_date = letter_content.get("objection_letter_date", "No objections")
                for obj_key, obj_text in letter_content.items():
                    if obj_key == "objection_letter_date":
                        continue
                    rows.append({
                        "SERFF#": file_key,
                        "State": state_abbr,
                        "Group_Code": group_code,
                        "Company_Code": company_code_first,
                        "Company_Code_all": company_codes_str,
                        "Objection_letter_date": letter_date,
                        "Objectionletter#": letter_key,
                        "Objection#": obj_key,
                        "Objection": obj_text.replace("\n", " ").strip(),
                        "download_week": download_week
                    })
    df = pd.DataFrame(rows, columns=[
        "SERFF#", "State", "Group_Code", "Company_Code", "Company_Code_all", 
        "Objection_letter_date", "Objectionletter#", "Objection#", "Objection", "download_week"
    ])
    return df

# --- Main Processing ---
pdf_folder = f"Filings/Final/{date}"  # Folder path based on date parameter

# Process objections using the old functions.
objection_results = process_all_pdfs_in_folder(pdf_folder)
json_output_path = f"objections_output_{date}.json"
with open(json_output_path, "w", encoding="utf-8") as f:
    json.dump(objection_results, f, default=lambda o: o.isoformat() if isinstance(o, datetime) else o, ensure_ascii=False, indent=4)
print(f"Saved objections JSON output to {json_output_path}")

df_objections = results_to_dataframe_objections(objection_results)
csv_output_path = f"objections_output_{date}.csv"
df_objections.to_csv(csv_output_path, index=False)
print(f"Saved objections CSV output to {csv_output_path}")

# Process additional filing info using the new function.
additional_results = process_all_pdfs_additional(pdf_folder)
additional_json_output_path = f"additional_filing_info_{date}.json"
with open(additional_json_output_path, "w", encoding="utf-8") as f:
    json.dump(additional_results, f, default=lambda o: o.isoformat() if isinstance(o, datetime) else o, ensure_ascii=False, indent=4)
print(f"Saved additional filing info JSON output to {additional_json_output_path}")

df_additional = additional_to_dataframe(additional_results)
additional_csv_output_path = f"additional_filing_info_{date}.csv"
df_additional.to_csv(additional_csv_output_path, index=False)
print(f"Saved additional filing info CSV output to {additional_csv_output_path}")
# Out:
# Filings/Final/2025-02-24\AR_LBPM-134402349.pdf
# 2025-03-04 07:03:10.655069
# Filings/Final/2025-02-24\AR_LBPM-134415366.pdf
# 2025-03-04 07:03:10.776022
# Filings/Final/2025-02-24\AR_SFMA-134403457.pdf
# 2025-03-04 07:03:10.875763
# Filings/Final/2025-02-24\AZ_ALSE-134423427.pdf
# 2025-03-04 07:03:11.035603
# Filings/Final/2025-02-24\AZ_ALSE-134423455.pdf
# 2025-03-04 07:03:11.436744
# Filings/Final/2025-02-24\AZ_ALSE-134423481.pdf
# 2025-03-04 07:03:11.934508
# Filings/Final/2025-02-24\AZ_ALSE-134424632.pdf
# 2025-03-04 07:03:12.725094
# Filings/Final/2025-02-24\AZ_ALSE-134424807.pdf
# 2025-03-04 07:03:12.990511
# Filings/Final/2025-02-24\AZ_ALSE-134424886.pdf
# 2025-03-04 07:03:13.215586
# Filings/Final/2025-02-24\AZ_ALSE-134424967.pdf
# 2025-03-04 07:03:13.413454
# Filings/Final/2025-02-24\AZ_FARM-134267371.pdf
# 2025-03-04 07:03:13.708456
# Filings/Final/2025-02-24\AZ_GMMX-134417367.pdf
# 2025-03-04 07:03:14.026352
# Filings/Final/2025-02-24\CA_ALSE-134306035.pdf
# 2025-03-04 07:03:14.363579
# Filings/Final/2025-02-24\CA_AMSI-134390951.pdf
# 2025-03-04 07:03:17.180413
# Filings/Final/2025-02-24\CA_HART-133954912.pdf
# 2025-03-04 07:03:26.082762
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30208\2638312109.py in ?()
#     414 # --- Main Processing ---
#     415 pdf_folder = f"Filings/Final/{date}"  # Folder path based on date parameter
#     416
#     417 # Process objections using the old functions.
# --> 418 objection_results = process_all_pdfs_in_folder(pdf_folder)
#     419 json_output_path = f"objections_output_{date}.json"
#     420 with open(json_output_path, "w", encoding="utf-8") as f:
#     421     json.dump(objection_results, f, default=lambda o: o.isoformat() if isinstance(o, datetime) else o, ensure_ascii=False, indent=4)
#
# ~\AppData\Local\Temp\ipykernel_30208\2638312109.py in ?(pdf_folder)
#     251     pdf_files = glob.glob(os.path.join(pdf_folder, "*.pdf"))
#     252     for pdf_file in pdf_files:
#     253         print(pdf_file)
#     254         print(datetime.now())
# --> 255         results.update(process_pdf_file(pdf_file))
#     256     return results
#
# ~\AppData\Local\Temp\ipykernel_30208\2638312109.py in ?(pdf_path)
#     230       - "group_code": extracted group code,
#     231       - "company_codes": list of CoCodes,
#     232       - "download_week": the download_week datetime.
#     233     """
# --> 234     full_text = extract_full_text(pdf_path)
#     235     parsed_letters = parse_objection_letters(full_text)
#     236     group_code, company_codes = extract_filing_company_info(full_text)
#     237     file_key = os.path.splitext(os.path.basename(pdf_path))[0]
#
# ~\AppData\Local\Temp\ipykernel_30208\2638312109.py in ?(pdf_path, max_pages)
#     112     If max_pages is provided, only extracts from the first max_pages pages.
#     113     """
#     114     doc = fitz.open(pdf_path)
#     115     full_text = ""
# --> 116     for i, page in enumerate(doc):
#     117         if max_pages is not None and i >= max_pages:
#     118             break
#     119         full_text += page.get_text() + "\n"
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymupdf\__init__.py in ?(self, i)
# -> 2872     def __getitem__(self, i=0):
#    2873         if isinstance(i, slice):
#    2874             return [self[j] for j in range(*i.indices(len(self)))]
#    2875         assert isinstance(i, int) or (isinstance(i, tuple) and len(i) == 2 and all(isinstance(x, int) for x in i)), \
#
# KeyboardInterrupt:

# %%
### Update to truncate pdf to first 100 pages for the objection extraction part of the pdf 3.4 ###

# %%
import os
import re
import glob
import fitz  # PyMuPDF
import json
import pandas as pd
from datetime import datetime
from pprint import pprint
from dotenv import load_dotenv
import tiktoken  # pip install tiktoken

# Load environment variables (which should include api_key and grok_api_key)
load_dotenv()

# === API Call Control Parameters for additional filing info (not used for objections) ===
# Set each to 'Y' to call the API, or 'N' to skip the API call.
CALL_GPT_3_5 = "Y"
CALL_O1_MINI = "N"
CALL_XAI = "N"

# Create OpenAI client for standard models
from openai import OpenAI
api_key = os.getenv("api_key")
client = OpenAI(api_key=api_key)

# Create a separate client for the xAI API
XAI_API_KEY = os.getenv("grok_api_key")
xai_client = OpenAI(api_key=XAI_API_KEY, base_url="https://api.x.ai/v1")

# Define the download week as a string and convert it to a datetime object.
date = "2025-02-24"
download_week_dt = datetime.strptime(date, "%Y-%m-%d")

# --- Helper functions for token counting and truncation using tiktoken ---
def count_tokens(text, model="gpt-3.5-turbo"):
    try:
        encoding = tiktoken.encoding_for_model(model)
    except Exception:
        encoding = tiktoken.get_encoding("cl100k_base")
    tokens = encoding.encode(text)
    return len(tokens)

def truncate_text(text, max_tokens, model="gpt-3.5-turbo"):
    try:
        encoding = tiktoken.encoding_for_model(model)
    except Exception:
        encoding = tiktoken.get_encoding("cl100k_base")
    tokens = encoding.encode(text)
    if len(tokens) > max_tokens:
        truncated_tokens = tokens[:max_tokens]
        truncated_text = encoding.decode(truncated_tokens)
        return truncated_text
    return text

# --- API call functions (used in additional filing info only) ---
def call_gpt_3_5_turbo(full_text):
    try:
        completion = client.chat.completions.create(
            model="gpt-3.5-turbo",
            messages=[
                {"role": "system", "content": "You are an analyst doing competitive intelligence research on insurance companies."},
                {"role": "user", "content": f"The following is a filing with a DOI from an insurance company: '{full_text}'. Give a summary of the rate filing."}
            ],
            max_tokens=300
        )
        print("GPT-3.5 Summary:", completion.choices[0].message.content)
        return completion.choices[0].message.content
    except Exception as e:
        print(f"Error calling GPT-3.5-turbo: {e}")
        return ""

def call_o1_mini(full_text):
    try:
        completion = client.chat.completions.create(
            model="o1-mini",
            messages=[
                {"role": "user", "content": "You are an analyst doing competitive intelligence research on insurance companies."},
                {"role": "user", "content": f"The following is a filing with a DOI from an insurance company: '{full_text}'. Give a summary of the rate filing."}
            ]
        )
        print("o1-mini Summary:", completion.choices[0].message.content)
        return completion.choices[0].message.content
    except Exception as e:
        print(f"Error calling o1-mini: {e}")
        return ""

def call_xai(full_text):
    try:
        completion = xai_client.chat.completions.create(
            model="grok-2-latest",
            messages=[
                {"role": "system", "content": "You are an analyst doing competitive intelligence research on insurance companies."},
                {"role": "user", "content": f"The following is a filing with a DOI from an insurance company: '{full_text}'. Give a summary of the rate filing."}
            ]
        )
        print("xAI Summary:", completion.choices[0].message.content)
        return completion.choices[0].message.content
    except Exception as e:
        print(f"Error calling xAI: {e}")
        return ""

# --- Extraction functions for non-API parts ---
def extract_full_text(pdf_path, max_pages=None):
    """
    Extracts full text from PDF.
    If max_pages is provided, only extracts from the first max_pages pages.
    """
    doc = fitz.open(pdf_path)
    full_text = ""
    for i, page in enumerate(doc):
        if max_pages is not None and i >= max_pages:
            break
        full_text += page.get_text() + "\n"
    doc.close()
    return full_text

def split_list_objections(text):
    parts = re.split(r"(?m)^\s*(?:\(?(\d+)\)?[.\)])\s*", text)
    objections = {}
    if len(parts) >= 3:
        for i in range(1, len(parts)-1, 2):
            num = parts[i].strip()
            obj_text = parts[i+1].strip()
            objections[f"objection{num}"] = obj_text
        if not objections:
            objections["objection1"] = text.strip()
    else:
        objections["objection1"] = text.strip()
    return objections

def parse_objection_letters(text):
    """
    Splits the full text into separate objection letter sections.
    A valid objection letter must contain "Objection Letter Date", "Introduction:" and "Conclusion:".
    Returns a dictionary where each key is "Objection_letterX" with its parsed objections.
    """
    pattern = r"(Objection Letter.*?Objection Letter Date\s+(\d{2}/\d{2}/\d{4}).*?Introduction:\s*(.*?)\s*Conclusion:)"
    matches = list(re.finditer(pattern, text, flags=re.IGNORECASE | re.DOTALL))
    letter_dict = {}
    for idx, m in enumerate(matches, start=1):
        letter_date = m.group(2).strip()
        body = m.group(3).strip()
        explicit_objs = list(re.finditer(r"Objection\s+(\d+)", body, flags=re.IGNORECASE))
        if len(explicit_objs) > 1:
            obj_pattern = r"(Objection\s+(\d+).*?)(?=(Objection\s+\d+|Conclusion:|$))"
            objections = {}
            for om in re.finditer(obj_pattern, body, flags=re.IGNORECASE | re.DOTALL):
                num = om.group(2).strip()
                obj_text = om.group(1).strip()
                objections[f"objection{num}"] = obj_text
        else:
            if re.search(r"(?m)^\s*(\(?\d+\)?[.\)])", body):
                objections = split_list_objections(body)
            else:
                objections = {"objection1": body}
        letter_dict[f"Objection_letter{idx}"] = {
            "objection_letter_date": letter_date,
            **objections
        }
    return letter_dict

def extract_filing_company_info(text):
    """
    Extracts filing company information.
    Returns a tuple: (group_code, company_codes)
    """
    company_codes = re.findall(r"CoCode:\s*(\d+)", text, flags=re.IGNORECASE)
    group_codes = re.findall(r"Group Code:\s*(\d+)", text, flags=re.IGNORECASE)
    company_codes = [int(code) for code in company_codes] if company_codes else []
    group_code = int(group_codes[0]) if group_codes else None
    return group_code, company_codes

# --- Extraction functions for additional filing info ---
def parse_filing_at_a_glance(text):
    """
    Extracts key filing info from the "Filing at a Glance" section.
    Returns a dictionary with keys: serff_tr_num, filing_type, date_submitted,
    effective_date_requested_new, effective_date_requested_renewal, serff_status, toi.
    """
    info = {}
    match = re.search(r"Filing at a Glance(.*?)(?=\n[A-Z][a-z]+ Information|$)", text, flags=re.IGNORECASE | re.DOTALL)
    section = match.group(1) if match else ""
    
    serff_match = re.search(r"SERFF Tr Num:\s*([A-Z0-9\-]+)", section, flags=re.IGNORECASE)
    info["serff_tr_num"] = serff_match.group(1).strip() if serff_match else ""
    
    filing_type_match = re.search(r"Filing Type:\s*([^\n]+)", section, flags=re.IGNORECASE)
    info["filing_type"] = filing_type_match.group(1).strip() if filing_type_match else ""
    
    date_submitted_match = re.search(r"Date Submitted:\s*(\d{2}/\d{2}/\d{4})", section, flags=re.IGNORECASE)
    info["date_submitted"] = date_submitted_match.group(1).strip() if date_submitted_match else ""
    
    effective_new_match = re.search(r"Effective Date\s*Requested\s*\(New\):\s*(\d{2}/\d{2}/\d{4})", section, flags=re.IGNORECASE)
    info["effective_date_requested_new"] = effective_new_match.group(1).strip() if effective_new_match else ""
    
    effective_renewal_match = re.search(r"Effective Date\s*Requested\s*\(Renewal\):\s*(\d{2}/\d{2}/\d{4})", section, flags=re.IGNORECASE)
    info["effective_date_requested_renewal"] = effective_renewal_match.group(1).strip() if effective_renewal_match else ""
    
    serff_status_match = re.search(r"SERFF Status:\s*([^\n]+)", section, flags=re.IGNORECASE)
    info["serff_status"] = serff_status_match.group(1).strip() if serff_status_match else ""
    
    toi_match = re.search(r"TOI:\s*([^\n]+)", section, flags=re.IGNORECASE)
    info["toi"] = toi_match.group(1).strip() if toi_match else ""
    
    return info

def parse_filing_description(text):
    """
    Extracts the Filing Description from the text.
    Returns the description string.
    """
    match = re.search(r"Filing Description:\s*(.*?)\s*(Filing Contact Information|Filing Company Information)", 
                      text, flags=re.IGNORECASE | re.DOTALL)
    if match:
        return match.group(1).strip()
    return ""

# --- Processing functions for objections (old version) ---
def process_pdf_file(pdf_path):
    """
    Processes a single PDF file for objections output.
    Truncates the PDF to the first 100 pages before processing.
    Returns a dictionary with keys:
      - "objections": parsed objection letters,
      - "group_code": extracted group code,
      - "company_codes": list of CoCodes,
      - "download_week": the download_week datetime.
    """
    # Truncate to first 100 pages
    full_text = extract_full_text(pdf_path, max_pages=100)
    parsed_letters = parse_objection_letters(full_text)
    group_code, company_codes = extract_filing_company_info(full_text)
    file_key = os.path.splitext(os.path.basename(pdf_path))[0]
    return {file_key: {
                "objections": parsed_letters,
                "group_code": group_code,
                "company_codes": company_codes,
                "download_week": download_week_dt
            }}

def process_all_pdfs_in_folder(pdf_folder):
    """
    Loops through all PDF files in the folder and processes each for objections output.
    Returns a nested dictionary.
    """
    results = {}
    pdf_files = glob.glob(os.path.join(pdf_folder, "*.pdf"))
    for pdf_file in pdf_files:
        print(pdf_file)
        print(datetime.now())
        results.update(process_pdf_file(pdf_file))
    return results

# --- Processing functions for additional filing info (with API calls) ---
def extract_full_text_all(pdf_path):
    """
    Extracts full text from the PDF using up to the first 3000 pages.
    """
    return extract_full_text(pdf_path, max_pages=3000)

def process_pdf_additional(pdf_path):
    """
    Processes a single PDF file and extracts additional filing info.
    For non-API info, uses the first 100 pages.
    For API calls, uses the full text (up to 3000 pages) subject to token constraints.
    Returns a dictionary with keys including API summaries.
    """
    # Non-API extraction (first 100 pages)
    limited_text = extract_full_text(pdf_path, max_pages=100)
    filing_at_a_glance = parse_filing_at_a_glance(limited_text)
    filing_description = parse_filing_description(limited_text)
    group_code, company_codes = extract_filing_company_info(limited_text)
    
    # API extraction using full text (up to 3000 pages)
    full_text_all = extract_full_text_all(pdf_path)
    token_count = count_tokens(full_text_all, model="gpt-3.5-turbo")
    print(f"Token count for API call in {os.path.basename(pdf_path)}: {token_count}")
    
    if token_count < 16385:
        api_text = full_text_all
        gpt_3_5_summary = call_gpt_3_5_turbo(full_text_all) if CALL_GPT_3_5 == "Y" else ""
    elif token_count < 75000:
        api_text = full_text_all
        gpt_3_5_summary = ""  # Skip GPT-3.5-turbo
    else:
        api_text = truncate_text(full_text_all, max_tokens=75000, model="gpt-3.5-turbo")
        gpt_3_5_summary = ""
    
    o1_mini_summary = call_o1_mini(api_text) if CALL_O1_MINI == "Y" else ""
    xai_summary = call_xai(api_text) if CALL_XAI == "Y" else ""
    
    additional = {
        "serff_tr_num": filing_at_a_glance.get("serff_tr_num", ""),
        "filing_type": filing_at_a_glance.get("filing_type", ""),
        "date_submitted": filing_at_a_glance.get("date_submitted", ""),
        "effective_date_requested_new": filing_at_a_glance.get("effective_date_requested_new", ""),
        "effective_date_requested_renewal": filing_at_a_glance.get("effective_date_requested_renewal", ""),
        "serff_status": filing_at_a_glance.get("serff_status", ""),
        "filing_description": filing_description,
        "filing_method": "",  # Not extracted
        "toi": filing_at_a_glance.get("toi", ""),
        "group_code": group_code,
        "company_codes": company_codes,
        "download_week": download_week_dt,
        "gpt_3_5_summary": gpt_3_5_summary,
        "o1_mini_summary": o1_mini_summary,
        "xai_summary": xai_summary
    }
    print(f"Processed additional filing info for: {os.path.basename(pdf_path)}")
    return additional

def process_all_pdfs_additional(pdf_folder):
    """
    Processes all PDFs in the folder for additional filing info.
    Returns a dictionary keyed by file name.
    """
    results = {}
    pdf_files = glob.glob(os.path.join(pdf_folder, "*.pdf"))
    for pdf_file in pdf_files:
        print(pdf_file)
        print(datetime.now())
        file_key = os.path.splitext(os.path.basename(pdf_file))[0]
        results[file_key] = process_pdf_additional(pdf_file)
    return results

def additional_to_dataframe(results):
    """
    Converts the additional filing info dictionary into a DataFrame.
    """
    rows = []
    for file_key, info in results.items():
        row = {
            "SERFF Tr Num": info.get("serff_tr_num", ""),
            "Filing Type": info.get("filing_type", ""),
            "Date Submitted": info.get("date_submitted", ""),
            "Effective Date Requested (New)": info.get("effective_date_requested_new", ""),
            "Effective Date Requested (Renewal)": info.get("effective_date_requested_renewal", ""),
            "SERFF Status": info.get("serff_status", ""),
            "Filing Description": info.get("filing_description", ""),
            "Filing Method": info.get("filing_method", ""),
            "TOI": info.get("toi", ""),
            "Group_Code": info.get("group_code", ""),
            "Company_Codes": str(info.get("company_codes", "")),
            "week_date": info.get("download_week", None),
            "gpt_3_5_summary": info.get("gpt_3_5_summary", ""),
            "o1_mini_summary": info.get("o1_mini_summary", ""),
            "xai_summary": info.get("xai_summary", "")
        }
        rows.append(row)
    df = pd.DataFrame(rows, columns=[
        "SERFF Tr Num", "Filing Type", "Date Submitted", 
        "Effective Date Requested (New)", "Effective Date Requested (Renewal)",
        "SERFF Status", "Filing Description", "Filing Method", "TOI",
        "Group_Code", "Company_Codes", "week_date",
        "gpt_3_5_summary", "o1_mini_summary", "xai_summary"
    ])
    return df

# --- DataFrame for objections ---
def results_to_dataframe_objections(results):
    """
    Converts the objections dictionary (from process_all_pdfs_in_folder) into a DataFrame.
    """
    rows = []
    for file_key, file_info in results.items():
        state_abbr = file_key.split('_')[0] if "_" in file_key else file_key[:2]
        group_code = file_info.get("group_code", "No objections")
        company_codes = file_info.get("company_codes", [])
        company_code_first = company_codes[0] if company_codes else "No objections"
        company_codes_str = str(company_codes) if company_codes else "No objections"
        download_week = file_info.get("download_week", None)
        letter_dict = file_info.get("objections", {})
        if not letter_dict:
            rows.append({
                "SERFF#": file_key,
                "State": state_abbr,
                "Group_Code": group_code,
                "Company_Code": company_code_first,
                "Company_Code_all": company_codes_str,
                "Objection_letter_date": "No objections",
                "Objectionletter#": "No objections",
                "Objection#": "No objections",
                "Objection": "No objections",
                "download_week": download_week
            })
        else:
            for letter_key, letter_content in letter_dict.items():
                letter_date = letter_content.get("objection_letter_date", "No objections")
                for obj_key, obj_text in letter_content.items():
                    if obj_key == "objection_letter_date":
                        continue
                    rows.append({
                        "SERFF#": file_key,
                        "State": state_abbr,
                        "Group_Code": group_code,
                        "Company_Code": company_code_first,
                        "Company_Code_all": company_codes_str,
                        "Objection_letter_date": letter_date,
                        "Objectionletter#": letter_key,
                        "Objection#": obj_key,
                        "Objection": obj_text.replace("\n", " ").strip(),
                        "download_week": download_week
                    })
    df = pd.DataFrame(rows, columns=[
        "SERFF#", "State", "Group_Code", "Company_Code", "Company_Code_all", 
        "Objection_letter_date", "Objectionletter#", "Objection#", "Objection", "download_week"
    ])
    return df

# --- Main Processing ---
pdf_folder = f"Filings/Final/{date}"  # Folder path based on date parameter

# Process objections using the old functions.
objection_results = process_all_pdfs_in_folder(pdf_folder)
json_output_path = f"objections_output_{date}.json"
with open(json_output_path, "w", encoding="utf-8") as f:
    json.dump(objection_results, f, default=lambda o: o.isoformat() if isinstance(o, datetime) else o, ensure_ascii=False, indent=4)
print(f"Saved objections JSON output to {json_output_path}")

df_objections = results_to_dataframe_objections(objection_results)
csv_output_path = f"objections_output_{date}.csv"
df_objections.to_csv(csv_output_path, index=False)
print(f"Saved objections CSV output to {csv_output_path}")

# Process additional filing info using the new function.
additional_results = process_all_pdfs_additional(pdf_folder)
additional_json_output_path = f"additional_filing_info_{date}.json"
with open(additional_json_output_path, "w", encoding="utf-8") as f:
    json.dump(additional_results, f, default=lambda o: o.isoformat() if isinstance(o, datetime) else o, ensure_ascii=False, indent=4)
print(f"Saved additional filing info JSON output to {additional_json_output_path}")

df_additional = additional_to_dataframe(additional_results)
additional_csv_output_path = f"additional_filing_info_{date}.csv"
df_additional.to_csv(additional_csv_output_path, index=False)
print(f"Saved additional filing info CSV output to {additional_csv_output_path}")
# Out:
# Filings/Final/2025-02-24\AR_LBPM-134402349.pdf
# 2025-03-04 07:08:54.302835
# Filings/Final/2025-02-24\AR_LBPM-134415366.pdf
# 2025-03-04 07:08:54.399484
# Filings/Final/2025-02-24\AR_SFMA-134403457.pdf
# 2025-03-04 07:08:54.451183
# Filings/Final/2025-02-24\AZ_ALSE-134423427.pdf
# 2025-03-04 07:08:54.535942
# Filings/Final/2025-02-24\AZ_ALSE-134423455.pdf
# 2025-03-04 07:08:54.755703
# Filings/Final/2025-02-24\AZ_ALSE-134423481.pdf
# 2025-03-04 07:08:54.893773
# Filings/Final/2025-02-24\AZ_ALSE-134424632.pdf
# 2025-03-04 07:08:55.168920
# Filings/Final/2025-02-24\AZ_ALSE-134424807.pdf
# 2025-03-04 07:08:55.332506
# Filings/Final/2025-02-24\AZ_ALSE-134424886.pdf
# 2025-03-04 07:08:55.468411
# Filings/Final/2025-02-24\AZ_ALSE-134424967.pdf
# 2025-03-04 07:08:55.575539
# Filings/Final/2025-02-24\AZ_FARM-134267371.pdf
# 2025-03-04 07:08:55.758705
# Filings/Final/2025-02-24\AZ_GMMX-134417367.pdf
# 2025-03-04 07:08:55.938940
# Filings/Final/2025-02-24\CA_ALSE-134306035.pdf
# 2025-03-04 07:08:56.121827
# Filings/Final/2025-02-24\CA_AMSI-134390951.pdf
# 2025-03-04 07:08:56.346524
# Filings/Final/2025-02-24\CA_HART-133954912.pdf
# 2025-03-04 07:08:56.589808
# Filings/Final/2025-02-24\CA_LBPM-134324308.pdf
# 2025-03-04 07:08:57.192654
# Filings/Final/2025-02-24\CA_LBPM-134324330.pdf
# 2025-03-04 07:08:57.373040
# Filings/Final/2025-02-24\CA_LBRM-134134101.pdf
# 2025-03-04 07:08:57.601357
# Filings/Final/2025-02-24\CA_LBRM-134324203.pdf
# 2025-03-04 07:08:58.007286
# Filings/Final/2025-02-24\CA_LBRM-134324217.pdf
# 2025-03-04 07:08:58.457963
# Filings/Final/2025-02-24\CA_LBRM-134354158.pdf
# 2025-03-04 07:08:58.891618
# Filings/Final/2025-02-24\CA_LEMO-134259792.pdf
# 2025-03-04 07:08:59.085140
# Filings/Final/2025-02-24\CO_ALSE-134421825.pdf
# 2025-03-04 07:08:59.396646
# Filings/Final/2025-02-24\CO_ALSE-134421846.pdf
# 2025-03-04 07:08:59.474159
# Filings/Final/2025-02-24\CO_TRVD-G134410645.pdf
# 2025-03-04 07:08:59.537995
# Filings/Final/2025-02-24\CO_TRVD-G134412529.pdf
# 2025-03-04 07:08:59.618723
# Filings/Final/2025-02-24\CT_FAIG-134409705.pdf
# 2025-03-04 07:08:59.683735
# Filings/Final/2025-02-24\CT_FAIG-134410056.pdf
# 2025-03-04 07:08:59.880129
# Filings/Final/2025-02-24\CT_FAIG-134410555.pdf
# 2025-03-04 07:09:00.563695
# Filings/Final/2025-02-24\CT_FAIG-134413686.pdf
# 2025-03-04 07:09:01.305721
# Filings/Final/2025-02-24\CT_LBPM-134347841.pdf
# 2025-03-04 07:09:01.518026
# Filings/Final/2025-02-24\CT_LBPM-134349046.pdf
# 2025-03-04 07:09:01.864840
# Filings/Final/2025-02-24\CT_LBPM-134358227.pdf
# 2025-03-04 07:09:02.243683
# Filings/Final/2025-02-24\CT_LBPM-134359707.pdf
# 2025-03-04 07:09:03.474611
# Filings/Final/2025-02-24\CT_TRVD-G134420493.pdf
# 2025-03-04 07:09:04.632559
# Filings/Final/2025-02-24\CT_TRVD-G134426399.pdf
# 2025-03-04 07:09:04.847796
# Filings/Final/2025-02-24\District_HART-134400407.pdf
# 2025-03-04 07:09:07.804504
# Filings/Final/2025-02-24\GA_FARM-134357205.pdf
# 2025-03-04 07:09:07.868119
# Filings/Final/2025-02-24\GA_FORE-134361553.pdf
# 2025-03-04 07:09:07.981187
# Filings/Final/2025-02-24\GA_HART-134406305.pdf
# 2025-03-04 07:09:08.054699
# Filings/Final/2025-02-24\GA_HART-134406348.pdf
# 2025-03-04 07:09:08.165536
# Filings/Final/2025-02-24\GA_HART-134414600.pdf
# 2025-03-04 07:09:08.287303
# Filings/Final/2025-02-24\GA_LBPM-134383820.pdf
# 2025-03-04 07:09:08.349425
# Filings/Final/2025-02-24\GA_LBPM-134414714.pdf
# 2025-03-04 07:09:08.535932
# Filings/Final/2025-02-24\GA_LEMO-134183570.pdf
# 2025-03-04 07:09:08.641873
# Filings/Final/2025-02-24\GA_LEMO-134374428.pdf
# 2025-03-04 07:09:09.037154
# Filings/Final/2025-02-24\GA_LEMO-134376013.pdf
# 2025-03-04 07:09:09.094863
# Filings/Final/2025-02-24\GA_LEMO-134376046.pdf
# 2025-03-04 07:09:09.263248
# Filings/Final/2025-02-24\GA_LEMO-134384633.pdf
# 2025-03-04 07:09:09.435833
# Filings/Final/2025-02-24\GA_SFMA-134413084.pdf
# 2025-03-04 07:09:09.651487
# Filings/Final/2025-02-24\GA_TRVD-G134400682.pdf
# 2025-03-04 07:09:10.093506
# Filings/Final/2025-02-24\HI_ALSE-134338646.pdf
# 2025-03-04 07:09:10.168526
# Filings/Final/2025-02-24\HI_HART-134349469.pdf
# 2025-03-04 07:09:10.475661
# Filings/Final/2025-02-24\IA_SFMA-134377596.pdf
# 2025-03-04 07:09:10.640773
# Filings/Final/2025-02-24\IA_TRVD-G134419374.pdf
# 2025-03-04 07:09:10.751493
# Filings/Final/2025-02-24\ID_AMSI-134173339.pdf
# 2025-03-04 07:09:10.878317
# Filings/Final/2025-02-24\ID_HART-134424457.pdf
# 2025-03-04 07:09:11.840179
# Filings/Final/2025-02-24\ID_SFMA-134424081.pdf
# 2025-03-04 07:09:11.931934
# Filings/Final/2025-02-24\IN_FARM-134411373.pdf
# 2025-03-04 07:09:12.087302
# Filings/Final/2025-02-24\IN_HART-134419899.pdf
# 2025-03-04 07:09:12.199800
# Filings/Final/2025-02-24\KS_ALSE-134335664.pdf
# 2025-03-04 07:09:12.239763
# Filings/Final/2025-02-24\KS_HART-134403020.pdf
# 2025-03-04 07:09:14.278769
# Filings/Final/2025-02-24\KS_LBPM-134379791.pdf
# 2025-03-04 07:09:14.329372
# Filings/Final/2025-02-24\KY_LBPM-134418505.pdf
# 2025-03-04 07:09:14.637759
# Filings/Final/2025-02-24\KY_LBPM-134419964.pdf
# 2025-03-04 07:09:14.692223
# Filings/Final/2025-02-24\KY_SFMA-134415672.pdf
# 2025-03-04 07:09:14.742300
# Filings/Final/2025-02-24\KY_TRVD-G134354974.pdf
# 2025-03-04 07:09:15.179712
# Filings/Final/2025-02-24\KY_TRVD-G134417165.pdf
# 2025-03-04 07:09:15.266533
# Filings/Final/2025-02-24\LA_LBPM-134415785.pdf
# 2025-03-04 07:09:15.387034
# Filings/Final/2025-02-24\MD_ALSE-134276603.pdf
# 2025-03-04 07:09:15.510657
# Filings/Final/2025-02-24\MD_ALSE-134280641.pdf
# 2025-03-04 07:09:20.314505
# Filings/Final/2025-02-24\MD_ALSE-134284768.pdf
# 2025-03-04 07:09:20.610749
# Filings/Final/2025-02-24\MD_ALSE-134426297.pdf
# 2025-03-04 07:09:20.834742
# Filings/Final/2025-02-24\MD_AMSI-134131102.pdf
# 2025-03-04 07:09:20.969610
# Filings/Final/2025-02-24\MD_AMSI-134415777.pdf
# 2025-03-04 07:09:21.707533
# Filings/Final/2025-02-24\MD_FARM-134406950.pdf
# 2025-03-04 07:09:22.336644
# Filings/Final/2025-02-24\MD_LEMO-134414879.pdf
# 2025-03-04 07:09:22.422655
# Filings/Final/2025-02-24\MI_ALSE-134371700.pdf
# 2025-03-04 07:09:22.630320
# Filings/Final/2025-02-24\MI_ALSE-134422885.pdf
# 2025-03-04 07:09:22.764407
# Filings/Final/2025-02-24\MI_FAIG-134421996.pdf
# 2025-03-04 07:09:22.987914
# Filings/Final/2025-02-24\MI_TRVD-G134420573.pdf
# 2025-03-04 07:09:23.031184
# Filings/Final/2025-02-24\MN_ALSE-134082968.pdf
# 2025-03-04 07:09:23.095915
# Filings/Final/2025-02-24\MN_ALSE-134082984.pdf
# 2025-03-04 07:09:23.163956
# Filings/Final/2025-02-24\MN_ALSE-134082986.pdf
# 2025-03-04 07:09:23.228791
# Filings/Final/2025-02-24\MN_ALSE-134199118.pdf
# 2025-03-04 07:09:23.301642
# Filings/Final/2025-02-24\MN_ALSE-134298706.pdf
# 2025-03-04 07:09:23.423155
# Filings/Final/2025-02-24\MN_ALSE-134298714.pdf
# 2025-03-04 07:09:23.637990
# Filings/Final/2025-02-24\MN_ALSE-134298726.pdf
# 2025-03-04 07:09:23.806890
# Filings/Final/2025-02-24\MN_ALSE-134298746.pdf
# 2025-03-04 07:09:23.919976
# Filings/Final/2025-02-24\MN_ALSE-134298769.pdf
# 2025-03-04 07:09:24.017842
# Filings/Final/2025-02-24\MN_ALSE-134298792.pdf
# 2025-03-04 07:09:24.215269
# Filings/Final/2025-02-24\MN_ALSE-134298821.pdf
# 2025-03-04 07:09:24.383842
# Filings/Final/2025-02-24\MN_ALSE-134298882.pdf
# 2025-03-04 07:09:24.496714
# Filings/Final/2025-02-24\MN_ALSE-134298893.pdf
# 2025-03-04 07:09:24.649053
# Filings/Final/2025-02-24\MN_AMSI-133860491.pdf
# 2025-03-04 07:09:24.740069
# Filings/Final/2025-02-24\MN_LBPM-134386436.pdf
# 2025-03-04 07:09:24.976428
# Filings/Final/2025-02-24\MN_TRVD-G134202060.pdf
# 2025-03-04 07:09:25.101786
# Filings/Final/2025-02-24\MS_TRVD-G134417920.pdf
# 2025-03-04 07:09:25.474577
# Filings/Final/2025-02-24\MS_TRVD-G134417957.pdf
# 2025-03-04 07:09:25.543880
# Filings/Final/2025-02-24\MS_TRVD-G134418006.pdf
# 2025-03-04 07:09:25.601757
# Filings/Final/2025-02-24\NC_ALSE-134422234.pdf
# 2025-03-04 07:09:25.639911
# Filings/Final/2025-02-24\NC_ALSE-134422247.pdf
# 2025-03-04 07:09:25.763913
# Filings/Final/2025-02-24\NC_AMSI-134398877.pdf
# 2025-03-04 07:09:25.862007
# Filings/Final/2025-02-24\NC_AMSI-134399667.pdf
# 2025-03-04 07:09:26.388595
# Filings/Final/2025-02-24\NC_USAA-134418343.pdf
# 2025-03-04 07:09:26.523475
# Filings/Final/2025-02-24\NC_USAA-134418345.pdf
# 2025-03-04 07:09:26.540037
# Filings/Final/2025-02-24\NC_USAA-134418351.pdf
# 2025-03-04 07:09:26.760013
# Filings/Final/2025-02-24\NC_USAA-134418355.pdf
# 2025-03-04 07:09:26.931327
# Filings/Final/2025-02-24\NE_SFMA-134388198.pdf
# 2025-03-04 07:09:27.096225
# Filings/Final/2025-02-24\NJ_AMSI-134319380.pdf
# 2025-03-04 07:09:27.154809
# Filings/Final/2025-02-24\NJ_FAIG-134306705.pdf
# 2025-03-04 07:09:27.234832
# Filings/Final/2025-02-24\NJ_FAIG-134420020.pdf
# 2025-03-04 07:09:27.570290
# Filings/Final/2025-02-24\NJ_FAIG-134421851.pdf
# 2025-03-04 07:09:27.825678
# Filings/Final/2025-02-24\NJ_FAIG-134423346.pdf
# 2025-03-04 07:09:27.888267
# Filings/Final/2025-02-24\NJ_FORE-134426624.pdf
# 2025-03-04 07:09:27.930482
# Filings/Final/2025-02-24\NJ_FORE-134426695.pdf
# 2025-03-04 07:09:28.020826
# Filings/Final/2025-02-24\NJ_LBPM-133259783.pdf
# 2025-03-04 07:09:28.098025
# Filings/Final/2025-02-24\NJ_LBPM-134367579.pdf
# 2025-03-04 07:09:29.443298
# Filings/Final/2025-02-24\NJ_TRVD-134175714.pdf
# 2025-03-04 07:09:29.835457
# Filings/Final/2025-02-24\NM_FAIG-134423489.pdf
# 2025-03-04 07:09:30.136699
# Filings/Final/2025-02-24\NM_SFMA-134400419.pdf
# 2025-03-04 07:09:30.243049
# Filings/Final/2025-02-24\NM_TRVD-G134414176.pdf
# 2025-03-04 07:09:32.377919
# Filings/Final/2025-02-24\NV_ALSE-134362303.pdf
# 2025-03-04 07:09:32.956863
# Filings/Final/2025-02-24\NV_SFMA-134400219.pdf
# 2025-03-04 07:09:33.237799
# Filings/Final/2025-02-24\NY_TRVD-134134854.pdf
# 2025-03-04 07:09:33.755034
# Filings/Final/2025-02-24\OH_LBPM-134390226.pdf
# 2025-03-04 07:09:34.051395
# Filings/Final/2025-02-24\OR_ALSE-134320625.pdf
# 2025-03-04 07:09:34.242689
# Filings/Final/2025-02-24\OR_ALSE-134399337.pdf
# 2025-03-04 07:09:34.921897
# Filings/Final/2025-02-24\OR_FORE-134407042.pdf
# 2025-03-04 07:09:35.118003
# Filings/Final/2025-02-24\OR_FORE-134407107.pdf
# 2025-03-04 07:09:35.175901
# Filings/Final/2025-02-24\OR_FORE-134407147.pdf
# 2025-03-04 07:09:35.226275
# Filings/Final/2025-02-24\OR_HART-134284670.pdf
# 2025-03-04 07:09:35.276997
# Filings/Final/2025-02-24\OR_LBPM-134420067.pdf
# 2025-03-04 07:09:35.409955
# Filings/Final/2025-02-24\OR_LBPM-134424504.pdf
# 2025-03-04 07:09:35.512845
# Filings/Final/2025-02-24\PA_FAIG-134385139.pdf
# 2025-03-04 07:09:35.572734
# Filings/Final/2025-02-24\PA_FAIG-134385402.pdf
# 2025-03-04 07:09:37.124697
# Filings/Final/2025-02-24\PA_HART-134400784.pdf
# 2025-03-04 07:09:37.235589
# Filings/Final/2025-02-24\RI_FORE-134405214.pdf
# 2025-03-04 07:09:37.302559
# Filings/Final/2025-02-24\RI_FORE-134406034.pdf
# 2025-03-04 07:09:37.546802
# Filings/Final/2025-02-24\RI_LBPM-134357428.pdf
# 2025-03-04 07:09:37.806781
# Filings/Final/2025-02-24\RI_SFMA-134180213.pdf
# 2025-03-04 07:09:39.547785
# Filings/Final/2025-02-24\RI_USAA-134357685.pdf
# 2025-03-04 07:09:40.123596
# Filings/Final/2025-02-24\SC_ALSE-134216877.pdf
# 2025-03-04 07:09:40.434736
# Filings/Final/2025-02-24\SD_TRVD-G134419614.pdf
# 2025-03-04 07:09:41.517950
# Filings/Final/2025-02-24\TN_ALSE-134407748.pdf
# 2025-03-04 07:09:41.634745
# Filings/Final/2025-02-24\TN_LBPM-134395911.pdf
# 2025-03-04 07:09:41.854365
# Filings/Final/2025-02-24\TN_LBPM-134418098.pdf
# 2025-03-04 07:09:42.074681
# Filings/Final/2025-02-24\TN_LEMO-134299492.pdf
# 2025-03-04 07:09:42.831506
# Filings/Final/2025-02-24\TN_SFMA-134378093.pdf
# 2025-03-04 07:09:43.286898
# Filings/Final/2025-02-24\TN_SFMA-134400104.pdf
# 2025-03-04 07:09:43.843198
# Filings/Final/2025-02-24\TX_ALSE-134425684.pdf
# 2025-03-04 07:09:44.359108
# Filings/Final/2025-02-24\TX_ALSE-134425865.pdf
# 2025-03-04 07:09:44.725109
# Filings/Final/2025-02-24\TX_AMSI-133493206.pdf
# 2025-03-04 07:09:45.065924
# Filings/Final/2025-02-24\TX_AMSI-134385509.pdf
# 2025-03-04 07:09:45.104483
# Filings/Final/2025-02-24\TX_FAIG-134410989.pdf
# 2025-03-04 07:09:45.138629
# Filings/Final/2025-02-24\TX_FAIG-134423267.pdf
# 2025-03-04 07:09:45.533816
# Filings/Final/2025-02-24\TX_HART-134398746.pdf
# 2025-03-04 07:09:45.945748
# Filings/Final/2025-02-24\TX_HART-134405817.pdf
# 2025-03-04 07:09:46.001283
# Filings/Final/2025-02-24\TX_HART-134407174.pdf
# 2025-03-04 07:09:46.063249
# Filings/Final/2025-02-24\TX_LBPM-134159927.pdf
# 2025-03-04 07:09:46.122068
# Filings/Final/2025-02-24\TX_LBPM-134367641.pdf
# 2025-03-04 07:09:46.391087
# Filings/Final/2025-02-24\TX_LBPM-134413687.pdf
# 2025-03-04 07:09:46.721618
# Filings/Final/2025-02-24\TX_LEMO-134323240.pdf
# 2025-03-04 07:09:49.092933
# Filings/Final/2025-02-24\TX_SFMA-134221173.pdf
# 2025-03-04 07:09:49.712506
# Filings/Final/2025-02-24\TX_SFMA-134227799.pdf
# 2025-03-04 07:09:50.029668
# Filings/Final/2025-02-24\TX_SFMA-134410201.pdf
# 2025-03-04 07:09:50.409349
# Filings/Final/2025-02-24\TX_SFMA-134410218.pdf
# 2025-03-04 07:09:50.489699
# Filings/Final/2025-02-24\TX_TRVD-G134425009.pdf
# 2025-03-04 07:09:50.591596
# Filings/Final/2025-02-24\UT_SFMA-134405135.pdf
# 2025-03-04 07:09:50.671705
# Filings/Final/2025-02-24\VA_FAIG-134391614.pdf
# 2025-03-04 07:09:50.803054
# Filings/Final/2025-02-24\VA_FARM-134394962.pdf
# 2025-03-04 07:09:50.992393
# Filings/Final/2025-02-24\VA_FORE-134214272.pdf
# 2025-03-04 07:09:51.233215
# Filings/Final/2025-02-24\VA_FORE-134214343.pdf
# 2025-03-04 07:09:51.414096
# Filings/Final/2025-02-24\VA_FORE-134214394.pdf
# 2025-03-04 07:09:51.577330
# Filings/Final/2025-02-24\VA_HART-134374576.pdf
# 2025-03-04 07:09:51.770742
# Filings/Final/2025-02-24\VA_LBPM-134395045.pdf
# 2025-03-04 07:09:52.047310
# Filings/Final/2025-02-24\VA_SFMA-134386972.pdf
# 2025-03-04 07:09:54.020358
# Filings/Final/2025-02-24\VT_FAIG-134392452.pdf
# 2025-03-04 07:09:54.906596
# Filings/Final/2025-02-24\VT_TRVD-G134383069.pdf
# 2025-03-04 07:09:55.122377
# Filings/Final/2025-02-24\WA_FAIG-134060459.pdf
# 2025-03-04 07:09:55.451054
# Filings/Final/2025-02-24\WI_SFMA-134414626.pdf
# 2025-03-04 07:09:55.807372
# Filings/Final/2025-02-24\WV_ALSE-134414963.pdf
# 2025-03-04 07:09:56.038695
# Filings/Final/2025-02-24\WY_FARM-134351956.pdf
# 2025-03-04 07:09:56.142582
# Filings/Final/2025-02-24\WY_FORE-134419284.pdf
# 2025-03-04 07:09:56.679922
# Filings/Final/2025-02-24\WY_FORE-134419401.pdf
# 2025-03-04 07:09:56.931278
# Saved objections JSON output to objections_output_2025-02-24.json
# Saved objections CSV output to objections_output_2025-02-24.csv
# Filings/Final/2025-02-24\AR_LBPM-134402349.pdf
# 2025-03-04 07:09:57.192124
# Token count for API call in AR_LBPM-134402349.pdf: 6626
# GPT-3.5 Summary: The rate filing submitted by American Economy Insurance Company for their Homeowners product in Arkansas is a Rate Type filing with the Filing Type as Rate. The filing was submitted on 02/11/2025 with a SERFF Tracking Number of LBPM-134402349. The filing status is Closed-Filed with an Effective Date Requested of 03/06/2025 for new business and 04/15/2025 for renewal policies.
#
# The primary changes included in the filing are related to the Home Rating Manual and the Home Tiering Manual, specifically focusing on the Multi-Policy Discount and Peril Offset aspects. The overall indicated change in rates is a decrease of 1.1%, which is expected to have a rate impact of -1.100% on written premiums. The filing affects approximately 10,549 policyholders with a written premium for this program of $39,236,602.
#
# The Rate Change History shows a gradual percentage increase in rates over the past years, with the current filing indicating a decrease in rates. The Multi-Policy Discount was adjusted by 2% to enhance segmentation and pricing alignment with risks. Additionally, supporting documents such as the Homeowner Rating Manual, NAIC Loss Cost Data Entry Document, and P&C Actuarial Justification were filed and included in the submission.
#
# Overall, the company aims to improve its competitive positioning and offer more competitive rates to policyholders while maintaining profitability and compliance with state regulations.
# Processed additional filing info for: AR_LBPM-134402349.pdf
# Filings/Final/2025-02-24\AR_LBPM-134415366.pdf
# 2025-03-04 07:10:02.136641
# Token count for API call in AR_LBPM-134415366.pdf: 11129
# GPT-3.5 Summary: The rate filing for Liberty Insurance Corporation includes several endorsements for their Homeowners product, namely the HOMEPROTECTOR PLUS, OPTIONAL LOSS SETTLEMENT, EXCESS DWELLING COVERAGE, and EXPANDED REPLACEMENT COST endorsements. These endorsements include changes to coverage limits, loss settlement provisions, additional coverages, and conditions for replacement cost provisions.
#
# The rate filing indicates that there is no rate data applicable to the filing, resulting in no written premium change or impact on policyholders. The overall percentage rate indicated and rate impact for this filing is 0.000%. There are no changes in written premium or policyholder impact due to this filing.
# Processed additional filing info for: AR_LBPM-134415366.pdf
# Filings/Final/2025-02-24\AR_SFMA-134403457.pdf
# 2025-03-04 07:10:04.184261
# Token count for API call in AR_SFMA-134403457.pdf: 6946
# GPT-3.5 Summary: Based on the filing from State Farm Fire and Casualty Company for their Arkansas Homeowners Program with the tracking number SFMA-134403457, here is a summary of the rate filing:
#
# 1. **Company Information**:
#    - Filing Company: State Farm Fire and Casualty Company
#    - State: Arkansas
#    - Product Name: HO-47811
#    - Project Name/Number: HO-47811/HO-47811
#
# 2. **Filing Type**:
#    - Rule Filing
#
# 3. **Changes Made**:
#    - Revised rates for the independent Arkansas Homeowners Program
#    - Results in a rate level change of 0.0%
#    - Rate changes consider the impact of policy language changes on underwriting experience
#    - Emphasis on achieving competitive premiums and financial stability
#
# 4. **Supporting Documents**:
#    - Includes P&C actuarial justification, loss cost data entry, and response to an objection
#
# 5. **Premium Adjustments**:
#    - Introduction of Wind/Hail deductible options (1%, 2%, 3%, 4%, 5%)
#    - Minimum 1% deductible required for Wind and Hail perils
#    - Premium adjustments outlined in detail for different deductible levels
#
# 6. **Objection Letter**:
#    - Request for detailed rating example related to wind/hail deductible factors
#    - Response provided with examples showing premium changes for different deductible scenarios
#
# In summary, the rate filing
# Processed additional filing info for: AR_SFMA-134403457.pdf
# Filings/Final/2025-02-24\AZ_ALSE-134423427.pdf
# 2025-03-04 07:10:08.675256
# Token count for API call in AZ_ALSE-134423427.pdf: 26212
# Processed additional filing info for: AZ_ALSE-134423427.pdf
# Filings/Final/2025-02-24\AZ_ALSE-134423455.pdf
# 2025-03-04 07:10:09.207295
# Token count for API call in AZ_ALSE-134423455.pdf: 86920
# Processed additional filing info for: AZ_ALSE-134423455.pdf
# Filings/Final/2025-02-24\AZ_ALSE-134423481.pdf
# 2025-03-04 07:10:09.914166
# Token count for API call in AZ_ALSE-134423481.pdf: 46180
# Processed additional filing info for: AZ_ALSE-134423481.pdf
# Filings/Final/2025-02-24\AZ_ALSE-134424632.pdf
# 2025-03-04 07:10:10.812819
# Token count for API call in AZ_ALSE-134424632.pdf: 27076
# Processed additional filing info for: AZ_ALSE-134424632.pdf
# Filings/Final/2025-02-24\AZ_ALSE-134424807.pdf
# 2025-03-04 07:10:11.359313
# Token count for API call in AZ_ALSE-134424807.pdf: 16357
# Error calling GPT-3.5-turbo: Error code: 400 - {'error': {'message': "This model's maximum context length is 16385 tokens. However, your messages resulted in 16403 tokens. Please reduce the length of the messages.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Processed additional filing info for: AZ_ALSE-134424807.pdf
# Filings/Final/2025-02-24\AZ_ALSE-134424886.pdf
# 2025-03-04 07:10:11.967817
# Token count for API call in AZ_ALSE-134424886.pdf: 15126
# GPT-3.5 Summary: The rate filing from Allstate Insurance Company for their Mobile Homeowners insurance program in Arizona includes the following proposed changes:
#
# 1. **Installment Fee Increase**:
#    - Increasing the Installment Fee for the Allstate Easy Pay Plan from $1.50 to $2.00
#    - Increasing the Installment Fee for all other payment methods (except Allstate Payroll Deductions) from $4.00 to $5.00
#
# 2. **Late Payment Fee Increase**:
#    - Raising the Late Payment Fee from $10.00 to $15.00
#
# 3. **Effective Date for Changes**:
#    - These changes will apply to new business written on or after 03/10/2025 and for renewals effective on or after 04/24/2025.
#
# These adjustments aim to update the fees associated with the installment and late payment processes in the Mobile Homeowners program offered by Allstate Insurance Company in Arizona.
# Processed additional filing info for: AZ_ALSE-134424886.pdf
# Filings/Final/2025-02-24\AZ_ALSE-134424967.pdf
# 2025-03-04 07:10:15.581933
# Token count for API call in AZ_ALSE-134424967.pdf: 36507
# Processed additional filing info for: AZ_ALSE-134424967.pdf
# Filings/Final/2025-02-24\AZ_FARM-134267371.pdf
# 2025-03-04 07:10:16.919161
# Token count for API call in AZ_FARM-134267371.pdf: 24014
# Processed additional filing info for: AZ_FARM-134267371.pdf
# Filings/Final/2025-02-24\AZ_GMMX-134417367.pdf
# 2025-03-04 07:10:17.595456
# Token count for API call in AZ_GMMX-134417367.pdf: 37283
# Processed additional filing info for: AZ_GMMX-134417367.pdf
# Filings/Final/2025-02-24\CA_ALSE-134306035.pdf
# 2025-03-04 07:10:18.156507
# Token count for API call in CA_ALSE-134306035.pdf: 270849
# Processed additional filing info for: CA_ALSE-134306035.pdf
# Filings/Final/2025-02-24\CA_AMSI-134390951.pdf
# 2025-03-04 07:10:21.504448
# Token count for API call in CA_AMSI-134390951.pdf: 656947
# Processed additional filing info for: CA_AMSI-134390951.pdf
# Filings/Final/2025-02-24\CA_HART-133954912.pdf
# 2025-03-04 07:10:26.186316
# Token count for API call in CA_HART-133954912.pdf: 6898174
# Processed additional filing info for: CA_HART-133954912.pdf
# Filings/Final/2025-02-24\CA_LBPM-134324308.pdf
# 2025-03-04 07:10:54.392738
# Token count for API call in CA_LBPM-134324308.pdf: 16210
# Error calling GPT-3.5-turbo: Error code: 400 - {'error': {'message': "This model's maximum context length is 16385 tokens. However, you requested 16556 tokens (16256 in the messages, 300 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Processed additional filing info for: CA_LBPM-134324308.pdf
# Filings/Final/2025-02-24\CA_LBPM-134324330.pdf
# 2025-03-04 07:10:55.051119
# Token count for API call in CA_LBPM-134324330.pdf: 17054
# Processed additional filing info for: CA_LBPM-134324330.pdf
# Filings/Final/2025-02-24\CA_LBRM-134134101.pdf
# 2025-03-04 07:10:55.397055
# Token count for API call in CA_LBRM-134134101.pdf: 272298
# Processed additional filing info for: CA_LBRM-134134101.pdf
# Filings/Final/2025-02-24\CA_LBRM-134324203.pdf
# 2025-03-04 07:10:59.205012
# Token count for API call in CA_LBRM-134324203.pdf: 51710
# Processed additional filing info for: CA_LBRM-134324203.pdf
# Filings/Final/2025-02-24\CA_LBRM-134324217.pdf
# 2025-03-04 07:11:00.176721
# Token count for API call in CA_LBRM-134324217.pdf: 52244
# Processed additional filing info for: CA_LBRM-134324217.pdf
# Filings/Final/2025-02-24\CA_LBRM-134354158.pdf
# 2025-03-04 07:11:01.114740
# Token count for API call in CA_LBRM-134354158.pdf: 15775
# GPT-3.5 Summary: The rate filing is a submission by First National Insurance Company of America to withdraw its Difference in Condition (DIC) product in the state of California, effective January 1, 2026. The company is simplifying its product offerings and focusing on core go-forward products. The submission includes the non-renewal of existing policies that expire on or after January 1, 2026, and outlines the communication plans with impacted agents and policyholders. Additionally, the filing involves the submission of supporting documents, correspondence with the California Department of Insurance, objection letters, response letters, and compliance with state regulations and privacy notices.
# Processed additional filing info for: CA_LBRM-134354158.pdf
# Filings/Final/2025-02-24\CA_LEMO-134259792.pdf
# 2025-03-04 07:11:04.042414
# Token count for API call in CA_LEMO-134259792.pdf: 208472
# Processed additional filing info for: CA_LEMO-134259792.pdf
# Filings/Final/2025-02-24\CO_ALSE-134421825.pdf
# 2025-03-04 07:11:05.356264
# Token count for API call in CO_ALSE-134421825.pdf: 5387
# GPT-3.5 Summary: The rate filing submitted by Allstate Indemnity Company pertains to a change in the underwriting guidelines for their Allstate Indemnity (AI) Renters product in the state of Colorado. The filing proposes revisions to the existing guidelines, particularly adding language above the administrative requirements.
#
# Key details of the rate filing include:
# - Filing Type: Rule
# - Effective Date Requested for New Business: 03/18/2025
# - Product Name: AI REN
# - State: Colorado
# - Project Name/Number: RMP Change/RITM06442052
#
# The filing specifies adjustments related to insurable interests, administrative requirements, fire protection criteria, prior insurance considerations, coverage limits and deductible requirements, ineligible dwelling types, and the potential initiation of a moratorium during catastrophic events.
#
# Additionally, the filing outlines contact information for the filing company and provides details on the representatives involved in the review and submission process, such as Jennifer Olson and Ken Neider. The filing was submitted on 02/17/2025 and was closed under the status of "Filed" on 02/19/2025.
# Processed additional filing info for: CO_ALSE-134421825.pdf
# Filings/Final/2025-02-24\CO_ALSE-134421846.pdf
# 2025-03-04 07:11:08.378077
# Token count for API call in CO_ALSE-134421846.pdf: 5008
# GPT-3.5 Summary: The rate filing from Allstate North American Insurance Company proposes changes to the underwriting guidelines for renters insurance in the state of Colorado. The key points of the filing include:
#
# - Company: Allstate North American Insurance Company
# - Product Name: ANAIC REN
# - State: Colorado
# - Type of Insurance: Tenant Homeowners (04.0004)
# - Filing Type: Rule
# - Effective Date Requested: 03/18/2025
# - Project Name/Number: RMP Change/RITM06442037
#
# Changes to the underwriting guidelines include:
# - Removing the Applicability section regarding where policy quotes can be initiated and completed
# - Specifying administrative requirements for bound applications and coverage endorsements
# - Credit history requirements for primary named insured
# - Conditions for insurable interest like property occupancy and policy ownership
# - Fire protection proximity and ineligible dwelling criteria
# - Policy restrictions on specific property types and occupants
# - Implementation of a moratorium under extreme circumstances
#
# The rate filing indicates a revised Risk Management Policy and includes supporting documents such as the Colorado Rate/Rule Form A and a Summary of Changes and Tracked Version of Guidelines. The filing was submitted on 02/17/2025, reviewed by Jennifer Olson and Ken Neider, and filed with the DOI on 02/19/2025. The filing is closed and effective for new business starting 03/18/2025.
# Processed additional filing info for: CO_ALSE-134421846.pdf
# Filings/Final/2025-02-24\CO_TRVD-G134410645.pdf
# 2025-03-04 07:11:11.682153
# Token count for API call in CO_TRVD-G134410645.pdf: 7953
# GPT-3.5 Summary: The rate filing is related to The Travelers Home and Marine Insurance Company's Quantum Homeowners product in the state of Colorado. The filing includes updates to two rules: Rule 511 for Loss Assessment Coverage and Rule 535 for Enhanced Home Package (EHP). The amendments were submitted with a comprehensive set of supporting documents, including Filing Memorandum and Colorado Rate/Rule Form A. The effective date requested for the changes is 04/07/2025. The rate impact indicated in the filing is 0.000%. The filing was submitted on 02/10/2025 and was closed as Filed on 02/11/2025, with no confidential information included. The company provided a detailed Explanatory Memorandum outlining the revisions to the rules. The filing aims to enhance and update the Quantum Homeowners product to comply with Colorado laws and regulations.
# Processed additional filing info for: CO_TRVD-G134410645.pdf
# Filings/Final/2025-02-24\CO_TRVD-G134412529.pdf
# 2025-03-04 07:11:14.120789
# Token count for API call in CO_TRVD-G134412529.pdf: 7187
# GPT-3.5 Summary: Based on the information provided in the filing, the insurance companies involved (The Automobile Insurance Company of Hartford, The Standard Fire Insurance Company, and The Travelers Indemnity Company of America) have filed for amendments to their homeowners and high-value homeowners products in the state of Colorado. The filing includes multiple rule revisions impacting Loss Assessment Coverage and Additional Coverage Endorsements such as ACE.
#
# The filing specifies that the revisions apply to renewal business issued on or after 02/16/2025 and effective on or after 04/07/2025. The amendments involve changes to eligibility requirements, limits of liability, coverage enhancements, and other details outlined in the respective rules for homeowners and high-value homeowners programs in Colorado.
#
# The filing does not indicate any overall rate impact associated with the changes. It provides a detailed breakdown of the revisions made to the rules, including the specific adjustments to coverage limits, premiums, and eligibility conditions for Loss Assessment Coverage and Additional Coverage Endorsements.
#
# The filing was submitted with the SERFF Tracking Number TRVD-G134412529 and impacts a total of 7,205 policyholders with an annual written premium of $16,497,030.00 across the three companies involved.
# Processed additional filing info for: CO_TRVD-G134412529.pdf
# Filings/Final/2025-02-24\CT_FAIG-134409705.pdf
# 2025-03-04 07:11:17.735811
# Token count for API call in CT_FAIG-134409705.pdf: 23339
# Processed additional filing info for: CT_FAIG-134409705.pdf
# Filings/Final/2025-02-24\CT_FAIG-134410056.pdf
# 2025-03-04 07:11:18.161720
# Token count for API call in CT_FAIG-134410056.pdf: 122008
# Processed additional filing info for: CT_FAIG-134410056.pdf
# Filings/Final/2025-02-24\CT_FAIG-134410555.pdf
# 2025-03-04 07:11:19.620341
# Token count for API call in CT_FAIG-134410555.pdf: 184149
# Processed additional filing info for: CT_FAIG-134410555.pdf
# Filings/Final/2025-02-24\CT_FAIG-134413686.pdf
# 2025-03-04 07:11:21.711311
# Token count for API call in CT_FAIG-134413686.pdf: 17927
# Processed additional filing info for: CT_FAIG-134413686.pdf
# Filings/Final/2025-02-24\CT_LBPM-134347841.pdf
# 2025-03-04 07:11:22.110421
# Token count for API call in CT_LBPM-134347841.pdf: 36821
# Processed additional filing info for: CT_LBPM-134347841.pdf
# Filings/Final/2025-02-24\CT_LBPM-134349046.pdf
# 2025-03-04 07:11:22.739977
# Token count for API call in CT_LBPM-134349046.pdf: 37995
# Processed additional filing info for: CT_LBPM-134349046.pdf
# Filings/Final/2025-02-24\CT_LBPM-134358227.pdf
# 2025-03-04 07:11:23.351768
# Token count for API call in CT_LBPM-134358227.pdf: 158981
# Processed additional filing info for: CT_LBPM-134358227.pdf
# Filings/Final/2025-02-24\CT_LBPM-134359707.pdf
# 2025-03-04 07:11:25.719741
# Token count for API call in CT_LBPM-134359707.pdf: 160774
# Processed additional filing info for: CT_LBPM-134359707.pdf
# Filings/Final/2025-02-24\CT_TRVD-G134420493.pdf
# 2025-03-04 07:11:28.495940
# Token count for API call in CT_TRVD-G134420493.pdf: 22556
# Processed additional filing info for: CT_TRVD-G134420493.pdf
# Filings/Final/2025-02-24\CT_TRVD-G134426399.pdf
# 2025-03-04 07:11:28.898777
# Token count for API call in CT_TRVD-G134426399.pdf: 207244
# Processed additional filing info for: CT_TRVD-G134426399.pdf
# Filings/Final/2025-02-24\District_HART-134400407.pdf
# 2025-03-04 07:11:35.039304
# Token count for API call in District_HART-134400407.pdf: 5151
# GPT-3.5 Summary: Based on the information provided in the filing, the rate filing for the Hartford Casualty Insurance Company and related entities pertains to the introduction of a credit card surcharge to their Home products. Policyholders who choose to pay their premium by credit card will incur a credit card surcharge, not exceeding 3% of the total premium amount. The surcharge will be collected by a third-party payment vendor and will be effective for all transactions processed on or after July 01, 2025.
#
# The rate filing indicated that there will be no overall percentage rate impact for this filing, with no change in written premium and no policyholders being affected in terms of number. The response letters submitted in relation to objections raised regarding the determination of the credit card surcharge amount provided explanations and clarifications on the proposed surcharge process and rules. The filing was approved with the effective date set for July 01, 2025.
# Processed additional filing info for: District_HART-134400407.pdf
# Filings/Final/2025-02-24\GA_FARM-134357205.pdf
# 2025-03-04 07:11:37.507139
# Token count for API call in GA_FARM-134357205.pdf: 9962
# GPT-3.5 Summary: The rate filing for the Farmers Insurance Exchange's FLEX Home product in Georgia involves updates to the underwriting rules for homeowners insurance. Changes include updates to roof type options for Scheduled Roof coverage based on roof age, as well as revisions to other underwriting guidelines.
#
# The filing details various aspects of the underwriting rules, including geographic and demographic data elements used in analyzing rating factors, information on prior insurance and claims history variables, exclusion criteria, credit rating considerations, and exclusion of certain rating variables not applicable to the product.
#
# A detailed list of rating variables and calculations for main and optional coverage components is provided, along with confirmation of adherence to regulatory requirements and neutrality in ratings. The filing encompasses supporting documents and responses to specific requirements outlined by the Department of Insurance in Georgia.
#
# Overall, the rate filing demonstrates a comprehensive review of underwriting guidelines and rating factors for the FLEX Home product, aiming to ensure compliance with state regulations and competitive pricing structures.
# Processed additional filing info for: GA_FARM-134357205.pdf
# Filings/Final/2025-02-24\GA_FORE-134361553.pdf
# 2025-03-04 07:11:40.184105
# Token count for API call in GA_FORE-134361553.pdf: 6529
# GPT-3.5 Summary: The rate filing is for Foremost Insurance Company's Landlord Manufactured Home Program in Georgia. It involves revisions to the rule and rate sections, with an effective date requested for both new and renewal policies starting on March 1, 2025. The filing includes details on the program, annual rates/premiums for various coverages, rules for eligibility, premium computation, cancellation, and more. Additionally, there are specific details about territories, deductibles, limits of liability, and discounts for fortified homes. The company has also provided supporting documents such as certification, fee transmittal, rate indication exhibits, explanatory memorandum, and a wind mitigation discount support document.
#
# Overall, the rate filing shows a neutral overall rate change of 0.000%, impacting 11,009 policyholders with a total written premium of $10,508,704. The filing complies with Georgia's rate filing fee requirement of $75 per filing and includes the necessary supporting documents and certifications for validation.
# Processed additional filing info for: GA_FORE-134361553.pdf
# Filings/Final/2025-02-24\GA_HART-134406305.pdf
# 2025-03-04 07:11:42.452481
# Token count for API call in GA_HART-134406305.pdf: 10332
# GPT-3.5 Summary: The rate filing pertains to a homeowners insurance product by Nutmeg Insurance Company, specifically for the state of Georgia. The product is named "GA Non-Adopt Homeowners 2022 Multistate Forms Implementation Effective 7/1/25 (Nutmeg)." The filing involved multistate forms, rules, and loss costs revisions for homeowners insurance. The effective date requested for this filing is 07/01/2025. The filing was approved and closed on 02/19/2025. The project was managed by various individuals within the company, and the responsible person for the filing was Geraldine Daly, the Product Analyst at Nutmeg Insurance Company.
# Processed additional filing info for: GA_HART-134406305.pdf
# Filings/Final/2025-02-24\GA_HART-134406348.pdf
# 2025-03-04 07:11:44.472139
# Token count for API call in GA_HART-134406348.pdf: 11113
# GPT-3.5 Summary: The rate filing pertains to the implementation of Homeowners 2022 Multistate Forms, Rules, and Loss Costs revisions in Georgia by Nutmeg Insurance Company. The filing was effective on July 1, 2025, with a SERFF Tracking Number HART-134406348. The company notified the non-adoption of the rules at the time until further notice. The filing includes various forms, rules, and loss costs revisions in compliance with the ISO guidelines and Georgia insurance department requirements. The effective date for policies written after July 1, 2025, was specified in the filing. Additionally, the company's decision on using or modifying the revision was highlighted, and any necessary actions to be taken were outlined in the filing documentation.
# Processed additional filing info for: GA_HART-134406348.pdf
# Filings/Final/2025-02-24\GA_HART-134414600.pdf
# 2025-03-04 07:11:46.854472
# Token count for API call in GA_HART-134414600.pdf: 4594
# GPT-3.5 Summary: Summary of the rate filing:
#
# - Filing Type: Rate/Rule other than PPA
# - Product Name: GA Home Credit Card Surcharge - HCIC HICMW HICSE PCIC TRUM Nutmeg
# - State: Georgia
# - TOI (Type of Insurance): 04.0 Homeowners
# - Sub-TOI (Sub-Type of Insurance): 04.0000 Homeowners Sub-TOI Combinations
# - Number of Companies: 6
#   1. Hartford Casualty Insurance Company
#   2. Hartford Insurance Company of the Midwest
#   3. Hartford Insurance Company of the Southeast
#   4. Property and Casualty Insurance Company of Hartford
#   5. Trumbull Insurance Company
#   6. Nutmeg Insurance Company
# - Effective Date Requested (New & Renewal): 07/01/2025
# - Filing Method: File & Use
# - Rate Change Type: Neutral
# - Overall Percentage of Last Rate Revision: 0.000%
# - Filing Fee: $450.00 ($75.00 per Writing Company)
# - Credit Card Surcharge: Policyholders paying by credit card will incur a surcharge not exceeding 3% of the total payment amount, effective for transactions processed on or after July 1, 2025.
# - Contact Person: Lesdy Richard, Sr Pricing Analyst, The Hartford Personal Lines
#
# This rate filing introduces a credit card surcharge to The Hartford's
# Processed additional filing info for: GA_HART-134414600.pdf
# Filings/Final/2025-02-24\GA_LBPM-134383820.pdf
# 2025-03-04 07:11:49.937653
# Token count for API call in GA_LBPM-134383820.pdf: 7046
# GPT-3.5 Summary: In this rate filing by Liberty Mutual and its affiliated companies, the following key points can be summarized:
#
# 1. **Companies**: Liberty Mutual Fire Insurance Company, Liberty Mutual Insurance Company, LM General Insurance Company, LM Insurance Corporation, The First Liberty Insurance Corporation, and Peerless Indemnity Insurance Company are involved in the rate filing.
#
# 2. **Product Name**: The rate filing pertains to the Homeowners insurance product in the state of Georgia.
#
# 3. **Filing Type**: The filing type is a Form filing.
#
# 4. **Date Submitted**: The filing was submitted on 01/21/2025.
#
# 5. **Approval Status**: The filing has been approved with a closed status, as of the disposition date on 02/20/2025.
#
# 6. **Effective Date**: The requested effective date for both new and renewal policies is 05/19/2025 and 06/23/2025, respectively.
#
# 7. **Author/Reviewer**: The filing was authored by Christine Ray and Robert Lively, with Jarrett Briscoe as the primary reviewer.
#
# 8. **Rate Information**: The rate indication is 0.000%, and there is no written premium change or number of policyholders affected by the rate filing.
#
# Overall, the rate filing for Homeowners insurance in Georgia by Liberty Mutual and its subsidiaries was approved with specific details provided regarding forms submitted, changes made, and the associated fees.
# Processed additional filing info for: GA_LBPM-134383820.pdf
# Filings/Final/2025-02-24\GA_LBPM-134414714.pdf
# 2025-03-04 07:11:53.734839
# Token count for API call in GA_LBPM-134414714.pdf: 16386
# Processed additional filing info for: GA_LBPM-134414714.pdf
# Filings/Final/2025-02-24\GA_LEMO-134183570.pdf
# 2025-03-04 07:11:53.886040
# Token count for API call in GA_LEMO-134183570.pdf: 270995
# Processed additional filing info for: GA_LEMO-134183570.pdf
# Filings/Final/2025-02-24\GA_LEMO-134374428.pdf
# 2025-03-04 07:11:55.517918
# Token count for API call in GA_LEMO-134374428.pdf: 3737
# GPT-3.5 Summary: Based on the filing information provided, Lemonade Insurance Company has submitted a rate filing for a new optional coverage called Refrigerated Property Coverage for homeowners in the state of Georgia. The filing requests that this new coverage be applicable to all new business policies written on or after May 15, 2025, and to all renewal business effective on or after May 16, 2025.
#
# The new Refrigerated Property Coverage endorsement provides coverage for covered property stored in freezers or refrigerators on the residence premises for direct loss caused by interruption of electrical service to the refrigeration unit or mechanical failure of the unit storing the property. It also specifies a special deductible exceeding $100 for covered losses to refrigerated property.
#
# The filing includes various attachments and supporting documents, such as Filing Compliance Certification, Filing Fee Transmittal Form, Explanatory Memorandum, and Readability Certification. The company has provided contact information for Felicia Williams, Senior Insurance Operations Associate, as well as details about the company's domicile, filing fees, and form schedules.
#
# Overall, Lemonade Insurance Company is introducing this new Refrigerated Property Coverage as part of its homeowners insurance program in Georgia, and the filing is in progress with the effective date requested for May 2025.
# Processed additional filing info for: GA_LEMO-134374428.pdf
# Filings/Final/2025-02-24\GA_LEMO-134376013.pdf
# 2025-03-04 07:11:58.384509
# Token count for API call in GA_LEMO-134376013.pdf: 22707
# Processed additional filing info for: GA_LEMO-134376013.pdf
# Filings/Final/2025-02-24\GA_LEMO-134376046.pdf
# 2025-03-04 07:11:58.768823
# Token count for API call in GA_LEMO-134376046.pdf: 8181
# GPT-3.5 Summary: The rate filing submitted by Metromile Insurance Company for their MIC Renters program in Georgia involves a revision and introduction of options related to Refrigerated Property Coverage. The filing includes the introduction of new coverage limit options ($100 and $250) in addition to the existing $500 coverage limit option. The proposed changes are set to take effect for all new business policies written on or after May 15, 2025, and for all renewal policies effective on or after May 16, 2025.
#
# The company's Actuarial Memorandum states that the proposed changes aim to offer additional coverage options without impacting rates. Various exhibits, such as refrigerated property exhibit, rate tables, and supporting documents, provide further details and actuarial analysis supporting the proposed adjustments to the renters program.
#
# Furthermore, the rate filing includes information on the fee transmittal, the rate change type as neutral, and the company's certification of adhering to Georgia's filing instructions and requirements. The filing was acknowledged and is set to be effective as per the specified dates. Additionally, correspondence regarding objections and responses is documented in the filing.
# Processed additional filing info for: GA_LEMO-134376046.pdf
# Filings/Final/2025-02-24\GA_LEMO-134384633.pdf
# 2025-03-04 07:12:02.007995
# Token count for API call in GA_LEMO-134384633.pdf: 25635
# Processed additional filing info for: GA_LEMO-134384633.pdf
# Filings/Final/2025-02-24\GA_SFMA-134413084.pdf
# 2025-03-04 07:12:02.286415
# Token count for API call in GA_SFMA-134413084.pdf: 69342
# Processed additional filing info for: GA_SFMA-134413084.pdf
# Filings/Final/2025-02-24\GA_TRVD-G134400682.pdf
# 2025-03-04 07:12:02.919057
# Token count for API call in GA_TRVD-G134400682.pdf: 5876
# GPT-3.5 Summary: The rate filing pertains to the Homesaver insurance program by The Automobile Insurance Company of Hartford, Connecticut, The Phoenix Insurance Company, and The Travelers Indemnity Company of America in the state of Georgia. The filing involves revisions to the Homesaver product, specifically implementing a Windstorm Mitigation Discount under Rule 424. The discount is based on windstorm mitigation types and offers premium credits for various certification levels.
#
# Key details of the rate filing include:
# - Filing Type: Rate/Rule other than PPA
# - Effective Date Requested: 02/28/2025
# - Companies Involved: The Automobile Insurance Company of Hartford, The Phoenix Insurance Company, The Travelers Indemnity Company of America
# - Product Name: Homesaver
# - State: Georgia
# - TOI: 04.0 Homeowners
# - Sub-TOI: 04.0000 Homeowners Sub-TOI Combinations
# - Filing Contact: Candice Root, Sr. Regulatory Analyst
# - Rate Change Type: Percentages
# - Key Rule Introduced: Windstorm Mitigation Discount - Forms HS661 and HS663 under Rule 424
#
# The filing also includes a correspondence summary indicating objection and response letters related to the proposed changes. Additionally, feedback was provided by Jarrett Briscoe requesting specific amendments to the discount percentages, which were addressed in the response letter submitted by Candice Root.
#
# This rate filing aims to introduce a new discount structure for windstorm mitigation types in
# Processed additional filing info for: GA_TRVD-G134400682.pdf
# Filings/Final/2025-02-24\HI_ALSE-134338646.pdf
# 2025-03-04 07:12:06.319885
# Token count for API call in HI_ALSE-134338646.pdf: 116700
# Processed additional filing info for: HI_ALSE-134338646.pdf
# Filings/Final/2025-02-24\HI_HART-134349469.pdf
# 2025-03-04 07:12:06.984629
# Token count for API call in HI_HART-134349469.pdf: 19393
# Processed additional filing info for: HI_HART-134349469.pdf
# Filings/Final/2025-02-24\IA_SFMA-134377596.pdf
# 2025-03-04 07:12:07.209020
# Token count for API call in IA_SFMA-134377596.pdf: 26319
# Processed additional filing info for: IA_SFMA-134377596.pdf
# Filings/Final/2025-02-24\IA_TRVD-G134419374.pdf
# 2025-03-04 07:12:07.386779
# Token count for API call in IA_TRVD-G134419374.pdf: 9149
# GPT-3.5 Summary: The rate filing submitted by The Automobile Insurance Company of Hartford, Connecticut, and associated companies includes revisions to their Quantum Homeowners 2.0, Quantum Home, and Legacy Home insurance programs. The filing covers various coverage packages and endorsements such as Rule 106 Coverage Packages, Rule 905 Loss Assessment, Rule 511 Loss Assessment Coverage, Rule 535 Enhanced Home Package, Rule 305 High Value Home Coverage, and Rule 530 Additional Coverage Endorsement.
#
# The filing was for the state of Iowa and was approved with an effective date requested of 03/14/2025 for new business and 05/13/2025 for renewals. The filing includes information on the companies involved, project details, premium changes, eligibility requirements, and details of each specific coverage package and endorsement. Overall, the filing aims to update and enhance the insurance offerings for homeowners in Iowa under the Quantum Homeowners 2.0, Quantum Home, and Legacy Home programs.
# Processed additional filing info for: IA_TRVD-G134419374.pdf
# Filings/Final/2025-02-24\ID_AMSI-134173339.pdf
# 2025-03-04 07:12:10.549501
# Token count for API call in ID_AMSI-134173339.pdf: 456563
# Processed additional filing info for: ID_AMSI-134173339.pdf
# Filings/Final/2025-02-24\ID_HART-134424457.pdf
# 2025-03-04 07:12:12.904506
# Token count for API call in ID_HART-134424457.pdf: 6003
# GPT-3.5 Summary: The rate filing pertains to the Idaho homeowners insurance market and specifically focuses on the revision of Rule 519 - Broadened Home-sharing Host Activities Coverage. The rule revision, identified as HO-2024-BPR1, is effective as of May 1, 2025, and impacts all forms except HO 00 14.
#
# ...
# Processed additional filing info for: TX_SFMA-134410201.pdf
# Filings/Final/2025-02-24\TX_SFMA-134410218.pdf
# 2025-03-04 07:25:02.110567
# Token count for API call in TX_SFMA-134410218.pdf: 4214
# GPT-3.5 Summary: The rate filing submitted by State Farm Lloyds for their Texas Homeowners insurance product (HO-48033) requests an overall rate revision of 9.900% with an effective date of 05/01/2025 for both new and renewal business. The filing falls under the category of Rate/Rule, with a Filing Type of File and Use. The filing includes information on the company and contact details, project details, supporting documents such as Exhibit A, Exhibit C, and Filing Memorandum, as well as attachment status for various filing requirements. The filing does not contain any personally identifiable information (PII) or confidential information. The filing also includes historical rate change information over a six-year period and a recoupment surcharge calculation related to the 2023 Texas FAIR Plan Association Assessment.
# Processed additional filing info for: TX_SFMA-134410218.pdf
# Filings/Final/2025-02-24\TX_TRVD-G134425009.pdf
# 2025-03-04 07:25:04.788430
# Token count for API call in TX_TRVD-G134425009.pdf: 6594
# GPT-3.5 Summary: The rate filing from Travelers Personal Insurance Company pertains to their Quantum Home 2.0 homeowners insurance product in the state of Texas. The filing includes underwriting guidelines detailing eligibility criteria for risks covered under the program. It outlines specific requirements and restrictions for various aspects such as property condition, loss history, liability exposures, property features, and more.
#
# Key points from the underwriting guidelines include:
# - Criteria for eligibility, including requirements for dwelling age, insurance coverage limits, inspections, and documentation.
# - Ineligible risks related to loss history, water damage, pets, property conditions, and specific property features.
# - Requirements for referral to underwriting, such as prior losses, property conditions, business activities, and historical home registry listings.
# - Catastrophe management provisions, including binding coverage suspensions for certain events like hurricanes, floods, wildfires, or earthquakes.
# - Specifications for coastal properties, water backup coverage, brushfire/wildfire risks, and wind/hail/tornado classifications.
#
# The filing also mentions that the rate information does not apply to this submission, focusing solely on underwriting guidelines for the Quantum Home 2.0 product.
# Processed additional filing info for: TX_TRVD-G134425009.pdf
# Filings/Final/2025-02-24\UT_SFMA-134405135.pdf
# 2025-03-04 07:25:07.816776
# Token count for API call in UT_SFMA-134405135.pdf: 27657
# Processed additional filing info for: UT_SFMA-134405135.pdf
# Filings/Final/2025-02-24\VA_FAIG-134391614.pdf
# 2025-03-04 07:25:08.027133
# Token count for API call in VA_FAIG-134391614.pdf: 12975
# GPT-3.5 Summary: The rate filing submitted by Farmers Property and Casualty Insurance Company, Farmers Casualty Insurance Company, and Economy Premier Assurance Company in Virginia pertains to their "Scheduled Personal Property" endorsement under the "Homeowners" product. The filing included revisions to the endorsement to comply with legislation HB 1257, with the effective date requested for both new and renewal policies set at 07/01/2025. The filing was submitted on 01/24/2025 and was subsequently approved and filed on 02/14/2025.
#
# The supporting documents related to this rate filing include certifications of compliance with Chapter 341 and Chapter 342 of Title 14 of the Virginia Administrative Code. Additionally, there were corresponding objection and response letters regarding the accuracy of the Forms List included in the filing. The overall rate impact indicated in the filing was 0.000%, with no written premium change or policyholders affected. The rate filing pertains to specific classes of personal property such as jewelry, furs, cameras, musical instruments, and more, providing coverage for newly acquired property and setting out territorial limits and special provisions as outlined in the endorsement documentation.
# Processed additional filing info for: VA_FAIG-134391614.pdf
# Filings/Final/2025-02-24\VA_FARM-134394962.pdf
# 2025-03-04 07:25:11.570416
# Token count for API call in VA_FARM-134394962.pdf: 24164
# Processed additional filing info for: VA_FARM-134394962.pdf
# Filings/Final/2025-02-24\VA_FORE-134214272.pdf
# 2025-03-04 07:25:11.877666
# Token count for API call in VA_FORE-134214272.pdf: 11279
# GPT-3.5 Summary: Summary of the Rate Filing:
# - Company: Foremost Insurance Company based in Grand Rapids, Michigan
# - Product Name: Classic Market Value Homeowners Program
# - State: Virginia
# - Type of Insurance: Homeowners
# - Sub-Type: Owner-Occupied Homeowners
# - Filing Type: Rate/Rule
# - Filing Status: Withdrawn
# - Effective Date Requested: 07/01/2025 for both new policies and renewals
# - Filing Author: Missi Glass
# - Reviewer: Madi Goldberg
# - Reason for Withdrawal: Company's note to reviewer mentioned withdrawal due to not using Inflection in their products
#
# The filing included revisions to rule and rate sections and the introduction of a new credit model. The company introduced the Verisk Inflection™ Model and made adjustments to premium modification rules. They also conducted a retrovalidation study to determine proper factors for the new credit model. Various supporting documents were provided along with the filing for regulatory approval. The filing was withdrawn before the effective date, indicating a change in plans by the company.
# Processed additional filing info for: VA_FORE-134214272.pdf
# Filings/Final/2025-02-24\VA_FORE-134214343.pdf
# 2025-03-04 07:25:14.941089
# Token count for API call in VA_FORE-134214343.pdf: 14525
# GPT-3.5 Summary: The rate filing is from Foremost Insurance Company for their Homeowners Program in Virginia, specifically for Owner Occupied Homeowners within the Homeowners TOI/Sub-TOI category. The filing was submitted with the intention to introduce a new credit model, the Verisk Inflection™ Model from Insurance Services Office, Inc. The primary author of the filing is Missi Glass, and the disposition status is Withdrawn.
#
# The filing included revisions to the rate section, introducing the new credit model and specifying the removal and recalibration of certain credit-based insurance risk assessment scores. Various rate pages were revised, schedule items were withdrawn, and supporting documents were included such as the COF-1 Rate Certification and a Summary of Revisions. There were objections from the reviewer regarding the calculation of insurance scores, but responses from the insurance company indicated adjustments made to address the concerns. Ultimately, the filing was withdrawn before implementation as the company decided not to use the Inflection model in their products.
# Processed additional filing info for: VA_FORE-134214343.pdf
# Filings/Final/2025-02-24\VA_FORE-134214394.pdf
# 2025-03-04 07:25:18.215828
# Token count for API call in VA_FORE-134214394.pdf: 12527
# GPT-3.5 Summary: The rate filing by Foremost Insurance Company for their Tenant Program in Virginia includes revisions to the rule and rate sections. The filing introduces a new credit model, the Verisk Inflection™ Model from Insurance Services Office, Inc. The effective date requested for both new and renewal policies is 07/01/2025. However, the filing was subsequently withdrawn on 02/19/2025. The filing also involved correspondence and responses related to objections and amendments aimed at refining the rate structure and credit model implementation.
# Processed additional filing info for: VA_FORE-134214394.pdf
# Filings/Final/2025-02-24\VA_HART-134374576.pdf
# 2025-03-04 07:25:20.229588
# Token count for API call in VA_HART-134374576.pdf: 16155
# Error calling GPT-3.5-turbo: Error code: 400 - {'error': {'message': "This model's maximum context length is 16385 tokens. However, you requested 16501 tokens (16201 in the messages, 300 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Processed additional filing info for: VA_HART-134374576.pdf
# Filings/Final/2025-02-24\VA_LBPM-134395045.pdf
# 2025-03-04 07:25:20.643586
# Token count for API call in VA_LBPM-134395045.pdf: 3363981
# Processed additional filing info for: VA_LBPM-134395045.pdf
# Filings/Final/2025-02-24\VA_SFMA-134386972.pdf
# 2025-03-04 07:26:17.592832
# Token count for API call in VA_SFMA-134386972.pdf: 95791
# Processed additional filing info for: VA_SFMA-134386972.pdf
# Filings/Final/2025-02-24\VT_FAIG-134392452.pdf
# 2025-03-04 07:26:20.071750
# Token count for API call in VT_FAIG-134392452.pdf: 13019
# GPT-3.5 Summary: The rate filing submitted by Economy Fire & Casualty Company for their Homeowners insurance product in Vermont includes updates and revisions to their rating plan and rules, specifically focusing on the Equipment Breakdown and Service Line coverage. The filing requests an effective date of June 1, 2025, for both new and renewal business.
#
# Key aspects of the rate filing include:
# 1. Renaming the Home System Protection to Equipment Breakdown and Service Line Coverage.
# 2. Revising rates for Equipment Breakdown and Service Line.
# 3. Providing coverage options with sublimits for Equipment Breakdown and Service Line.
# 4. Ensuring no rating penalty applies under the Property Loss Experience Rating Plan or the Claims Free Discount for claims related to this coverage.
# 5. Including supportive documents such as histograms, certification statements, side-by-side comparisons, and actuarial memorandums.
#
# The rate change type is classified as neutral, indicating no overall percentage change in rates compared to the last revision in November 2024. The company has also confirmed compliance with Vermont regulations regarding rate stability rules in their filing. The filing includes detailed instructions and calculations for developing premiums based on various rating variables and factors for different categories of insured properties (Homeowners, Condo, Renters, etc.).
# Processed additional filing info for: VT_FAIG-134392452.pdf
# Filings/Final/2025-02-24\VT_TRVD-G134383069.pdf
# 2025-03-04 07:26:23.994402
# Token count for API call in VT_TRVD-G134383069.pdf: 19260
# Processed additional filing info for: VT_TRVD-G134383069.pdf
# Filings/Final/2025-02-24\WA_FAIG-134060459.pdf
# 2025-03-04 07:26:24.249594
# Token count for API call in WA_FAIG-134060459.pdf: 173259
# Processed additional filing info for: WA_FAIG-134060459.pdf
# Filings/Final/2025-02-24\WI_SFMA-134414626.pdf
# 2025-03-04 07:26:25.425398
# Token count for API call in WI_SFMA-134414626.pdf: 35089
# Processed additional filing info for: WI_SFMA-134414626.pdf
# Filings/Final/2025-02-24\WV_ALSE-134414963.pdf
# 2025-03-04 07:26:25.673837
# Token count for API call in WV_ALSE-134414963.pdf: 5104
# GPT-3.5 Summary: The rate filing submitted by Allstate Vehicle and Property Insurance Company to the West Virginia Department of Insurance is related to changes in the installment plans for their AVPIC Homeowners insurance product. The filing includes proposed revisions to the installment fees for different payment methods. Key details of the rate filing are as follows:
#
# - Company: Allstate Vehicle and Property Insurance Company
# - Product Name: AVPIC HO Increase Installment Plans
# - State: West Virginia
# - Line of Business: Homeowners
# - Filing Type: Rule
# - Effective Date Requested (New): 07/14/2025
# - Effective Date Requested (Renewal): 08/28/2025
# - Project Name/Number: Changes to Installment Plans/RITM06397372
# - Filing Status: Approved
# - Filing Contact: Kelly Urban, State Filings Analyst
# - Filing Description: The filing proposes changes to installment fees for the AVPIC Homeowners product, including adjustments to the Allstate Easy Pay Plan and other payment methods.
#
# The rate changes involve increasing the installment fee for the Allstate Easy Pay Plan from $1.50 to $2.00, raising the fee for other payment methods (excluding Allstate Payroll Deductions) from $3.00 to $5.00, while continuing to offer no installment fees for Allstate Payroll Deductions. The objections raised by the West Virginia Office of the Insurance Commissioner regarding the maximum installment amounts on personal lines policies were
# Processed additional filing info for: WV_ALSE-134414963.pdf
# Filings/Final/2025-02-24\WY_FARM-134351956.pdf
# 2025-03-04 07:26:29.191176
# Token count for API call in WY_FARM-134351956.pdf: 94807
# Processed additional filing info for: WY_FARM-134351956.pdf
# Filings/Final/2025-02-24\WY_FORE-134419284.pdf
# 2025-03-04 07:26:30.084498
# Token count for API call in WY_FORE-134419284.pdf: 9365
# GPT-3.5 Summary: From the provided filing information, the rate filing pertains to a Homeowners Program offered by Foremost Insurance Company in Wyoming. The filing was submitted on 02/17/2025 and approved with an effective date of 06/01/2025 for both new and renewal policies. The filing includes changes to Form 5447, specifically related to liability coverages, policy conditions, transfer of policy, and cancellation terms. The revised form removes references to minimum earned premium and adds new conditions regarding cancellation and nonrenewal procedures. Additionally, the filing includes supporting documents such as Rate and Form Certification of Compliance, Associated Forms List, Summary of Revisions, Forms List, and Form Comparison. The filing is in compliance with state regulations, and the company is responsible for ensuring full compliance with all applicable statutes and regulations for coverage provided to Wyoming citizens.
# Processed additional filing info for: WY_FORE-134419284.pdf
# Filings/Final/2025-02-24\WY_FORE-134419401.pdf
# 2025-03-04 07:26:32.505958
# Token count for API call in WY_FORE-134419401.pdf: 8731
# GPT-3.5 Summary: Based on the information provided in the filing, it appears that Foremost Insurance Company submitted a rate filing for its Homeowners ACV Program in the state of Wyoming. The filing involved a required change specific to Wyoming, which included updates to the policy conditions related to legal action, policy transfer, cancellation, nonrenewal, and automatic termination. The filing also included a revision to Form 35037 (Required Change - Wyoming) to remove a reference to minimum earned premium as requested in a previous filing.
#
# The rate filing aimed to make these policy changes effective for all new and renewal policies written to be effective on and after June 1, 2025. The filing was submitted electronically via SERFF, and it received approval with a disposition status of "Approved." The effective date for the changes, both for new policies and renewals, was set for June 1, 2025. Various supporting documents, such as the Rate and Form Certification of Compliance, Associated Forms List, Summary of Revisions, and Form Comparison, were also submitted and satisfied as part of the filing process.
# Processed additional filing info for: WY_FORE-134419401.pdf
# Saved additional filing info JSON output to additional_filing_info_2025-02-24.json
# Saved additional filing info CSV output to additional_filing_info_2025-02-24.csv

# %%
###Update to add token count parameter for each API call 3.4 ###

# %%
import os
import re
import glob
import fitz  # PyMuPDF
import json
import pandas as pd
from datetime import datetime
from pprint import pprint
from dotenv import load_dotenv
import tiktoken  # pip install tiktoken

# Load environment variables (which should include api_key and grok_api_key)
load_dotenv()

# === API Call Control Parameters for additional filing info (not used for objections) ===
# Set each to 'Y' to call the API, or 'N' to skip the API call.
CALL_GPT_3_5 = "Y"
CALL_O1_MINI = "N"  # Example value; set to 'Y' or 'N'
CALL_XAI = "N"      # Example value; set to 'Y' or 'N'

# === User-defined Maximum Token Parameters for API calls ===
# These define the maximum number of tokens to send to each model.
# You can change these values or prompt the user for them.
MAX_TOKENS_GPT3_5 = 15000
MAX_TOKENS_O1_MINI = 12000
MAX_TOKENS_XAI = 12000

# Create OpenAI client for standard models
from openai import OpenAI
api_key = os.getenv("api_key")
client = OpenAI(api_key=api_key)

# Create a separate client for the xAI API
XAI_API_KEY = os.getenv("grok_api_key")
xai_client = OpenAI(api_key=XAI_API_KEY, base_url="https://api.x.ai/v1")

# Define the download week as a string and convert it to a datetime object.
date = "2025-03-03"
download_week_dt = datetime.strptime(date, "%Y-%m-%d")

# --- Helper functions for token counting and truncation using tiktoken ---
def count_tokens(text, model="gpt-3.5-turbo"):
    try:
        encoding = tiktoken.encoding_for_model(model)
    except Exception:
        encoding = tiktoken.get_encoding("cl100k_base")
    tokens = encoding.encode(text)
    return len(tokens)

def truncate_text(text, max_tokens, model="gpt-3.5-turbo"):
    try:
        encoding = tiktoken.encoding_for_model(model)
    except Exception:
        encoding = tiktoken.get_encoding("cl100k_base")
    tokens = encoding.encode(text)
    if len(tokens) > max_tokens:
        truncated_tokens = tokens[:max_tokens]
        truncated_text = encoding.decode(truncated_tokens)
        return truncated_text
    return text

# --- API call functions (used in additional filing info only) ---
def call_gpt_3_5_turbo(full_text):
    try:
        completion = client.chat.completions.create(
            model="gpt-3.5-turbo",
            messages=[
                {"role": "system", "content": "You are an analyst doing competitive intelligence research on insurance companies."},
                {"role": "user", "content": f"The following is a filing with a DOI from an insurance company: '{full_text}'. Give a summary of the rate filing."}
            ],
            max_tokens=300
        )
        print("GPT-3.5 Summary:", completion.choices[0].message.content)
        return completion.choices[0].message.content
    except Exception as e:
        print(f"Error calling GPT-3.5-turbo: {e}")
        return ""

def call_o1_mini(full_text):
    try:
        completion = client.chat.completions.create(
            model="o1-mini",
            messages=[
                {"role": "user", "content": "You are an analyst doing competitive intelligence research on insurance companies."},
                {"role": "user", "content": f"The following is a filing with a DOI from an insurance company: '{full_text}'. Give a summary of the rate filing."}
            ]
        )
        print("o1-mini Summary:", completion.choices[0].message.content)
        return completion.choices[0].message.content
    except Exception as e:
        print(f"Error calling o1-mini: {e}")
        return ""

def call_xai(full_text):
    try:
        completion = xai_client.chat.completions.create(
            model="grok-2-latest",
            messages=[
                {"role": "system", "content": "You are an analyst doing competitive intelligence research on insurance companies."},
                {"role": "user", "content": f"The following is a filing with a DOI from an insurance company: '{full_text}'. Give a summary of the rate filing."}
            ]
        )
        print("xAI Summary:", completion.choices[0].message.content)
        return completion.choices[0].message.content
    except Exception as e:
        print(f"Error calling xAI: {e}")
        return ""

# --- Extraction functions for non-API parts ---
def extract_full_text(pdf_path, max_pages=None):
    """
    Extracts full text from PDF.
    If max_pages is provided, only extracts from the first max_pages pages.
    """
    doc = fitz.open(pdf_path)
    full_text = ""
    for i, page in enumerate(doc):
        if max_pages is not None and i >= max_pages:
            break
        full_text += page.get_text() + "\n"
    doc.close()
    return full_text

def split_list_objections(text):
    parts = re.split(r"(?m)^\s*(?:\(?(\d+)\)?[.\)])\s*", text)
    objections = {}
    if len(parts) >= 3:
        for i in range(1, len(parts)-1, 2):
            num = parts[i].strip()
            obj_text = parts[i+1].strip()
            objections[f"objection{num}"] = obj_text
        if not objections:
            objections["objection1"] = text.strip()
    else:
        objections["objection1"] = text.strip()
    return objections

def parse_objection_letters(text):
    """
    Splits the full text into separate objection letter sections.
    A valid objection letter must contain "Objection Letter Date", "Introduction:" and "Conclusion:".
    Returns a dictionary where each key is "Objection_letterX" with its parsed objections.
    """
    pattern = r"(Objection Letter.*?Objection Letter Date\s+(\d{2}/\d{2}/\d{4}).*?Introduction:\s*(.*?)\s*Conclusion:)"
    matches = list(re.finditer(pattern, text, flags=re.IGNORECASE | re.DOTALL))
    letter_dict = {}
    for idx, m in enumerate(matches, start=1):
        letter_date = m.group(2).strip()
        body = m.group(3).strip()
        explicit_objs = list(re.finditer(r"Objection\s+(\d+)", body, flags=re.IGNORECASE))
        if len(explicit_objs) > 1:
            obj_pattern = r"(Objection\s+(\d+).*?)(?=(Objection\s+\d+|Conclusion:|$))"
            objections = {}
            for om in re.finditer(obj_pattern, body, flags=re.IGNORECASE | re.DOTALL):
                num = om.group(2).strip()
                obj_text = om.group(1).strip()
                objections[f"objection{num}"] = obj_text
        else:
            if re.search(r"(?m)^\s*(\(?\d+\)?[.\)])", body):
                objections = split_list_objections(body)
            else:
                objections = {"objection1": body}
        letter_dict[f"Objection_letter{idx}"] = {
            "objection_letter_date": letter_date,
            **objections
        }
    return letter_dict

def extract_filing_company_info(text):
    """
    Extracts filing company information.
    Returns a tuple: (group_code, company_codes)
    """
    company_codes = re.findall(r"CoCode:\s*(\d+)", text, flags=re.IGNORECASE)
    group_codes = re.findall(r"Group Code:\s*(\d+)", text, flags=re.IGNORECASE)
    company_codes = [int(code) for code in company_codes] if company_codes else []
    group_code = int(group_codes[0]) if group_codes else None
    return group_code, company_codes

# --- Extraction functions for additional filing info ---
def parse_filing_at_a_glance(text):
    """
    Extracts key filing info from the "Filing at a Glance" section.
    Returns a dictionary with keys: serff_tr_num, filing_type, date_submitted,
    effective_date_requested_new, effective_date_requested_renewal, serff_status, toi.
    """
    info = {}
    match = re.search(r"Filing at a Glance(.*?)(?=\n[A-Z][a-z]+ Information|$)", text, flags=re.IGNORECASE | re.DOTALL)
    section = match.group(1) if match else ""
    
    serff_match = re.search(r"SERFF Tr Num:\s*([A-Z0-9\-]+)", section, flags=re.IGNORECASE)
    info["serff_tr_num"] = serff_match.group(1).strip() if serff_match else ""
    
    filing_type_match = re.search(r"Filing Type:\s*([^\n]+)", section, flags=re.IGNORECASE)
    info["filing_type"] = filing_type_match.group(1).strip() if filing_type_match else ""
    
    date_submitted_match = re.search(r"Date Submitted:\s*(\d{2}/\d{2}/\d{4})", section, flags=re.IGNORECASE)
    info["date_submitted"] = date_submitted_match.group(1).strip() if date_submitted_match else ""
    
    effective_new_match = re.search(r"Effective Date\s*Requested\s*\(New\):\s*(\d{2}/\d{2}/\d{4})", section, flags=re.IGNORECASE)
    info["effective_date_requested_new"] = effective_new_match.group(1).strip() if effective_new_match else ""
    
    effective_renewal_match = re.search(r"Effective Date\s*Requested\s*\(Renewal\):\s*(\d{2}/\d{2}/\d{4})", section, flags=re.IGNORECASE)
    info["effective_date_requested_renewal"] = effective_renewal_match.group(1).strip() if effective_renewal_match else ""
    
    serff_status_match = re.search(r"SERFF Status:\s*([^\n]+)", section, flags=re.IGNORECASE)
    info["serff_status"] = serff_status_match.group(1).strip() if serff_status_match else ""
    
    toi_match = re.search(r"TOI:\s*([^\n]+)", section, flags=re.IGNORECASE)
    info["toi"] = toi_match.group(1).strip() if toi_match else ""
    
    return info

def parse_filing_description(text):
    """
    Extracts the Filing Description from the text.
    Returns the description string.
    """
    match = re.search(r"Filing Description:\s*(.*?)\s*(Filing Contact Information|Filing Company Information)", 
                      text, flags=re.IGNORECASE | re.DOTALL)
    if match:
        return match.group(1).strip()
    return ""

# --- Processing functions for objections (old version) ---
def process_pdf_file(pdf_path):
    """
    Processes a single PDF file for objections output.
    Truncates the PDF to the first 100 pages before processing.
    Returns a dictionary with keys:
      - "objections": parsed objection letters,
      - "group_code": extracted group code,
      - "company_codes": list of CoCodes,
      - "download_week": the download_week datetime.
    """
    # Truncate to first 100 pages
    full_text = extract_full_text(pdf_path, max_pages=100)
    parsed_letters = parse_objection_letters(full_text)
    group_code, company_codes = extract_filing_company_info(full_text)
    file_key = os.path.splitext(os.path.basename(pdf_path))[0]
    return {file_key: {
                "objections": parsed_letters,
                "group_code": group_code,
                "company_codes": company_codes,
                "download_week": download_week_dt
            }}

def process_all_pdfs_in_folder(pdf_folder):
    """
    Loops through all PDF files in the folder and processes each for objections output.
    Returns a nested dictionary.
    """
    results = {}
    pdf_files = glob.glob(os.path.join(pdf_folder, "*.pdf"))
    for pdf_file in pdf_files:
        print(pdf_file)
        print(datetime.now())
        results.update(process_pdf_file(pdf_file))
    return results

# --- Processing functions for additional filing info (with API calls) ---
def extract_full_text_all(pdf_path):
    """
    Extracts full text from the PDF using up to the first 3000 pages.
    """
    return extract_full_text(pdf_path, max_pages=3000)

def process_pdf_additional(pdf_path):
    """
    Processes a single PDF file and extracts additional filing info.
    For non-API info, uses the first 100 pages.
    For API calls, uses the full text (up to 3000 pages) subject to token constraints.
    Returns a dictionary with keys including API summaries.
    """
    # Non-API extraction (first 100 pages)
    limited_text = extract_full_text(pdf_path, max_pages=100)
    filing_at_a_glance = parse_filing_at_a_glance(limited_text)
    filing_description = parse_filing_description(limited_text)
    group_code, company_codes = extract_filing_company_info(limited_text)
    
    # API extraction using full text (up to 3000 pages)
    full_text_all = extract_full_text_all(pdf_path)
    print(f"Token count for API call in {os.path.basename(pdf_path)}: {count_tokens(full_text_all, model='gpt-3.5-turbo')}")
    
    # Always call GPT-3.5-turbo if parameter is set to 'Y', using user-defined token limit.
    if CALL_GPT_3_5 == "Y":
        gpt_api_text = truncate_text(full_text_all, max_tokens=MAX_TOKENS_GPT3_5, model="gpt-3.5-turbo")
        gpt_3_5_summary = call_gpt_3_5_turbo(gpt_api_text)
    else:
        gpt_3_5_summary = ""
    
    # For o1-mini and xAI, use the user-defined token limits.
    if CALL_O1_MINI == "Y":
        o1_api_text = truncate_text(full_text_all, max_tokens=MAX_TOKENS_O1_MINI, model="o1-mini")
        o1_mini_summary = call_o1_mini(o1_api_text)
    else:
        o1_mini_summary = ""
    
    if CALL_XAI == "Y":
        xai_api_text = truncate_text(full_text_all, max_tokens=MAX_TOKENS_XAI, model="grok-2-latest")
        xai_summary = call_xai(xai_api_text)
    else:
        xai_summary = ""
    
    additional = {
        "serff_tr_num": filing_at_a_glance.get("serff_tr_num", ""),
        "filing_type": filing_at_a_glance.get("filing_type", ""),
        "date_submitted": filing_at_a_glance.get("date_submitted", ""),
        "effective_date_requested_new": filing_at_a_glance.get("effective_date_requested_new", ""),
        "effective_date_requested_renewal": filing_at_a_glance.get("effective_date_requested_renewal", ""),
        "serff_status": filing_at_a_glance.get("serff_status", ""),
        "filing_description": filing_description,
        "filing_method": "",  # Not extracted
        "toi": filing_at_a_glance.get("toi", ""),
        "group_code": group_code,
        "company_codes": company_codes,
        "download_week": download_week_dt,
        "gpt_3_5_summary": gpt_3_5_summary,
        "o1_mini_summary": o1_mini_summary,
        "xai_summary": xai_summary
    }
    print(f"Processed additional filing info for: {os.path.basename(pdf_path)}")
    return additional

def process_all_pdfs_additional(pdf_folder):
    """
    Processes all PDFs in the folder for additional filing info.
    Returns a dictionary keyed by file name.
    """
    results = {}
    pdf_files = glob.glob(os.path.join(pdf_folder, "*.pdf"))
    for pdf_file in pdf_files:
        print(pdf_file)
        print(datetime.now())
        file_key = os.path.splitext(os.path.basename(pdf_file))[0]
        results[file_key] = process_pdf_additional(pdf_file)
    return results

def additional_to_dataframe(results):
    """
    Converts the additional filing info dictionary into a DataFrame.
    """
    rows = []
    for file_key, info in results.items():
        row = {
            "SERFF Tr Num": info.get("serff_tr_num", ""),
            "Filing Type": info.get("filing_type", ""),
            "Date Submitted": info.get("date_submitted", ""),
            "Effective Date Requested (New)": info.get("effective_date_requested_new", ""),
            "Effective Date Requested (Renewal)": info.get("effective_date_requested_renewal", ""),
            "SERFF Status": info.get("serff_status", ""),
            "Filing Description": info.get("filing_description", ""),
            "Filing Method": info.get("filing_method", ""),
            "TOI": info.get("toi", ""),
            "Group_Code": info.get("group_code", ""),
            "Company_Codes": str(info.get("company_codes", "")),
            "week_date": info.get("download_week", None),
            "gpt_3_5_summary": info.get("gpt_3_5_summary", ""),
            "o1_mini_summary": info.get("o1_mini_summary", ""),
            "xai_summary": info.get("xai_summary", "")
        }
        rows.append(row)
    df = pd.DataFrame(rows, columns=[
        "SERFF Tr Num", "Filing Type", "Date Submitted", 
        "Effective Date Requested (New)", "Effective Date Requested (Renewal)",
        "SERFF Status", "Filing Description", "Filing Method", "TOI",
        "Group_Code", "Company_Codes", "week_date",
        "gpt_3_5_summary", "o1_mini_summary", "xai_summary"
    ])
    return df

# --- DataFrame for objections ---
def results_to_dataframe_objections(results):
    """
    Converts the objections dictionary (from process_all_pdfs_in_folder) into a DataFrame.
    """
    rows = []
    for file_key, file_info in results.items():
        state_abbr = file_key.split('_')[0] if "_" in file_key else file_key[:2]
        group_code = file_info.get("group_code", "No objections")
        company_codes = file_info.get("company_codes", [])
        company_code_first = company_codes[0] if company_codes else "No objections"
        company_codes_str = str(company_codes) if company_codes else "No objections"
        download_week = file_info.get("download_week", None)
        letter_dict = file_info.get("objections", {})
        if not letter_dict:
            rows.append({
                "SERFF#": file_key,
                "State": state_abbr,
                "Group_Code": group_code,
                "Company_Code": company_code_first,
                "Company_Code_all": company_codes_str,
                "Objection_letter_date": "No objections",
                "Objectionletter#": "No objections",
                "Objection#": "No objections",
                "Objection": "No objections",
                "download_week": download_week
            })
        else:
            for letter_key, letter_content in letter_dict.items():
                letter_date = letter_content.get("objection_letter_date", "No objections")
                for obj_key, obj_text in letter_content.items():
                    if obj_key == "objection_letter_date":
                        continue
                    rows.append({
                        "SERFF#": file_key,
                        "State": state_abbr,
                        "Group_Code": group_code,
                        "Company_Code": company_code_first,
                        "Company_Code_all": company_codes_str,
                        "Objection_letter_date": letter_date,
                        "Objectionletter#": letter_key,
                        "Objection#": obj_key,
                        "Objection": obj_text.replace("\n", " ").strip(),
                        "download_week": download_week
                    })
    df = pd.DataFrame(rows, columns=[
        "SERFF#", "State", "Group_Code", "Company_Code", "Company_Code_all", 
        "Objection_letter_date", "Objectionletter#", "Objection#", "Objection", "download_week"
    ])
    return df

# --- Main Processing ---
pdf_folder = f"Filings/Final/{date}"  # Folder path based on date parameter

# Process objections using the old functions.
objection_results = process_all_pdfs_in_folder(pdf_folder)
json_output_path = f"objections_output_{date}.json"
with open(json_output_path, "w", encoding="utf-8") as f:
    json.dump(objection_results, f, default=lambda o: o.isoformat() if isinstance(o, datetime) else o, ensure_ascii=False, indent=4)
print(f"Saved objections JSON output to {json_output_path}")

df_objections = results_to_dataframe_objections(objection_results)
csv_output_path = f"objections_output_{date}.csv"
df_objections.to_csv(csv_output_path, index=False)
print(f"Saved objections CSV output to {csv_output_path}")

# Process additional filing info using the new function.
additional_results = process_all_pdfs_additional(pdf_folder)
additional_json_output_path = f"additional_filing_info_{date}.json"
with open(additional_json_output_path, "w", encoding="utf-8") as f:
    json.dump(additional_results, f, default=lambda o: o.isoformat() if isinstance(o, datetime) else o, ensure_ascii=False, indent=4)
print(f"Saved additional filing info JSON output to {additional_json_output_path}")

df_additional = additional_to_dataframe(additional_results)
additional_csv_output_path = f"additional_filing_info_{date}.csv"
df_additional.to_csv(additional_csv_output_path, index=False)
print(f"Saved additional filing info CSV output to {additional_csv_output_path}")
# Out:
# Filings/Final/2025-03-03\AL_ALSE-134300517.pdf
# 2025-03-05 07:38:47.721856
# Filings/Final/2025-03-03\AL_LBPM-134436753.pdf
# 2025-03-05 07:38:47.797844
# Filings/Final/2025-03-03\AR_TRVD-G134425501.pdf
# 2025-03-05 07:38:53.047600
# Filings/Final/2025-03-03\AZ_TRVD-134038097.pdf
# 2025-03-05 07:38:53.282250
# Filings/Final/2025-03-03\AZ_TRVD-G134416866.pdf
# 2025-03-05 07:38:53.698131
# Filings/Final/2025-03-03\AZ_TRVD-G134417169.pdf
# 2025-03-05 07:38:54.092514
# Filings/Final/2025-03-03\CA_ALSE-134306035.pdf
# 2025-03-05 07:38:54.322003
# Filings/Final/2025-03-03\CA_LBRM-134233558.pdf
# 2025-03-05 07:38:55.003396
# Filings/Final/2025-03-03\CA_LBRM-134354159.pdf
# 2025-03-05 07:38:55.611450
# Filings/Final/2025-03-03\CO_LBPM-134412448.pdf
# 2025-03-05 07:38:56.352865
# Filings/Final/2025-03-03\CO_LEMO-134207600.pdf
# 2025-03-05 07:38:56.534432
# Filings/Final/2025-03-03\CO_USAA-134337652.pdf
# 2025-03-05 07:38:57.086351
# Filings/Final/2025-03-03\CT_TRVD-G134412788.pdf
# 2025-03-05 07:38:57.443973
# Filings/Final/2025-03-03\GA_ALSE-134333693.pdf
# 2025-03-05 07:38:58.884954
# Filings/Final/2025-03-03\GA_ALSE-134336829.pdf
# 2025-03-05 07:38:59.398343
# Filings/Final/2025-03-03\GA_ALSE-134336890.pdf
# 2025-03-05 07:38:59.773849
# Filings/Final/2025-03-03\GA_ALSE-134337450.pdf
# 2025-03-05 07:39:00.188034
# Filings/Final/2025-03-03\GA_ALSE-134337637.pdf
# 2025-03-05 07:39:01.111472
# Filings/Final/2025-03-03\GA_ALSE-134337677.pdf
# 2025-03-05 07:39:01.421559
# Filings/Final/2025-03-03\GA_ALSE-134337686.pdf
# 2025-03-05 07:39:01.922105
# Filings/Final/2025-03-03\GA_LEMO-134374428.pdf
# 2025-03-05 07:39:02.341089
# Filings/Final/2025-03-03\GA_LEMO-134376013.pdf
# 2025-03-05 07:39:02.434636
# Filings/Final/2025-03-03\GA_TRVD-G134360540.pdf
# 2025-03-05 07:39:02.684396
# Filings/Final/2025-03-03\GA_TRVD-G134400530.pdf
# 2025-03-05 07:39:03.121858
# Filings/Final/2025-03-03\IA_AMSI-134274777.pdf
# 2025-03-05 07:39:03.459575
# Filings/Final/2025-03-03\IL_HART-134383807.pdf
# 2025-03-05 07:39:03.569227
# Filings/Final/2025-03-03\IL_LEMO-134419957.pdf
# 2025-03-05 07:39:03.668195
# Filings/Final/2025-03-03\KS_GMMX-134433936.pdf
# 2025-03-05 07:39:03.843694
# Filings/Final/2025-03-03\KS_LBPM-134379791.pdf
# 2025-03-05 07:39:04.106346
# Filings/Final/2025-03-03\KS_LBPM-134409706.pdf
# 2025-03-05 07:39:05.114031
# Filings/Final/2025-03-03\KY_ALSE-134398573.pdf
# 2025-03-05 07:39:05.427416
# Filings/Final/2025-03-03\KY_ALSE-134398945.pdf
# 2025-03-05 07:39:05.646859
# Filings/Final/2025-03-03\KY_USAA-134421819.pdf
# 2025-03-05 07:39:05.939969
# Filings/Final/2025-03-03\LA_LBPM-134284450.pdf
# 2025-03-05 07:39:06.036478
# Filings/Final/2025-03-03\MI_ALSE-134422885.pdf
# 2025-03-05 07:39:06.376207
# Filings/Final/2025-03-03\MI_ALSE-134443416.pdf
# 2025-03-05 07:39:06.838310
# Filings/Final/2025-03-03\MI_LBPM-134437577.pdf
# 2025-03-05 07:39:19.911009
# Filings/Final/2025-03-03\MI_LBPM-134437587.pdf
# 2025-03-05 07:39:19.993730
# Filings/Final/2025-03-03\MN_ALSE-134409609.pdf
# 2025-03-05 07:39:20.053299
# Filings/Final/2025-03-03\MN_ALSE-134409640.pdf
# 2025-03-05 07:39:20.209596
# Filings/Final/2025-03-03\MN_AMSI-134380414.pdf
# 2025-03-05 07:39:20.379598
# Filings/Final/2025-03-03\MN_TRVD-G134202060.pdf
# 2025-03-05 07:39:20.665525
# Filings/Final/2025-03-03\MO_LBPM-134358153.pdf
# 2025-03-05 07:39:21.267187
# Filings/Final/2025-03-03\MO_LBPM-134364067.pdf
# 2025-03-05 07:39:21.515090
# Filings/Final/2025-03-03\MO_TRVD-G134325887.pdf
# 2025-03-05 07:39:22.638007
# Filings/Final/2025-03-03\NC_USAA-134418343.pdf
# 2025-03-05 07:39:22.693802
# Filings/Final/2025-03-03\NC_USAA-134418345.pdf
# 2025-03-05 07:39:22.918260
# Filings/Final/2025-03-03\NC_USAA-134418351.pdf
# 2025-03-05 07:39:23.124415
# Filings/Final/2025-03-03\NC_USAA-134418355.pdf
# 2025-03-05 07:39:23.465287
# Filings/Final/2025-03-03\ND_GMMX-134414147.pdf
# 2025-03-05 07:39:23.674039
# Filings/Final/2025-03-03\ND_GMMX-134414190.pdf
# 2025-03-05 07:39:23.744407
# Filings/Final/2025-03-03\ND_GMMX-134414199.pdf
# 2025-03-05 07:39:23.807567
# Filings/Final/2025-03-03\NE_TRVD-G134437855.pdf
# 2025-03-05 07:39:23.901052
# Filings/Final/2025-03-03\NJ_LBPM-134367579.pdf
# 2025-03-05 07:39:24.122955
# Filings/Final/2025-03-03\NM_TRVD-G134428427.pdf
# 2025-03-05 07:39:24.409054
# Filings/Final/2025-03-03\NV_AMSI-134209900.pdf
# 2025-03-05 07:39:24.638536
# Filings/Final/2025-03-03\NV_HART-134384733.pdf
# 2025-03-05 07:39:24.733095
# Filings/Final/2025-03-03\NV_HART-134433449.pdf
# 2025-03-05 07:39:24.884302
# Filings/Final/2025-03-03\OR_ALSE-134413946.pdf
# 2025-03-05 07:39:24.963547
# Filings/Final/2025-03-03\OR_ALSE-134413977.pdf
# 2025-03-05 07:39:25.190126
# Filings/Final/2025-03-03\OR_ALSE-134417934.pdf
# 2025-03-05 07:39:25.310103
# Filings/Final/2025-03-03\OR_ALSE-134417942.pdf
# 2025-03-05 07:39:25.482403
# Filings/Final/2025-03-03\OR_ALSE-134417973.pdf
# 2025-03-05 07:39:25.622703
# Filings/Final/2025-03-03\OR_ALSE-134418009.pdf
# 2025-03-05 07:39:25.716259
# Filings/Final/2025-03-03\OR_ALSE-134418028.pdf
# 2025-03-05 07:39:25.818435
# Filings/Final/2025-03-03\PA_LEMO-134412814.pdf
# 2025-03-05 07:39:25.913871
# Filings/Final/2025-03-03\RI_LBPM-134392464.pdf
# 2025-03-05 07:39:26.090363
# Filings/Final/2025-03-03\SC_AMSI-134171194.pdf
# 2025-03-05 07:39:26.494276
# Filings/Final/2025-03-03\SC_LBPM-134400516.pdf
# 2025-03-05 07:39:26.762641
# Filings/Final/2025-03-03\SC_LBPM-134401992.pdf
# 2025-03-05 07:39:26.982247
# Filings/Final/2025-03-03\SC_LBPM-134406290.pdf
# 2025-03-05 07:39:27.175836
# Filings/Final/2025-03-03\TN_HART-134429213.pdf
# 2025-03-05 07:39:27.548240
# Filings/Final/2025-03-03\TN_LBPM-134412900.pdf
# 2025-03-05 07:39:27.624509
# Filings/Final/2025-03-03\TN_LBPM-134434596.pdf
# 2025-03-05 07:39:27.919906
# Filings/Final/2025-03-03\TN_USAA-134436312.pdf
# 2025-03-05 07:39:28.223274
# Filings/Final/2025-03-03\TX_ALSE-133994457.pdf
# 2025-03-05 07:39:28.308246
# Filings/Final/2025-03-03\TX_ALSE-133994492.pdf
# 2025-03-05 07:39:28.949167
# Filings/Final/2025-03-03\TX_ALSE-133995002.pdf
# 2025-03-05 07:39:29.388905
# Filings/Final/2025-03-03\TX_GMMX-134436826.pdf
# 2025-03-05 07:39:29.777454
# Filings/Final/2025-03-03\TX_LBPM-134367508.pdf
# 2025-03-05 07:39:30.118009
# Filings/Final/2025-03-03\UT_LBPM-134409711.pdf
# 2025-03-05 07:39:30.222697
# Filings/Final/2025-03-03\VA_AMSI-134375543.pdf
# 2025-03-05 07:39:30.418584
# Filings/Final/2025-03-03\VA_HART-134429350.pdf
# 2025-03-05 07:39:30.473481
# Filings/Final/2025-03-03\VA_TRVD-G134337488.pdf
# 2025-03-05 07:39:30.497974
# Filings/Final/2025-03-03\WA_GMMX-134441494.pdf
# 2025-03-05 07:39:30.931754
# Filings/Final/2025-03-03\WV_AMSI-134244221.pdf
# 2025-03-05 07:39:31.294017
# Saved objections JSON output to objections_output_2025-03-03.json
# Saved objections CSV output to objections_output_2025-03-03.csv
# Filings/Final/2025-03-03\AL_ALSE-134300517.pdf
# 2025-03-05 07:39:31.918965
# Token count for API call in AL_ALSE-134300517.pdf: 1798
# GPT-3.5 Summary: Summary of the Rate Filing:
# - Company: Allstate North American Insurance Company
# - Product Name: ANAIC HO (Homeowners Insurance)
# - State: Alabama
# - Type of Insurance: Homeowners (Owner Occupied)
# - Filing Type: Model - Other
# - Date Submitted: 10/29/2024
# - SERFF Tracking #: ALSE-134300517
# - Filing Status: Closed-Approved
# - Effective Date: On Approval
# - Filing Contact: Rhonda Amann (State Filings Manager)
# - Filing Description: Allstate is introducing a new Homeowners insurance program using Geographic and Hurricane Rate Plan Models in a subsequent rate filing.
# - Filing Fee: $100.00 (Property, Casualty, Marine, and Surety Model filing)
#
# Overall, the rate filing involves the introduction of a new Homeowners insurance program by Allstate in Alabama, utilizing specific Geographic and Hurricane Rate Plan Models. The filing has been approved by the state and the company has outlined its intention to implement this new program upon approval.
# Processed additional filing info for: AL_ALSE-134300517.pdf
# Filings/Final/2025-03-03\AL_LBPM-134436753.pdf
# 2025-03-05 07:39:35.895082
# Token count for API call in AL_LBPM-134436753.pdf: 3887596
# GPT-3.5 Summary: The rate filing submitted by Liberty Mutual Insurance Company and Peerless Indemnity Insurance Company for their Homeowners insurance product in Alabama includes revisions to the rating factors within their homeowner program. The effective date for these revisions is specified as April 1, 2025, for new business policies and May 6, 2025, for renewal business policies. The overall rate effect for this change is noted as a decrease of -25.0%.
#
# The filing includes modifications to various rate components such as Base Rates, Fixed Expenses, and Fixed Expenses for Landlord properties. The documents submitted with the filing provide detailed information on the changes made to each component, including base rates and expense rates. The filing also mentions the approval status, with the disposition date noted as February 27, 2025, and a status of "Closed-Approved."
#
# The companies involved, Liberty Mutual Insurance Company and Peerless Indemnity Insurance Company, have provided detailed contact information for further inquiries related to the filing. The filing includes a description of the rate revisions, information on the associated fees, details on any models used in the calculation of rates, and the statutory guidelines followed for trade secret confidentiality.
#
# Overall, the rate filing aims to adjust the rating factors for the Homeowners insurance product in Alabama, with the changes expected to benefit policyholders through a reduced overall rate effect.
# Processed additional filing info for: AL_LBPM-134436753.pdf
# Filings/Final/2025-03-03\AR_TRVD-G134425501.pdf
# 2025-03-05 07:41:38.404945
# Token count for API call in AR_TRVD-G134425501.pdf: 31150
# GPT-3.5 Summary: Based on the filing provided, here is a summary of the rate filing for the insurance company in Arkansas:
#
# 1. **Companies Listed:** The Automobile Insurance Company of Hartford, Connecticut; The Standard Fire Insurance Company; The Travelers Home and Marine Insurance Company; The Travelers Indemnity Company of America; Travelers Commercial Insurance Company; Travelers Personal Insurance Company
#
# 2. **Product Name:** Quantum Homeowners 2.0, Quantum Homeowners, Homeowners
#
# 3. **State:** Arkansas
#
# 4. **Type of Insurance:** Homeowners insurance
#
# 5. **Filing Type:** Rule
#
# 6. **Effective Date Requested:**
#    - New: 04/13/2025
#    - Renewal: 06/02/2025
#
# 7. **Overall Rate Impact:** 0.000%
#
# 8. **Additional Coverages and Enhancements:** The filing includes various additional coverages and enhancements such as High Value Home Coverage, Loss Assessment Coverage, Enhanced Home Package, and more.
#
# 9. **Premium Adjustments:** Premium adjustments are made based on factors like construction type, protection class, coverage limits, and additional coverages chosen by the insured.
#
# 10. **Endorsements:** Endorsements like ACE Endorsement, Loss Assessment Coverage, Dwelling Under Construction Coverage, and Identity Fraud Expense Reimbursement Coverage are available for added protections.
#
# 11. **Optional Coverages:** Optional coverages are offered for building additions, increased limits for business property,
# Processed additional filing info for: AR_TRVD-G134425501.pdf
# Filings/Final/2025-03-03\AZ_TRVD-134038097.pdf
# 2025-03-05 07:41:43.440172
# Token count for API call in AZ_TRVD-134038097.pdf: 25162
# GPT-3.5 Summary: The rate filing is a submission by The Travelers Home and Marine Insurance Company for their product TIS 1.0 in Arizona for homeowners insurance. The filing involves a rule change and was submitted on 03/21/2024. The effective date requested for both new business and renewals is 04/28/2024. The filing has been acknowledged by the state, with a disposition date of 02/28/2025. The filing includes objections from the Department of Insurance related to model validation, statistical testing, model outputs, and other compliance issues. The objections have triggered responses from the company addressing each specific objection in detail. The correspondence includes extension requests and responses to objections from the state reviewer, Kim Richardson. The company's Regulatory Analyst, Kim Richardson, is the primary contact for the filing.
# Processed additional filing info for: AZ_TRVD-134038097.pdf
# Filings/Final/2025-03-03\AZ_TRVD-G134416866.pdf
# 2025-03-05 07:41:47.151171
# Token count for API call in AZ_TRVD-G134416866.pdf: 29358
# GPT-3.5 Summary: The insurance company, The Travelers Home and Marine Insurance Company, has submitted a rate filing for its Quantum Homeowners & High Value Homeowners - Dwelling product in the state of Arizona. The filing includes amendments to their Homeowners program, with a +8.0% impact on Dwelling. The filing is a rate increase type with an overall percentage rate indicated for this filing at 22.000%. The effective date requested for the renewal is 04/26/2025.
#
# The rate filing was submitted on 02/13/2025 and was acknowledged with a disposition date of 02/27/2025. The filing includes multiple companies under The Travelers brand, such as The Travelers Home and Marine Insurance Company and Travelers Commercial Insurance Company. The filing company's project name/number is PIECSR-581/2025-02-0704A.
#
# Various supporting documents and schedules have been filed alongside the rate changes, such as the Actuarial Supporting Exhibit Requirements, the General Filing Checklist and Instructions for All Lines, and others. Additionally, objections and responses have been submitted regarding the rate changes, addressing concerns about the indicated rate change and steps taken to reduce the possibility of inadequate rates.
#
# The rate change is based on thorough analysis, considering factors like past and prospective loss experience, catastrophe hazards, underwriting profit, and industry trends. The insurer has detailed methodologies and calculations supporting the rate adjustments, including factors like Premium Trend, Loss Trend, Catastrophe Loss
# Processed additional filing info for: AZ_TRVD-G134416866.pdf
# Filings/Final/2025-03-03\AZ_TRVD-G134417169.pdf
# 2025-03-05 07:41:52.042706
# Token count for API call in AZ_TRVD-G134417169.pdf: 25306
# GPT-3.5 Summary: Based on the provided filing information, it appears that The Travelers Home and Marine Insurance Company and Travelers Commercial Insurance Company have submitted a rate filing for their Quantum Homeowners & High Value Homeowners - Condo products in the state of Arizona. Here is a summary of the key details from the filing:
#
# 1. **Product Name**: Quantum Homeowners & High Value Homeowners - Condo
# 2. **Companies**: The Travelers Home and Marine Insurance Company, Travelers Commercial Insurance Company
# 3. **State**: Arizona
# 4. **Type of Filing**: Rate
# 5. **Effective Date Requested**: New – 04/26/2025; Renewal – 04/26/2025
# 6. **Overall Rate Impact**:
#    - The Travelers Home and Marine Insurance Company: 11.7% indicated change, 2.0% rate impact
#    - Travelers Commercial Insurance Company: 11.7% indicated change, 2.0% rate impact
# 7. **Filing Status**: Acknowledged
# 8. **SERFF Status**: Closed-Acknowledged
# 9. **Filing Contact**: Kim Richardson, Sr. Regulatory Analyst
#    - Email: klricha2@travelers.com
#    - Phone: 865-777-6535
# 10. **Company Information**:
#    - The Travelers Home and Marine Insurance Company:
#      - Address: One Tower Square, Hartford, CT 06183
# Processed additional filing info for: AZ_TRVD-G134417169.pdf
# Filings/Final/2025-03-03\CA_ALSE-134306035.pdf
# 2025-03-05 07:41:56.554713
# Token count for API call in CA_ALSE-134306035.pdf: 288931
# GPT-3.5 Summary: Here is a detailed summary of the objections and responses highlighted in the filings related to the underwriting guidelines of Encompass Insurance Company:
#
# 1. **Objection 1 (Addressed in Response 1 on 01/06/2025):**
#    - **Summary:** The objection raised concerns about changes in the wildfire risk score and their impact on policyholders. Specific questions were posed regarding policyholder impact and reasons for the changes.
#    - **Response:** Encompass detailed their mitigation efforts against wildfire risk, explaining the rationale behind changing the renewal wildfire score to 20. They clarified that there is no rate impact as Encompass does not rate on wildfire score.
#
# 2. **Objection 2 (Addressed in Response 1 on 01/17/2025):**
#    - **Summary:** This objection pertained to the determination of current rates sufficiency, the premium amount for policies planned for non-renewal, and the process for non-renewals.
#    - **Response:** Encompass reviewed loss experience for different wildfire risk score categories and determined that current rates are sufficient. The premium amount for non-renewal policies was $3,688,724, and no non-renewals had started as of their response date. Encompass planned to start non-renewals on 5/1/25 but paused this due to wildfire moratoriums.
#
# 3. **Objection 3 (Addressed in Response 1 on 01/28/2025):
# Processed additional filing info for: CA_ALSE-134306035.pdf
# Filings/Final/2025-03-03\CA_LBRM-134233558.pdf
# 2025-03-05 07:42:05.018935
# Token count for API call in CA_LBRM-134233558.pdf: 100562
# GPT-3.5 Summary: The rate filing submitted by First National Insurance Company of America, Safeco Insurance Company of America, and Safeco Insurance Company of Illinois pertains to homeowners insurance in California. The filing includes updates to the eligibility guidelines and rules to clarify and refine their underwriting appetite. The effective date requested for both new business and renewal business is 04/19/2025. The filing was submitted on 09/03/2024 and was approved with a disposition date of 03/03/2025. The filing encompasses changes to the Product Guide, Eligibility Guidelines, and supporting documents, with no rate changes indicated. The disposition status is approved, and the changes specified in the application have been approved for implementation.
# Processed additional filing info for: CA_LBRM-134233558.pdf
# Filings/Final/2025-03-03\CA_LBRM-134354159.pdf
# 2025-03-05 07:42:09.731745
# Token count for API call in CA_LBRM-134354159.pdf: 49975
# GPT-3.5 Summary: Based on the filing provided, the First National Insurance Company of America is formally submitting a withdrawal filing for its Legacy Homeowners Product in the state of California. The withdrawal is effective as of January 1, 2026, and the company has affirmed that it will not renew any policies from the withdrawn program into any similar programs offered by the same insurer group in California. Additionally, the company has agreed not to file a replacement program for at least 3 years after the effective date of the withdrawal.
#
# Key Points from the Filing:
# 1. **Company Information:**
#    - Filing Company: First National Insurance Company of America
#    - Domiciled in: New Hampshire
#    - State of Filing: California
#    - Product Name: Homeowners
#
# 2. **Filing Details:**
#    - **Effective Date Requested:** 01/01/2026
#    - **Filing Type:** Rate/Rule/Form
#    - **Disposition Status:** Acknowledged
#
# 3. **Submitted Documents and Changes:**
#    - Withdrawal Letter
#    - Non-Renewal Notice
#    - New Prior Approval Rate Application
#    - Exhibit 1 - Legacy
#    - PriorAppRateAPL Forms
#    - Product Guide changes
#
# 4. **Correspondence Summary:**
#    - Series of Objection and Response Letters exchanged between Christine Ray and Yizun Chen regarding the withdrawal and non-renewal process.
#
# Overall, the filing indicates a strategic decision
# Processed additional filing info for: CA_LBRM-134354159.pdf
# Filings/Final/2025-03-03\CO_LBPM-134412448.pdf
# 2025-03-05 07:42:15.778705
# Token count for API call in CO_LBPM-134412448.pdf: 22981
# GPT-3.5 Summary: The rate filing document provides detailed information on the proposed updates for Dwelling and Condominium products by Safeco Insurance Company of America and American Economy Insurance Company in Colorado. Here is a summary of the key points from the filing:
#
# - Companies Involved:
#   - American Economy Insurance Company
#   - Safeco Insurance Company of America
#
# - Product Name: Homeowners
#
# - Type of Filing: Rate
# - Date Submitted: 02/14/2025
#
# **American Economy Insurance Company:**
# - Proposed Updates for Condominium Products:
#   - Base Rates
#   - Coverage A Base
#   - Loss Assessment
# - Overall Impact: 36.0%
#
# **Safeco Insurance Company of America:**
# - Proposed Updates for Homeowners Products:
#   - Base Rates
#   - Package Unities
#   - Roof Age
# - Proposed Updates for Condominium Products:
#   - Base Rates
#   - Loss Assessment
# - Impact:
#   - Homeowners: 13%
#   - Condominium: 35.9%
#
# - Overall Rate Information:
#   - Overall Percentage Rate Indicated For This Filing: 19.6%
#   - Overall Percentage Rate Impact For This Filing: 15.2%
#   - Effective Date Requested (New): 04/14/2025
#   - Effective Date Requested (Renewal): 05/31/2025
#
# - Filing Notes:
#   - The filing has been reviewed and filed with a
# Processed additional filing info for: CO_LBPM-134412448.pdf
# Filings/Final/2025-03-03\CO_LEMO-134207600.pdf
# 2025-03-05 07:42:20.311601
# Token count for API call in CO_LEMO-134207600.pdf: 180781
# GPT-3.5 Summary: - **Company Name:** Lemonade Insurance Company
# - **Product Name:** Homeowners
# - **State:** Colorado
# - **Type of Insurance:** Homeowners
# - **Filing Type:** Loss Cost
# - **Overall % Indicated Change:** 27.210%
# - **Overall % Rate Impact:** 19.740%
# - **Written Premium Change for this Program:** $3,287,215
# - **Number of Policy Holders Affected for this Program:** 50,821
# - **Written Premium for this Program:** $16,652,557
# - **Maximum % Change (where required):** 48.530%
# - **Minimum % Change (where required):** 0.000%
# - **Requested Rate Level Changes:** 35.0% for HO-3, 1.0% for HO-4, and 35.0% for HO-6, resulting in an all-forms rate impact of 19.74%
# - **Effective Date Requested (New):** 10/09/2024
# - **Effective Date Requested (Renewal):** 12/08/2024
#
# This rate filing includes various supporting documents such as regulatory filings, rate/rule attachments, actuarial supporting exhibits, inquiry responses, and a confidentiality index. Lemonade Insurance Company has proposed a significant rate level change, with specific adjustments for different types of homeowners policies, and has requested specific effective dates for implementing these changes.
# Processed additional filing info for: CO_LEMO-134207600.pdf
# Filings/Final/2025-03-03\CO_USAA-134337652.pdf
# 2025-03-05 07:42:25.887616
# Token count for API call in CO_USAA-134337652.pdf: 75452
# GPT-3.5 Summary: The rate filing submitted by United Services Automobile Association (USAA), USAA Casualty Insurance Company (USAA-CIC), USAA General Indemnity Company (USAA-GIC), and Garrison Property and Casualty Insurance Company includes the following key details:
#
# 1. **Filing Description:** The filing proposes a revision to Homeowners premium rates with an overall effect of 6.0%, to be effective for new business on 1/14/2025 and for renewal business on 4/1/2025.
#
# 2. **Companies:** United Services Automobile Association, USAA Casualty Insurance Company, USAA General Indemnity Company, and Garrison Property and Casualty Insurance Company are involved in the filing.
#
# 3. **Rate Changes:** The overall rate impact and changes for the companies vary with USAA at 8.8%, USAA-CIC at 6.3%, USAA-GIC at 2.5%, and Garrison at 1.5%.
#
# 4. **Exhibits:** The filing includes supporting exhibits such as the Underwriting Profit & Contingency Provision, Investment income table of contents, and more to support the rate changes.
#
# This filing aims to ensure that the rates are adequate and comply with the regulatory standards for Homeowners insurance in the state of Colorado. It also includes detailed explanations of the rate changes, targeting underwriting profits, and contingency provisions for each company within the group. Additionally, the filing mentions the use
# Processed additional filing info for: CO_USAA-134337652.pdf
# Filings/Final/2025-03-03\CT_TRVD-G134412788.pdf
# 2025-03-05 07:42:31.696994
# Token count for API call in CT_TRVD-G134412788.pdf: 2465285
# GPT-3.5 Summary: Based on the information provided in the rate filing, here is a summary of the key details:
#
# 1. Company: Travelers Personal Insurance Company
# 2. Product: Quantum Home 2.0
# 3. State: Connecticut
# 4. Type of Insurance: Homeowners (TOI: 04.0 Homeowners)
# 5. Filing Type: Rate/Rule
# 6. Effective Date Requested: New Business - 05/18/2025, Renewal Business - 07/24/2025
# 7. Rate Change Type: Increase
# 8. Overall Percentage of Last Rate Revision: 14.700%
# 9. Previous Rate Revision Date: 04/26/2024
# 10. Rate Filing Method: File & Use
# 11. Number of Policy Holders Affected: 85,504
# 12. Written Premium Change: $12,634,440
# 13. Contact Information: Steven Harris, Sr. Regulatory Services Analyst, srharri2@travelers.com, 865-777-6181
# 14. Territory Factors: Detailed tables for various territories and lines of coverage
#
# The rate filing reflects an increase in rates for the Quantum Home 2.0 homeowners insurance product in Connecticut, with new rates set to take effect on 05/18/2025 for new business and 07/24/2025 for renewal business. The filing includes detailed rate and rule changes, as well as supporting documents such as base rates, territory factors
# Processed additional filing info for: CT_TRVD-G134412788.pdf
# Filings/Final/2025-03-03\GA_ALSE-134333693.pdf
# 2025-03-05 07:43:04.815452
# Token count for API call in GA_ALSE-134333693.pdf: 31120
# GPT-3.5 Summary: Based on the information provided in the filing with the Department of Insurance (DOI), here are key details regarding Allstate Fire and Casualty Insurance Company's revision for AFCIC HO in Georgia:
#
# 1. **Project Details:**
#    - **Product Name:** AFCIC HO
#    - **Project Name/Number:** Fortified Home Discount/RITM06297272
#    - **Effective Date Requested:** 03/01/2025
#
# 2. **Filing Overview:**
#    - **Filing Type:** Rate/Rule other than PPA
#    - **Date Submitted:** 11/26/2024
#    - **Disposition Status:** Acknowledged
#    - **Effective Date:** 03/01/2025
#    - **Filing Contact:** Rhonda Amann, State Filings Manager
#    - **Company Tracking #:** R57116: FORTIFIED HOME DISCOUNT
#    - **SERFF Tracking #:** ALSE-134333693
#
# 3. **Changes Introduced:**
#    - **Introduction of Fortified Home Discount:** Allstate is introducing a Fortified Home Discount to the AFCIC HO program for owner-occupied homeowners in Georgia.
#
# 4. **Correspondence Summary:**
#    - Responses and objections handled in a timely manner.
#    - Compliance with DOI requirements and regulations.
#    - Rate indications and supporting documents submitted as required.
#
# 5. **Manual Changes:**
#    - Manual sections revised to accommodate the Fortified Home Discount
# Processed additional filing info for: GA_ALSE-134333693.pdf
# Filings/Final/2025-03-03\GA_ALSE-134336829.pdf
# 2025-03-05 07:43:09.880971
# Token count for API call in GA_ALSE-134336829.pdf: 40939
# GPT-3.5 Summary: Based on the information available in the filing, Allstate Indemnity Company is introducing the Fortified Home Discount to its Allstate Indemnity Company Homeowners - Manufactured Home (AI MFH) program in the state of Georgia. This change will apply to new business written on or after 6/16/2025 and for renewals effective on or after 7/31/2025.
#
# The project name/number for this initiative is Fortified Home Discount/RITM06297678. The filing was submitted on 12/02/2024, with a disposition date of 03/03/2025, and the effective date requested for the new and renewal business is 03/01/2025. The filing was acknowledged and the SERFF status is closed-acknowledged.
#
# The Company Tracking # for this filing is R57109: FORTIFIED HOME DISCOUNT, and the State-specific filing fee amount was $75.00. The filing fee was processed on 12/02/2024 at 01:05 PM under transaction #301807182.
#
# The contact person for this filing is Rhonda Amann, the State Filings Manager, who can be reached at RAMA0@allstate.com or 847-402-3149 (phone). The company's domicile is Illinois, and the company is a Property and Casualty insurer.
#
# The filing includes various attachments such as the Compliance Certification, Explanatory Memorandum
# Processed additional filing info for: GA_ALSE-134336829.pdf
# Filings/Final/2025-03-03\GA_ALSE-134336890.pdf
# 2025-03-05 07:43:14.771368
# Token count for API call in GA_ALSE-134336890.pdf: 16217
# GPT-3.5 Summary: This rate filing by Allstate Insurance Company introduces the Fortified Home Discount to its Mobile Home program in Georgia. The filing includes changes to the package premium calculation method, introducing new discounts for original owners, retired individuals, and members of approved groups. Additionally, the filing includes provisions for various coverages under Sections I and II, eligibility criteria, discount factors for protective devices, and details on Deductibles and Premium Group Numbers. The filing also outlines procedures for policy endorsements, premium determinations, and discounts for specific demographics such as retirees and Good Hands People. In summary, the rate filing introduces new pricing structures and discounts to enhance the insurance offerings for mobile homeowners in Georgia.
# Processed additional filing info for: GA_ALSE-134336890.pdf
# Filings/Final/2025-03-03\GA_ALSE-134337450.pdf
# 2025-03-05 07:43:17.606444
# Token count for API call in GA_ALSE-134337450.pdf: 1194682
# GPT-3.5 Summary: Based on the filing provided on Allstate Vehicle and Property Insurance Company introducing the Fortified Home Discount for homeowners in Georgia, the company has made several changes and adjustments. Here are the key aspects of the filing worth noting:
#
# 1. **Introduction of Fortified Home Discount**: Allstate Vehicle and Property Insurance Company introduced the Fortified Home Discount for the Allstate Vehicle and Casualty Insurance Company Homeowners – Owner Occupied Homeowners program in Georgia.
#
# 2. **Effective Date**: The requested effective date for the new business and renewal business affected by the Fortified Home Discount is 03/01/2025. The company has committed to performing an audit of impacted policyholders and processing corrective action refunds.
#
# 3. **Filing Adjustments**: A comprehensive explanation and documentation of the Fortified Home Discount factors applied to premium components for Wind, Hail, and Hurricane perils were included, along with the approval of the Actuarial Standards of Practice.
#
# 4. **Geographic/Demographic Data Elements**: The filing identified that zip code was the only geographic/demographic variable used to determine territorial relativities, as obtained directly from policyholders.
#
# 5. **Credit Scoring Models**: No credit-related variables were updated with this filing. The Credit Scoring Models and Proprietary Information attachment confirmed this aspect.
#
# 6. **Manual and Rule Changes**: The filing included updates to the Rates Manual, specifically PCP-1, PCP-2, PCP-3, and RP-13.
# Processed additional filing info for: GA_ALSE-134337450.pdf
# Filings/Final/2025-03-03\GA_ALSE-134337637.pdf
# 2025-03-05 07:43:28.486754
# Token count for API call in GA_ALSE-134337637.pdf: 592915
# GPT-3.5 Summary: The rate filing from Allstate Property and Casualty Insurance Company for their APC HO Product in Georgia introduces the Fortified Home Discount to their Homeowners - Owner Occupied Homeowners program. The filing was submitted on December 2, 2024, with a requested effective date of March 1, 2025, for both new business and renewals. The filing was closed and acknowledged on March 3, 2025.
#
# Key details of the rate filing include:
# - Filing Type: Rate/Rule other than PPA
# - Company: Allstate Property and Casualty Insurance Company
# - Product Name: APC HO
# - State: Georgia
# - Project Name/Number: Fortified Home Discount/RITM06297486
# - Effective Date Requested: 03/01/2025
# - Author: Rhonda Amann
# - Reviewer: Jarrett Briscoe
# - SERFF Status: Closed-Acknowledged
# - State Status: Acknowledged
# - Disposition Status: Acknowledged
# - Disposition Date: 03/03/2025
# - Filing Fee: $75.00
# - Contact Information: Rhonda Amann, State Filings Manager
#
# The Fortified Home Discount is intended to apply to new business written on or after June 16, 2025, and for renewals effective on or after July 31, 2025. The filing provided detailed changes to the manual, rating factors, and discounts
# Processed additional filing info for: GA_ALSE-134337637.pdf
# Filings/Final/2025-03-03\GA_ALSE-134337677.pdf
# 2025-03-05 07:43:38.301481
# Token count for API call in GA_ALSE-134337677.pdf: 911093
# GPT-3.5 Summary: Based on the information provided in the filing, it seems that Allstate Insurance Company has submitted a rate/rule filing for its AIC HO (Homeowners - Owner Occupied) program in the state of Georgia. The filing introduces the Fortified Home Discount, which will apply to new business written on or after 6/16/2025 and renewals effective on or after 7/31/2025.
#
# Key Details from the Filing:
# 1. **Company Information:**
#    - Company Name: Allstate Insurance Company
#    - Domicile: Illinois
#    - Company Type: Property and Casualty
#    - Contact: Rhonda Amann, State Filings Manager
#
# 2. **Filing Details:**
#    - Filing Type: Rate/Rule other than PPA
#    - Effective Date Requested: 03/01/2025
#    - SERFF Tracking Number: ALSE-134337677
#    - State Tracking #: Not provided
#    - Company Tracking #: R57117: FORTIFIED HOME DISCOUNT
#
# 3. **Changes Introduced:**
#    - Introduction of Fortified Home Discount to the AIC HO program
#    - Specific eligibility criteria for the discount, including IBHS certification for dwellings
#    - Discount factors for Gold, Silver, and Roof levels
#    - Exclusion of policies with Windstorm and Hail Exclusion endorsement from the discount
#
# 4. **Correspondence Summary:**
#    - Objection raised
# Processed additional filing info for: GA_ALSE-134337677.pdf
# Filings/Final/2025-03-03\GA_ALSE-134337686.pdf
# 2025-03-05 07:43:47.653715
# Token count for API call in GA_ALSE-134337686.pdf: 514963
# GPT-3.5 Summary: This filing by Allstate Indemnity Company in Georgia introduces the Fortified Home Discount to its Homeowners - Owner Occupied Homeowners (HO) program. The change is applicable to new business written on or after 6/16/2025 and renewals effective on or after 7/31/2025. The effective date requested for both new and renewal business is 03/01/2025.
#
# The filing was submitted on 12/02/2024 and had a disposition date of 03/03/2025, with the status being acknowledged. The SERFF Tracking Number is ALSE-134337686.
#
# The key elements of this filing include:
# 1. Introduction of Fortified Home Discount.
# 2. Description of the eligibility criteria for the discount.
# 3. Summary of manual changes related to the new discount.
# 4. Premium calculation options for the Homeowners program, including various discounts and factors.
# 5. Credit Scoring Models and Proprietary Information.
#
# The filing also includes general company and contact information, supporting documentation schedules, and a correspondence summary related to objection and response letters. Additionally, there are details on rate changes and a breakdown of the company's filing fees.
# Processed additional filing info for: GA_ALSE-134337686.pdf
# Filings/Final/2025-03-03\GA_LEMO-134374428.pdf
# 2025-03-05 07:43:55.782956
# Token count for API call in GA_LEMO-134374428.pdf: 4242
# GPT-3.5 Summary: Based on the filing information provided for Lemonade Insurance Company's rate filing for homeowners insurance in Georgia, the primary update is the introduction of a new optional coverage named Refrigerated Property Coverage. This coverage is added as an endorsement to Lemonade's existing homeowners, renters, and condominium insurance forms in Georgia.
#
# The Refrigerated Property Coverage endorsement provides coverage for up to $500 for property stored in freezers or refrigerators on the insured's residence premises. It covers direct losses caused by interruptions of electrical service to the refrigeration unit or mechanical failures of the unit storing the property, provided the refrigeration unit was maintained in proper working condition before the loss. The coverage comes with a special deductible where the insurer pays only the part of the loss that exceeds $100, with no other deductible applying to this coverage.
#
# The rate filing includes the necessary form revisions and additional supporting documents, such as a Readability Certification confirming compliance with Georgia's readability standards. The submission was successfully approved and the effective date for the new coverage is requested to be May 15, 2025, for new business policies and May 16, 2025, for renewal business policies. Lemonade Insurance Company has paid the required state fees for the filing.
#
# Overall, the rate filing focuses on introducing a new optional coverage tailored towards providing additional protection for perishable items stored in freezers or refrigerators on the insured's property.
# Processed additional filing info for: GA_LEMO-134374428.pdf
# Filings/Final/2025-03-03\GA_LEMO-134376013.pdf
# 2025-03-05 07:43:59.019862
# Token count for API call in GA_LEMO-134376013.pdf: 23444
# GPT-3.5 Summary: Based on the filing information provided, Lemonade Insurance Company has introduced a new optional coverage called Refrigerated Property Coverage for their Homeowners program in Georgia. The requested effective dates for this new coverage are May 15, 2025, for new business policies and May 16, 2025, for renewal business policies. The filing includes rate tables and rules specifically related to Refrigerated Property Coverage, with available coverage limits of $100, $250, and $500.
#
# Furthermore, the Rate Order of Calculation has been updated to include rating variables related to Refrigerated Property Coverage. The actuarial memorandum states that there will be no rate impact due to the introduction of this new coverage. The supporting documents include an Explanatory Memorandum, Actuarial Memo, and exhibits detailing the proposed changes in the filing.
#
# Lemonade Insurance Company has paid the required filing fee of $75.00 for this rate filing in Georgia. The company's compliance certification and transmittal forms have been submitted as part of the filing documentation. The filing has been acknowledged and the effective dates for the changes requested in the filing have been confirmed by the regulator.
# Processed additional filing info for: GA_LEMO-134376013.pdf
# Filings/Final/2025-03-03\GA_TRVD-G134360540.pdf
# 2025-03-05 07:44:03.147709
# Token count for API call in GA_TRVD-G134360540.pdf: 24605
# GPT-3.5 Summary: The rate filing submitted by Travelers Personal Insurance Company for their Quantum Home 2.0 product in Georgia involves amendments to the Windstorm Mitigation Discount table. The filing includes updates to provide premium discounts to eligible policyholders in compliance with Georgia House Bill 279. The overall impact of the filing is indicated as +0.0%.
#
# The proposed changes apply to both new business issued and effective on or after 2/28/2025, and to renewal business issued on or after 2/28/2025 with an effective date on or after 4/19/2025. The Explanatory Memorandum outlines the changes made to the Windstorm Mitigation Discount factors and the expected impact on policyholders.
#
# The filing also includes information on the dwelling, tenant, condo, landlord dwelling, and landlord condo categories, showing the rate changes over a 3-year history in various aspects of the policy.
#
# Overall, the rate filing demonstrates Travelers' commitment to complying with regulatory requirements and enhancing their product offerings for policyholders in Georgia.
# Processed additional filing info for: GA_TRVD-G134360540.pdf
# Filings/Final/2025-03-03\GA_TRVD-G134400530.pdf
# 2025-03-05 07:44:06.697559
# Token count for API call in GA_TRVD-G134400530.pdf: 12596
# GPT-3.5 Summary: The rate filing submitted by The Travelers Home and Marine Insurance Company in Georgia involves revisions to their Quantum Home, Quantum High Value Home, Homeowners, and High Value Homeowners programs. The filing introduces Windstorm Mitigation Discounts for various property types, with specific eligibility criteria and premium credit factors outlined for each type. The effective date requested for these changes is 02/28/2025. The company has also provided supporting documents, correspondence with the Department of Insurance, and explanations for the rate changes. Additionally, the filing includes information on the companies involved, project details, contact information, and compliance with state-specific fee requirements.
# Processed additional filing info for: GA_TRVD-G134400530.pdf
# Filings/Final/2025-03-03\IA_AMSI-134274777.pdf
# 2025-03-05 07:44:09.128603
# Token count for API call in IA_AMSI-134274777.pdf: 3796
# GPT-3.5 Summary: The rate filing is a submission made by American Strategic Insurance Corp (ASIC) for their Iowa Homeowners program. The filing includes revisions to their Homeowners program, specifically related to rates and rules within the homeowners insurance product. The filing was submitted on 10/10/2024 and approved with an effective date of 11/13/2024.
#
# Key details of the rate filing include:
# - Filing Type: Rate/Rule
# - Product Name: IA Homeowners
# - State: Iowa
# - Tracks the SERFF number: AMSI-134274777
# - Tracks state-related, company-related tracking numbers (IA.HO3.2024.Q3)
# - Primary Authors: Michael Heinz, Hakeem Yusuff, Cristin Weaver-Nason
# - Reviewer(s): Travis Grassel (primary), Wayne Lacher
# - Filtering Company: American Strategic Insurance Corp
#
# The filing involved modifications to rate-related documents such as the Rate Order of Calculation (ROC) and the HOH Rule Manual. The rate filing was part of the American Strategic Insurance Corp's efforts to update their homeowners insurance program for the State of Iowa, leading to the removal of rate capping rules and related documents from their program materials.
#
# Furthermore, the rate filing included a breakdown of how premiums are calculated, specific criteria and factors that affect the premium calculation, fees associated with the filing, and details on the minimum earned premium and rounding off premium amounts. Additionally, the rate filing outlines measures for rate increases and
# Processed additional filing info for: IA_AMSI-134274777.pdf
# Filings/Final/2025-03-03\IL_HART-134383807.pdf
# 2025-03-05 07:44:12.053377
# Token count for API call in IL_HART-134383807.pdf: 4377
# GPT-3.5 Summary: Based on the filing information provided, it appears that the insurance company, Sentinel Insurance Company, Ltd., in collaboration with Hartford Accident and Indemnity Company, is undergoing a transfer process for Homeowners Insurance policies in Illinois. The filing involves consolidating home products into a new home rate plan through an Affiliate Transfer process.
#
# Key points regarding the rate filing include:
#
# 1. **Purpose**: The filing aims to transfer Agency Rate Plans from Sentinel Insurance Company to Hartford Accident and Indemnity Company. This consolidation process is designed to provide enhanced features and benefits to policyholders.
#
# 2. **Policyholder Impact**: Policyholders may experience changes in coverage options and limits as some features offered in older products may not be available in the new home product. Policyholders will be transitioned to the closest match available where possible.
#
# 3. **Transition Process**: The transfer will occur seamlessly at renewal, with no interruption in coverage. It is scheduled to begin with policy renewals effective August 30, 2025, and will last for one year. Policyholders will be notified in advance through a transfer notice as required by regulatory standards.
#
# 4. **Communication**: The insurance company plans to communicate with policyholders to discuss their coverage options and limits, ensuring they are informed and can address any queries they may have.
#
# 5. **Company Contacts**: The filing was prepared by Deveroux Myers, Assistant Director of Product Management, and Lisa Curra, Pricing Analyst, with designated contact information provided for further inquiries.
#
# Overall,
# Processed additional filing info for: IL_HART-134383807.pdf
# Filings/Final/2025-03-03\IL_LEMO-134419957.pdf
# 2025-03-05 07:44:15.376882
# Token count for API call in IL_LEMO-134419957.pdf: 5790
# GPT-3.5 Summary: Based on the information provided in the filing, Lemonade Insurance Company submitted a Benefits Endorsement rule filing for their Homeowners insurance product in the state of Illinois. The filing was submitted on 02/19/2025 and the effective date requested is 03/18/2025 for new business and 05/17/2025 for renewals.
#
# The Benefits Endorsement introduces rule changes aimed at enhancing the safety, value, usability, and protection of the insured's assets by providing various benefits such as subscriptions, goods, services, devices, or other rewards. The rule filing includes the addition of Rule 32 - Benefits Endorsement to the Homeowners insurance program. Additionally, Lemonade Insurance Company included supporting documents such as an Explanatory Memorandum and a detailed Manual outlining the rules and coverage details associated with the Benefits Endorsement.
#
# The filing process was completed with a disposition date of 02/24/2025, where the filing status was marked as "Filed." The filing qualifies for public access, and the rate/rule schedules have been updated to reflect the changes made in the filing. Lemonade Insurance Company looks forward to the review and implementation of the Benefits Endorsement rule changes in their Homeowners insurance program in Illinois.
# Processed additional filing info for: IL_LEMO-134419957.pdf
# Filings/Final/2025-03-03\KS_GMMX-134433936.pdf
# 2025-03-05 07:44:18.342725
# Token count for API call in KS_GMMX-134433936.pdf: 4510
# GPT-3.5 Summary: Based on the filing information provided, Encompass Indemnity Company submitted a new supplemental application under the name "KS EIC C360_Form Filing" for their Custom360 Property program to the Kansas Department of Insurance. The filing included various forms and supporting documents, such as the Custom360 Property Supplemental Application (A15816KS), Explanatory Memo - Forms, and Forms List Template. The effective dates requested for the new supplemental application were 04/14/2025 for new business and 05/21/2025 for renewals. The filing was designated for the homeowners insurance line of business, specifically targeting owner-occupied homeowners.
#
# The submission was given a disposition of "Approved and Filed" by Josh Carlson on 03/03/2025, and the status was confirmed as closed and approved in SERFF. The filing included a detailed list of forms and endorsements associated with the Custom360 program, outlining optional and mandatory elements for different coverage types in various situations, such as for primary residences, condos, renters, and premier clients.
#
# In summary, Encompass Indemnity Company's rate filing for the KS EIC C360_Form Filing supplemental application for homeowners insurance in Kansas was successfully approved and is set to be effective from 04/14/2025 for new policies and 05/21/2025 for renewals.
# Processed additional filing info for: KS_GMMX-134433936.pdf
# Filings/Final/2025-03-03\KS_LBPM-134379791.pdf
# 2025-03-05 07:44:21.760664
# Token count for API call in KS_LBPM-134379791.pdf: 31184
# GPT-3.5 Summary: The rate filing from Safeco Insurance Company of America pertains to the Kansas homeowners insurance segment. The filing proposes revisions to rates and rules that would be effective on April 26, 2025, specifically for renewal business. The key changes outlined in the filing include adjustments to base rates for homes and condos, new roof age factors for homes, and rate stabilization factors for condos. Overall, the filing indicates a 0.0% overall uncapped impact.
#
# The narrative in the filing elaborates on the detailed analysis undertaken by Safeco Insurance to arrive at the proposed rate revisions. It includes a review of past and prospective loss experience within and outside the state, consideration of catastrophe hazards, insurer operating expenses, and the rationale behind the selected profit margin. Additionally, the filing certifies compliance with the requirements of the Kansas Insurance Department.
#
# ...
# 2025-03-05 07:55:57.218012
# Token count for API call in TN_USAA-134436312.pdf: 7944
# GPT-3.5 Summary: The rate filing pertains to a proposed change in claims free discount factors for homeowners insurance under the product name "HOMEOWNERS" in Tennessee. The filing was submitted by United Services Automobile Association and its subsidiaries USAA Casualty Insurance Company, USAA General Indemnity Company, and Garrison Property and Casualty Insurance Company. The proposed change is specified to have an overall effect of 0.0% and is scheduled to be effective on June 9, 2025, for new business and August 25, 2025, for renewal business. The filing includes detailed rate information, company tracking numbers, contact information, and explanations of the changes in discount factors and their impact on premiums.
# Processed additional filing info for: TN_USAA-134436312.pdf
# Filings/Final/2025-03-03\TX_ALSE-133994457.pdf
# 2025-03-05 07:55:59.369386
# Token count for API call in TX_ALSE-133994457.pdf: 181388
# GPT-3.5 Summary: The rate filing is for the Allstate Vehicle and Property Insurance Company's AVPIC Homeowners - Owner Occupied Homeowners program in the state of Texas. The filing proposes an overall 12.5% rate level change, achieved through revisions to Rate Adjustment Factors, Retained Risk Provision Base Rate Factors, RRP Rate Adjustment Factor, and RRP Zone Definitions. The changes are detailed in various documents including exhibits, actuarial support, and a filing memorandum. The proposed rate change applies to new business written on or after 2/26/2024 and for renewals effective on or after 4/11/2024. The company tracking number for this filing is R56546: RAF (+12.5%). The filing was submitted on 02/14/2024 and the disposition status is Closed with no additional information required at this time.
# Processed additional filing info for: TX_ALSE-133994457.pdf
# Filings/Final/2025-03-03\TX_ALSE-133994492.pdf
# 2025-03-05 07:56:05.265280
# Token count for API call in TX_ALSE-133994492.pdf: 45511
# GPT-3.5 Summary: Based on the attached documents from Allstate Indemnity Company regarding their rate filing for manufactured homes in Texas, the following key points can be highlighted:
#
# 1. **Rate Adjustment**: The company is proposing an overall rate level change of 6.7% for the Allstate Indemnity Company (AI) Manufactured Home program in Texas. This change will apply to new business written on or after 02/26/2024 and for renewals effective on or after 04/11/2024.
#
# 2. **Filing Details**: The filing covers the Allstate Indemnity Company's AI Manufactured Home program within the Homeowners and Mobile Homeowners categories in Texas.
#
# 3. **Actuarial Support**: The filing includes Actuarial Support documents, such as Exhibit D and Exhibit E, which provide detailed information supporting the rate adjustments proposed by the company.
#
# 4. **SERFF Tracking**: The filing details include the SERFF Tracking Number as ALSE-133994492, State Tracking Number as S719100, and Company Tracking Number as R56416.
#
# 5. **Filing Memorandum**: The filing contains a comprehensive Filing Memorandum outlining the rate adjustments and other relevant details.
#
# 6. **Dispositions**: The filing has been closed with no additional information required as of 02/27/2025.
#
# 7. **Objection Response**: The company has responded to an objection letter dated 04/11/2024, addressing specific requirements
# Processed additional filing info for: TX_ALSE-133994492.pdf
# Filings/Final/2025-03-03\TX_ALSE-133995002.pdf
# 2025-03-05 07:56:11.148624
# Token count for API call in TX_ALSE-133995002.pdf: 108096
# GPT-3.5 Summary: The information provided in the attachment pertains to the actuarial analysis and adjustments made by Allstate Texas Lloyd’s for weather and non-weather losses, specifically focusing on water, lightning, and wind/hail perils in Texas. Here is a summary of the key points discussed in the attachment:
#
# 1. **Underlying Data:** Allstate Texas Lloyd’s considers historical loss experience for water, lightning, and wind/hail perils when determining the indicated provision for losses. The analysis includes allocated loss adjustment expenses (ALAE) and is done using a maximum of five accident years.
#
# 2. **Severity Accident Year Weights:** Each accident year is assigned a credibility weight when determining the severity provisions for weather losses. A 20% weight is typically assigned to each accident year to ensure a stable indication.
#
# 3. **Severity Development:** Ultimate accident year weather severity is determined using the Link Ratio method, which assumes that future development is proportional to losses that have already emerged. No additive loss development is estimated for weather losses.
#
# 4. **Severity Trend:** Historical trend analyses for each peril (water, lightning, wind/hail) are conducted, and trends are selected based on past results, data credibility, and actuarial judgment. These trends are then projected for the future policy period.
#
# 5. **Adjustments due to Underwriting Actions:** Historical data is adjusted to account for underwriting actions taken by Allstate, such as redefining coastal zones and implementing policy exclusions. Adjustment factors are applied
# Processed additional filing info for: TX_ALSE-133995002.pdf
# Filings/Final/2025-03-03\TX_GMMX-134436826.pdf
# 2025-03-05 07:56:17.089527
# Token count for API call in TX_GMMX-134436826.pdf: 30515
# GPT-3.5 Summary: Based on the detailed filing provided, it appears that Allstate utilized the Fama-French Three-factor Model and the Discounted Cash Flow Model to calculate the appropriate underwriting profit provision. The filing contains various financial calculations and analyses related to determining the cost of equity capital, developing the underwriting profit provision, estimating investment income, and calculating the necessary pre-tax underwriting profit provision.
#
# Key points from the filing include:
# 1. Allstate calculated the cost of equity capital using the Fama-French Three-factor Model and the Discounted Cash Flow Model.
# 2. The underwriting profit provision was calculated based on the cost of equity, market-to-book ratios, dividend payout ratios, and other financial metrics.
# 3. Investment income on equity and policyholder-supplied funds were factored into the calculation of the underwriting profit provision.
# 4. Various financial ratios and averages were used to determine the income needed by the company and the appropriate underwriting profit provision.
# 5. Allstate's tax rate on underwriting income was reported as 21%.
#
# In summary, the filing showcases a comprehensive analysis of financial data and methodologies used by Allstate to calculate the underwriting profit provision, providing insights into the company's pricing strategies and financial soundness.
# Processed additional filing info for: TX_GMMX-134436826.pdf
# Filings/Final/2025-03-03\TX_LBPM-134367508.pdf
# 2025-03-05 07:56:21.094477
# Token count for API call in TX_LBPM-134367508.pdf: 7548
# GPT-3.5 Summary: Based on the information provided in the filing, the rate filing submitted by American Economy Insurance Company for their Homeowners insurance product in Texas involved an Endorsement (Amendments) under TOI 04.0 Homeowners/04.0000 Homeowners Sub-TOI Combinations. The filing was designated as LBPM-134367508 with a State Tracking number of S726909 and a Company Tracking number of 25-TX-S-HO-F-HMR2-END.
#
# The company's effective dates requested for the filing were 04/19/2025 for new policies and 06/25/2025 for renewals. The filing was made on 01/09/2025 and had an APDR-Approved by Director status with a disposition date of 02/17/2025. The Filing Contact was Beth Coffey, and the Filing Company was American Economy Insurance Company, part of the Liberty Mutual Group.
#
# The filing involved revisions to the Special Personal Property Coverage form (HOM-7308/TXEP) to make style and formatting changes, as well as transitioning it from a countrywide to a state-specific form. The revisions included adjustments to coverage for specific perils and property types in the Personal Property We Cover section.
#
# The filing also included various supporting documents, such as an Explanatory Memorandum and a Summary of Changes exhibit. Additionally, the company indicated its willingness to adjust the format of the forms to meet marketing and distribution needs within
# Processed additional filing info for: TX_LBPM-134367508.pdf
# Filings/Final/2025-03-03\UT_LBPM-134409711.pdf
# 2025-03-05 07:56:24.978596
# Token count for API call in UT_LBPM-134409711.pdf: 14820
# GPT-3.5 Summary: The rate filing submitted by Safeco Insurance Company of America to the Utah Insurance Department consists of revisions to their Homeowners insurance program in Utah. The filing includes updates to the Special Provisions related to fungi, wet or dry rot, or bacteria coverage, collapse coverage, and additional property coverages. The revisions also address definitions, property conditions, and liability coverages. The changes provide clarity on coverage, exclusions, duties after loss, and suit against the insurer. The filing demonstrates Safeco's commitment to enhancing their insurance offerings and ensuring compliance with Utah laws and regulations.
# Processed additional filing info for: UT_LBPM-134409711.pdf
# Filings/Final/2025-03-03\VA_AMSI-134375543.pdf
# 2025-03-05 07:56:27.701472
# Token count for API call in VA_AMSI-134375543.pdf: 5422
# GPT-3.5 Summary: The rate filing submitted by American Strategic Insurance Corp to the Department of Insurance in Virginia involves the withdrawal of three forms: ASI HO VA SSH 06 15, HO 05 22 07 97, and HO 23 65 04 91. The filing was submitted on January 10, 2025, and the disposition date was March 3, 2025, with a filing status of "Filed." The effective date requested for both new and renewal policies was January 10, 2025. The filing included multiple objection and response letters regarding the withdrawal of the forms and their production status. The forms were confirmed to have ceased production on specific dates in 2023, and the company clarified the number of policies still utilizing the forms. The rate filing also addressed increased special limits of liability under Coverage C - Personal Property in Virginia. The status of the forms involved in the filing was changed to "Withdrawn" as per the schedule items.
# Processed additional filing info for: VA_AMSI-134375543.pdf
# Filings/Final/2025-03-03\VA_HART-134429350.pdf
# 2025-03-05 07:56:31.264125
# Token count for API call in VA_HART-134429350.pdf: 3207
# GPT-3.5 Summary: This rate filing pertains to the introduction of a credit card surcharge for The Hartford's Home products in various insurance companies under The Hartford umbrella. The proposal involves transferring credit card payment processing to a third-party vendor, resulting in policyholders who choose to pay by credit card incurring a surcharge not exceeding 3% of the total payment amount. The surcharge will be applied uniformly and will be effective for all transactions processed on or after July 1, 2025. It is emphasized that this filing is not a rate filing but was classified as such due to system constraints in the state of Virginia. The filing was prepared by Lesdy Richard, Senior Pricing Analyst, and any inquiries should be directed to her.
# Processed additional filing info for: VA_HART-134429350.pdf
# Filings/Final/2025-03-03\VA_TRVD-G134337488.pdf
# 2025-03-05 07:56:33.004593
# Token count for API call in VA_TRVD-G134337488.pdf: 3413303
# GPT-3.5 Summary: The rate filing for the Quantum Home 2.0 product by Travelers Personal Insurance Company in Virginia involved proposed changes to their Homeowners product. The filing indicated an overall impact of +0.0%, with the changes applying to new business effective from 12/6/2024 and renewal business effective from 1/25/2025. The filing included various rate and rule manuals, supporting documents, and certifications related to the proposed changes.
#
# The status of the filing was marked as "Filed" with an effective date of 12/6/2024 for new business and 1/25/2025 for renewal business. The disposition date was 2/26/2025, indicating that the filing was successfully processed. It was a Rate/Rule filing type under the Homeowners category. The project was identified by the number 77081, and the filing tracking number was TRVD-G134337488. The filing pertained to the Virginia insurance market.
#
# The filing company, Travelers Personal Insurance Company, outlined the proposed changes and provided details on the impact, effective dates, authorship, review process, and contact information for regulatory inquiries. The filing also included objection letters, responses, and correspondence summaries related to the filing process. Overall, the filing appeared to have been successfully addressed and reconciled with the regulatory requirements in Virginia.
# Processed additional filing info for: VA_TRVD-G134337488.pdf
# Filings/Final/2025-03-03\WA_GMMX-134441494.pdf
# 2025-03-05 07:57:09.644915
# Token count for API call in WA_GMMX-134441494.pdf: 73559
# GPT-3.5 Summary: The rate filing you provided includes several amendments and provisions related to property coverage for homes and personal liability insurance. Here is a summary of the key changes and information gathered from the filing:
#
# 1. **Insurance Company:** Encompass Insurance Company
# 2. **State:** Washington
# 3. **Type of Insurance:** Homeowners insurance
# 4. **Product Name:** WA EIC PROPERTY C360 LAW CHANGE 48.18.290 & 48.18.2901
# 5. **Effective Date Requested:** 07/01/2025
# 6. **Filing Type:** Form
# 7. **Author:** Angie Gillespie
# 8. **Reviewer:** Dennis Godwin
# 9. **General Information:** The filing involves updating home line state amendments to comply with the WA S 5798 nonrenewal 60-day required timeline.
#
# ### Changes in Definitions:
# - Amendment Of Dwelling Fire Provisions include revised definitions of Bodily Injury, Domestic Abuse, Actual Cash Value, and Replacement Cost.
# - Amendment Of Elite Home Provisions includes changes in the definitions of Bodily Injury, Domestic Abuse, Actual Cash Value, and Replacement Cost.
#
# ### Key Provisions:
# - **Real Property - Insuring Agreement:** Provides details about coverage for dwellings and structures on the residence premises.
# - **Limit Of Liability:** Specifies the covered losses settled on a replacement cost basis.
# - **Tangible Personal Property - Limit Of Liability:** Outlines the covered losses and settlement basis for tangible personal property.
# -
# Processed additional filing info for: WA_GMMX-134441494.pdf
# Filings/Final/2025-03-03\WV_AMSI-134244221.pdf
# 2025-03-05 07:57:21.591315
# Token count for API call in WV_AMSI-134244221.pdf: 1174752
# GPT-3.5 Summary: The rate filing submitted by American Strategic Insurance Corp for their Homeowners product in West Virginia includes a proposed rate increase with an overall indicated change of 8.000%. The filing was submitted on 01/28/2025 and approved with an effective date of 08/06/2025 for new business and 10/06/2025 for renewals. The filing included various documents such as rate pages, rules manual, actuarial summary, certification, rate change histogram, and more.
#
# The base rates and territory factors were included in the filing, with details on different aspects such as Tornado, Wind, Hail, Water Backup, Fire, Liability, Theft, Earthquake, and more. The company proposed adjustments to the HOH Rules Manual and responded to objections raised during the review process.
#
# Overall, the filing detailed the proposed rate changes, supporting documents, correspondence summaries, objections raised, and responses provided by the company. The filing fees amounted to $100 per company, and the status of the filing was marked as closed and approved.
# Processed additional filing info for: WV_AMSI-134244221.pdf
# Saved additional filing info JSON output to additional_filing_info_2025-03-03.json
# Saved additional filing info CSV output to additional_filing_info_2025-03-03.csv

# %%
### Adding state and sub-toi to the additional_info section. Adding toi, sub-toi and filing type to the objection files (3.12) ###

# %%
import os
import re
import glob
import fitz  # PyMuPDF
import json
import pandas as pd
from datetime import datetime
from pprint import pprint
from dotenv import load_dotenv
import tiktoken  # pip install tiktoken

# Load environment variables (which should include api_key and grok_api_key)
load_dotenv()

# === API Call Control Parameters for additional filing info (not used for objections) ===
# Set each to 'Y' to call the API, or 'N' to skip the API call.
CALL_GPT_3_5 = "N"
CALL_O1_MINI = "N"  # Example value; set to 'Y' or 'N'
CALL_XAI = "N"      # Example value; set to 'Y' or 'N'

# === User-defined Maximum Token Parameters for API calls ===
MAX_TOKENS_GPT3_5 = 15000
MAX_TOKENS_O1_MINI = 12000
MAX_TOKENS_XAI = 12000

# Create OpenAI client for standard models
from openai import OpenAI
api_key = os.getenv("api_key")
client = OpenAI(api_key=api_key)

# Create a separate client for the xAI API
XAI_API_KEY = os.getenv("grok_api_key")
xai_client = OpenAI(api_key=XAI_API_KEY, base_url="https://api.x.ai/v1")

# Define the download week as a string and convert it to a datetime object.
date = "2025-03-10"
download_week_dt = datetime.strptime(date, "%Y-%m-%d")

# --- Helper functions for token counting and truncation using tiktoken ---
def count_tokens(text, model="gpt-3.5-turbo"):
    try:
        encoding = tiktoken.encoding_for_model(model)
    except Exception:
        encoding = tiktoken.get_encoding("cl100k_base")
    tokens = encoding.encode(text)
    return len(tokens)

def truncate_text(text, max_tokens, model="gpt-3.5-turbo"):
    try:
        encoding = tiktoken.encoding_for_model(model)
    except Exception:
        encoding = tiktoken.get_encoding("cl100k_base")
    tokens = encoding.encode(text)
    if len(tokens) > max_tokens:
        truncated_tokens = tokens[:max_tokens]
        truncated_text = encoding.decode(truncated_tokens)
        return truncated_text
    return text

# --- API call functions (used in additional filing info only) ---
def call_gpt_3_5_turbo(full_text):
    try:
        completion = client.chat.completions.create(
            model="gpt-3.5-turbo",
            messages=[
                {"role": "system", "content": "You are an analyst doing competitive intelligence research on insurance companies."},
                {"role": "user", "content": f"The following is a filing with a DOI from an insurance company: '{full_text}'. Give a summary of the rate filing."}
            ],
            max_tokens=300
        )
        print("GPT-3.5 Summary:", completion.choices[0].message.content)
        return completion.choices[0].message.content
    except Exception as e:
        print(f"Error calling GPT-3.5-turbo: {e}")
        return ""

def call_o1_mini(full_text):
    try:
        completion = client.chat.completions.create(
            model="o1-mini",
            messages=[
                {"role": "user", "content": "You are an analyst doing competitive intelligence research on insurance companies."},
                {"role": "user", "content": f"The following is a filing with a DOI from an insurance company: '{full_text}'. Give a summary of the rate filing."}
            ]
        )
        print("o1-mini Summary:", completion.choices[0].message.content)
        return completion.choices[0].message.content
    except Exception as e:
        print(f"Error calling o1-mini: {e}")
        return ""

def call_xai(full_text):
    try:
        completion = xai_client.chat.completions.create(
            model="grok-2-latest",
            messages=[
                {"role": "system", "content": "You are an analyst doing competitive intelligence research on insurance companies."},
                {"role": "user", "content": f"The following is a filing with a DOI from an insurance company: '{full_text}'. Give a summary of the rate filing."}
            ]
        )
        print("xAI Summary:", completion.choices[0].message.content)
        return completion.choices[0].message.content
    except Exception as e:
        print(f"Error calling xAI: {e}")
        return ""

# --- Extraction functions for non-API parts ---
def extract_full_text(pdf_path, max_pages=None):
    """
    Extracts full text from a PDF.
    If max_pages is provided, only extracts from the first max_pages pages.
    """
    doc = fitz.open(pdf_path)
    full_text = ""
    for i, page in enumerate(doc):
        if max_pages is not None and i >= max_pages:
            break
        full_text += page.get_text() + "\n"
    doc.close()
    return full_text

def split_list_objections(text):
    parts = re.split(r"(?m)^\s*(?:\(?(\d+)\)?[.\)])\s*", text)
    objections = {}
    if len(parts) >= 3:
        for i in range(1, len(parts)-1, 2):
            num = parts[i].strip()
            obj_text = parts[i+1].strip()
            objections[f"objection{num}"] = obj_text
        if not objections:
            objections["objection1"] = text.strip()
    else:
        objections["objection1"] = text.strip()
    return objections

def parse_objection_letters(text):
    """
    Splits the full text into separate objection letter sections.
    A valid objection letter must contain "Objection Letter Date", "Introduction:" and "Conclusion:".
    Returns a dictionary where each key is "Objection_letterX" with its parsed objections.
    """
    pattern = r"(Objection Letter.*?Objection Letter Date\s+(\d{2}/\d{2}/\d{4}).*?Introduction:\s*(.*?)\s*Conclusion:)"
    matches = list(re.finditer(pattern, text, flags=re.IGNORECASE | re.DOTALL))
    letter_dict = {}
    for idx, m in enumerate(matches, start=1):
        letter_date = m.group(2).strip()
        body = m.group(3).strip()
        explicit_objs = list(re.finditer(r"Objection\s+(\d+)", body, flags=re.IGNORECASE))
        if len(explicit_objs) > 1:
            obj_pattern = r"(Objection\s+(\d+).*?)(?=(Objection\s+\d+|Conclusion:|$))"
            objections = {}
            for om in re.finditer(obj_pattern, body, flags=re.IGNORECASE | re.DOTALL):
                num = om.group(2).strip()
                obj_text = om.group(1).strip()
                objections[f"objection{num}"] = obj_text
        else:
            if re.search(r"(?m)^\s*(\(?\d+\)?[.\)])", body):
                objections = split_list_objections(body)
            else:
                objections = {"objection1": body}
        letter_dict[f"Objection_letter{idx}"] = {
            "objection_letter_date": letter_date,
            **objections
        }
    return letter_dict

def extract_filing_company_info(text):
    """
    Extracts filing company information.
    Returns a tuple: (group_code, company_codes)
    """
    company_codes = re.findall(r"CoCode:\s*(\d+)", text, flags=re.IGNORECASE)
    group_codes = re.findall(r"Group Code:\s*(\d+)", text, flags=re.IGNORECASE)
    company_codes = [int(code) for code in company_codes] if company_codes else []
    group_code = int(group_codes[0]) if group_codes else None
    return group_code, company_codes

# --- Extraction functions for additional filing info ---
def parse_filing_at_a_glance(text):
    """
    Extracts key filing info from the "Filing at a Glance" section.
    Returns a dictionary with keys:
      serff_tr_num, filing_type, date_submitted, effective_date_requested_new,
      effective_date_requested_renewal, serff_status, toi, sub_toi.
    """
    info = {}
    match = re.search(r"Filing at a Glance(.*?)(?=\n[A-Z][a-z]+ Information|$)", text, flags=re.IGNORECASE | re.DOTALL)
    section = match.group(1) if match else ""
    
    serff_match = re.search(r"SERFF Tr Num:\s*([A-Z0-9\-]+)", section, flags=re.IGNORECASE)
    info["serff_tr_num"] = serff_match.group(1).strip() if serff_match else ""
    
    filing_type_match = re.search(r"Filing Type:\s*([^\n]+)", section, flags=re.IGNORECASE)
    info["filing_type"] = filing_type_match.group(1).strip() if filing_type_match else ""
    
    date_submitted_match = re.search(r"Date Submitted:\s*(\d{2}/\d{2}/\d{4})", section, flags=re.IGNORECASE)
    info["date_submitted"] = date_submitted_match.group(1).strip() if date_submitted_match else ""
    
    effective_new_match = re.search(r"Effective Date\s*Requested\s*\(New\):\s*(\d{2}/\d{2}/\d{4})", section, flags=re.IGNORECASE)
    info["effective_date_requested_new"] = effective_new_match.group(1).strip() if effective_new_match else ""
    
    effective_renewal_match = re.search(r"Effective Date\s*Requested\s*\(Renewal\):\s*(\d{2}/\d{2}/\d{4})", section, flags=re.IGNORECASE)
    info["effective_date_requested_renewal"] = effective_renewal_match.group(1).strip() if effective_renewal_match else ""
    
    serff_status_match = re.search(r"SERFF Status:\s*([^\n]+)", section, flags=re.IGNORECASE)
    info["serff_status"] = serff_status_match.group(1).strip() if serff_status_match else ""
    
    toi_match = re.search(r"TOI:\s*([^\n]+)", section, flags=re.IGNORECASE)
    info["toi"] = toi_match.group(1).strip() if toi_match else ""
    
    sub_toi_match = re.search(r"Sub-TOI:\s*([^\n]+)", section, flags=re.IGNORECASE)
    info["sub_toi"] = sub_toi_match.group(1).strip() if sub_toi_match else ""
    
    return info

def parse_filing_description(text):
    """
    Extracts the Filing Description from the text.
    Returns the description string.
    """
    match = re.search(r"Filing Description:\s*(.*?)\s*(Filing Contact Information|Filing Company Information)", 
                      text, flags=re.IGNORECASE | re.DOTALL)
    if match:
        return match.group(1).strip()
    return ""

# --- Processing functions for objections (old version) ---
def process_pdf_file(pdf_path):
    """
    Processes a single PDF file for objections output.
    Truncates the PDF to the first 100 pages before processing.
    Returns a dictionary with keys:
      - "objections": parsed objection letters,
      - "group_code": extracted group code,
      - "company_codes": list of CoCodes,
      - "download_week": the download_week datetime,
      - "toi": TOI value,
      - "sub_toi": Sub-TOI value,
      - "filing_type": Filing Type.
    """
    # Truncate to first 100 pages
    full_text = extract_full_text(pdf_path, max_pages=100)
    parsed_letters = parse_objection_letters(full_text)
    group_code, company_codes = extract_filing_company_info(full_text)
    filing_info = parse_filing_at_a_glance(full_text)
    file_key = os.path.splitext(os.path.basename(pdf_path))[0]
    return {file_key: {
                "objections": parsed_letters,
                "group_code": group_code,
                "company_codes": company_codes,
                "download_week": download_week_dt,
                "toi": filing_info.get("toi", ""),
                "sub_toi": filing_info.get("sub_toi", ""),
                "filing_type": filing_info.get("filing_type", "")
            }}

def process_all_pdfs_in_folder(pdf_folder):
    """
    Loops through all PDF files in the folder and processes each for objections output.
    Returns a nested dictionary.
    """
    results = {}
    pdf_files = glob.glob(os.path.join(pdf_folder, "*.pdf"))
    for pdf_file in pdf_files:
        print(pdf_file)
        print(datetime.now())
        results.update(process_pdf_file(pdf_file))
    return results

# --- Processing functions for additional filing info (with API calls) ---
def extract_full_text_all(pdf_path):
    """
    Extracts full text from the PDF using up to the first 3000 pages.
    """
    return extract_full_text(pdf_path, max_pages=3000)

def process_pdf_additional(pdf_path):
    """
    Processes a single PDF file and extracts additional filing info.
    For non-API info, uses the first 100 pages.
    For API calls, uses the full text (up to 3000 pages) subject to token constraints.
    Returns a dictionary with keys including API summaries.
    """
    # Non-API extraction (first 100 pages)
    limited_text = extract_full_text(pdf_path, max_pages=100)
    filing_at_a_glance = parse_filing_at_a_glance(limited_text)
    filing_description = parse_filing_description(limited_text)
    group_code, company_codes = extract_filing_company_info(limited_text)
    
    # Compute state from file name (first two letters)
    state = os.path.splitext(os.path.basename(pdf_path))[0][:2]
    
    # API extraction using full text (up to 3000 pages)
    full_text_all = extract_full_text_all(pdf_path)
    print(f"Token count for API call in {os.path.basename(pdf_path)}: {count_tokens(full_text_all, model='gpt-3.5-turbo')}")
    
    if CALL_GPT_3_5 == "Y":
        gpt_api_text = truncate_text(full_text_all, max_tokens=MAX_TOKENS_GPT3_5, model="gpt-3.5-turbo")
        gpt_3_5_summary = call_gpt_3_5_turbo(gpt_api_text)
    else:
        gpt_3_5_summary = ""
    
    if CALL_O1_MINI == "Y":
        o1_api_text = truncate_text(full_text_all, max_tokens=MAX_TOKENS_O1_MINI, model="o1-mini")
        o1_mini_summary = call_o1_mini(o1_api_text)
    else:
        o1_mini_summary = ""
    
    if CALL_XAI == "Y":
        xai_api_text = truncate_text(full_text_all, max_tokens=MAX_TOKENS_XAI, model="grok-2-latest")
        xai_summary = call_xai(xai_api_text)
    else:
        xai_summary = ""
    
    additional = {
        "serff_tr_num": filing_at_a_glance.get("serff_tr_num", ""),
        "filing_type": filing_at_a_glance.get("filing_type", ""),
        "date_submitted": filing_at_a_glance.get("date_submitted", ""),
        "effective_date_requested_new": filing_at_a_glance.get("effective_date_requested_new", ""),
        "effective_date_requested_renewal": filing_at_a_glance.get("effective_date_requested_renewal", ""),
        "serff_status": filing_at_a_glance.get("serff_status", ""),
        "filing_description": filing_description,
        "filing_method": "",  # Not extracted in this version.
        "toi": filing_at_a_glance.get("toi", ""),
        "sub_toi": filing_at_a_glance.get("sub_toi", ""),
        "group_code": group_code,
        "company_codes": company_codes,
        "download_week": download_week_dt,
        "state": state,
        "gpt_3_5_summary": gpt_3_5_summary,
        "o1_mini_summary": o1_mini_summary,
        "xai_summary": xai_summary
    }
    print(f"Processed additional filing info for: {os.path.basename(pdf_path)}")
    return additional

def process_all_pdfs_additional(pdf_folder):
    """
    Processes all PDFs in the folder for additional filing info.
    Returns a dictionary keyed by file name.
    """
    results = {}
    pdf_files = glob.glob(os.path.join(pdf_folder, "*.pdf"))
    for pdf_file in pdf_files:
        print(pdf_file)
        print(datetime.now())
        file_key = os.path.splitext(os.path.basename(pdf_file))[0]
        results[file_key] = process_pdf_additional(pdf_file)
    return results

def additional_to_dataframe(results):
    """
    Converts the additional filing info dictionary into a DataFrame.
    """
    rows = []
    for file_key, info in results.items():
        row = {
            "SERFF Tr Num": info.get("serff_tr_num", ""),
            "Filing Type": info.get("filing_type", ""),
            "Date Submitted": info.get("date_submitted", ""),
            "Effective Date Requested (New)": info.get("effective_date_requested_new", ""),
            "Effective Date Requested (Renewal)": info.get("effective_date_requested_renewal", ""),
            "SERFF Status": info.get("serff_status", ""),
            "Filing Description": info.get("filing_description", ""),
            "Filing Method": info.get("filing_method", ""),
            "TOI": info.get("toi", ""),
            "Sub-TOI": info.get("sub_toi", ""),
            "State": info.get("state", ""),
            "Group_Code": info.get("group_code", ""),
            "Company_Codes": str(info.get("company_codes", "")),
            "week_date": info.get("download_week", None),
            "gpt_3_5_summary": info.get("gpt_3_5_summary", ""),
            "o1_mini_summary": info.get("o1_mini_summary", ""),
            "xai_summary": info.get("xai_summary", "")
        }
        rows.append(row)
    df = pd.DataFrame(rows, columns=[
        "SERFF Tr Num", "Filing Type", "Date Submitted", 
        "Effective Date Requested (New)", "Effective Date Requested (Renewal)",
        "SERFF Status", "Filing Description", "Filing Method", "TOI", "Sub-TOI", "State",
        "Group_Code", "Company_Codes", "week_date",
        "gpt_3_5_summary", "o1_mini_summary", "xai_summary"
    ])
    return df

# --- DataFrame for objections ---
def results_to_dataframe_objections(results):
    """
    Converts the objections dictionary (from process_all_pdfs_in_folder) into a DataFrame.
    """
    rows = []
    for file_key, file_info in results.items():
        state_abbr = file_key.split('_')[0] if "_" in file_key else file_key[:2]
        group_code = file_info.get("group_code", "No objections")
        company_codes = file_info.get("company_codes", [])
        company_code_first = company_codes[0] if company_codes else "No objections"
        company_codes_str = str(company_codes) if company_codes else "No objections"
        download_week = file_info.get("download_week", None)
        # Also get the additional fields from the objections output.
        filing_type = file_info.get("filing_type", "")
        toi = file_info.get("toi", "")
        sub_toi = file_info.get("sub_toi", "")
        letter_dict = file_info.get("objections", {})
        if not letter_dict:
            rows.append({
                "SERFF#": file_key,
                "State": state_abbr,
                "Filing Type": filing_type,
                "TOI": toi,
                "Sub-TOI": sub_toi,
                "Group_Code": group_code,
                "Company_Code": company_code_first,
                "Company_Code_all": company_codes_str,
                "Objection_letter_date": "No objections",
                "Objectionletter#": "No objections",
                "Objection#": "No objections",
                "Objection": "No objections",
                "download_week": download_week
            })
        else:
            for letter_key, letter_content in letter_dict.items():
                letter_date = letter_content.get("objection_letter_date", "No objections")
                for obj_key, obj_text in letter_content.items():
                    if obj_key == "objection_letter_date":
                        continue
                    rows.append({
                        "SERFF#": file_key,
                        "State": state_abbr,
                        "Filing Type": filing_type,
                        "TOI": toi,
                        "Sub-TOI": sub_toi,
                        "Group_Code": group_code,
                        "Company_Code": company_code_first,
                        "Company_Code_all": company_codes_str,
                        "Objection_letter_date": letter_date,
                        "Objectionletter#": letter_key,
                        "Objection#": obj_key,
                        "Objection": obj_text.replace("\n", " ").strip(),
                        "download_week": download_week
                    })
    df = pd.DataFrame(rows, columns=[
        "SERFF#", "State", "Filing Type", "TOI", "Sub-TOI",
        "Group_Code", "Company_Code", "Company_Code_all", 
        "Objection_letter_date", "Objectionletter#", "Objection#", "Objection", "download_week"
    ])
    return df

# --- Main Processing ---
pdf_folder = f"Filings/Final/{date}"  # Folder path based on date parameter

# Process objections using the old functions.
objection_results = process_all_pdfs_in_folder(pdf_folder)
json_output_path = f"objections_output_{date}.json"
with open(json_output_path, "w", encoding="utf-8") as f:
    json.dump(objection_results, f, default=lambda o: o.isoformat() if isinstance(o, datetime) else o, ensure_ascii=False, indent=4)
print(f"Saved objections JSON output to {json_output_path}")

df_objections = results_to_dataframe_objections(objection_results)
csv_output_path = f"objections_output_{date}.csv"
df_objections.to_csv(csv_output_path, index=False)
print(f"Saved objections CSV output to {csv_output_path}")

# Process additional filing info using the new function.
additional_results = process_all_pdfs_additional(pdf_folder)
additional_json_output_path = f"additional_filing_info_{date}.json"
with open(additional_json_output_path, "w", encoding="utf-8") as f:
    json.dump(additional_results, f, default=lambda o: o.isoformat() if isinstance(o, datetime) else o, ensure_ascii=False, indent=4)
print(f"Saved additional filing info JSON output to {additional_json_output_path}")

df_additional = additional_to_dataframe(additional_results)
additional_csv_output_path = f"additional_filing_info_{date}.csv"
df_additional.to_csv(additional_csv_output_path, index=False)
print(f"Saved additional filing info CSV output to {additional_csv_output_path}")
# Out:
# Filings/Final/2025-03-10\AZ_HART-134440906.pdf
# 2025-03-12 07:30:41.103664
# Filings/Final/2025-03-10\AZ_HART-134440946.pdf
# 2025-03-12 07:30:41.235540
# Filings/Final/2025-03-10\AZ_TRVD-G134444542.pdf
# 2025-03-12 07:30:41.465506
# Filings/Final/2025-03-10\AZ_TRVD-G134444680.pdf
# 2025-03-12 07:30:41.562031
# Filings/Final/2025-03-10\CA_LBRM-134354159.pdf
# 2025-03-12 07:30:41.647059
# Filings/Final/2025-03-10\CA_LBRM-134354250.pdf
# 2025-03-12 07:30:42.117225
# Filings/Final/2025-03-10\CO_GMMX-134450913.pdf
# 2025-03-12 07:30:42.576027
# Filings/Final/2025-03-10\CO_LBPM-134412448.pdf
# 2025-03-12 07:30:42.632881
# Filings/Final/2025-03-10\District_TRVD-G134382426.pdf
# 2025-03-12 07:30:42.793658
# Filings/Final/2025-03-10\District_TRVD-G134382657.pdf
# 2025-03-12 07:30:43.166127
# Filings/Final/2025-03-10\District_TRVD-G134382695.pdf
# 2025-03-12 07:30:43.464019
# Filings/Final/2025-03-10\GA_ALSE-134337450.pdf
# 2025-03-12 07:30:43.798890
# Filings/Final/2025-03-10\GA_HART-134414600.pdf
# 2025-03-12 07:30:44.421269
# Filings/Final/2025-03-10\GA_LBPM-134447081.pdf
# 2025-03-12 07:30:44.473084
# Filings/Final/2025-03-10\GA_LBPM-134447335.pdf
# 2025-03-12 07:30:44.534918
# Filings/Final/2025-03-10\GA_LBPM-134449473.pdf
# 2025-03-12 07:30:44.586549
# Filings/Final/2025-03-10\GA_SFMA-134413084.pdf
# 2025-03-12 07:30:44.637823
# Filings/Final/2025-03-10\GA_TRVD-G134360540.pdf
# 2025-03-12 07:30:44.932539
# Filings/Final/2025-03-10\GA_TRVD-G134400530.pdf
# 2025-03-12 07:30:45.129831
# Filings/Final/2025-03-10\ID_LBPM-134449496.pdf
# 2025-03-12 07:30:45.236708
# Filings/Final/2025-03-10\IL_ALSE-134437284.pdf
# 2025-03-12 07:30:45.307079
# Filings/Final/2025-03-10\IL_SFMA-134413708.pdf
# 2025-03-12 07:30:45.337304
# Filings/Final/2025-03-10\KS_GMMX-134433936.pdf
# 2025-03-12 07:30:45.382829
# Filings/Final/2025-03-10\KS_SFMA-134449763.pdf
# 2025-03-12 07:30:45.458851
# Filings/Final/2025-03-10\KS_TRVD-G134448245.pdf
# 2025-03-12 07:30:45.532200
# Filings/Final/2025-03-10\ME_TRVD-G134422686.pdf
# 2025-03-12 07:30:45.893159
# Filings/Final/2025-03-10\MI_ALSE-134422885.pdf
# 2025-03-12 07:30:45.920192
# Filings/Final/2025-03-10\MI_ALSE-134443416.pdf
# 2025-03-12 07:30:46.156088
# Filings/Final/2025-03-10\MI_ALSE-134445641.pdf
# 2025-03-12 07:30:53.938298
# Filings/Final/2025-03-10\MI_AMSI-134336870.pdf
# 2025-03-12 07:30:53.955967
# Filings/Final/2025-03-10\MI_HART-134433875.pdf
# 2025-03-12 07:30:54.256568
# Filings/Final/2025-03-10\MI_HART-134433892.pdf
# 2025-03-12 07:30:54.499297
# Filings/Final/2025-03-10\MI_LBPM-134437577.pdf
# 2025-03-12 07:30:54.732699
# Filings/Final/2025-03-10\MI_TRVD-G134446450.pdf
# 2025-03-12 07:30:54.809370
# Filings/Final/2025-03-10\MN_SFMA-134414598.pdf
# 2025-03-12 07:30:55.222157
# Filings/Final/2025-03-10\MO_USAA-134449959.pdf
# 2025-03-12 07:30:55.910675
# Filings/Final/2025-03-10\NC_ALSE-134449660.pdf
# 2025-03-12 07:30:55.963755
# Filings/Final/2025-03-10\NC_USAA-134418343.pdf
# 2025-03-12 07:30:56.108514
# Filings/Final/2025-03-10\NC_USAA-134418345.pdf
# 2025-03-12 07:30:56.285501
# Filings/Final/2025-03-10\NC_USAA-134418351.pdf
# 2025-03-12 07:30:56.442493
# Filings/Final/2025-03-10\NC_USAA-134418355.pdf
# 2025-03-12 07:30:56.743283
# Filings/Final/2025-03-10\ND_GMMX-134414147.pdf
# 2025-03-12 07:30:56.981959
# Filings/Final/2025-03-10\ND_GMMX-134414190.pdf
# 2025-03-12 07:30:57.067342
# Filings/Final/2025-03-10\ND_GMMX-134414199.pdf
# 2025-03-12 07:30:57.134310
# Filings/Final/2025-03-10\NE_GMMX-134443628.pdf
# 2025-03-12 07:30:57.204350
# Filings/Final/2025-03-10\NJ_AMSI-134443262.pdf
# 2025-03-12 07:30:58.177972
# Filings/Final/2025-03-10\NJ_LBPM-134367579.pdf
# 2025-03-12 07:30:58.284651
# Filings/Final/2025-03-10\NJ_LEMO-134389427.pdf
# 2025-03-12 07:30:58.419470
# Filings/Final/2025-03-10\NV_HART-134384733.pdf
# 2025-03-12 07:30:58.486508
# Filings/Final/2025-03-10\OK_AMSI-134369860.pdf
# 2025-03-12 07:30:58.569009
# Filings/Final/2025-03-10\OR_AMSI-134435230.pdf
# 2025-03-12 07:30:58.886896
# Filings/Final/2025-03-10\OR_AMSI-134435390.pdf
# 2025-03-12 07:30:58.970148
# Filings/Final/2025-03-10\OR_HART-134431622.pdf
# 2025-03-12 07:30:59.038443
# Filings/Final/2025-03-10\OR_LEMO-134373821.pdf
# 2025-03-12 07:30:59.103476
# Filings/Final/2025-03-10\PA_LEMO-134412814.pdf
# 2025-03-12 07:30:59.618877
# Filings/Final/2025-03-10\SC_LBPM-134400516.pdf
# 2025-03-12 07:30:59.726420
# Filings/Final/2025-03-10\SC_LBPM-134401992.pdf
# 2025-03-12 07:30:59.864577
# Filings/Final/2025-03-10\SC_LBPM-134406290.pdf
# 2025-03-12 07:30:59.999615
# Filings/Final/2025-03-10\TN_ALSE-134450014.pdf
# 2025-03-12 07:31:00.246536
# Filings/Final/2025-03-10\TX_HART-134398746.pdf
# 2025-03-12 07:31:00.466788
# Filings/Final/2025-03-10\TX_HART-134405817.pdf
# 2025-03-12 07:31:00.520595
# Filings/Final/2025-03-10\TX_HART-134407174.pdf
# 2025-03-12 07:31:00.549075
# Filings/Final/2025-03-10\TX_HART-134429816.pdf
# 2025-03-12 07:31:00.607651
# Filings/Final/2025-03-10\TX_SFMA-134410201.pdf
# 2025-03-12 07:31:00.787611
# Filings/Final/2025-03-10\TX_SFMA-134410218.pdf
# 2025-03-12 07:31:00.890542
# Filings/Final/2025-03-10\TX_SFMA-134447409.pdf
# 2025-03-12 07:31:01.007718
# Filings/Final/2025-03-10\TX_USAA-134443395.pdf
# 2025-03-12 07:31:01.036812
# Filings/Final/2025-03-10\TX_USAA-134443396.pdf
# 2025-03-12 07:31:01.603458
# Filings/Final/2025-03-10\VA_AMSI-134375543.pdf
# 2025-03-12 07:31:01.658591
# Filings/Final/2025-03-10\VA_LEMO-134441439.pdf
# 2025-03-12 07:31:01.714645
# Filings/Final/2025-03-10\WA_LBPM-134447017.pdf
# 2025-03-12 07:31:01.779309
# Filings/Final/2025-03-10\WI_AMSI-133860671.pdf
# 2025-03-12 07:31:02.079416
# Filings/Final/2025-03-10\WI_LBPM-134430805.pdf
# 2025-03-12 07:31:02.243846
# Filings/Final/2025-03-10\WI_LEMO-134385206.pdf
# 2025-03-12 07:31:02.733938
# Filings/Final/2025-03-10\WI_SFMA-134421547.pdf
# 2025-03-12 07:31:03.230978
# Filings/Final/2025-03-10\WV_AMSI-134244221.pdf
# 2025-03-12 07:31:03.397538
# Saved objections JSON output to objections_output_2025-03-10.json
# Saved objections CSV output to objections_output_2025-03-10.csv
# Filings/Final/2025-03-10\AZ_HART-134440906.pdf
# 2025-03-12 07:31:03.973941
# Token count for API call in AZ_HART-134440906.pdf: 32521
# Processed additional filing info for: AZ_HART-134440906.pdf
# Filings/Final/2025-03-10\AZ_HART-134440946.pdf
# 2025-03-12 07:31:10.241875
# Token count for API call in AZ_HART-134440946.pdf: 32956
# Processed additional filing info for: AZ_HART-134440946.pdf
# Filings/Final/2025-03-10\AZ_TRVD-G134444542.pdf
# 2025-03-12 07:31:10.505618
# Token count for API call in AZ_TRVD-G134444542.pdf: 9533
# Processed additional filing info for: AZ_TRVD-G134444542.pdf
# Filings/Final/2025-03-10\AZ_TRVD-G134444680.pdf
# 2025-03-12 07:31:10.652558
# Token count for API call in AZ_TRVD-G134444680.pdf: 10206
# Processed additional filing info for: AZ_TRVD-G134444680.pdf
# Filings/Final/2025-03-10\CA_LBRM-134354159.pdf
# 2025-03-12 07:31:10.833210
# Token count for API call in CA_LBRM-134354159.pdf: 49975
# Processed additional filing info for: CA_LBRM-134354159.pdf
# Filings/Final/2025-03-10\CA_LBRM-134354250.pdf
# 2025-03-12 07:31:11.773059
# Token count for API call in CA_LBRM-134354250.pdf: 52617
# Processed additional filing info for: CA_LBRM-134354250.pdf
# Filings/Final/2025-03-10\CO_GMMX-134450913.pdf
# 2025-03-12 07:31:12.624232
# Token count for API call in CO_GMMX-134450913.pdf: 9971
# Processed additional filing info for: CO_GMMX-134450913.pdf
# Filings/Final/2025-03-10\CO_LBPM-134412448.pdf
# 2025-03-12 07:31:12.732169
# Token count for API call in CO_LBPM-134412448.pdf: 22981
# Processed additional filing info for: CO_LBPM-134412448.pdf
# Filings/Final/2025-03-10\District_TRVD-G134382426.pdf
# 2025-03-12 07:31:13.027648
# Token count for API call in District_TRVD-G134382426.pdf: 180824
# Processed additional filing info for: District_TRVD-G134382426.pdf
# Filings/Final/2025-03-10\District_TRVD-G134382657.pdf
# 2025-03-12 07:31:13.878952
# Token count for API call in District_TRVD-G134382657.pdf: 126544
# Processed additional filing info for: District_TRVD-G134382657.pdf
# Filings/Final/2025-03-10\District_TRVD-G134382695.pdf
# 2025-03-12 07:31:14.849304
# Token count for API call in District_TRVD-G134382695.pdf: 151123
# Processed additional filing info for: District_TRVD-G134382695.pdf
# Filings/Final/2025-03-10\GA_ALSE-134337450.pdf
# 2025-03-12 07:31:15.672842
# Token count for API call in GA_ALSE-134337450.pdf: 1194682
# Processed additional filing info for: GA_ALSE-134337450.pdf
# Filings/Final/2025-03-10\GA_HART-134414600.pdf
# 2025-03-12 07:31:18.882532
# Token count for API call in GA_HART-134414600.pdf: 5792
# Processed additional filing info for: GA_HART-134414600.pdf
# Filings/Final/2025-03-10\GA_LBPM-134447081.pdf
# 2025-03-12 07:31:18.963758
# Token count for API call in GA_LBPM-134447081.pdf: 3938
# Processed additional filing info for: GA_LBPM-134447081.pdf
# Filings/Final/2025-03-10\GA_LBPM-134447335.pdf
# 2025-03-12 07:31:19.041277
# Token count for API call in GA_LBPM-134447335.pdf: 3961
# Processed additional filing info for: GA_LBPM-134447335.pdf
# Filings/Final/2025-03-10\GA_LBPM-134449473.pdf
# 2025-03-12 07:31:19.146241
# Token count for API call in GA_LBPM-134449473.pdf: 4311
# Processed additional filing info for: GA_LBPM-134449473.pdf
# Filings/Final/2025-03-10\GA_SFMA-134413084.pdf
# 2025-03-12 07:31:19.238101
# Token count for API call in GA_SFMA-134413084.pdf: 69930
# Processed additional filing info for: GA_SFMA-134413084.pdf
# Filings/Final/2025-03-10\GA_TRVD-G134360540.pdf
# 2025-03-12 07:31:20.518819
# Token count for API call in GA_TRVD-G134360540.pdf: 24605
# Processed additional filing info for: GA_TRVD-G134360540.pdf
# Filings/Final/2025-03-10\GA_TRVD-G134400530.pdf
# 2025-03-12 07:31:20.874257
# Token count for API call in GA_TRVD-G134400530.pdf: 12596
# Processed additional filing info for: GA_TRVD-G134400530.pdf
# Filings/Final/2025-03-10\ID_LBPM-134449496.pdf
# 2025-03-12 07:31:21.070008
# Token count for API call in ID_LBPM-134449496.pdf: 4559
# Processed additional filing info for: ID_LBPM-134449496.pdf
# Filings/Final/2025-03-10\IL_ALSE-134437284.pdf
# 2025-03-12 07:31:21.163825
# Token count for API call in IL_ALSE-134437284.pdf: 2353
# Processed additional filing info for: IL_ALSE-134437284.pdf
# Filings/Final/2025-03-10\IL_SFMA-134413708.pdf
# 2025-03-12 07:31:21.217311
# Token count for API call in IL_SFMA-134413708.pdf: 9652
# Processed additional filing info for: IL_SFMA-134413708.pdf
# Filings/Final/2025-03-10\KS_GMMX-134433936.pdf
# 2025-03-12 07:31:21.293187
# Token count for API call in KS_GMMX-134433936.pdf: 4510
# Processed additional filing info for: KS_GMMX-134433936.pdf
# Filings/Final/2025-03-10\KS_SFMA-134449763.pdf
# 2025-03-12 07:31:21.456851
# Token count for API call in KS_SFMA-134449763.pdf: 4404
# Processed additional filing info for: KS_SFMA-134449763.pdf
# Filings/Final/2025-03-10\KS_TRVD-G134448245.pdf
# 2025-03-12 07:31:21.549045
# Token count for API call in KS_TRVD-G134448245.pdf: 1370694
# Processed additional filing info for: KS_TRVD-G134448245.pdf
# Filings/Final/2025-03-10\ME_TRVD-G134422686.pdf
# 2025-03-12 07:31:28.027453
# Token count for API call in ME_TRVD-G134422686.pdf: 2036
# Processed additional filing info for: ME_TRVD-G134422686.pdf
# Filings/Final/2025-03-10\MI_ALSE-134422885.pdf
# 2025-03-12 07:31:28.056871
# Token count for API call in MI_ALSE-134422885.pdf: 79397
# Processed additional filing info for: MI_ALSE-134422885.pdf
# Filings/Final/2025-03-10\MI_ALSE-134443416.pdf
# 2025-03-12 07:31:28.733219
# Token count for API call in MI_ALSE-134443416.pdf: 10611263
# Processed additional filing info for: MI_ALSE-134443416.pdf
# Filings/Final/2025-03-10\MI_ALSE-134445641.pdf
# 2025-03-12 07:36:21.188013
# Token count for API call in MI_ALSE-134445641.pdf: 1964
# Processed additional filing info for: MI_ALSE-134445641.pdf
# Filings/Final/2025-03-10\MI_AMSI-134336870.pdf
# 2025-03-12 07:36:21.230605
# Token count for API call in MI_AMSI-134336870.pdf: 1088156
# Processed additional filing info for: MI_AMSI-134336870.pdf
# Filings/Final/2025-03-10\MI_HART-134433875.pdf
# 2025-03-12 07:36:23.809206
# Token count for API call in MI_HART-134433875.pdf: 1993710
# Processed additional filing info for: MI_HART-134433875.pdf
# Filings/Final/2025-03-10\MI_HART-134433892.pdf
# 2025-03-12 07:36:27.769791
# Token count for API call in MI_HART-134433892.pdf: 1993388
# Processed additional filing info for: MI_HART-134433892.pdf
# Filings/Final/2025-03-10\MI_LBPM-134437577.pdf
# 2025-03-12 07:36:32.032347
# Token count for API call in MI_LBPM-134437577.pdf: 5861
# Processed additional filing info for: MI_LBPM-134437577.pdf
# Filings/Final/2025-03-10\MI_TRVD-G134446450.pdf
# 2025-03-12 07:36:32.170119
# Token count for API call in MI_TRVD-G134446450.pdf: 131849
# Processed additional filing info for: MI_TRVD-G134446450.pdf
# Filings/Final/2025-03-10\MN_SFMA-134414598.pdf
# 2025-03-12 07:36:33.049863
# Token count for API call in MN_SFMA-134414598.pdf: 39313
# Processed additional filing info for: MN_SFMA-134414598.pdf
# Filings/Final/2025-03-10\MO_USAA-134449959.pdf
# 2025-03-12 07:36:34.127369
# Token count for API call in MO_USAA-134449959.pdf: 5990
# Processed additional filing info for: MO_USAA-134449959.pdf
# Filings/Final/2025-03-10\NC_ALSE-134449660.pdf
# 2025-03-12 07:36:34.202969
# Token count for API call in NC_ALSE-134449660.pdf: 19698
# Processed additional filing info for: NC_ALSE-134449660.pdf
# Filings/Final/2025-03-10\NC_USAA-134418343.pdf
# 2025-03-12 07:36:34.442413
# Token count for API call in NC_USAA-134418343.pdf: 32087
# Processed additional filing info for: NC_USAA-134418343.pdf
# Filings/Final/2025-03-10\NC_USAA-134418345.pdf
# 2025-03-12 07:36:34.767716
# Token count for API call in NC_USAA-134418345.pdf: 32056
# Processed additional filing info for: NC_USAA-134418345.pdf
# Filings/Final/2025-03-10\NC_USAA-134418351.pdf
# 2025-03-12 07:36:35.058749
# Token count for API call in NC_USAA-134418351.pdf: 32051
# Processed additional filing info for: NC_USAA-134418351.pdf
# Filings/Final/2025-03-10\NC_USAA-134418355.pdf
# 2025-03-12 07:36:35.362545
# Token count for API call in NC_USAA-134418355.pdf: 32216
# Processed additional filing info for: NC_USAA-134418355.pdf
# Filings/Final/2025-03-10\ND_GMMX-134414147.pdf
# 2025-03-12 07:36:35.645762
# Token count for API call in ND_GMMX-134414147.pdf: 5248
# Processed additional filing info for: ND_GMMX-134414147.pdf
# Filings/Final/2025-03-10\ND_GMMX-134414190.pdf
# 2025-03-12 07:36:35.755846
# Token count for API call in ND_GMMX-134414190.pdf: 5248
# Processed additional filing info for: ND_GMMX-134414190.pdf
# Filings/Final/2025-03-10\ND_GMMX-134414199.pdf
# 2025-03-12 07:36:35.862962
# Token count for API call in ND_GMMX-134414199.pdf: 5226
# Processed additional filing info for: ND_GMMX-134414199.pdf
# Filings/Final/2025-03-10\NE_GMMX-134443628.pdf
# 2025-03-12 07:36:36.055679
# Token count for API call in NE_GMMX-134443628.pdf: 82171
# Processed additional filing info for: NE_GMMX-134443628.pdf
# Filings/Final/2025-03-10\NJ_AMSI-134443262.pdf
# 2025-03-12 07:36:37.614116
# Token count for API call in NJ_AMSI-134443262.pdf: 17378
# Processed additional filing info for: NJ_AMSI-134443262.pdf
# Filings/Final/2025-03-10\NJ_LBPM-134367579.pdf
# 2025-03-12 07:36:37.844208
# Token count for API call in NJ_LBPM-134367579.pdf: 17024
# Processed additional filing info for: NJ_LBPM-134367579.pdf
# Filings/Final/2025-03-10\NJ_LEMO-134389427.pdf
# 2025-03-12 07:36:38.120822
# Token count for API call in NJ_LEMO-134389427.pdf: 5219
# Processed additional filing info for: NJ_LEMO-134389427.pdf
# Filings/Final/2025-03-10\NV_HART-134384733.pdf
# 2025-03-12 07:36:38.210483
# Token count for API call in NV_HART-134384733.pdf: 9853
# Processed additional filing info for: NV_HART-134384733.pdf
# Filings/Final/2025-03-10\OK_AMSI-134369860.pdf
# 2025-03-12 07:36:38.335596
# Token count for API call in OK_AMSI-134369860.pdf: 52585
# Processed additional filing info for: OK_AMSI-134369860.pdf
# Filings/Final/2025-03-10\OR_AMSI-134435230.pdf
# 2025-03-12 07:36:38.798802
# Token count for API call in OR_AMSI-134435230.pdf: 16029
# Processed additional filing info for: OR_AMSI-134435230.pdf
# Filings/Final/2025-03-10\OR_AMSI-134435390.pdf
# 2025-03-12 07:36:38.961618
# Token count for API call in OR_AMSI-134435390.pdf: 9454
# Processed additional filing info for: OR_AMSI-134435390.pdf
# Filings/Final/2025-03-10\OR_HART-134431622.pdf
# 2025-03-12 07:36:39.076214
# Token count for API call in OR_HART-134431622.pdf: 8298
# Processed additional filing info for: OR_HART-134431622.pdf
# Filings/Final/2025-03-10\OR_LEMO-134373821.pdf
# 2025-03-12 07:36:39.174305
# Token count for API call in OR_LEMO-134373821.pdf: 142948
# Processed additional filing info for: OR_LEMO-134373821.pdf
# Filings/Final/2025-03-10\PA_LEMO-134412814.pdf
# 2025-03-12 07:36:40.072952
# Token count for API call in PA_LEMO-134412814.pdf: 10750
# Processed additional filing info for: PA_LEMO-134412814.pdf
# Filings/Final/2025-03-10\SC_LBPM-134400516.pdf
# 2025-03-12 07:36:40.207858
# Token count for API call in SC_LBPM-134400516.pdf: 12099
# Processed additional filing info for: SC_LBPM-134400516.pdf
# Filings/Final/2025-03-10\SC_LBPM-134401992.pdf
# 2025-03-12 07:36:40.438798
# Token count for API call in SC_LBPM-134401992.pdf: 9532
# Processed additional filing info for: SC_LBPM-134401992.pdf
# Filings/Final/2025-03-10\SC_LBPM-134406290.pdf
# 2025-03-12 07:36:40.617893
# Token count for API call in SC_LBPM-134406290.pdf: 17149
# Processed additional filing info for: SC_LBPM-134406290.pdf
# Filings/Final/2025-03-10\TN_ALSE-134450014.pdf
# 2025-03-12 07:36:40.989627
# Token count for API call in TN_ALSE-134450014.pdf: 86309
# Processed additional filing info for: TN_ALSE-134450014.pdf
# Filings/Final/2025-03-10\TX_HART-134398746.pdf
# 2025-03-12 07:36:41.426256
# Token count for API call in TX_HART-134398746.pdf: 5421
# Processed additional filing info for: TX_HART-134398746.pdf
# Filings/Final/2025-03-10\TX_HART-134405817.pdf
# 2025-03-12 07:36:41.540026
# Token count for API call in TX_HART-134405817.pdf: 5440
# Processed additional filing info for: TX_HART-134405817.pdf
# Filings/Final/2025-03-10\TX_HART-134407174.pdf
# 2025-03-12 07:36:41.628967
# Token count for API call in TX_HART-134407174.pdf: 5458
# Processed additional filing info for: TX_HART-134407174.pdf
# Filings/Final/2025-03-10\TX_HART-134429816.pdf
# 2025-03-12 07:36:41.717368
# Token count for API call in TX_HART-134429816.pdf: 12307
# Processed additional filing info for: TX_HART-134429816.pdf
# Filings/Final/2025-03-10\TX_SFMA-134410201.pdf
# 2025-03-12 07:36:42.102143
# Token count for API call in TX_SFMA-134410201.pdf: 9109
# Processed additional filing info for: TX_SFMA-134410201.pdf
# Filings/Final/2025-03-10\TX_SFMA-134410218.pdf
# 2025-03-12 07:36:42.291707
# Token count for API call in TX_SFMA-134410218.pdf: 11903
# Processed additional filing info for: TX_SFMA-134410218.pdf
# Filings/Final/2025-03-10\TX_SFMA-134447409.pdf
# 2025-03-12 07:36:42.554757
# Token count for API call in TX_SFMA-134447409.pdf: 3624
# Processed additional filing info for: TX_SFMA-134447409.pdf
# Filings/Final/2025-03-10\TX_USAA-134443395.pdf
# 2025-03-12 07:36:42.609956
# Token count for API call in TX_USAA-134443395.pdf: 654116
# Processed additional filing info for: TX_USAA-134443395.pdf
# Filings/Final/2025-03-10\TX_USAA-134443396.pdf
# 2025-03-12 07:36:46.129996
# Token count for API call in TX_USAA-134443396.pdf: 4650
# Processed additional filing info for: TX_USAA-134443396.pdf
# Filings/Final/2025-03-10\VA_AMSI-134375543.pdf
# 2025-03-12 07:36:46.227859
# Token count for API call in VA_AMSI-134375543.pdf: 5422
# Processed additional filing info for: VA_AMSI-134375543.pdf
# Filings/Final/2025-03-10\VA_LEMO-134441439.pdf
# 2025-03-12 07:36:46.340494
# Token count for API call in VA_LEMO-134441439.pdf: 9989
# Processed additional filing info for: VA_LEMO-134441439.pdf
# Filings/Final/2025-03-10\WA_LBPM-134447017.pdf
# 2025-03-12 07:36:46.450443
# Token count for API call in WA_LBPM-134447017.pdf: 92030
# Processed additional filing info for: WA_LBPM-134447017.pdf
# Filings/Final/2025-03-10\WI_AMSI-133860671.pdf
# 2025-03-12 07:36:47.103385
# Token count for API call in WI_AMSI-133860671.pdf: 34542
# Processed additional filing info for: WI_AMSI-133860671.pdf
# Filings/Final/2025-03-10\WI_LBPM-134430805.pdf
# 2025-03-12 07:36:47.379345
# Token count for API call in WI_LBPM-134430805.pdf: 18224
# Processed additional filing info for: WI_LBPM-134430805.pdf
# Filings/Final/2025-03-10\WI_LEMO-134385206.pdf
# 2025-03-12 07:36:47.878253
# Token count for API call in WI_LEMO-134385206.pdf: 354400
# Processed additional filing info for: WI_LEMO-134385206.pdf
# Filings/Final/2025-03-10\WI_SFMA-134421547.pdf
# 2025-03-12 07:36:49.502624
# Token count for API call in WI_SFMA-134421547.pdf: 22752
# Processed additional filing info for: WI_SFMA-134421547.pdf
# Filings/Final/2025-03-10\WV_AMSI-134244221.pdf
# 2025-03-12 07:36:49.876428
# Token count for API call in WV_AMSI-134244221.pdf: 1174752
# Processed additional filing info for: WV_AMSI-134244221.pdf
# Saved additional filing info JSON output to additional_filing_info_2025-03-10.json
# Saved additional filing info CSV output to additional_filing_info_2025-03-10.csv

# %%
### Added 2 calls to the Anthropic API (3.13) ###

# %%
import os
import re
import glob
import fitz  # PyMuPDF
import json
import pandas as pd
from datetime import datetime
from pprint import pprint
from dotenv import load_dotenv
import tiktoken  # pip install tiktoken
import anthropic  # pip install anthropic

# Load environment variables (which should include api_key, grok_api_key, and anthropic_api_key)
load_dotenv()

# === API Call Control Parameters for additional filing info (not used for objections) ===
# Set each to 'Y' to call the API, or 'N' to skip the API call.
CALL_GPT_3_5 = "Y"
CALL_O1_MINI = "N"  # Example value; set to 'Y' or 'N'
CALL_XAI = "N"      # Example value; set to 'Y' or 'N'
CALL_CLAUDE3_HAIKU = "Y"         # New: call Anthropic claude-3-haiku?
CALL_CLAUDE3_5_SONNET = "N"        # New: call Anthropic claude-3-5-sonnet?

# === User-defined Maximum Token Parameters for API calls ===
MAX_TOKENS_GPT3_5 = 15000
MAX_TOKENS_O1_MINI = 15000
MAX_TOKENS_XAI = 15000
MAX_TOKENS_CLAUDE3_HAIKU = 15000   # New max tokens for claude-3-haiku
MAX_TOKENS_CLAUDE3_5_SONNET = 15000  # New max tokens for claude-3-5-sonnet

# Create OpenAI client for standard models
from openai import OpenAI
api_key = os.getenv("api_key")
client = OpenAI(api_key=api_key)

# Create a separate client for the xAI API
XAI_API_KEY = os.getenv("grok_api_key")
xai_client = OpenAI(api_key=XAI_API_KEY, base_url="https://api.x.ai/v1")

# Create Anthropics client
anthropic_api_key = os.getenv("anthropic_api_key")
anthropic_client = anthropic.Anthropic(api_key=anthropic_api_key)

# Define the download week as a string and convert it to a datetime object.
date = "2025-03-10"
download_week_dt = datetime.strptime(date, "%Y-%m-%d")

# --- Helper functions for token counting and truncation using tiktoken ---
def count_tokens(text, model="gpt-3.5-turbo"):
    try:
        encoding = tiktoken.encoding_for_model(model)
    except Exception:
        encoding = tiktoken.get_encoding("cl100k_base")
    tokens = encoding.encode(text)
    return len(tokens)

def truncate_text(text, max_tokens, model="gpt-3.5-turbo"):
    try:
        encoding = tiktoken.encoding_for_model(model)
    except Exception:
        encoding = tiktoken.get_encoding("cl100k_base")
    tokens = encoding.encode(text)
    if len(tokens) > max_tokens:
        truncated_tokens = tokens[:max_tokens]
        truncated_text = encoding.decode(truncated_tokens)
        return truncated_text
    return text

# --- API call functions (used in additional filing info only) ---
def call_gpt_3_5_turbo(full_text):
    try:
        completion = client.chat.completions.create(
            model="gpt-3.5-turbo",
            messages=[
                {"role": "system", "content": "You are an analyst doing competitive intelligence research on insurance companies."},
                {"role": "user", "content": f"The following is a filing with a DOI from an insurance company: '{full_text}'. Give a summary of the rate filing."}
            ],
            max_tokens=1000
        )
        print("GPT-3.5 Summary:", completion.choices[0].message.content)
        return completion.choices[0].message.content
    except Exception as e:
        print(f"Error calling GPT-3.5-turbo: {e}")
        return ""

def call_o1_mini(full_text):
    try:
        completion = client.chat.completions.create(
            model="o1-mini",
            messages=[
                {"role": "user", "content": "You are an analyst doing competitive intelligence research on insurance companies."},
                {"role": "user", "content": f"The following is a filing with a DOI from an insurance company: '{full_text}'. Give a summary of the rate filing."}
            ]
        )
        print("o1-mini Summary:", completion.choices[0].message.content)
        return completion.choices[0].message.content
    except Exception as e:
        print(f"Error calling o1-mini: {e}")
        return ""

def call_xai(full_text):
    try:
        completion = xai_client.chat.completions.create(
            model="grok-2-latest",
            messages=[
                {"role": "system", "content": "You are an analyst doing competitive intelligence research on insurance companies."},
                {"role": "user", "content": f"The following is a filing with a DOI from an insurance company: '{full_text}'. Give a summary of the rate filing."}
            ]
        )
        print("xAI Summary:", completion.choices[0].message.content)
        return completion.choices[0].message.content
    except Exception as e:
        print(f"Error calling xAI: {e}")
        return ""

# --- New Anthropic API call functions ---
def call_claude_3_haiku(full_text):
    try:
        message = anthropic_client.messages.create(
            model="claude-3-haiku-20240307",
            max_tokens=1024,
            messages=[
                {"role": "user", "content": "You are an analyst doing competitive intelligence research on insurance companies."},
                {"role": "user", "content": f"The following is a filing with a DOI from an insurance company: '{full_text}'. Give a summary of the rate filing."}
            ]
        )
        print("Claude-3 Haiku Summary:", message.content[0].text)
        return message.content[0].text
    except Exception as e:
        print(f"Error calling Claude-3 Haiku: {e}")
        return ""

def call_claude_3_5_sonnet(full_text):
    try:
        message = anthropic_client.messages.create(
            model="claude-3-5-sonnet-20241022",
            max_tokens=1024,
            messages=[
                {"role": "user", "content": "You are an analyst doing competitive intelligence research on insurance companies."},
                {"role": "user", "content": f"The following is a filing with a DOI from an insurance company: '{full_text}'. Give a summary of the rate filing."}
            ]
        )
        print("Claude-3.5 Sonnet Summary:", message.content[0].text)
        return message.content[0].text
    except Exception as e:
        print(f"Error calling Claude-3.5 Sonnet: {e}")
        return ""

# --- Extraction functions for non-API parts ---
def extract_full_text(pdf_path, max_pages=None):
    """
    Extracts full text from a PDF.
    If max_pages is provided, only extracts from the first max_pages pages.
    """
    doc = fitz.open(pdf_path)
    full_text = ""
    for i, page in enumerate(doc):
        if max_pages is not None and i >= max_pages:
            break
        full_text += page.get_text() + "\n"
    doc.close()
    return full_text

def split_list_objections(text):
    parts = re.split(r"(?m)^\s*(?:\(?(\d+)\)?[.\)])\s*", text)
    objections = {}
    if len(parts) >= 3:
        for i in range(1, len(parts)-1, 2):
            num = parts[i].strip()
            obj_text = parts[i+1].strip()
            objections[f"objection{num}"] = obj_text
        if not objections:
            objections["objection1"] = text.strip()
    else:
        objections["objection1"] = text.strip()
    return objections

def parse_objection_letters(text):
    """
    Splits the full text into separate objection letter sections.
    A valid objection letter must contain "Objection Letter Date", "Introduction:" and "Conclusion:".
    Returns a dictionary where each key is "Objection_letterX" with its parsed objections.
    """
    pattern = r"(Objection Letter.*?Objection Letter Date\s+(\d{2}/\d{2}/\d{4}).*?Introduction:\s*(.*?)\s*Conclusion:)"
    matches = list(re.finditer(pattern, text, flags=re.IGNORECASE | re.DOTALL))
    letter_dict = {}
    for idx, m in enumerate(matches, start=1):
        letter_date = m.group(2).strip()
        body = m.group(3).strip()
        explicit_objs = list(re.finditer(r"Objection\s+(\d+)", body, flags=re.IGNORECASE))
        if len(explicit_objs) > 1:
            obj_pattern = r"(Objection\s+(\d+).*?)(?=(Objection\s+\d+|Conclusion:|$))"
            objections = {}
            for om in re.finditer(obj_pattern, body, flags=re.IGNORECASE | re.DOTALL):
                num = om.group(2).strip()
                obj_text = om.group(1).strip()
                objections[f"objection{num}"] = obj_text
        else:
            if re.search(r"(?m)^\s*(\(?\d+\)?[.\)])", body):
                objections = split_list_objections(body)
            else:
                objections = {"objection1": body}
        letter_dict[f"Objection_letter{idx}"] = {
            "objection_letter_date": letter_date,
            **objections
        }
    return letter_dict

def extract_filing_company_info(text):
    """
    Extracts filing company information.
    Returns a tuple: (group_code, company_codes)
    """
    company_codes = re.findall(r"CoCode:\s*(\d+)", text, flags=re.IGNORECASE)
    group_codes = re.findall(r"Group Code:\s*(\d+)", text, flags=re.IGNORECASE)
    company_codes = [int(code) for code in company_codes] if company_codes else []
    group_code = int(group_codes[0]) if group_codes else None
    return group_code, company_codes

# --- Extraction functions for additional filing info ---
def parse_filing_at_a_glance(text):
    """
    Extracts key filing info from the "Filing at a Glance" section.
    Returns a dictionary with keys:
      serff_tr_num, filing_type, date_submitted, effective_date_requested_new,
      effective_date_requested_renewal, serff_status, toi, sub_toi.
    """
    info = {}
    match = re.search(r"Filing at a Glance(.*?)(?=\n[A-Z][a-z]+ Information|$)", text, flags=re.IGNORECASE | re.DOTALL)
    section = match.group(1) if match else ""
    
    serff_match = re.search(r"SERFF Tr Num:\s*([A-Z0-9\-]+)", section, flags=re.IGNORECASE)
    info["serff_tr_num"] = serff_match.group(1).strip() if serff_match else ""
    
    filing_type_match = re.search(r"Filing Type:\s*([^\n]+)", section, flags=re.IGNORECASE)
    info["filing_type"] = filing_type_match.group(1).strip() if filing_type_match else ""
    
    date_submitted_match = re.search(r"Date Submitted:\s*(\d{2}/\d{2}/\d{4})", section, flags=re.IGNORECASE)
    info["date_submitted"] = date_submitted_match.group(1).strip() if date_submitted_match else ""
    
    effective_new_match = re.search(r"Effective Date\s*Requested\s*\(New\):\s*(\d{2}/\d{2}/\d{4})", section, flags=re.IGNORECASE)
    info["effective_date_requested_new"] = effective_new_match.group(1).strip() if effective_new_match else ""
    
    effective_renewal_match = re.search(r"Effective Date\s*Requested\s*\(Renewal\):\s*(\d{2}/\d{2}/\d{4})", section, flags=re.IGNORECASE)
    info["effective_date_requested_renewal"] = effective_renewal_match.group(1).strip() if effective_renewal_match else ""
    
    serff_status_match = re.search(r"SERFF Status:\s*([^\n]+)", section, flags=re.IGNORECASE)
    info["serff_status"] = serff_status_match.group(1).strip() if serff_status_match else ""
    
    toi_match = re.search(r"TOI:\s*([^\n]+)", section, flags=re.IGNORECASE)
    info["toi"] = toi_match.group(1).strip() if toi_match else ""
    
    sub_toi_match = re.search(r"Sub-TOI:\s*([^\n]+)", section, flags=re.IGNORECASE)
    info["sub_toi"] = sub_toi_match.group(1).strip() if sub_toi_match else ""
    
    return info

def parse_filing_description(text):
    """
    Extracts the Filing Description from the text.
    Returns the description string.
    """
    match = re.search(r"Filing Description:\s*(.*?)\s*(Filing Contact Information|Filing Company Information)", 
                      text, flags=re.IGNORECASE | re.DOTALL)
    if match:
        return match.group(1).strip()
    return ""

# --- Processing functions for objections (old version) ---
def process_pdf_file(pdf_path):
    """
    Processes a single PDF file for objections output.
    Truncates the PDF to the first 100 pages before processing.
    Returns a dictionary with keys:
      - "objections": parsed objection letters,
      - "group_code": extracted group code,
      - "company_codes": list of CoCodes,
      - "download_week": the download_week datetime,
      - "toi": TOI value,
      - "sub_toi": Sub-TOI value,
      - "filing_type": Filing Type.
    """
    # Truncate to first 100 pages
    full_text = extract_full_text(pdf_path, max_pages=100)
    parsed_letters = parse_objection_letters(full_text)
    group_code, company_codes = extract_filing_company_info(full_text)
    filing_info = parse_filing_at_a_glance(full_text)
    file_key = os.path.splitext(os.path.basename(pdf_path))[0]
    return {file_key: {
                "objections": parsed_letters,
                "group_code": group_code,
                "company_codes": company_codes,
                "download_week": download_week_dt,
                "toi": filing_info.get("toi", ""),
                "sub_toi": filing_info.get("sub_toi", ""),
                "filing_type": filing_info.get("filing_type", "")
            }}

def process_all_pdfs_in_folder(pdf_folder):
    """
    Loops through all PDF files in the folder and processes each for objections output.
    Returns a nested dictionary.
    """
    results = {}
    pdf_files = glob.glob(os.path.join(pdf_folder, "*.pdf"))
    for pdf_file in pdf_files:
        print(pdf_file)
        print(datetime.now())
        results.update(process_pdf_file(pdf_file))
    return results

# --- Processing functions for additional filing info (with API calls) ---
def extract_full_text_all(pdf_path):
    """
    Extracts full text from the PDF using up to the first 3000 pages.
    """
    return extract_full_text(pdf_path, max_pages=3000)

def process_pdf_additional(pdf_path):
    """
    Processes a single PDF file and extracts additional filing info.
    For non-API info, uses the first 100 pages.
    For API calls, uses the full text (up to 3000 pages) subject to token constraints.
    Returns a dictionary with keys including API summaries.
    """
    # Non-API extraction (first 100 pages)
    limited_text = extract_full_text(pdf_path, max_pages=100)
    filing_at_a_glance = parse_filing_at_a_glance(limited_text)
    filing_description = parse_filing_description(limited_text)
    group_code, company_codes = extract_filing_company_info(limited_text)
    
    # Compute state from file name (first two letters)
    state = os.path.splitext(os.path.basename(pdf_path))[0][:2]
    
    # API extraction using full text (up to 3000 pages)
    full_text_all = extract_full_text_all(pdf_path)
    print(f"Token count for API call in {os.path.basename(pdf_path)}: {count_tokens(full_text_all, model='gpt-3.5-turbo')}")
    
    # Always call GPT-3.5-turbo if enabled, using user-defined token limit.
    if CALL_GPT_3_5 == "Y":
        gpt_api_text = truncate_text(full_text_all, max_tokens=MAX_TOKENS_GPT3_5, model="gpt-3.5-turbo")
        gpt_3_5_summary = call_gpt_3_5_turbo(gpt_api_text)
    else:
        gpt_3_5_summary = ""
    
    if CALL_O1_MINI == "Y":
        o1_api_text = truncate_text(full_text_all, max_tokens=MAX_TOKENS_O1_MINI, model="o1-mini")
        o1_mini_summary = call_o1_mini(o1_api_text)
    else:
        o1_mini_summary = ""
    
    if CALL_XAI == "Y":
        xai_api_text = truncate_text(full_text_all, max_tokens=MAX_TOKENS_XAI, model="grok-2-latest")
        xai_summary = call_xai(xai_api_text)
    else:
        xai_summary = ""
    
    # New: Anthropic API calls
    if CALL_CLAUDE3_HAIKU == "Y":
        claude_3_haiku_text = truncate_text(full_text_all, max_tokens=MAX_TOKENS_CLAUDE3_HAIKU, model="gpt-3.5-turbo")
        claude_3_haiku_summary = call_claude_3_haiku(claude_3_haiku_text)
    else:
        claude_3_haiku_summary = ""
    
    if CALL_CLAUDE3_5_SONNET == "Y":
        claude_3_5_sonnet_text = truncate_text(full_text_all, max_tokens=MAX_TOKENS_CLAUDE3_5_SONNET, model="gpt-3.5-turbo")
        claude_3_5_sonnet_summary = call_claude_3_5_sonnet(claude_3_5_sonnet_text)
    else:
        claude_3_5_sonnet_summary = ""

    
    additional = {
        "serff_tr_num": filing_at_a_glance.get("serff_tr_num", ""),
        "filing_type": filing_at_a_glance.get("filing_type", ""),
        "date_submitted": filing_at_a_glance.get("date_submitted", ""),
        "effective_date_requested_new": filing_at_a_glance.get("effective_date_requested_new", ""),
        "effective_date_requested_renewal": filing_at_a_glance.get("effective_date_requested_renewal", ""),
        "serff_status": filing_at_a_glance.get("serff_status", ""),
        "filing_description": filing_description,
        "filing_method": "",  # Not extracted in this version.
        "toi": filing_at_a_glance.get("toi", ""),
        "sub_toi": filing_at_a_glance.get("sub_toi", ""),
        "group_code": group_code,
        "company_codes": company_codes,
        "download_week": download_week_dt,
        "state": state,
        "gpt_3_5_summary": gpt_3_5_summary,
        "o1_mini_summary": o1_mini_summary,
        "xai_summary": xai_summary,
        "claude_3_haiku_summary": claude_3_haiku_summary,
        "claude_3_5_sonnet_summary": claude_3_5_sonnet_summary
    }
    print(f"Processed additional filing info for: {os.path.basename(pdf_path)}")
    return additional

def process_all_pdfs_additional(pdf_folder):
    """
    Processes all PDFs in the folder for additional filing info.
    Returns a dictionary keyed by file name.
    """
    results = {}
    pdf_files = glob.glob(os.path.join(pdf_folder, "*.pdf"))
    for pdf_file in pdf_files:
        print(pdf_file)
        print(datetime.now())
        file_key = os.path.splitext(os.path.basename(pdf_file))[0]
        results[file_key] = process_pdf_additional(pdf_file)
    return results

def additional_to_dataframe(results):
    """
    Converts the additional filing info dictionary into a DataFrame.
    """
    rows = []
    for file_key, info in results.items():
        row = {
            "SERFF Tr Num": info.get("serff_tr_num", ""),
            "Filing Type": info.get("filing_type", ""),
            "Date Submitted": info.get("date_submitted", ""),
            "Effective Date Requested (New)": info.get("effective_date_requested_new", ""),
            "Effective Date Requested (Renewal)": info.get("effective_date_requested_renewal", ""),
            "SERFF Status": info.get("serff_status", ""),
            "Filing Description": info.get("filing_description", ""),
            "Filing Method": info.get("filing_method", ""),
            "TOI": info.get("toi", ""),
            "Sub-TOI": info.get("sub_toi", ""),
            "State": info.get("state", ""),
            "Group_Code": info.get("group_code", ""),
            "Company_Codes": str(info.get("company_codes", "")),
            "week_date": info.get("download_week", None),
            "gpt_3_5_summary": info.get("gpt_3_5_summary", ""),
            "o1_mini_summary": info.get("o1_mini_summary", ""),
            "xai_summary": info.get("xai_summary", ""),
            "claude_3_haiku_summary": info.get("claude_3_haiku_summary", ""),
            "claude_3_5_sonnet_summary": info.get("claude_3_5_sonnet_summary", "")
        }
        rows.append(row)
    df = pd.DataFrame(rows, columns=[
        "SERFF Tr Num", "Filing Type", "Date Submitted", 
        "Effective Date Requested (New)", "Effective Date Requested (Renewal)",
        "SERFF Status", "Filing Description", "Filing Method", "TOI", "Sub-TOI", "State",
        "Group_Code", "Company_Codes", "week_date",
        "gpt_3_5_summary", "o1_mini_summary", "xai_summary",
        "claude_3_haiku_summary", "claude_3_5_sonnet_summary"
    ])
    return df

# --- DataFrame for objections ---
def results_to_dataframe_objections(results):
    """
    Converts the objections dictionary (from process_all_pdfs_in_folder) into a DataFrame.
    """
    rows = []
    for file_key, file_info in results.items():
        state_abbr = file_key.split('_')[0] if "_" in file_key else file_key[:2]
        group_code = file_info.get("group_code", "No objections")
        company_codes = file_info.get("company_codes", [])
        company_code_first = company_codes[0] if company_codes else "No objections"
        company_codes_str = str(company_codes) if company_codes else "No objections"
        download_week = file_info.get("download_week", None)
        filing_type = file_info.get("filing_type", "")
        toi = file_info.get("toi", "")
        sub_toi = file_info.get("sub_toi", "")
        letter_dict = file_info.get("objections", {})
        if not letter_dict:
            rows.append({
                "SERFF#": file_key,
                "State": state_abbr,
                "Filing Type": filing_type,
                "TOI": toi,
                "Sub-TOI": sub_toi,
                "Group_Code": group_code,
                "Company_Code": company_code_first,
                "Company_Code_all": company_codes_str,
                "Objection_letter_date": "No objections",
                "Objectionletter#": "No objections",
                "Objection#": "No objections",
                "Objection": "No objections",
                "download_week": download_week
            })
        else:
            for letter_key, letter_content in letter_dict.items():
                letter_date = letter_content.get("objection_letter_date", "No objections")
                for obj_key, obj_text in letter_content.items():
                    if obj_key == "objection_letter_date":
                        continue
                    rows.append({
                        "SERFF#": file_key,
                        "State": state_abbr,
                        "Filing Type": filing_type,
                        "TOI": toi,
                        "Sub-TOI": sub_toi,
                        "Group_Code": group_code,
                        "Company_Code": company_code_first,
                        "Company_Code_all": company_codes_str,
                        "Objection_letter_date": letter_date,
                        "Objectionletter#": letter_key,
                        "Objection#": obj_key,
                        "Objection": obj_text.replace("\n", " ").strip(),
                        "download_week": download_week
                    })
    df = pd.DataFrame(rows, columns=[
        "SERFF#", "State", "Filing Type", "TOI", "Sub-TOI",
        "Group_Code", "Company_Code", "Company_Code_all", 
        "Objection_letter_date", "Objectionletter#", "Objection#", "Objection", "download_week"
    ])
    return df

# --- Main Processing ---
print("Starting processing...")
pdf_folder = f"Filings/Final/{date}"  # Folder path based on date parameter

# Process objections using the old functions.
objection_results = process_all_pdfs_in_folder(pdf_folder)
json_output_path = f"objections_output_{date}.json"
with open(json_output_path, "w", encoding="utf-8") as f:
    json.dump(objection_results, f, default=lambda o: o.isoformat() if isinstance(o, datetime) else o, ensure_ascii=False, indent=4)
print(f"Saved objections JSON output to {json_output_path}")

df_objections = results_to_dataframe_objections(objection_results)
csv_output_path = f"objections_output_{date}.csv"
df_objections.to_csv(csv_output_path, index=False)
print(f"Saved objections CSV output to {csv_output_path}")

# Process additional filing info using the new function.
additional_results = process_all_pdfs_additional(pdf_folder)
additional_json_output_path = f"additional_filing_info_{date}.json"
with open(additional_json_output_path, "w", encoding="utf-8") as f:
    json.dump(additional_results, f, default=lambda o: o.isoformat() if isinstance(o, datetime) else o, ensure_ascii=False, indent=4)
print(f"Saved additional filing info JSON output to {additional_json_output_path}")

df_additional = additional_to_dataframe(additional_results)
additional_csv_output_path = f"additional_filing_info_{date}.csv"
df_additional.to_csv(additional_csv_output_path, index=False)
print(f"Saved additional filing info CSV output to {additional_csv_output_path}")
# Out:
# Starting processing...
# Filings/Final/2025-03-10\AZ_HART-134440906.pdf
# 2025-03-13 07:25:37.910550
# Filings/Final/2025-03-10\AZ_HART-134440946.pdf
# 2025-03-13 07:25:38.196223
# Filings/Final/2025-03-10\AZ_TRVD-G134444542.pdf
# 2025-03-13 07:25:38.783062
# Filings/Final/2025-03-10\AZ_TRVD-G134444680.pdf
# 2025-03-13 07:25:39.045037
# Filings/Final/2025-03-10\CA_LBRM-134354159.pdf
# 2025-03-13 07:25:39.212056
# Filings/Final/2025-03-10\CA_LBRM-134354250.pdf
# 2025-03-13 07:25:40.595245
# Filings/Final/2025-03-10\CO_GMMX-134450913.pdf
# 2025-03-13 07:25:41.267487
# Filings/Final/2025-03-10\CO_LBPM-134412448.pdf
# 2025-03-13 07:25:41.370773
# Filings/Final/2025-03-10\District_TRVD-G134382426.pdf
# 2025-03-13 07:25:41.677222
# Filings/Final/2025-03-10\District_TRVD-G134382657.pdf
# 2025-03-13 07:25:43.161633
# Filings/Final/2025-03-10\District_TRVD-G134382695.pdf
# 2025-03-13 07:25:44.263639
# Filings/Final/2025-03-10\GA_ALSE-134337450.pdf
# 2025-03-13 07:25:45.258423
# Filings/Final/2025-03-10\GA_HART-134414600.pdf
# 2025-03-13 07:25:47.029391
# Filings/Final/2025-03-10\GA_LBPM-134447081.pdf
# 2025-03-13 07:25:47.108028
# Filings/Final/2025-03-10\GA_LBPM-134447335.pdf
# 2025-03-13 07:25:47.191977
# Filings/Final/2025-03-10\GA_LBPM-134449473.pdf
# 2025-03-13 07:25:47.303250
# Filings/Final/2025-03-10\GA_SFMA-134413084.pdf
# 2025-03-13 07:25:47.406229
# Filings/Final/2025-03-10\GA_TRVD-G134360540.pdf
# 2025-03-13 07:25:47.978545
# Filings/Final/2025-03-10\GA_TRVD-G134400530.pdf
# 2025-03-13 07:25:48.367793
# Filings/Final/2025-03-10\ID_LBPM-134449496.pdf
# 2025-03-13 07:25:48.781469
# Filings/Final/2025-03-10\IL_ALSE-134437284.pdf
# 2025-03-13 07:25:48.906189
# Filings/Final/2025-03-10\IL_SFMA-134413708.pdf
# 2025-03-13 07:25:48.947514
# Filings/Final/2025-03-10\KS_GMMX-134433936.pdf
# 2025-03-13 07:25:49.021829
# Filings/Final/2025-03-10\KS_SFMA-134449763.pdf
# 2025-03-13 07:25:49.159796
# Filings/Final/2025-03-10\KS_TRVD-G134448245.pdf
# 2025-03-13 07:25:49.238979
# Filings/Final/2025-03-10\ME_TRVD-G134422686.pdf
# 2025-03-13 07:25:49.758934
# Filings/Final/2025-03-10\MI_ALSE-134422885.pdf
# 2025-03-13 07:25:49.800929
# Filings/Final/2025-03-10\MI_ALSE-134443416.pdf
# 2025-03-13 07:25:50.195401
# Filings/Final/2025-03-10\MI_ALSE-134445641.pdf
# 2025-03-13 07:26:03.468008
# Filings/Final/2025-03-10\MI_AMSI-134336870.pdf
# 2025-03-13 07:26:03.494575
# Filings/Final/2025-03-10\MI_HART-134433875.pdf
# 2025-03-13 07:26:04.145008
# Filings/Final/2025-03-10\MI_HART-134433892.pdf
# 2025-03-13 07:26:04.473244
# Filings/Final/2025-03-10\MI_LBPM-134437577.pdf
# 2025-03-13 07:26:04.729323
# Filings/Final/2025-03-10\MI_TRVD-G134446450.pdf
# 2025-03-13 07:26:04.838289
# Filings/Final/2025-03-10\MN_SFMA-134414598.pdf
# 2025-03-13 07:26:05.228487
# Filings/Final/2025-03-10\MO_USAA-134449959.pdf
# 2025-03-13 07:26:06.209668
# Filings/Final/2025-03-10\NC_ALSE-134449660.pdf
# 2025-03-13 07:26:06.271773
# Filings/Final/2025-03-10\NC_USAA-134418343.pdf
# 2025-03-13 07:26:06.419926
# Filings/Final/2025-03-10\NC_USAA-134418345.pdf
# 2025-03-13 07:26:06.614826
# Filings/Final/2025-03-10\NC_USAA-134418351.pdf
# 2025-03-13 07:26:06.800005
# Filings/Final/2025-03-10\NC_USAA-134418355.pdf
# 2025-03-13 07:26:07.088239
# Filings/Final/2025-03-10\ND_GMMX-134414147.pdf
# 2025-03-13 07:26:07.303686
# Filings/Final/2025-03-10\ND_GMMX-134414190.pdf
# 2025-03-13 07:26:07.383010
# Filings/Final/2025-03-10\ND_GMMX-134414199.pdf
# 2025-03-13 07:26:07.454396
# Filings/Final/2025-03-10\NE_GMMX-134443628.pdf
# 2025-03-13 07:26:07.516643
# Filings/Final/2025-03-10\NJ_AMSI-134443262.pdf
# 2025-03-13 07:26:08.664398
# Filings/Final/2025-03-10\NJ_LBPM-134367579.pdf
# 2025-03-13 07:26:08.792592
# Filings/Final/2025-03-10\NJ_LEMO-134389427.pdf
# 2025-03-13 07:26:09.013348
# Filings/Final/2025-03-10\NV_HART-134384733.pdf
# 2025-03-13 07:26:09.069941
# Filings/Final/2025-03-10\OK_AMSI-134369860.pdf
# 2025-03-13 07:26:09.148587
# Filings/Final/2025-03-10\OR_AMSI-134435230.pdf
# 2025-03-13 07:26:09.531565
# Filings/Final/2025-03-10\OR_AMSI-134435390.pdf
# 2025-03-13 07:26:09.654200
# Filings/Final/2025-03-10\OR_HART-134431622.pdf
# 2025-03-13 07:26:09.728337
# Filings/Final/2025-03-10\OR_LEMO-134373821.pdf
# 2025-03-13 07:26:09.777144
# Filings/Final/2025-03-10\PA_LEMO-134412814.pdf
# 2025-03-13 07:26:10.459825
# Filings/Final/2025-03-10\SC_LBPM-134400516.pdf
# 2025-03-13 07:26:10.635281
# Filings/Final/2025-03-10\SC_LBPM-134401992.pdf
# 2025-03-13 07:26:10.944964
# Filings/Final/2025-03-10\SC_LBPM-134406290.pdf
# 2025-03-13 07:26:11.225791
# Filings/Final/2025-03-10\TN_ALSE-134450014.pdf
# 2025-03-13 07:26:11.549229
# Filings/Final/2025-03-10\TX_HART-134398746.pdf
# 2025-03-13 07:26:11.883676
# Filings/Final/2025-03-10\TX_HART-134405817.pdf
# 2025-03-13 07:26:12.077172
# Filings/Final/2025-03-10\TX_HART-134407174.pdf
# 2025-03-13 07:26:12.186568
# Filings/Final/2025-03-10\TX_HART-134429816.pdf
# 2025-03-13 07:26:12.300699
# Filings/Final/2025-03-10\TX_SFMA-134410201.pdf
# 2025-03-13 07:26:12.626212
# Filings/Final/2025-03-10\TX_SFMA-134410218.pdf
# 2025-03-13 07:26:12.751352
# Filings/Final/2025-03-10\TX_SFMA-134447409.pdf
# 2025-03-13 07:26:13.027471
# Filings/Final/2025-03-10\TX_USAA-134443395.pdf
# 2025-03-13 07:26:13.063549
# Filings/Final/2025-03-10\TX_USAA-134443396.pdf
# 2025-03-13 07:26:14.006338
# Filings/Final/2025-03-10\VA_AMSI-134375543.pdf
# 2025-03-13 07:26:14.068589
# Filings/Final/2025-03-10\VA_LEMO-134441439.pdf
# 2025-03-13 07:26:14.136724
# Filings/Final/2025-03-10\WA_LBPM-134447017.pdf
# 2025-03-13 07:26:14.217612
# Filings/Final/2025-03-10\WI_AMSI-133860671.pdf
# 2025-03-13 07:26:15.459228
# Filings/Final/2025-03-10\WI_LBPM-134430805.pdf
# 2025-03-13 07:26:16.298701
# Filings/Final/2025-03-10\WI_LEMO-134385206.pdf
# 2025-03-13 07:26:17.038736
# Filings/Final/2025-03-10\WI_SFMA-134421547.pdf
# 2025-03-13 07:26:17.828161
# Filings/Final/2025-03-10\WV_AMSI-134244221.pdf
# 2025-03-13 07:26:18.110262
# Saved objections JSON output to objections_output_2025-03-10.json
# Saved objections CSV output to objections_output_2025-03-10.csv
# Filings/Final/2025-03-10\AZ_HART-134440906.pdf
# 2025-03-13 07:26:19.145753
# Token count for API call in AZ_HART-134440906.pdf: 32521
# GPT-3.5 Summary: Based on the provided filing information of the Hartford Insurance Company of the Southeast for their AZ Home Prevail Condo product in Arizona, here is a summary of the rate filing:
#
# 1. **Company Details:**
#    - **Filing Company:** Hartford Insurance Company of the Southeast
#    - **Product:** AZ Home Prevail Condo- HICSE
#    - **State:** Arizona
#    - **Type of Insurance:** Homeowners (HO) - Condominium Homeowners
#    - **Filing Type:** Rate
#
# 2. **Filing Overview:**
#    - Proposed revisions for The Hartford’s Home product effective April 3, 2025, for New Business and May 24, 2025, for Renewal Business.
#    - Updates to Condo Forms with an overall impact of a proposed 19.9% change.
#    - Adjustments to base rates included in the review.
#
# 3. **Rate Information:**
#    - **Filing Method:** File and Use
#    - **Overall Percentage of Last Rate Revision:** 11.9%
#    - **Effective Date of Last Rate Revision:** 05/02/2024
#    - **Current Rate Impact:** 19.9% overall rate change
#    - **Written Premium Change:** $133,365
#    - **Number of Policyholders Affected:** 1,135
#    - **Written Premium for this Program:** $670,177
#
# 4. **Correspondence Summary:
# Claude-3 Haiku Summary: Based on the information provided, here is a summary of the key points in the rate filing:
#
# 1. Overview:
#    - The filing is for revisions to The Hartford's Home product in the Hartford Insurance Company of the Southeast writing company in Arizona.
#    - The changes will be effective April 3, 2025 for new business and May 24, 2025 for renewal business.
#    - The overall impact of the proposed changes to Condo Forms is 19.9%.
#    - Base rates are being adjusted with this review.
#
# 2. Indicated Rate Level Change:
#    - The indicated rate level change for the Condo Forms is 59.8%.
#    - However, the selected rate change is 19.9%.
#    - The filing explains that the company will take steps to address the possibility of inadequate rates, as required by Arizona statute.
#
# 3. Key Exhibits:
#    - Exhibit 2 provides the detailed calculation of the indicated rate level change, including the projected loss ratio, expenses, and profit provision.
#    - Exhibit 3 shows the projected loss ratio analysis, using historical data, loss development factors, and trend factors.
#    - Exhibit 4 and Exhibit 5 detail the selection of frequency, severity, and premium trends.
#    - Exhibit 6 outlines the application of the historical and prospective trends.
#    - Exhibit 7 provides the loss development factors used in the analysis.
#
# 4. Regulatory Requirements:
#    - The filing acknowledges that Arizona is a "use and file" state, and the Department may reengage with the filer if the rates are found to not comply with state law.
#    - The filing includes the required certifications and checklists for homeowners rate and rule filings in Arizona.
#
# In summary, this is a rate filing for revisions to The Hartford's Condo Forms in Arizona, with an indicated rate change of 59.8% but a selected rate change of 19.9%, and the company's explanation for addressing the possibility of inadequate rates.
# Processed additional filing info for: AZ_HART-134440906.pdf
# Filings/Final/2025-03-10\AZ_HART-134440946.pdf
# 2025-03-13 07:26:28.407426
# Token count for API call in AZ_HART-134440946.pdf: 32956
# GPT-3.5 Summary: The rate filing is for the Hartford Insurance Company of the Southeast's Homeowners insurance product in Arizona, specifically for the AZ Home Prevail Building. The proposed revisions will take effect on April 3, 2025, for new business, and on May 24, 2025, for renewal business. The overall impact of the proposed rate changes to Building Forms is 20.0%, with base rates being adjusted as part of the review.
#
# The rate change type is an increase, with an overall percentage change of 12.4% compared to the last rate revision as of May 2, 2024. The filing method is "File and Use," and the SERFF Tracking Number for the filing is HART-134440946.
#
# The rate filing includes adjustments to Building Forms and updates to Condo Forms separately, affecting Owner Occupied Homeowners policies. The filing involves various departments' personnel, and the effective date requested for the new rates is April 3, 2025.
#
# If you need more specific details or further analysis, feel free to ask.
# Claude-3 Haiku Summary: Based on the information provided, this appears to be a rate filing by Hartford Insurance Company of the Southeast for their homeowners (HO) insurance product in Arizona. The key details are:
#
# - The overall indicated rate level change is 67.0%, but the company is implementing a 20.0% rate increase.
#
# - The rate changes will be effective April 3, 2025 for new business and May 24, 2025 for renewal business.
#
# - The filing includes updates to the building forms, while the condo forms are being filed separately.
#
# - The key exhibits include:
#     - Indicated Rate Level Change calculation
#     - Projected Loss Ratio analysis
#     - Loss cost trend selections
#     - Premium trend selections
#     - Loss development factors
#     - Catastrophe load, non-cat hail/wildfire load, and expense provisions
#
# - The filing appears to be in response to an objection letter from the Arizona Department of Insurance, which asked the company to explain steps being taken to address the 67% indicated rate need while only implementing a 20% increase.
#
# In summary, this is a comprehensive rate filing by Hartford to update their homeowners rates in Arizona, including responding to a regulatory inquiry around the divergence between the indicated and implemented rate changes.
# Processed additional filing info for: AZ_HART-134440946.pdf
# Filings/Final/2025-03-10\AZ_TRVD-G134444542.pdf
# 2025-03-13 07:26:35.700507
# Token count for API call in AZ_TRVD-G134444542.pdf: 9533
# GPT-3.5 Summary: The rate filing submitted by The Automobile Insurance Company of Hartford, Connecticut, The Standard Fire Insurance Company, and The Travelers Indemnity Company of America pertains to the Legacy Homeowners product in the state of Arizona. The filing date was 03/04/2025 with a disposition date of 03/06/2025. The filing type was a Rule amendment specifically focusing on the Loss Assessment Coverage under Rule 511.
#
# The changes in the filing were detailed in an Explanatory Memorandum and included revisions to the eligibility requirements for Loss Assessment Coverage. The revision applies to renewal business issued on or after 4/13/2025, with an effective date of 6/2/2025. The amendment was made by The Automobile Insurance Company of Hartford, Connecticut, The Standard Fire Insurance Company, and The Travelers Indemnity Company of America, impacting their Arizona Homeowners product.
#
# The filing did not have any overall rate impact, as confirmed in the filing documentation. The justification for the rate changes, along with compliance with Arizona laws and requirements, was outlined to demonstrate that the rates are not excessive, inadequate, or unfairly discriminatory. The filing also included necessary supporting documents and disclosures, as per Arizona regulations.
#
# The Amendments will be made to the Rule 511, Loss Assessment Coverage, including changes to the eligibility criteria and coverage descriptions for assessment related to the residence premises, excluding assessments due to earthquakes. The revised policy will now offer options for increased limits with corresponding premiums
# Claude-3 Haiku Summary: Based on the information provided, this is a rate/rule filing for the Travelers Insurance group's homeowners program in Arizona. The key points are:
#
# 1. The filing is revising Rule 511: Loss Assessment Coverage.
#
# 2. The changes are to the eligibility requirements for the Loss Assessment Coverage limit. Specifically, the changes state that after new business issuance, the Loss Assessment limit may only be increased effective upon renewal.
#
# 3. There is no rate impact associated with this change.
#
# 4. The changes apply to renewal business issued on or after 4/13/2025 and effective on or after 6/2/2025.
#
# In summary, this is a rule filing to revise the eligibility requirements for the Loss Assessment Coverage limit, with no rate impact. The changes are being made to the Travelers Insurance group's homeowners program in Arizona.
# Processed additional filing info for: AZ_TRVD-G134444542.pdf
# Filings/Final/2025-03-10\AZ_TRVD-G134444680.pdf
# 2025-03-13 07:26:41.500854
# Token count for API call in AZ_TRVD-G134444680.pdf: 10206
# GPT-3.5 Summary: The rate filing submitted by The Travelers Home and Marine Insurance Company and Travelers Commercial Insurance Company for their Quantum Homeowners product in Arizona includes revisions to two key rules: Rule 511 for Loss Assessment Coverage and Rule 535 for Enhanced Home Package. The revisions focus on eligibility requirements for both coverages with no associated rate impact. The changes are applicable to renewal business issued on or after 4/13/2025 and effective beginning 6/2/2025. The purpose of the filing is to update and enhance the coverage offerings for Quantum Homeowners policies in compliance with Arizona insurance laws and regulations.
# Claude-3 Haiku Summary: Based on the information provided, this appears to be a rate/rule filing by The Travelers Home and Marine Insurance Company and Travelers Commercial Insurance Company for their Quantum Homeowners product in Arizona. The key points are:
#
# 1. The filing is revising two rules:
#
# - Rule 511 - Loss Assessment Coverage
# - Rule 535 - Enhanced Home Package
#
# 2. The revisions pertain to the eligibility requirements for these coverages/endorsements. There is no rate impact associated with these changes.
#
# 3. The changes apply to renewal business issued on or after 4/13/2025 and effective on or after 6/2/2025.
#
# 4. The filing does not include any rate changes, only revisions to the rules governing the Loss Assessment Coverage and Enhanced Home Package endorsements.
#
# 5. The purpose of the filing appears to be updating the eligibility requirements for these optional coverages, without changing the underlying rates.
#
# In summary, this is a rule filing to modify the underwriting eligibility for two optional homeowners endorsements, with no rate impact. The changes will apply to renewal business going forward.
# Processed additional filing info for: AZ_TRVD-G134444680.pdf
# Filings/Final/2025-03-10\CA_LBRM-134354159.pdf
# 2025-03-13 07:26:48.301372
# Token count for API call in CA_LBRM-134354159.pdf: 49975
# GPT-3.5 Summary: Based on the filing information provided, the First National Insurance Company of America has submitted a withdrawal filing for its Legacy Homeowners Product to the California Department of Insurance. The withdrawal is effective from January 1, 2026. The company has stated that it will discontinue offering this product in the state of California and will not renew any policies from the withdrawn program into any similar programs offered by the same insurer group in California. In addition, the company has agreed not to file a replacement program for at least three years after the effective date of the withdrawal.
#
# The filing includes various exhibits such as the Prior Approval Rate Application, Exhibit 1 Filing History, Withdrawal Letter, and Non-Renewal Notice. The filing contact information is provided for Christine Ray, and the company details include its address, phone number, and other relevant identification information.
#
# In response to objection letters and correspondence from Yizun Chen, various adjustments have been made to the filing to address concerns and clarify information related to the withdrawal of the Legacy Homeowners Product.
# Christine Ray has responded to these objections and has provided explanations for the decisions taken by the company.
#
# The Rate/Rule Schedule and Optional Coverages sections of the filing outline the various coverage options, policy limits, and rates associated with the Homeowners Product. These details highlight the coverage options available to customers and the premium adjustments for specific coverage enhancements.
#
# Overall, the filing indicates a comprehensive approach by the First National Insurance Company of America in managing the withdrawal of its
# Claude-3 Haiku Summary: Based on the information provided, here is a summary of the key points from the rate filing:
#
# 1. First National Insurance Company of America is submitting a withdrawal filing for its Legacy Homeowners Product in California, effective 01/01/2026.
#
# 2. The company will no longer be offering this product in California and has agreed to the following terms:
# - It will not renew any policies from the withdrawn Legacy Homeowners program into any similar programs offered by the same insurer group in California.
# - It will not file a replacement program for at least three years after the effective date of the withdrawal.
#
# 3. The filing includes exhibits such as the prior approval rate application, filing history, withdrawal notice, and non-renewal notices.
#
# 4. The rate data does not apply to this filing, as it is a withdrawal filing and not a rate change.
#
# 5. The filing was reviewed and acknowledged by the state regulator. No rate revisions were made as part of this withdrawal filing.
#
# In summary, this is a withdrawal filing where the insurance company is exiting a specific homeowners product in California and has agreed to certain terms around non-renewal and no replacement filings for a period of time.
# Processed additional filing info for: CA_LBRM-134354159.pdf
# Filings/Final/2025-03-10\CA_LBRM-134354250.pdf
# 2025-03-13 07:26:57.071401
# Token count for API call in CA_LBRM-134354250.pdf: 52617
# GPT-3.5 Summary: From the provided filing, we can gather that the General Insurance Company of America, part of Liberty Mutual Group, has submitted a withdrawal filing for its Essential Homeowners Product in the state of California. The withdrawal is in accordance with the California Department of Insurance regulations, indicating a strategic decision to simplify and focus on core products.
#
# Key Details of the Filing:
# - Company: General Insurance Company of America (part of Liberty Mutual Group)
# - Product Name: Homeowners
# - State: California
# - Filing Type: Rate/Rule/Form
# - Filing Date: 12/17/2024
# - Effective Date Requested: 01/01/2026
# - SERFF Tracking #: LBRM-134354250
# - Status: Acknowledged
# - Disposition Date: 03/06/2025
#
# The filing includes various supporting documents such as the Product Guide, Prior Approval Rate Application, Exhibit 1, Non-Renewal Letter, and Withdrawal Notice. The company has committed not to renew policies from the withdrawn program into similar ones for at least three years after the effective date of the withdrawal.
#
# Additionally, objections and responses have been exchanged between the reviewer and the filer regarding various aspects of the filing. These include clarification requests, objections related to non-renewal justifications, deemer provisions, and program name updates, which have been addressed by the filer.
#
# The filing also includes Rate/Rule Schedules, Correspondence Summaries, and
# Claude-3 Haiku Summary: Based on the information provided in the filing, it appears that General Insurance Company of America (GICA) is submitting a withdrawal filing for its Essential Homeowners (H3) product in California. The key points are:
#
# 1. GICA is withdrawing the Essential Homeowners (H3) product and will no longer offer it in California. This is part of their strategy to simplify and focus their homeowner product investments.
#
# 2. GICA has already submitted updated rate indications reflecting the policy impacts of withdrawing this product in their pending rate filing (SERFF # LBRM-134133915).
#
# 3. As part of the withdrawal, GICA has agreed to the following terms:
#    a. After 01/01/2026, GICA will not renew any policies from the withdrawn Essential Homeowners (H3) program into any similar programs offered by the same insurer group in California.
#    b. GICA will not file a replacement program for at least three years after the effective date of the withdrawal of the Essential Homeowners (H3) program.
#
# 4. The filing includes the following exhibits:
#    - Prior Approval Rate Application
#    - Exhibit 1 - Filing History
#    - Withdrawal Letter
#    - Non-renewal Notice
#
# 5. The withdrawal is effective 01/01/2026 for both new and renewal business.
#
# In summary, this is a withdrawal filing for GICA's Essential Homeowners (H3) product in California, with the company agreeing to certain restrictions around renewing and replacing the withdrawn product.
# Processed additional filing info for: CA_LBRM-134354250.pdf
# Filings/Final/2025-03-10\CO_GMMX-134450913.pdf
# 2025-03-13 07:27:06.978613
# Token count for API call in CO_GMMX-134450913.pdf: 9971
# GPT-3.5 Summary: Based on the information provided from the filing with the DOI, the insurance company Encompass Insurance Company submitted a rate filing for a new product related to homeowners, condo, renters, and landlord insurance policies in Colorado. The product name is labeled as CO_Encompass_Insurance_Co_C360_PROP_Implemetation. The filing includes summaries of coverage for each type of policy mentioned above.
#
# The rate filing details the coverage options provided by Encompass Insurance Company for each type of policy, including coverage for dwelling, personal property, other structures, loss of use/additional living expenses, personal liability, and medical payments to others. The filing also outlines general exclusions and reasons for cancellation, nonrenewal, or an increase in premium for each type of policy.
#
# Encompass Insurance Company emphasizes the importance of conducting an annual review of property coverage to ensure policyholders are adequately insured, especially in Colorado where there is potential for large losses due to various natural disasters. Additionally, the company advises policyholders to maintain a copy of their policy documents in a safe and secure location away from their property.
#
# Overall, the rate filing provides a comprehensive overview of the coverage options and considerations for homeowners, condo, renters, and landlord insurance policies offered by Encompass Insurance Company in Colorado.
# Claude-3 Haiku Summary: Based on the information provided, this appears to be a form filing rather than a rate filing. The key points are:
#
# 1. This is a filing by Encompass Insurance Company for their new product in Colorado - "CO_Encompass_Insurance_Co_C360_PROP_Implemetation".
#
# 2. The filing includes the summary of coverage forms for different types of homeowner/condominium/renter/landlord policies. These are disclosure forms that summarize the key coverages, exclusions, and policy provisions.
#
# 3. It is a form filing under the Homeowners TOI/Sub-TOI, so it does not include any rate/premium information.
#
# 4. The filing was submitted on 3/7/2025, reviewed, and closed as "Filed" on the same date by the Colorado DOI.
#
# 5. There are no details provided about any rate changes or factors affecting premiums. The filing appears to be focused on introducing the new policy forms rather than making any rate changes.
#
# In summary, this is a form filing to introduce new homeowner, condominium, renter, and landlord policy summary disclosure forms. It does not contain any rate or premium information.
# Processed additional filing info for: CO_GMMX-134450913.pdf
# Filings/Final/2025-03-10\CO_LBPM-134412448.pdf
# 2025-03-13 07:27:30.419301
# Token count for API call in CO_LBPM-134412448.pdf: 22981
# GPT-3.5 Summary: The rate filing involves two insurance companies, Safeco Insurance Company of America and American Economy Insurance Company, proposing updates for their Dwelling and Condominium products in Colorado. Here is a summary of the rate filing:
#
# 1. **Companies Involved:** Safeco Insurance Company of America and American Economy Insurance Company
# 2. **Product Name:** Homeowners
# 3. **State:** Colorado
# 4. **Type of Filing:** Rate
# 5. **Date Submitted:** 02/14/2025
# 6. **Effective Date Requested:** 04/14/2025 for New Business and 05/31/2025 for Renewal Business
# 7. **Impact of Update:**
#     - Safeco Insurance Company of America: Home - 13%, Condo - 35.9%
#     - American Economy Insurance Company: Condo - 36.0%
# 8. **Overall Rate Impact for Multiple Company Filings:** 19.6%
# 9. **Reviewers:** Allen Ames, Amanda Scott, Ken Neider
# 10. **Disposition Date:** 03/03/2025
# 11. **Disposition Status:** Filed
#
# Both companies have proposed changes to their base rates, package relativities, roof age factors, loss assessment coverages, and other components of their Dwelling and Condominium products in the state of Colorado. The filings contain detailed rate tables, loss assessment coverage levels, and rate adjustment calculations.
#
# For additional detailed information or specific exhibit data,
# Claude-3 Haiku Summary: Based on the filing, the key points are:
#
# 1. Safeco Insurance Company of America and American Economy Insurance Company are proposing updates to their Dwelling and Condominium products in Colorado, effective April 14, 2025 for new business and May 31, 2025 for renewal business.
#
# 2. The overall rate impact is 15.2%, with Safeco having a 13.5% rate impact and American Economy having a 36.0% rate impact.
#
# 3. Safeco is updating the following for their home product: base rates, package unities, and roof age. For their condo product, they are updating base rates and loss assessment.
#
# 4. American Economy is updating base rates, coverage A base, and loss assessment for their condo product.
#
# 5. The filing includes supporting documentation such as rate/rule forms, actuarial justification memos, and historical rate change information.
#
# 6. The companies are using generalized linear models (GLMs) in their rating, and have provided references to prior SERFF filings containing the GLM details.
#
# 7. The filing was reviewed and approved by the Colorado Department of Insurance on March 3, 2025.
#
# In summary, this is a comprehensive rate filing by two insurance companies to update their homeowners and condominium rates in the Colorado market, with detailed supporting information provided.
# Processed additional filing info for: CO_LBPM-134412448.pdf
# Filings/Final/2025-03-10\District_TRVD-G134382426.pdf
# 2025-03-13 07:27:38.858264
# Token count for API call in District_TRVD-G134382426.pdf: 180824
# GPT-3.5 Summary: Based on the provided information, the rate filing appears to be related to a Personal Liability Umbrella Supplement for the insurance company, covering damages for which an insured becomes legally liable due to bodily injury, property damage, or personal injury caused by an occurrence. The supplement includes definitions for terms like "asbestos," "auto," "bodily injury," "business," "declarations," and "electronic vandalism," among others.
#
# The rate filing involves a fuel system definition, restrictions on coverage for certain types of animals, and exclusions related to electronic vandalism, lead, and damage caused by intentional acts. It also specifies conditions for cancellation, limits of liability, and the applicability of the supplement to different scenarios. Additionally, it provides definitions for terms such as "family member," "fuel system," and "fungi."
#
# The rate filing text includes detailed information on the coverage, definitions, conditions, and exclusions that apply to the Personal Liability Umbrella Supplement offered by the insurance company. It outlines the scope of coverage, limits of liability, definitions of key terms, and how the policy applies to various situations.
# Claude-3 Haiku Summary: Based on the information provided, this appears to be a filing by The Standard Fire Insurance Company, The Automobile Insurance Company of Hartford, Connecticut, and The Travelers Indemnity Company of America for revisions to forms related to their Legacy Home and Legacy HVH homeowners insurance products in the District of Columbia.
#
# The key details are:
#
# 1. The filing is for form revisions, not rate changes. The filing indicates "If there is rating impact, please submit a separate rate filing" and the rate information shows 0% overall rate impact.
#
# 2. The forms being revised include:
# - SPECIAL PROVISIONS - DISTRICT OF COLUMBIA (HA-300 DC)
# - PERSONAL INJURY (HO-82)
# - SPECIAL PROVISIONS - DISTRICT OF COLUMBIA (HV 01 08)
# - PERSONAL LIABILITY UMBRELLA SUPPLEMENT (58200)
#
# 3. The revisions appear to update these forms with changes such as:
# - Definitions for terms like "electronic vandalism" and "fuel system"
# - Modifications to exclusions and coverage provisions
# - Updates to cancellation and other policy conditions
#
# 4. The filing was submitted on 1/17/2025, reviewed by the regulator, and ultimately approved on 3/6/2025 with an effective date of 7/7/2025.
#
# In summary, this appears to be a routine form revision filing by these insurance companies to update their homeowners insurance policies sold in the District of Columbia, without any significant rate impact.
# Processed additional filing info for: District_TRVD-G134382426.pdf
# Filings/Final/2025-03-10\District_TRVD-G134382657.pdf
# 2025-03-13 07:28:10.094622
# Token count for API call in District_TRVD-G134382657.pdf: 126544
# GPT-3.5 Summary: Based on the details provided in the filing with a DOI from Travelers Personal Insurance Company for their product Quantum Home 2.0 in the District of Columbia, the rate filing involves revisions and updates to various forms and endorsements related to Homeowners insurance coverage. Here are the key points:
#
# 1. **Product Name:** Quantum Home 2.0
# 2. **State:** District of Columbia
# 3. **TOI/Sub-TOI:** 04.0 Homeowners/04.0000 Homeowners Sub-TOI Combinations
# 4. **Filing Type:** Form
# 5. **Effective Date:** Requested for 05/18/2025 for new policies and 07/07/2025 for renewals
# 6. **Products revised and approved include:**
#     - Special Provisions - District of Columbia
#     - Special Personal Property Coverage
#     - Permitted Incidental Occupancies Coverage Residence Premises
#     - Personal Injury Coverage
#     - Personal Property Replacement Cost Loss Settlement
#     - Identity Fraud Expense Reimbursement Coverage
#     - Trust Coverage
#     - Equipment Breakdown Coverage
#     - Personal Liability Umbrella Supplement
# 7. **Disposition:** Approved
# 8. **Additional Coverages:** Personal Injury Coverage, Loss Assessment
#
# This rate filing involves approval and revision of various forms and coverages within the Quantum Home 2.0 product for Homeowners insurance in the District of Columbia, enhancing coverage options and updating policy terms and conditions to align with regulatory
# Claude-3 Haiku Summary: Based on the filing, this appears to be a form filing by Travelers Personal Insurance Company for revisions to their Quantum Home 2.0 product in the District of Columbia. The key points from the filing are:
#
# 1. The filing includes revisions to various policy forms, including:
#    - Special Provisions - District of Columbia (HQ-300 DC)
#    - Special Personal Property Coverage (HQ-015 CW)
#    - Permitted Incidental Occupancies Coverage Residence Premises (HQ-042 CW)
#    - Personal Injury Coverage (HQ-082 CW)
#    - Personal Property Replacement Cost Loss Settlement (HQ-290 CW)
#    - Identity Fraud Expense Reimbursement Coverage (HQ-455 CW)
#    - Trust Coverage (HQ-615 CW)
#    - Equipment Breakdown Coverage (HQ-855 CW)
#    - Personal Liability Umbrella Supplement (HQ-01P CW)
#
# 2. The filing does not include any rate or rule changes, only form revisions. If there is any rating impact from the form changes, the company is instructed to submit a separate rate filing.
#
# 3. The filing was approved by the District of Columbia Department of Insurance, effective May 18, 2025 for new business and July 7, 2025 for renewals.
#
# In summary, this appears to be a routine form filing by Travelers to update various policy forms for their Quantum Home 2.0 product in the District of Columbia, without any associated rate changes.
# Processed additional filing info for: District_TRVD-G134382657.pdf
# Filings/Final/2025-03-10\District_TRVD-G134382695.pdf
# 2025-03-13 07:28:19.833361
# Token count for API call in District_TRVD-G134382695.pdf: 151123
# GPT-3.5 Summary: The rate filing for the insurance company in question involves revisions and updates to various forms and endorsements related to homeowners insurance and personal liability umbrella supplement in the District of Columbia. The product covered by this filing is the Quantum Homeowners & Quantum HVH.
#
# Key details from the filing:
# - Companies involved: The Travelers Home and Marine Insurance Company and Travelers Personal Security Insurance Company.
# - State: District of Columbia
# - Type of Insurance: Homeowners insurance and Personal Liability Umbrella Supplement
# - Product Name: Quantum Homeowners & Quantum HVH
# - Filing Type: Form
# - Date Submitted: 01/17/2025
# - SERFF Tracking Number: TRVD-G134382695
# - Status: Closed-APPROVED
# - Disposition Date: 03/06/2025
# - Effective Date Requested: 07/07/2025
# - Overall Percentage Rate Impact: 0.000%
# - Rate Data: Rate data does NOT apply to filing
#
# The filing includes revisions to various forms such as SPECIAL PROVISIONS - DISTRICT OF COLUMBIA, PERSONAL INJURY, ENHANCED HOME PACKAGE forms, and PERSONAL LIABILITY UMBRELLA SUPPLEMENT. The forms have been updated with new edition dates to reflect changes and enhancements. The filing has been approved for these changes.
# Claude-3 Haiku Summary: Based on the filing, this appears to be a form filing by The Travelers Home and Marine Insurance Company and Travelers Personal Security Insurance Company for their Quantum Homeowners & Quantum HVH products in the District of Columbia.
#
# The key points are:
#
# - The filing includes revisions to several forms, including:
#   - SPECIAL PROVISIONS - DISTRICT OF COLUMBIA (HO-300 DC and HV-300 DC)
#   - PERSONAL INJURY (HO-82)
#   - ENHANCED HOME PACKAGE forms (HO-4, HO-2/HO-3, HO-6)
#   - PERSONAL LIABILITY UMBRELLA SUPPLEMENT (58200)
#
# - The changes appear to be primarily updates and revisions to these existing forms, with no indication of any rate or rule changes.
#
# - The filing was approved effective 7/7/2025, with no rate impact noted.
#
# - The filing also includes an Explanatory Memorandum providing additional details on the form revisions.
#
# In summary, this appears to be a routine form filing by Travelers to update their homeowners and umbrella forms for the District of Columbia market, with no significant rate or product changes indicated.
# Processed additional filing info for: District_TRVD-G134382695.pdf
# Filings/Final/2025-03-10\GA_ALSE-134337450.pdf
# 2025-03-13 07:28:46.309547
# Token count for API call in GA_ALSE-134337450.pdf: 1194682
# GPT-3.5 Summary: Based on the provided filing, Allstate Vehicle and Property Insurance Company is introducing a Fortified Home Discount to its AVPIC HO program for owner-occupied homeowners in the state of Georgia. The filing includes changes that will apply to new business written on or after 6/16/2025 and for renewals effective on or after 7/31/2025.
#
# Here are some key details from the filing:
#
# 1. **Product Information**:
#    - Product Name: AVPIC HO
#    - State: Georgia
#    - Filing Type: Rate/Rule other than PPA
#
# 2. **Filing Details**:
#    - Effective Date Requested (New): 03/01/2025
#
# 3. **Filing Contact**:
#    - Rhonda Amann, State Filings Manager
#
# 4. **Company Information**:
#    - Company Name: Allstate Vehicle and Property Insurance Company
#    - State of Domicile: Illinois
#    - Phone: 847-402-5000
#    - FEIN Number: 04-2680300
#
# 5. **Rate Information**:
#    - Filing Method: Prior Approval
#    - Overall Percentage of Last Rate Revision: 19.9%
#    - Effective Date of Last Rate Revision: 09/09/2024
#
# 6. **Attachments and Supporting Documents**:
#    - Filing Compliance Certification
#    - Required Additional Information
#    - Credit Scoring Models and Proprietary Information
# Claude-3 Haiku Summary: Based on the information provided, it does not appear that the use of no prior insurance or insurance lapse is used in any manner in the rating for this Allstate Vehicle and Property Insurance Company filing in Georgia. The summary indicates that the only geographic/demographic variable used is zip code, which is obtained directly from policyholders. The filing does not mention the use of no prior insurance or insurance lapse as a rating factor or component variable. The summary of the filing focuses on the introduction of a new Fortified Home Discount.
# Processed additional filing info for: GA_ALSE-134337450.pdf
# Filings/Final/2025-03-10\GA_HART-134414600.pdf
# 2025-03-13 07:29:03.640749
# Token count for API call in GA_HART-134414600.pdf: 5792
# GPT-3.5 Summary: Summary of the Rate Filing:
# 1. Company: The rate filing was submitted by multiple companies within The Hartford Insurance Group, including Hartford Casualty Insurance Company, Hartford Insurance Company of the Midwest, Hartford Insurance Company of the Southeast, Property and Casualty Insurance Company of Hartford, Trumbull Insurance Company, and Nutmeg Insurance Company.
# 2. State: The rate filing was made for the state of Georgia.
# 3. Filing Type: The filing falls under Rate/Rule other than PPA for Homeowners insurance.
# 4. Product: The filing introduces a credit card surcharge for policyholders who choose to pay premiums by credit card, affecting all transactions processed on or after July 01, 2025.
# 5. Filing Compliance: The filing fees for this submission totaled $450.00, with each of the six writing companies associated with the filing contributing $75.00 per company.
# 6. Effective Date: The requested effective date for the new credit card surcharge program is July 01, 2025, for both new and renewal policies.
# 7. Approval Status: The filing status is acknowledged, with the effective date set for July 01, 2025.
# 8. Impact: The overall rate impact of the filing across all companies is indicated as 0.000%, with no changes in written premium, policyholders affected, or written premium amount for the program.
# 9. Disclosures: Several supporting documents were provided with the filing, including a Filing Compliance Certification,
# Claude-3 Haiku Summary: Based on the information provided in the filing, this appears to be a rate filing from The Hartford insurance group to introduce a credit card surcharge for their homeowners insurance products in Georgia.
#
# The key points are:
#
# - The filing is being made by 6 insurance companies under The Hartford group - Hartford Casualty Insurance Company, Hartford Insurance Company of the Midwest, Hartford Insurance Company of the Southeast, Property and Casualty Insurance Company of Hartford, Trumbull Insurance Company, and Nutmeg Insurance Company.
#
# - The filing is for the introduction of a credit card surcharge of up to 3% of the total payment amount for policyholders who choose to pay their homeowners insurance premium by credit card.
#
# - The surcharge will be charged and collected by a third-party payment vendor, and will be shown to the policyholder at the time of the transaction.
#
# - The surcharge is effective for all transactions processed on or after July 1, 2025.
#
# - The filing indicates there is no overall rate increase or premium impact associated with this credit card surcharge. The surcharge is a pass-through cost to policyholders who use a credit card for payment.
#
# - The filing was acknowledged by the Georgia Department of Insurance on March 5, 2025.
#
# In summary, this appears to be a filing to introduce a credit card surcharge for homeowners insurance policies in Georgia, with no overall rate impact to policyholders.
# Processed additional filing info for: GA_HART-134414600.pdf
# Filings/Final/2025-03-10\GA_LBPM-134447081.pdf
# 2025-03-13 07:29:21.457542
# Token count for API call in GA_LBPM-134447081.pdf: 3938
# GPT-3.5 Summary: The rate filing submitted by LM General Insurance Company and LM Insurance Corporation for their Homeowners insurance product in Georgia involves updating their premium payment plan and associated fees. The filing includes adjustments to billing fees to align with the fee structure by state, line of business, and brand. The changes aim to simplify and streamline processes, thereby improving customer, employee, and agent experience. The effective date requested for the new rates is June 21, 2025. The filing involves a neutral rate change type with an overall percentage of the last rate revision at 15.4% on November 9, 2024. Additionally, the premium payment plan allows for multiple installment payments, subject to installment fees, with reduced fees for electronic funds transfer and waivers for payroll deduction.
# Claude-3 Haiku Summary: Based on the information provided in the insurance company's DOI filing, this appears to be a rate/rule filing for their Homeowners insurance product in the state of Georgia. The key details are:
#
# - The filing is to update the premium payment plan rules, specifically related to the installment fee charged. The filing indicates the installment fee will be reduced for customers paying by electronic funds transfer or waived for those paying by payroll deduction.
#
# - This is a neutral rate filing, meaning there is no overall rate change being requested. The filing is focused on updating the policy administration rules around premium payment options.
#
# - The filing was submitted by LM General Insurance Company and LM Insurance Corporation, which are part of the Liberty Mutual Insurance Group.
#
# - The total filing fee for the two companies is $150, which is the $75 per company fee required by Georgia, as the domicile state (Illinois) does not have a fee for rate/rule filings.
#
# - The effective date for the new premium payment plan rules is requested to be June 21, 2025.
#
# In summary, this filing is focused on updating the premium payment plan and installment fee structure for the Homeowners insurance product in Georgia, with the goal of simplifying billing processes and options for customers. There is no overall rate level change being requested.
# Processed additional filing info for: GA_LBPM-134447081.pdf
# Filings/Final/2025-03-10\GA_LBPM-134447335.pdf
# 2025-03-13 07:29:26.370850
# Token count for API call in GA_LBPM-134447335.pdf: 3961
# GPT-3.5 Summary: The rate filing submitted by Liberty Mutual Insurance Company and Liberty Mutual Personal Insurance Company pertains to their Homeowners insurance product in Georgia. The filing was submitted on 03/06/2025, with an effective date requested of 06/21/2025 for new policies and 07/26/2025 for renewals.
#
# The filing includes updates to their premium payment plan and fees for Homeowners insurance policies. Specifically, it outlines that premium payments can be made in multiple installments after an initial down payment, with potential installment fees, late fees, and fees for dishonored payments. The changes aim to simplify and streamline processes and align billing fees across states and lines of business.
#
# The overall rate change indicated in this filing is neutral, with a 0.0% impact on written premium and policyholders affected. The submission includes detailed information on company details, filing fees, rate changes, and supporting documents such as the Premium Payment Plan and Explanatory Memorandum.
#
# Overall, the rate filing focuses on adjusting billing fees to improve customer, employee, and agent experience, with specific changes to the premium payment plan for Homeowners insurance policies in Georgia.
# Claude-3 Haiku Summary: Based on the information provided in the insurance company's filing, the key points are:
#
# 1. The filing is to update the premium payment plan and fees for the GA Homeowners product.
#
# 2. The key changes are:
# - A flat $5 installment fee will be charged for premium payments made in multiple installments, with a $2 reduction for customers paying by electronic funds transfer or no fee for customers paying by payroll deduction.
# - A $25 fee will be charged for premium payments dishonored due to non-sufficient funds.
# - A $15 late fee will be charged for unpaid premium installment bills.
#
# 3. The effective date for these changes is June 21, 2025.
#
# 4. The filing indicates these changes are part of an effort to simplify and streamline the billing processes, with the goal of improving customer, employee, and agent experience.
#
# 5. The filing includes the required supporting documents such as the filing compliance certification, fee transmittal form, and explanatory memorandum.
#
# In summary, this is a rate/rule filing by Liberty Mutual to update the premium payment plan and associated fees for their GA Homeowners product.
# Processed additional filing info for: GA_LBPM-134447335.pdf
# Filings/Final/2025-03-10\GA_LBPM-134449473.pdf
# 2025-03-13 07:29:30.940818
# Token count for API call in GA_LBPM-134449473.pdf: 4311
# GPT-3.5 Summary: From the provided filing information, here is a summary of the rate filing for The First Liberty Insurance Corporation's Homeowners insurance product in Georgia:
#
# - **Company**: The First Liberty Insurance Corporation
# - **Product Name**: Homeowners
# - **State**: Georgia
# - **Type of Insurance**: Homeowners
# - **Filing Type**: Rate/Rule other than PPA
# - **Filing Method**: Prior Approval
# - **Effective Date Requested (New)**: 06/21/2025
# - **Effective Date Requested (Renewal)**: 07/26/2025
# - **Rate Change Type**: Neutral
# - **Overall Percentage of Last Rate Revision**: 12.500%
# - **Filing Fee**: $75.00
# - **Rate Indication**: 0.0%
# - **Update**: The filing was submitted to update billing fees for alignment in the fee structure by state, line of business, and brand to simplify and streamline processes.
#
# In summary, The First Liberty Insurance Corporation made a rate filing for its Homeowners insurance product in Georgia with a neutral rate change and requested an effective date for the new rates. The filing included updates to billing fees to improve customer, employee, and agent experience.
# Claude-3 Haiku Summary: Based on the filing, the key points are:
#
# 1. The First Liberty Insurance Corporation is submitting this rate filing to update their fees for Homeowners insurance in Georgia.
#
# 2. The main changes are:
# ...
# - A redlined version showing the changes made to the previous form
# - A Certification of Compliance with the Virginia requirements for homeowners insurance policy forms
#
# This appears to be a procedural filing to update the policy form language, rather than a rate or rule change filing.
# Processed additional filing info for: VA_LEMO-134441439.pdf
# Filings/Final/2025-03-10\WA_LBPM-134447017.pdf
# 2025-03-13 07:51:20.442822
# Token count for API call in WA_LBPM-134447017.pdf: 92030
# GPT-3.5 Summary: The
# Claude-3 Haiku Summary: Based on the filing, this appears to be a new homeowners insurance program being introduced by American Economy Insurance Company in Washington state. The key points are:
#
# - This is a new Homeowners program that will be available for new business effective June 23, 2025. There is no in-force impact or existing policyholder base.
#
# - The filing includes a full set of policy forms, including the Homeowners Declarations, policy contract (HOM-7030 and HOM-7050), endorsements, and supporting documents.
#
# - The policy forms provide standard homeowners coverage for the dwelling, other structures, personal property, additional living expenses, and liability. Coverage includes perils like fire, windstorm, explosion, theft, etc. with standard exclusions.
#
# - The filing also includes endorsements providing optional coverages like Valuable Articles, Earthquake, Water Escape, Theft of Building Materials, and others.
#
# - This appears to be a comprehensive new homeowners insurance product that American Economy Insurance Company is seeking to introduce in the Washington market. The filing provides the full set of forms and policy contract details for regulatory review and approval.
#
# In summary, this is a new homeowners insurance program filing by American Economy Insurance Company for the state of Washington, including the policy forms, endorsements, and supporting documents.
# Processed additional filing info for: WA_LBPM-134447017.pdf
# Filings/Final/2025-03-10\WI_AMSI-133860671.pdf
# 2025-03-13 07:51:52.251844
# Token count for API call in WI_AMSI-133860671.pdf: 34542
# GPT-3.5 Summary: The rate filing submitted by American Strategic Insurance Corp. for its Wisconsin Homeowners Program includes revisions to the Homeowners HOH program for owner-occupied homeowners. The filing includes rate changes, rule manual updates, and rate pages for various aspects such as policy term, renewal process, cancellation policy, multiple locations coverage, construction definitions, coverage limits, loss settlement, coverage options, policy forms, additional endorsements, and various discounts and surcharges.
#
# The filing involves company contact information, author and reviewer details, disposition status, effective dates, filing type (Rate/Rule), and details of the products, TOIs, and sub-TOIs affected. The effective date requested for the new rates is 03/26/2025, while for renewal rates, it is 05/26/2025. The filing includes information on premium changes, written premium, the number of policyholders affected, and other financial impacts.
#
# The document provides a comprehensive overview of the rate changes, rule updates, supporting documents, filing fees, dispositions, and various rate and rule schedule items related to the American Strategic Insurance Corp.'s Homeowners Program in Wisconsin. The filing details key aspects of the underwriting and rating process, including discounts, surcharges, premium calculations, payment plans, and fee structures.
# Claude-3 Haiku Summary: Based on the filing, the key points are:
#
# 1. American Strategic Insurance Corp. is filing a revision to its Homeowners HOH program in Wisconsin.
#
# 2. The overall indicated change is 23.9% and the overall rate impact is 23.4%. This will result in a $10,809,241 written premium change, affecting 36,212 policyholders.
#
# 3. The filing includes revisions to the rate manual, rules, and rate pages.
#
# 4. Key rating factors include insurance score, prior claims, prior liability limit, household characteristics, dog ownership, occupancy, dwelling characteristics (age, construction, roof, etc.), and various discounts/surcharges.
#
# 5. The filing includes various optional endorsements that provide additional coverages and limits.
#
# 6. The filing was filed using the Use & File method and the effective dates are March 26, 2025 for new business and May 26, 2025 for renewals.
#
# 7. The filing was reviewed and filed by the Wisconsin Department of Insurance on March 10, 2025.
#
# In summary, this is a comprehensive rate revision filing by American Strategic Insurance Corp. for its Wisconsin Homeowners program, incorporating updates to rates, rules, and endorsements.
# Processed additional filing info for: WI_AMSI-133860671.pdf
# Filings/Final/2025-03-10\WI_LBPM-134430805.pdf
# 2025-03-13 07:52:01.784110
# Token count for API call in WI_LBPM-134430805.pdf: 18224
# GPT-3.5 Summary: The rate filing involves multiple insurance companies under the Liberty Mutual Group offering homeowners, condo, renters, and simple renters insurance programs in Wisconsin. The filing includes updated policy forms and declarations for Homeowners, Condo, Renters, and Simple Renters programs. The key changes in the forms include updates to the policy period provisions, with references to the Declarations Page for the effective time of the policy.
#
# The revised forms have been certified for compliance with Wisconsin Statutes and administrative rules by the respective officers of the insurance companies. These adjustments ensure the policies align with state regulations and standards. The program's rate remains unchanged, with no impact on written premiums or the number of policyholders affected.
#
# Overall, the filing aims to update and enhance the policy forms for homeowners, condo, renters, and simple renters programs in compliance with regulatory requirements and to ensure ease of readability and compliance for policyholders and agents.
# Claude-3 Haiku Summary: Based on the information provided, this appears to be a filing by multiple Liberty Mutual insurance companies to make revisions to their Homeowners, Condo, Renters, and Simple Renters insurance program forms for use in Wisconsin.
#
# The key points about the rate filing are:
#
# 1. It is a file and use filing, so the forms can be used 30 days after the filing is received by the Wisconsin Office of the Commissioner of Insurance (OCI).
#
# 2. There are no changes to the overall rate level - the filing indicates a 0.000% overall rate impact.
#
# 3. The filing includes revisions to various policy declarations, application, and endorsement forms, primarily to update the policy period language.
#
# 4. The forms have been reviewed for compliance with Wisconsin statutes and regulations, and the readability scores meet the required minimums.
#
# 5. The filing includes a forms exhibit summarizing the specific form changes, as well as mock-ups of the revised forms.
#
# 6. Overall, this appears to be a routine filing to update existing policy forms rather than introduce any significant product changes. The goal seems to be ensuring the forms comply with Wisconsin requirements and providing flexibility in formatting the forms for marketing purposes.
# Processed additional filing info for: WI_LBPM-134430805.pdf
# Filings/Final/2025-03-10\WI_LEMO-134385206.pdf
# 2025-03-13 07:52:29.527798
# Token count for API call in WI_LEMO-134385206.pdf: 354400
# GPT-3.5 Summary: Based on the information provided from the filing with the Department of Insurance, it appears that Lemonade Insurance Company has submitted a revision to its homeowners insurance program for review and approval by the state of Wisconsin. The filing is specific to the Homeowners product offered by Lemonade.
#
# Key details from the filing include:
# 1. Project Name/Number: WI Base Rate/LIC-HO-WI-2502F
# 2. Effective Date Requested: New policies effective 06/17/2025, renewals effective 08/16/2025
# 3. Various endorsements and forms included in the filing, such as Additional Insured endorsements, Loss Assessment Coverage, Equipment Breakdown Endorsements, and Coverage Limitations for Mold, among others.
# 4. Disposition Status: Deemed Approved as of 03/04/2025
# 5. The company contact listed in the filing is Jodi Bansfield at Lemonade Insurance Company.
#
# The filing also indicates that Lemonade Insurance Company has responded to objections related to the filing, including locking the Certificate of Compliance and readability and submitting the necessary documentation. The response indicates compliance with the requirements outlined by the regulatory body.
#
# This filing gives insights into Lemonade Insurance Company's efforts to update and enhance its homeowners insurance product offering in the state of Wisconsin, ensuring compliance with regulatory guidelines and addressing objections as needed.
# Claude-3 Haiku Summary: Based on the filing, here is a summary of the key details:
#
# - Lemonade Insurance Company is submitting a revision to its homeowners insurance program for the state of Wisconsin.
#
# - The filing includes updated forms and endorsements for Lemonade's Homeowners, Renters, and Condo products.
#
# - The requested effective date for new business is June 17, 2025, and the requested effective date for renewal business is August 16, 2025.
#
# - The filing includes a variety of standard homeowners policy forms and endorsements, such as:
#     - Lemonade Homeowners, Renters, and Condo forms
#     - Endorsements for Interested Party, Scheduled Personal Property, Special Provisions for Wisconsin, Additional Insured, Water Backup, and various exclusions (e.g. Swimming Pool, Trampoline, Canine Liability, Ineligible Firearm)
#     - Endorsements for Equipment Breakdown, Buried Utility Lines, Mold/Fungus Exclusion, Personal Injury Coverage, and Additional Insured - Household Resident
#
# - Supporting documents include a Certification of Compliance, Explanatory Memorandum, and redlined versions of the form changes.
#
# - The filing does not appear to include any rate or rule changes, as the rate data section indicates "Rate data does NOT apply to filing."
#
# In summary, this appears to be a standard homeowners program filing with updated forms and endorsements, but no changes to the underlying rates or rating plan.
# Processed additional filing info for: WI_LEMO-134385206.pdf
# Filings/Final/2025-03-10\WI_SFMA-134421547.pdf
# 2025-03-13 07:52:41.312909
# Token count for API call in WI_SFMA-134421547.pdf: 22752
# GPT-3.5 Summary: 1. **Summary of Rate Change**: State Farm Fire and Casualty Company in Wisconsin is filing revised rates for their Non-Tenant Homeowners, Renters, and Condominium Unitowners policy forms, resulting in an average rate change of 19.6% for the Homeowners Program.
#
# 2. **Rate Change History**: The company has implemented rate changes in the past years, showing a gradual increase in rates for the Non-Tenant Homeowners policy form over the years, with the last implemented change of 6.2% on 6/15/2023.
#
# 3. **General Information**: State Farm focuses on maintaining financial solidity by not solely relying on rate activity but also by enhancing services and investing in loss prevention and control activities.
#
# 4. **Loss Mitigation and Resilience**: State Farm is committed to increasing Homeowners Resiliency through loss prevention, education, and public awareness programs, as well as supporting national organizations focused on safety and building codes.
#
# 5. **Supporting Documentation**: The filing includes detailed exhibits on loss mitigation efforts, including internal programs, public awareness campaigns, home monitoring technology, and support of national organizations in the safety industry.
#
# 6. **Future Effective Dates**: The proposed rate changes are intended to be effective on 04/15/2025 for new business and 06/15/2025 for renewals.
#
# 7. **Contacts**: The filing contact information includes Adam Swope, F.C.A.S, CPCU, MAAA,
# Claude-3 Haiku Summary: Here is a summary of the key points from the State Farm Insurance Companies Wisconsin Homeowners rate filing:
#
# 1. Indicated Rate Changes:
# - Non-Tenant Homeowners: 25.5% increase
# - Renters: 14.2% increase
# - Condominium Unitowners: 25.8% increase
# - Overall Homeowners Program: 25.2% increase
#
# 2. Key Changes:
# - Implemented basic premium changes resulting in a 19.9% increase for Non-Tenant Homeowners
# - Introduced 1%, 2%, 3%, 4%, and 5% Wind/Hail deductible options
# - Revised the Roof Surfaces - Impact Resistant adjustments
# - Implemented basic premium and Condominiums Building Property - Increased Limits changes for Renters (8.2% increase)
#   and Condominium Unitowners (22.3% increase)
#
# 3. Ratemaking Methodology:
# - Developed credibility-weighted loss ratios by peril
# - Trended historical premiums, losses, and expenses
# - Included provisions for catastrophe losses, adjusting and other expenses, and profit & contingencies
#
# 4. State Farm's Ongoing Loss Mitigation Efforts:
# - Internal programs (fraud investigation, premium discounts for loss prevention devices)
# - Public awareness and education initiatives
# - Support for building code improvements and research with industry organizations
#
# Overall, the filing proposes rate increases to address the expected underwriting performance for the Wisconsin Homeowners
# program, while also highlighting State Farm's holistic approach to loss mitigation and resilience.
# Processed additional filing info for: WI_SFMA-134421547.pdf
# Filings/Final/2025-03-10\WV_AMSI-134244221.pdf
# 2025-03-13 07:53:09.738797
# Token count for API call in WV_AMSI-134244221.pdf: 1174752
# GPT-3.5 Summary: The rate filing submitted by American Strategic Insurance Corp for their West Virginia Homeowners (HOH) product includes updates to their existing rates and rules. The filing was submitted on 01/28/2025 and was approved on 02/28/2025.
#
# Key details of the rate filing:
# - Company: American Strategic Insurance Corp
# - Product Name: Homeowners
# - State: West Virginia
# - Type of Insurance: Homeowners
# - Filing Type: Rate/Rule
# - Effective Date (New): 08/06/2025
# - Effective Date (Renewal): 10/06/2025
# - Filing Method: Prior Approval
# - Rate Change Type: Increase
# - Overall Percentage of Last Rate Revision: 20.000%
# - Overall % Indicated Change: 8.000%
# - Overall % Rate Impact: 8.000%
# - Written Premium Change for this Program: $758,256
# - Number of Policy Holders Affected: 5,995
# - Written Premium for this Program: $9,478,197
#
# The rate filing includes updates to various documents such as the HOH Rules Manual, Rate Abstract P&C, Actuarial Memorandum, Certification, Actuarial Summary, Rate Change Histogram, and Marked Rate Factor Pages.
#
# The filing also includes changes to Territory Factors based on Zip Codes, affecting various aspects like Tornado, Wind, Hail, Water Backup, Water Weather, Fire Brush, Liability
# Claude-3 Haiku Summary: Based on the information provided, this is a rate filing by American Strategic Insurance Corp (ASIC) for their West Virginia Homeowners (HOH) product. The key details are:
#
# Summary of the Rate Filing:
# - ASIC is proposing an 8% overall rate increase for their West Virginia HOH product.
# - The overall written premium change for this program is an increase of $758,256.
# - The filing will affect 5,995 policyholders, with a total written premium of $9,478,197 for this program.
# - The maximum rate increase is 624% and the minimum rate decrease is 50%.
# - The filing includes revised rate pages, rules manual, and various supporting documents.
# - The new rates are proposed to be effective for new business on 8/6/2025 and for renewals on 10/6/2025.
# - The filing was reviewed and approved by the regulator on 2/28/2025.
#
# In summary, this is a comprehensive rate revision filing by ASIC for their West Virginia homeowners insurance product, seeking an 8% overall increase to address evolving market conditions and costs.
# Processed additional filing info for: WV_AMSI-134244221.pdf
# Saved additional filing info JSON output to additional_filing_info_2025-03-10.json
# Saved additional filing info CSV output to additional_filing_info_2025-03-10.csv
